# %% [markdown]
# #### IMPORT

# %%
import os, platform

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from matplotlib import pyplot


from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc


from sklearn.metrics import roc_curve, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %% [markdown]
# #### PARAMETERS
# - Set the condition
# > * N_FEATURES: Number of Features
# > * CHECK_BLANKS: Check for blank data. If any blank data is found, the whole row of data will be deleted.
# > * CHECK_CLASS_IMBALANCE: Check for dataset class imbalance. The more balance the dataset, the less biases the model will be.

# %%
##############################
# # deep learning features # #
##############################
SEED = 1005 # random seed for reproducibility

# should make this dynamic
N_FEATURES = 220 #36 #220 #9 #220 #36 #36 #120 #220
# N_CLASSES= 12
TIMESTEPS = 1
EPOCH=300
BATCH_SIZE=10

###############
# # dataset # #
###############
DATASET_DIR_NAME = "dataset"
SAMPLE_DATASET_NAME = "own_train_full" + ".csv"
ACTUAL_DATASET_NAME = "own_test_full" + ".csv"

# ACTUAL_DATASET_NAME = "combi_andy_full" + ".csv"
# ACTUAL_DATASET_NAME = "combi_azfar_full" + ".csv"
# ACTUAL_DATASET_NAME = "combi_bryce_full" + ".csv"
# ACTUAL_DATASET_NAME = "combi_chris_full" + ".csv"
# ACTUAL_DATASET_NAME = "combi_cy_full" + ".csv"
# ACTUAL_DATASET_NAME = "combi_gerald_full" + ".csv"
# ACTUAL_DATASET_NAME = "combi_ken_full" + ".csv"
# ACTUAL_DATASET_NAME = "combi_sz_full" + ".csv" #notdone
# ACTUAL_DATASET_NAME = "combi_vale_full" + ".csv"
# ACTUAL_DATASET_NAME = "combi_ye_full" + ".csv"  #notdone
# ACTUAL_DATASET_NAME = "combi_ys_full" + ".csv" #notdone

# SAMPLE_DATASET_NAME = "own_train_semi" + ".csv"
# ACTUAL_DATASET_NAME = "own_test_semi" + ".csv"
# SAMPLE_DATASET_NAME = "own_train_bare" + ".csv"
# ACTUAL_DATASET_NAME = "own_test_bare" + ".csv"
# SAMPLE_DATASET_NAME = "own_train_5" + ".csv"
# ACTUAL_DATASET_NAME = "own_test_5" + ".csv"
# SAMPLE_DATASET_NAME = "same_train_full" + ".csv"
# ACTUAL_DATASET_NAME = "same_test_full" + ".csv"
# SAMPLE_DATASET_NAME = "same_train_semi" + ".csv"
# ACTUAL_DATASET_NAME = "same_test_semi" + ".csv"
# SAMPLE_DATASET_NAME = "same_train_bare" + ".csv"
# ACTUAL_DATASET_NAME = "same_test_bare" + ".csv"
# SAMPLE_DATASET_NAME = "same_train_5" + ".csv"
# ACTUAL_DATASET_NAME = "same_test_5" + ".csv"


MODEL_DIR_NAME = "model"
MODEL_NAME = "own_full_model_v4" + ".h5"
RESULT_NAME = "own_full_v4" + ".csv"

DATASET_DIR_PATH = os.path.join(os.getcwd(), DATASET_DIR_NAME)
SAMPLE_DATASET_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME)
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME)

MODEL_DIR_PATH = os.path.join(os.getcwd(), MODEL_DIR_NAME)
MODEL_PATH = os.path.join(MODEL_DIR_PATH, MODEL_NAME)

CLASSES_COL_NAME = "Subject"
CLASSES_COL_NUM = 0
FEATURES_COL_NUM = 2

CLASS_LIST = ['andy', 'azfar', 'bryce', 'chris', 'cy', 'gerald', 'ken', 'qk', 'sz', 'vale', 'ye', 'ys']

#################
# # sns theme # #
#################
# sns.set_theme(style="darkgrid") # (dark background with white gridlines)
sns.set_theme(style="whitegrid") # (white background with grey gridlines)
# sns.set_theme(style="dark") # (dark background with no gridlines)
# sns.set_theme(style="white") # (white background with no gridlines)
# sns.set_theme(style="ticks") # (white background with axis ticks and no gridlines)

def df_drop(df):
#     df.drop(df[df['Subject']=='adhy'].index, inplace=True)
    df.drop(df[df['Subject']=='alan'].index, inplace=True)
    df.drop(df[df['Subject']=='andy'].index, inplace=True)
    df.drop(df[df['Subject']=='bryce'].index, inplace=True)
    df.drop(df[df['Subject']=='chris'].index, inplace=True)
#     df.drop(df[df['Subject']=='cy'].index, inplace=True)
    df.drop(df[df['Subject']=='gerald'].index, inplace=True)
    df.drop(df[df['Subject']=='jc'].index, inplace=True)
    df.drop(df[df['Subject']=='jonah'].index, inplace=True)
#     df.drop(df[df['Subject']=='qk'].index, inplace=True)
    
    return df

# %%
if os.path.isdir(DATASET_DIR_PATH) is True:
    print(f"Dataset directory exists at: {DATASET_DIR_PATH}")
    pass
else:
    try:
        os.mkdir(DATASET_DIR_PATH, 666)
        print(f"Dataset directory have been created at: {DATASET_DIR_PATH}")
    except:
        print("Error: Dataset Directory not created")
        
if os.path.isdir(MODEL_DIR_PATH) is True:
    print(f"Model directory exists at: {MODEL_DIR_PATH}")
    pass
else:
    try:
        os.mkdir(MODEL_DIR_PATH, 666)
        print(f"Model directory have been created at: {MODEL_DIR_PATH}")
    except:
        print("Error: Model Directory not created")
# Out:
# Dataset directory exists at: C:\Users\andyc\Documents\GitHub\deep-captcha\dataset
# Model directory exists at: C:\Users\andyc\Documents\GitHub\deep-captcha\model

# %% [markdown]
# #### CREATE MODEL
# - Create base model
# - Wrap it with KerasClassifier

# %%
# create base model
def create_base_model():
    model = Sequential()
#     model.add(LSTM(units=1024, return_sequences=True,
#              input_shape=(TIMESTEPS,N_FEATURES)))
#     model.add(Dense(1024, activation='sigmoid'))
#     model.add(Dropout(0.2))
# #     model.add(BatchNormalization())
    
#     model.add(LSTM(units=512, return_sequences=True))
#     model.add(Dense(512, activation='sigmoid'))
#     model.add(Dropout(0.2))
# #     model.add(BatchNormalization())
    
#     model.add(LSTM(units=256, return_sequences=True))
#     model.add(Dense(256, activation='sigmoid'))
#     model.add(Dropout(0.2))

    model.add(LSTM(units=128, return_sequences=True,
             input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dropout(0.2))
#     model.add(BatchNormalization())
    
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dropout(0.2))
#     model.add(BatchNormalization())
    
    model.add(LSTM(units=32, return_sequences=True))
    model.add(Dense(32, activation='sigmoid'))
    model.add(Dropout(0.2))
    
#     model.add(BatchNormalization())

#     model.add(BatchNormalization())
    
#     model.add(LSTM(units=128, return_sequences=True))
#     model.add(Activation="sigmoid")
#     model.add(Dropout(0.2))
# #     model.add(BatchNormalization())
    
#     model.add(LSTM(units=64, return_sequences=True))
#     model.add(Activation="sigmoid")
#     model.add(Dropout(0.2))
# #     model.add(BatchNormalization())
    
#     model.add(LSTM(units=32, return_sequences=True))
#     model.add(Activation="sigmoid")
#     model.add(Dropout(0.2))
#     model.add(BatchNormalization())
    # softmax for multi-class classification
    model.add(Flatten())
    print(n_classes)
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    


    # model.add(LSTM(units=128, return_sequences=True, 
    #              input_shape=(TIMESTEPS,N_FEATURES)))
    # model.add(Dropout(0.2))
    # model.add(BatchNormalization())
    # model.add(LSTM(units=128, return_sequences=True))
    # model.add(Dropout(0.2))
    # model.add(BatchNormalization())
    # model.add(LSTM(units=64, return_sequences=True))
    # model.add(Dropout(0.2))
    # model.add(BatchNormalization())
    
   

    
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=EPOCH, 
                            batch_size=BATCH_SIZE)
    return model

# %%
# divide data into features X and target (classes) Y
def prepare_dataset(df):
    X = df.values[:,FEATURES_COL_NUM:].astype(float)
    Y = df.values[:,CLASSES_COL_NUM].astype(str)

    # convert target Y to labelbinarizer Y for model
    # fit_transform is not used to reuse lb
    Y = Y.reshape(-1, 1)
    lb = LabelBinarizer().fit(Y)
    Y = lb.transform(Y)


    #################################
    # # get all the encoded class # #
    #################################
    print("LabelBinarizer is able to decipher: ")
    print(lb.classes_)
    print("\n")

    ###########################
    # # print X and Y shape # #
    ###########################
    print(f"X | Features | Dataset Shape: {X.shape}")
    print(f"Y | Classes  | Dataset Shape: {Y.shape}")

    return X, Y, lb

# %%
def split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED):

    ##############################################################
    # # split dataset into train and test set of 0.8/0.2 ratio # #
    ##############################################################
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=SPLIT_RATIO, random_state=SEED)

    ############################
    # # reshaping of dataset # #
    ############################

    # reshaping the dataset to include LSTM Timesteps
    print(X_train.dtype)
    X_train = np.asarray(X_train, dtype=np.float32)
    print(X_train.dtype)
    X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
    print(X_test.dtype)
    X_test = np.asarray(X_test, dtype=np.float32)
    print(X_test.dtype)
    X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

    # retrieve number of classes
    n_classes = y_train.shape[1]

    print(f"X train shape: {X_train.shape}")
    print(f"Y train shape: {y_train.shape}")
    print(f"X test shape: {X_test.shape}")
    print(f"Y test shape: {y_test.shape}")
    print(f"Number of Classes: {n_classes}")

    return X_train, X_test, y_train, y_test, n_classes

def reshape_dataset(X, TIMESTEPS):
    # reshaping the dataset to include LSTM Timesteps
    X = np.asarray(X, dtype=np.float32)
    X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))
    return X

# %% [markdown]
# #### CHECK DATASET

# %%
#     sns.catplot(x="Subject", y="D|0", data=df)

    
#     sns.catplot(x="Subject", y="D|1", hue="D|1", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|3", hue="D|3", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|4", hue="D|4", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|5", hue="D|5", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|6", hue="D|6", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|7", hue="D|7", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|8", hue="D|8", data=df, legend=False)
# df = pd.read_csv(SAMPLE_DATASET_PATH)
# df.head()
# sns.catplot(x="Subject", y="D|1", hue="D|1", data=df, legend=False)
# sns.catplot(x="Subject", y="I|1+2", hue="I|1+2", data=df, legend=False)
# sns.catplot(x="Subject", y="PF|1+2", hue="PF|1+2", data=df, legend=False)
# sns.catplot(x="Subject", y="RF|1+2", hue="RF|1+2", data=df, legend=False)
# sns.catplot(x="Subject", y="DT|1+2", hue="DT|1+2", data=df, legend=False)
# sns.catplot(x="Subject", y="D|9", hue="D|9", data=df, legend=False)


#     sns.catplot(x="Subject", y="TT|1+3", hue="TT|1+3", data=df, legend=False)
#     sns.catplot(x="Subject", y="QT|1+4", hue="QT|1+4", data=df, legend=False)

# %% [markdown]
# #### FIT AND SAVE MODEL
# - Fitting of model
# - Get Accuracy and Loss of Mdoel
# - Saving Model

# %%
############################
# # reshaping of dataset # #
############################
# loading of dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)
df.head()

# df = df_drop(df)
dataset = df.values

# divide data into features X and target (classes) Y
# convert target Y to labelbinarizer Y for model
X, Y, lb = prepare_dataset(df)

# reshaping the dataset to include LSTM Timesteps
X = reshape_dataset(X, TIMESTEPS)
n_classes = Y.shape[1]

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# LabelBinarizer is able to decipher:
# ['andy' 'azfar' 'bryce' 'chris' 'cy' 'gerald' 'ken' 'qk' 'sz' 'vale' 'ye'
#  'ys']
#
#
# X | Features | Dataset Shape: (1200, 220)
# Y | Classes  | Dataset Shape: (1200, 12)
# 12
# Epoch 1/300
# 120/120 [==============================] - 4s 5ms/step - loss: 2.5521 - accuracy: 0.0775
# Epoch 2/300
# 120/120 [==============================] - 1s 4ms/step - loss: 2.4264 - accuracy: 0.1175
# Epoch 3/300
# 120/120 [==============================] - 1s 5ms/step - loss: 2.2053 - accuracy: 0.1458
# Epoch 4/300
# 120/120 [==============================] - 1s 4ms/step - loss: 2.0475 - accuracy: 0.1900
# Epoch 5/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.9561 - accuracy: 0.2375
# Epoch 6/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.8435 - accuracy: 0.2642
# Epoch 7/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.7785 - accuracy: 0.3033
# Epoch 8/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.6742 - accuracy: 0.3317
# Epoch 9/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.6730 - accuracy: 0.3408
# Epoch 10/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.5856 - accuracy: 0.3542
# Epoch 11/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.5484 - accuracy: 0.3683
# Epoch 12/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.5232 - accuracy: 0.3950
# Epoch 13/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.4826 - accuracy: 0.4067
# Epoch 14/300
# 120/120 [==============================] - 1s 5ms/step - loss: 1.4293 - accuracy: 0.4125
# Epoch 15/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.4363 - accuracy: 0.4200
# Epoch 16/300
# 120/120 [==============================] - 0s 4ms/step - loss: 1.3826 - accuracy: 0.4217
# Epoch 17/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.3770 - accuracy: 0.4258
# Epoch 18/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.3136 - accuracy: 0.4642
# Epoch 19/300
# 120/120 [==============================] - 1s 5ms/step - loss: 1.3133 - accuracy: 0.4658
# Epoch 20/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.2969 - accuracy: 0.4625
# Epoch 21/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.2178 - accuracy: 0.5133
# Epoch 22/300
# 120/120 [==============================] - 1s 5ms/step - loss: 1.1971 - accuracy: 0.5250
# Epoch 23/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.1771 - accuracy: 0.5150
# Epoch 24/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.1631 - accuracy: 0.5392
# Epoch 25/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.1189 - accuracy: 0.5392
# Epoch 26/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.1034 - accuracy: 0.5575
# Epoch 27/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.0915 - accuracy: 0.5625
# Epoch 28/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.0779 - accuracy: 0.5575
# Epoch 29/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.0537 - accuracy: 0.5633
# Epoch 30/300
# 120/120 [==============================] - 1s 4ms/step - loss: 1.0493 - accuracy: 0.5692
# Epoch 31/300
# 120/120 [==============================] - 1s 4ms/step - loss: 0.9850 - accuracy: 0.6083
# Epoch 32/300
# 120/120 [==============================] - 1s 4ms/step - loss: 0.9614 - accuracy: 0.6275
# Epoch 33/300
# 120/120 [==============================] - 1s 4ms/step - loss: 0.9882 - accuracy: 0.6083
# Epoch 34/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.9339 - accuracy: 0.6258
# Epoch 35/300
# 120/120 [==============================] - 1s 4ms/step - loss: 0.8949 - accuracy: 0.6583
# Epoch 36/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.8716 - accuracy: 0.6692
# Epoch 37/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.8005 - accuracy: 0.7108
# Epoch 38/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.8164 - accuracy: 0.7133
# Epoch 39/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.7963 - accuracy: 0.7025
# Epoch 40/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.7023 - accuracy: 0.7400
# Epoch 41/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.7405 - accuracy: 0.7208
# Epoch 42/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.7200 - accuracy: 0.7483
# Epoch 43/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.6698 - accuracy: 0.7708
# Epoch 44/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.6909 - accuracy: 0.7550
# Epoch 45/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.7028 - accuracy: 0.7300
# Epoch 46/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.6554 - accuracy: 0.7583
# Epoch 47/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.6861 - accuracy: 0.7283
# Epoch 48/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.7217 - accuracy: 0.7358
# Epoch 49/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.6854 - accuracy: 0.7383
# Epoch 50/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.6567 - accuracy: 0.7442
# Epoch 51/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.6628 - accuracy: 0.7567
# Epoch 52/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.6659 - accuracy: 0.7475
# Epoch 53/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.7091 - accuracy: 0.7367
# Epoch 54/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.6253 - accuracy: 0.7733
# Epoch 55/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.6028 - accuracy: 0.7783
# Epoch 56/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.6063 - accuracy: 0.7908
# Epoch 57/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.5805 - accuracy: 0.7925
# Epoch 58/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.5988 - accuracy: 0.7717
# Epoch 59/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.5816 - accuracy: 0.8042
# Epoch 60/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.5960 - accuracy: 0.7850
# Epoch 61/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.5852 - accuracy: 0.7892
# Epoch 62/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.5385 - accuracy: 0.8083
# Epoch 63/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.5261 - accuracy: 0.8133
# Epoch 64/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4881 - accuracy: 0.8350
# Epoch 65/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4978 - accuracy: 0.8233
# Epoch 66/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4629 - accuracy: 0.8558
# Epoch 67/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.5039 - accuracy: 0.8333
# Epoch 68/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.5169 - accuracy: 0.8217
# Epoch 69/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4920 - accuracy: 0.8458
# Epoch 70/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4295 - accuracy: 0.8750
# Epoch 71/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4794 - accuracy: 0.8483
# Epoch 72/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4541 - accuracy: 0.8633
# Epoch 73/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4534 - accuracy: 0.8633
# Epoch 74/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4739 - accuracy: 0.8575
# Epoch 75/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4085 - accuracy: 0.8867
# Epoch 76/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4052 - accuracy: 0.8758
# Epoch 77/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4101 - accuracy: 0.8708
# Epoch 78/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4516 - accuracy: 0.8633
# Epoch 79/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4171 - accuracy: 0.8642
# Epoch 80/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4387 - accuracy: 0.8667
# Epoch 81/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4060 - accuracy: 0.8733
# Epoch 82/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4084 - accuracy: 0.8708
# Epoch 83/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3995 - accuracy: 0.8967
# Epoch 84/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3484 - accuracy: 0.8950
# Epoch 85/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3601 - accuracy: 0.8942
# Epoch 86/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3841 - accuracy: 0.8867
# Epoch 87/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3843 - accuracy: 0.8767
# Epoch 88/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4109 - accuracy: 0.8767
# Epoch 89/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3480 - accuracy: 0.9008
# Epoch 90/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3173 - accuracy: 0.9133
# Epoch 91/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3540 - accuracy: 0.9042
# Epoch 92/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3100 - accuracy: 0.9117
# Epoch 93/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3319 - accuracy: 0.9117
# Epoch 94/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3009 - accuracy: 0.9208
# Epoch 95/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3244 - accuracy: 0.9117
# Epoch 96/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3575 - accuracy: 0.9025
# Epoch 97/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3153 - accuracy: 0.9133
# Epoch 98/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3131 - accuracy: 0.9083
# Epoch 99/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3029 - accuracy: 0.9167
# Epoch 100/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3226 - accuracy: 0.9083
# Epoch 101/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2688 - accuracy: 0.9225
# Epoch 102/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3032 - accuracy: 0.9133
# Epoch 103/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3104 - accuracy: 0.9167
# Epoch 104/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3604 - accuracy: 0.8942
# Epoch 105/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3260 - accuracy: 0.9067
# Epoch 106/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2482 - accuracy: 0.9367
# Epoch 107/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2854 - accuracy: 0.9275
# Epoch 108/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2338 - accuracy: 0.9283
# Epoch 109/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2764 - accuracy: 0.9242
# Epoch 110/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3507 - accuracy: 0.9042
# Epoch 111/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2452 - accuracy: 0.9308
# Epoch 112/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2927 - accuracy: 0.9183
# Epoch 113/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2297 - accuracy: 0.9450
# Epoch 114/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2437 - accuracy: 0.9317
# Epoch 115/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2650 - accuracy: 0.9292
# Epoch 116/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2114 - accuracy: 0.9442
# Epoch 117/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1975 - accuracy: 0.9442
# Epoch 118/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3567 - accuracy: 0.8983
# Epoch 119/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2584 - accuracy: 0.9350
# Epoch 120/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2279 - accuracy: 0.9367
# Epoch 121/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2084 - accuracy: 0.9425
# Epoch 122/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2169 - accuracy: 0.9400
# Epoch 123/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2364 - accuracy: 0.9308
# Epoch 124/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2715 - accuracy: 0.9167
# Epoch 125/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2078 - accuracy: 0.9492
# Epoch 126/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1817 - accuracy: 0.9567
# Epoch 127/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2186 - accuracy: 0.9450
# Epoch 128/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2385 - accuracy: 0.9417
# Epoch 129/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1921 - accuracy: 0.9492
# Epoch 130/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2007 - accuracy: 0.9508
# Epoch 131/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1610 - accuracy: 0.9533
# Epoch 132/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2018 - accuracy: 0.9417
# Epoch 133/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1770 - accuracy: 0.9475
# Epoch 134/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2023 - accuracy: 0.9508
# Epoch 135/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1657 - accuracy: 0.9550
# Epoch 136/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1688 - accuracy: 0.9508
# Epoch 137/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2097 - accuracy: 0.9450
# Epoch 138/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1603 - accuracy: 0.9592
# Epoch 139/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1634 - accuracy: 0.9633
# Epoch 140/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2136 - accuracy: 0.9433
# Epoch 141/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1704 - accuracy: 0.9575
# Epoch 142/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1658 - accuracy: 0.9600
# Epoch 143/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2321 - accuracy: 0.9417
# Epoch 144/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1930 - accuracy: 0.9492
# Epoch 145/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2324 - accuracy: 0.9442
# Epoch 146/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1422 - accuracy: 0.9658
# Epoch 147/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1231 - accuracy: 0.9708
# Epoch 148/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2068 - accuracy: 0.9433
# Epoch 149/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1181 - accuracy: 0.9683
# Epoch 150/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1645 - accuracy: 0.9533
# Epoch 151/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2279 - accuracy: 0.9333
# Epoch 152/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1678 - accuracy: 0.9600
# Epoch 153/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2203 - accuracy: 0.9483
# Epoch 154/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1479 - accuracy: 0.9583
# Epoch 155/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1588 - accuracy: 0.9642
# Epoch 156/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1633 - accuracy: 0.9567
# Epoch 157/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2044 - accuracy: 0.9417
# Epoch 158/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1852 - accuracy: 0.9492
# Epoch 159/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1642 - accuracy: 0.9617
# Epoch 160/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1842 - accuracy: 0.9517
# Epoch 161/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1324 - accuracy: 0.9650
# Epoch 162/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2177 - accuracy: 0.9525
# Epoch 163/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1861 - accuracy: 0.9500
# Epoch 164/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1185 - accuracy: 0.9708
# Epoch 165/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1111 - accuracy: 0.9700
# Epoch 166/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1591 - accuracy: 0.9583
# Epoch 167/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1697 - accuracy: 0.9592
# Epoch 168/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1125 - accuracy: 0.9742
# Epoch 169/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1129 - accuracy: 0.9650
# Epoch 170/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1598 - accuracy: 0.9500
# Epoch 171/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1627 - accuracy: 0.9550
# Epoch 172/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1311 - accuracy: 0.9625
# Epoch 173/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0894 - accuracy: 0.9792
# Epoch 174/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1596 - accuracy: 0.9567
# Epoch 175/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1497 - accuracy: 0.9542
# Epoch 176/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1193 - accuracy: 0.9708
# Epoch 177/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2331 - accuracy: 0.9433
# Epoch 178/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1258 - accuracy: 0.9642
# Epoch 179/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0876 - accuracy: 0.9775
# Epoch 180/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1711 - accuracy: 0.9525
# Epoch 181/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1408 - accuracy: 0.9642
# Epoch 182/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0925 - accuracy: 0.9750
# Epoch 183/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1215 - accuracy: 0.9700
# Epoch 184/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0799 - accuracy: 0.9817
# Epoch 185/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1560 - accuracy: 0.9592
# Epoch 186/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1621 - accuracy: 0.9608
# Epoch 187/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0973 - accuracy: 0.9733
# Epoch 188/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1276 - accuracy: 0.9683
# Epoch 189/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1197 - accuracy: 0.9725
# Epoch 190/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1073 - accuracy: 0.9783
# Epoch 191/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0970 - accuracy: 0.9758
# Epoch 192/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0689 - accuracy: 0.9858
# Epoch 193/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0831 - accuracy: 0.9783
# Epoch 194/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1903 - accuracy: 0.9525
# Epoch 195/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1173 - accuracy: 0.9675
# Epoch 196/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1321 - accuracy: 0.9650
# Epoch 197/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2132 - accuracy: 0.9492
# Epoch 198/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0748 - accuracy: 0.9825
# Epoch 199/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1030 - accuracy: 0.9733
# Epoch 200/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1087 - accuracy: 0.9733
# Epoch 201/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1813 - accuracy: 0.9483
# Epoch 202/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1151 - accuracy: 0.9758
# Epoch 203/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0873 - accuracy: 0.9783
# Epoch 204/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1306 - accuracy: 0.9683
# Epoch 205/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1044 - accuracy: 0.9683
# Epoch 206/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0954 - accuracy: 0.9750
# Epoch 207/300
# 120/120 [==============================] - 1s 6ms/step - loss: 0.1114 - accuracy: 0.9650
# Epoch 208/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0784 - accuracy: 0.9783
# Epoch 209/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0881 - accuracy: 0.9775
# Epoch 210/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0751 - accuracy: 0.9783
# Epoch 211/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0942 - accuracy: 0.9775
# Epoch 212/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0899 - accuracy: 0.9775
# Epoch 213/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1245 - accuracy: 0.9658
# Epoch 214/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1758 - accuracy: 0.9542
# Epoch 215/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0790 - accuracy: 0.9792
# Epoch 216/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0811 - accuracy: 0.9800
# Epoch 217/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1342 - accuracy: 0.9633
# Epoch 218/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1590 - accuracy: 0.9583
# Epoch 219/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1271 - accuracy: 0.9600
# Epoch 220/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1021 - accuracy: 0.9767
# Epoch 221/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1448 - accuracy: 0.9625
# Epoch 222/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0994 - accuracy: 0.9767
# Epoch 223/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0594 - accuracy: 0.9833
# Epoch 224/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0557 - accuracy: 0.9875
# Epoch 225/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1850 - accuracy: 0.9500
# Epoch 226/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1039 - accuracy: 0.9733
# Epoch 227/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2991 - accuracy: 0.9392
# Epoch 228/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1005 - accuracy: 0.9750
# Epoch 229/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0969 - accuracy: 0.9767
# Epoch 230/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0826 - accuracy: 0.9750
# Epoch 231/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0514 - accuracy: 0.9900
# Epoch 232/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1110 - accuracy: 0.9658
# Epoch 233/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0907 - accuracy: 0.9742
# Epoch 234/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0847 - accuracy: 0.9792
# Epoch 235/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0966 - accuracy: 0.9775
# Epoch 236/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0705 - accuracy: 0.9825
# Epoch 237/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0617 - accuracy: 0.9850
# Epoch 238/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0952 - accuracy: 0.9767
# Epoch 239/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0698 - accuracy: 0.9808
# Epoch 240/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0821 - accuracy: 0.9808
# Epoch 241/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9742
# Epoch 242/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1631 - accuracy: 0.9608
# Epoch 243/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0886 - accuracy: 0.9775
# Epoch 244/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1209 - accuracy: 0.9708
# Epoch 245/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0969 - accuracy: 0.9742
# Epoch 246/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0876 - accuracy: 0.9750
# Epoch 247/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0893 - accuracy: 0.9767
# Epoch 248/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0821 - accuracy: 0.9775
# Epoch 249/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.3265 - accuracy: 0.9408
# Epoch 250/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1848 - accuracy: 0.9533
# Epoch 251/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0780 - accuracy: 0.9808
# Epoch 252/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0800 - accuracy: 0.9833
# Epoch 253/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1056 - accuracy: 0.9758
# Epoch 254/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1327 - accuracy: 0.9617
# Epoch 255/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0709 - accuracy: 0.9825
# Epoch 256/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0570 - accuracy: 0.9808
# Epoch 257/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0690 - accuracy: 0.9800
# Epoch 258/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1021 - accuracy: 0.9758
# Epoch 259/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0873 - accuracy: 0.9767
# Epoch 260/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0539 - accuracy: 0.9892
# Epoch 261/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0776 - accuracy: 0.9808
# Epoch 262/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1518 - accuracy: 0.9642
# Epoch 263/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1309 - accuracy: 0.9625
# Epoch 264/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0553 - accuracy: 0.9858
# Epoch 265/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0481 - accuracy: 0.9867
# Epoch 266/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0901 - accuracy: 0.9800
# Epoch 267/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0563 - accuracy: 0.9883
# Epoch 268/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0676 - accuracy: 0.9800
# Epoch 269/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0632 - accuracy: 0.9825
# Epoch 270/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1065 - accuracy: 0.9742
# Epoch 271/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0757 - accuracy: 0.9783
# Epoch 272/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1167 - accuracy: 0.9750
# Epoch 273/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0750 - accuracy: 0.9742
# Epoch 274/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0750 - accuracy: 0.9792
# Epoch 275/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1269 - accuracy: 0.9692
# Epoch 276/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0521 - accuracy: 0.9833
# Epoch 277/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1088 - accuracy: 0.9758
# Epoch 278/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1033 - accuracy: 0.9692
# Epoch 279/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0752 - accuracy: 0.9767
# Epoch 280/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0456 - accuracy: 0.9875
# Epoch 281/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1169 - accuracy: 0.9700
# Epoch 282/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1089 - accuracy: 0.9717
# Epoch 283/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1648 - accuracy: 0.9600
# Epoch 284/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0797 - accuracy: 0.9817
# Epoch 285/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1020 - accuracy: 0.9700
# Epoch 286/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0797 - accuracy: 0.9792
# Epoch 287/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0686 - accuracy: 0.9808
# Epoch 288/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0451 - accuracy: 0.9867
# Epoch 289/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0466 - accuracy: 0.9875
# Epoch 290/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0613 - accuracy: 0.9867
# Epoch 291/300
# 120/120 [==============================] - 1s 7ms/step - loss: 0.0918 - accuracy: 0.9783
# Epoch 292/300
# 120/120 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 0.9783
# Epoch 293/300
# 120/120 [==============================] - 1s 6ms/step - loss: 0.2364 - accuracy: 0.9550
# Epoch 294/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0895 - accuracy: 0.9750
# Epoch 295/300
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0643 - accuracy: 0.9842
# Epoch 296/300
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0430 - accuracy: 0.9875
# Epoch 297/300
# 120/120 [==============================] - 1s 6ms/step - loss: 0.0883 - accuracy: 0.9733
# Epoch 298/300
# 120/120 [==============================] - 1s 8ms/step - loss: 0.0895 - accuracy: 0.9775
# Epoch 299/300
# 120/120 [==============================] - 1s 7ms/step - loss: 0.0501 - accuracy: 0.9892
# Epoch 300/300
# 120/120 [==============================] - 1s 7ms/step - loss: 0.0368 - accuracy: 0.9908

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# #### SAVE MODEL

# %%
##################
# # save model # #
##################
model.model.save(MODEL_PATH)

# %% [markdown]
# # LIVE TESTING
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()
# pred_df = df_drop(pred_df)
# Out:
#   Subject  Password       D|0     I|0+1    PF|0+1    RF|0+1    DT|0+1  \
# 0    andy  Co5mical  0.073992  0.003000  0.076992  0.094482  0.168474
# 1    andy  Co5mical  0.100974  0.012187  0.113161  0.101644  0.202618
# 2    andy  Co5mical  0.089725  0.045267  0.134991  0.167849  0.257574
# 3    andy  Co5mical  0.067997  0.054379  0.122376  0.144052  0.212049
# 4    andy  Co5mical  0.102257  0.003956  0.106213  0.089189  0.191446
#
#         D|1     I|1+2    PF|1+2  ...  T7-RF-VAR  T7-G-VAR   T7-I-SD  T7-PF-SD  \
# 0  0.091483  0.045362  0.136844  ...   0.002609  0.001499  0.042155  0.029788
# 1  0.089456  0.033577  0.123034  ...   0.004042  0.005144  0.048238  0.056383
# 2  0.122583  0.005957  0.128540  ...   0.009055  0.005173  0.087968  0.064734
# 3  0.089673  0.000993  0.090666  ...   0.007376  0.004978  0.081239  0.065912
# 4  0.085233  0.045437  0.130670  ...   0.002313  0.003616  0.024290  0.036328
#
#    T7-RF-SD   T7-G-SD  T8_I|0+7  T8_PF|0+7  T8_RF|0+7  T8_G|0+7
# 0  0.051080  0.038712  0.499024   0.573016   0.566388  0.640380
# 1  0.063579  0.071723  0.518507   0.619481   0.597307  0.698281
# 2  0.095156  0.071922  0.504553   0.594277   0.596016  0.685741
# 3  0.085884  0.070557  0.477528   0.545525   0.563112  0.631109
# 4  0.048092  0.060130  0.470455   0.572712   0.537894  0.640151
#
# [5 rows x 222 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
results = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

########################
# # predict all rows # #
########################
pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[46:54,FEATURES_COL_NUM:]
# print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

Y = CLASS_LIST
print(Y)
Y = np.asarray(Y)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)
# Out:
# ['andy', 'azfar', 'bryce', 'chris', 'cy', 'gerald', 'ken', 'qk', 'sz', 'vale', 'ye', 'ys']

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

# pred_proba = np.sum(pred_proba, axis=0)
# pred_proba = np.reshape(pred_proba, (1, 9))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

pred_results = np.column_stack((pred, acc))
pred_results = np.column_stack((results, pred_results))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(data=pred_results, index=None, columns=['Results', 'Prediction', 'Accuracy'])
# df = pd.DataFrame(data=pred_results, index=None, columns=['Prediction', 'Accuracy'])
print(df)

# =IF(EXACT(B2, C2), "Match", "Nope")

df.to_csv(RESULT_NAME)
# Out:
#    Results Prediction    Accuracy
# 0     andy       andy   0.9999893
# 1     andy       andy  0.99998915
# 2     andy       andy   0.9999888
# 3     andy       andy   0.9999889
# 4     andy       andy  0.99998903
# 5    azfar      azfar  0.99983275
# 6    azfar      azfar   0.9998313
# 7    azfar      azfar   0.7885289
# 8    azfar      azfar   0.9998318
# 9    azfar      azfar  0.99982786
# 10   bryce      bryce   0.9946801
# 11   bryce      bryce   0.9946577
# 12   bryce      bryce   0.9945675
# 13   bryce      bryce   0.9941525
# 14   bryce      bryce   0.9943287
# 15   chris      chris   0.9922368
# 16   chris      chris  0.99285066
# 17   chris      chris   0.9913906
# 18   chris      chris  0.99256104
# 19   chris      chris  0.98485667
# 20      cy         cy   0.9981761
# 21      cy         cy   0.9982014
# 22      cy         cy   0.9981458
# 23      cy         cy   0.9972415
# 24      cy         cy  0.99793136
# 25  gerald     gerald  0.99403644
# 26  gerald     gerald   0.9957267
# 27  gerald     gerald   0.9941801
# 28  gerald     gerald   0.9911931
# 29  gerald     gerald   0.9714012
# 30     ken        ken  0.99986374
# 31     ken        ken  0.99986506
# 32     ken        ken   0.9998603
# 33     ken        ken   0.9998635
# 34     ken        ken  0.99986494
# 35      qk         qk   0.9993698
# 36      qk         qk  0.99948347
# 37      qk         qk   0.9994918
# 38      qk         qk  0.99949396
# 39      qk         qk   0.6600583
# 40      sz      azfar  0.64280707
# 41      sz         sz   0.9992706
# 42      sz         sz   0.9992675
# 43      sz         sz   0.9992717
# 44      sz         sz  0.99926966
# 45    vale       vale   0.9979965
# 46    vale       vale  0.99978286
# 47    vale       vale   0.9997838
# 48    vale       vale  0.99978215
# 49    vale       vale  0.99977905
# 50      ye         ye    0.998898
# 51      ye         ye   0.9989613
# 52      ye         ye   0.9981548
# 53      ye         ye  0.99879706
# 54      ye         ye    0.996095
# 55      ys         ys  0.99736696
# 56      ys         ys   0.9994242
# 57      ys         ys    0.999099
# 58      ys         ys   0.9991302
# 59      ys         ys   0.9996809
