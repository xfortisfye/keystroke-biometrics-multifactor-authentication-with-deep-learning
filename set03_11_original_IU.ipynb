# %% [markdown]
# #### IMPORT

# %%
import os, platform
import py7zr

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %% [markdown]
# #### PARAMETERS
# - Set the condition
# > * N_FEATURES: Number of Features
# > * CHECK_BLANKS: Check for blank data. If any blank data is found, the whole row of data will be deleted.
# > * CHECK_CLASS_IMBALANCE: Check for dataset class imbalance. The more balance the dataset, the less biases the model will be.

# %%
##############################
# # deep learning features # #
##############################
SEED = 1005 # random seed for reproducibility

# should make this dynamic
N_FEATURES = 96
TIMESTEPS = 1
EPOCH=200
BATCH_SIZE=100

SPLIT_RATIO=0.2

###############
# # preview # #
###############
f = False
t = True

# checking dataset
CHECK_BLANKS = True
CHECK_CLASS_IMBALANCE = True

# evaluate suitable kfold number and kfold model
MIN_KFOLD = 2
MAX_KFOLD = 11
N_KFOLD = 5
EVAL_KFOLD_NUM = False
EVAL_KFOLD_MODEL = False
PERFORM_KFOLD = False

# model testing
TEST_MODEL = True
CON_MATRIX = True
ROC_GRAPH = True

###############
# # dataset # #
###############
CLASSES_COL_NAME = "Subject"
CLASSES_COL_NUM = 0
FEATURES_COL_NUM = 3

METHOD = "IU"
# METHOD = "DU"

DATASET_DIR_NAME = "dataset\set03\\11_original_IUDU"
SAMPLE_DATASET_NAME = "original_train"
ACTUAL_DATASET_NAME = "original_test_" + METHOD

MODEL_DIR_NAME = "dataset\set03\\11_original_IUDU"
MODEL_NAME = "model_" + "set11_original_" + METHOD

RESULT_DIR_NAME = "dataset\set03\\11_original_IUDU"
RESULT_NAME = "result_" + "set11_original_" + METHOD

DATASET_DIR_PATH = os.path.join(os.getcwd(), DATASET_DIR_NAME)
SAMPLE_DATASET_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".csv")
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME + ".csv")

MODEL_DIR_PATH = os.path.join(os.getcwd(), MODEL_DIR_NAME)
MODEL_PATH = os.path.join(MODEL_DIR_PATH, MODEL_NAME + ".h5")

RESULT_DIR_PATH = os.path.join(os.getcwd(), RESULT_DIR_NAME)
RESULT_PATH = os.path.join(RESULT_DIR_PATH, RESULT_NAME + ".csv")

#################
# # sns theme # #
#################
# sns.set_theme(style="darkgrid") # (dark background with white gridlines)
sns.set_theme(style="whitegrid") # (white background with grey gridlines)
# sns.set_theme(style="dark") # (dark background with no gridlines)
# sns.set_theme(style="white") # (white background with no gridlines)
# sns.set_theme(style="ticks") # (white background with axis ticks and no gridlines)

# %%
if os.path.isdir(DATASET_DIR_PATH) is True:
    print(f"Dataset directory exists at: {DATASET_DIR_PATH}")
else:
    try:
        os.mkdir(DATASET_DIR_PATH, 666)
        print(f"Dataset directory have been created at: {DATASET_DIR_PATH}")
    except:
        print("Error: Dataset Directory not created")
        
if os.path.isdir(MODEL_DIR_PATH) is True:
    print(f"Model directory exists at: {MODEL_DIR_PATH}")
else:
    try:
        os.mkdir(MODEL_DIR_PATH, 666)
        print(f"Model directory have been created at: {MODEL_DIR_PATH}")
    except:
        print("Error: Model Directory not created")
    
if os.path.exists(SAMPLE_DATASET_PATH) is True:
    print(f"Training dataset exists at: {SAMPLE_DATASET_PATH}")
else:
    try:
        SAMPLE_7Z_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".7z")
        with py7zr.SevenZipFile(SAMPLE_7Z_PATH, mode='r') as z:
            z.extractall(path=DATASET_DIR_PATH)
        print(f"Decompress 7z file to: {SAMPLE_7Z_PATH}")
    except:
        print("Error: Failed to decompress 7z file.")
# Out:
# Dataset directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set03\11_original_IUDU
# Model directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set03\11_original_IUDU
# Training dataset exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set03\11_original_IUDU\original_train.csv

# %% [markdown]
# #### CREATE MODEL
# - Create base model
# - Wrap it with KerasClassifier

# %%
#create base model
def create_base_model():
    model = Sequential()
    model.add(LSTM(units=256, return_sequences=True,
             input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dense(256, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=32, return_sequences=True))
    model.add(Dense(32, activation='sigmoid'))
    model.add(Dropout(0.2))

    # softmax for multi-class classification
    model.add(Flatten())
    print("There are a total of " + str(n_classes) + " classes.")
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=EPOCH, 
                            batch_size=BATCH_SIZE)
    return model

# %%
# divide data into features X and target (classes) Y
def prepare_dataset(df):
    X = df.values[:,FEATURES_COL_NUM:].astype(float)
    Y = df.values[:,CLASSES_COL_NUM].astype(str)

    # convert target Y to labelbinarizer Y for model
    # fit_transform is not used to reuse lb
    Y = Y.reshape(-1, 1)
    lb = LabelBinarizer().fit(Y)
    Y = lb.transform(Y)

    #################################
    # # get all the encoded class # #
    #################################
    print("LabelBinarizer is able to decipher: ")
    print(lb.classes_)
    print("\n")

    ###########################
    # # print X and Y shape # #
    ###########################
    print(f"X | Features | Dataset Shape: {X.shape}")
    print(f"Y | Classes  | Dataset Shape: {Y.shape}")

    return X, Y, lb, lb.classes_.tolist()

# %%
def split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED):

    ##############################################################
    # # split dataset into train and test set of 0.8/0.2 ratio # #
    ##############################################################
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=SPLIT_RATIO, random_state=SEED)

    ############################
    # # reshaping of dataset # #
    ############################

    # reshaping the dataset to include LSTM Timesteps
    print(X_train.dtype)
    X_train = np.asarray(X_train, dtype=np.float32)
    print(X_train.dtype)
    X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
    print(X_test.dtype)
    X_test = np.asarray(X_test, dtype=np.float32)
    print(X_test.dtype)
    X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

    print(f"X train shape: {X_train.shape}")
    print(f"Y train shape: {y_train.shape}")
    print(f"X test shape: {X_test.shape}")
    print(f"Y test shape: {y_test.shape}")
    
    return X_train, X_test, y_train, y_test

def reshape_dataset(X, TIMESTEPS):
    # reshaping the dataset to include LSTM Timesteps
    X = np.asarray(X, dtype=np.float32)
    X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))
    return X

# %% [markdown]
# #### LOAD DATASET

# %%
# load dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)
df.head()
# Out:
#   Subject Sequence    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    adhy    wench  0.152282 -0.073436   0.078847   0.088479   0.240761
# 1    adhy    early  0.111913  0.151502   0.263416   0.288136   0.400049
# 2    adhy    relax  0.144175 -0.088621   0.055554   0.031521   0.175696
# 3    adhy    quick  0.152776 -0.081124   0.071653   0.054981   0.207758
# 4    adhy    xerus  0.070740  0.145027   0.215768   0.288192   0.358933
#
#      T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T4-RF|VAR  T4-NG|VAR   T4-I|SD  \
# 0  0.161915  0.102870   0.264785  ...   0.000301   0.000111  0.000517
# 1  0.136634 -0.016052   0.120582  ...   0.010378   0.007122  0.073101
# 2  0.120141  0.024040   0.144181  ...   0.027081   0.021776  0.159465
# 3  0.136105 -0.079724   0.056381  ...   0.000021   0.000267  0.012384
# 4  0.143165 -0.015681   0.127484  ...   0.018517   0.007202  0.141381
#
#    T4-PF|SD  T4-RF|SD  T4-NG|SD  T5-I|0+4  T5-PF|0+4  T5-RF|0+4  T5-NG|0+4
# 0  0.006294  0.017362  0.010551  0.447594   0.599876   0.575588   0.727871
# 1  0.055621  0.101870  0.084390  0.512567   0.624480   0.608445   0.720359
# 2  0.142471  0.164562  0.147567  0.343992   0.488168   0.464252   0.608427
# 3  0.000596  0.004537  0.016325  0.215807   0.368583   0.318909   0.471685
# 4  0.090169  0.136078  0.084866  0.441357   0.512098   0.553000   0.623741
#
# [5 rows x 99 columns]

# %% [markdown]
# #### CHECK DATASET

# %%
########################
# # check for blanks # #
########################
if CHECK_BLANKS is True:
    # checking for blanks
    print("Checking for blanks...")
    if df.isnull().values.any() is True:
        df = df.dropna(axis=0, how="any")
        print("Blank rows has been dropped.")
    else:
        print("No blank value has been found.")
        
#################################
# # check for class imbalance # #
#################################
if CHECK_CLASS_IMBALANCE is True:
    print("Checking for class imbalance...")
    sns.countplot(x=CLASSES_COL_NAME, data=df).set_title("Class Imbalance")
#     df.loc[(df!=0).any(axis=1)]
    plt.show()

sns.catplot(x="Subject", y="T2-D|0", hue="T2-D|0", data=df, legend=False)
sns.catplot(x="Subject", y="T2-I|0+1", hue="T2-I|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-PF|0+1", hue="T2-PF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-RF|0+1", hue="T2-RF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-D|1", hue="T2-D|1", data=df, legend=False)
# Out:
# Checking for blanks...
# No blank value has been found.
# Checking for class imbalance...

# %% [markdown]
# #### PREPARE DATASET
# - Split data based on X / Features and Y / Classes
# - Binarize Y into binary labels

# %%
X, Y, lb, class_list = prepare_dataset(df)
n_classes = len(class_list)
print(f"Number of Classes: {n_classes}")
# Out:
# LabelBinarizer is able to decipher:
# ['adhy' 'andy' 'bryce' 'chris' 'cy' 'hr' 'jc' 'ys']
#
#
# X | Features | Dataset Shape: (800, 96)
# Y | Classes  | Dataset Shape: (800, 8)
# Number of Classes: 8

# %% [markdown]
# #### SPLIT DATASET
# - Split dataset into train set and test set 0.8 / 0.2

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED)
# Out:
# float64
# float32
# float64
# float32
# X train shape: (640, 1, 96)
# Y train shape: (640, 8)
# X test shape: (160, 1, 96)
# Y test shape: (160, 8)

# %% [markdown]
# #### PERFORM VALIDATION (w KFold Validation)
# - Evaluate best KFold Validation
# - Generate loss and accuracy graph
# - Perform KFold validation

# %% [markdown]
# ##### Evaluate suitable folds for kfold validation

# %%
###############################################
# # evaluate suitable kfold value for model # #
###############################################
def evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD):
    
    # evaluate the model    
    folds = range(MIN_KFOLD, MAX_KFOLD)
    means, mins, maxs = list(), list(), list()
    
    # evaluate each k value
    for k in folds:
        # define the test condition
        kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
        
        # evaluate k value
        model = create_model()
        scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
        k_mean = np.mean(scores)
        k_min = scores.min()
        k_max = scores.max()
        
        # report performance
        print(f"No. of Folds: {k} | Accuracy: {k_mean*100:.3f} | Min: {k_min*100:.3f} | Max: {k_max*100:.3f}")
        
        # store mean accuracy and min and max relative to the mean
        means.append(k_mean)
        mins.append(k_mean - k_min)
        maxs.append(k_max - k_mean)
        
    # line plot of k mean values with min/max error bars
    clear_output(wait=True)
    pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
    # show the plot
    pyplot.show()
    
if EVAL_KFOLD_NUM is True:
    evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD)
else:
    print("EVAL_KFOLD_NUM is not True")
# Out:
# EVAL_KFOLD_NUM is not True

# %% [markdown]
# ##### Generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=50, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print(f"Accuracy | Mean: {np.mean(scores)*100:.3f} | Std: {np.std(scores)*100:.3f} | Length/no.: {len(scores)}")
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    clear_output(wait=True)
    plt.show()
    
if EVAL_KFOLD_MODEL is True:
    evaluate_kfold_model(X_train, y_train, SEED)
else:
    print("EVAL_KFOLD_MODEL is not true")
# Out:
# EVAL_KFOLD_MODEL is not true

# %% [markdown]
# ##### Perform Actual KFold validation

# %%
if PERFORM_KFOLD is True:
    # create model
    model = create_model()
    kfold = KFold(n_splits=N_KFOLD, shuffle=True, random_state=SEED)
    valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# ##### Get Validation Accuracy

# %%
if PERFORM_KFOLD is True:
    print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# #### FIT MODEL FOR TESTING
# - Fit the Model
# - View Accuracy and Loss Graph
# - View Model Summary

# %%
#####################
# # fit the model # #
#####################

if TEST_MODEL is True:
    model = create_model()
    es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                       verbose=1)
    history = model.fit(X_train, y_train, callbacks=es, verbose=1)
# Out:
# There are a total of 8 classes.
# Epoch 1/200
# 7/7 [==============================] - 7s 14ms/step - loss: 2.2940 - accuracy: 0.1250
# Epoch 2/200
# 7/7 [==============================] - 0s 16ms/step - loss: 2.2192 - accuracy: 0.1203
# Epoch 3/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.2115 - accuracy: 0.1266
# Epoch 4/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.1778 - accuracy: 0.1219
# Epoch 5/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.1476 - accuracy: 0.1109
# Epoch 6/200
# 7/7 [==============================] - 0s 16ms/step - loss: 2.1475 - accuracy: 0.1250
# Epoch 7/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.1481 - accuracy: 0.1203
# Epoch 8/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.1327 - accuracy: 0.1266
# Epoch 9/200
# 7/7 [==============================] - 0s 16ms/step - loss: 2.1510 - accuracy: 0.1141
# Epoch 10/200
# 7/7 [==============================] - 0s 16ms/step - loss: 2.1427 - accuracy: 0.1141
# Epoch 11/200
# 7/7 [==============================] - 0s 16ms/step - loss: 2.1289 - accuracy: 0.1094
# Epoch 12/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.1215 - accuracy: 0.1375
# Epoch 13/200
# 7/7 [==============================] - 0s 16ms/step - loss: 2.1129 - accuracy: 0.1453
# Epoch 14/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.1163 - accuracy: 0.1328
# Epoch 15/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.1067 - accuracy: 0.1219
# Epoch 16/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.0953 - accuracy: 0.1344
# Epoch 17/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.0800 - accuracy: 0.1453
# Epoch 18/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.0571 - accuracy: 0.1437
# Epoch 19/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.0474 - accuracy: 0.1672
# Epoch 20/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.0123 - accuracy: 0.1969
# Epoch 21/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.0080 - accuracy: 0.2047
# Epoch 22/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.9771 - accuracy: 0.2219
# Epoch 23/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.9725 - accuracy: 0.2125
# Epoch 24/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.9424 - accuracy: 0.2641
# Epoch 25/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.9559 - accuracy: 0.2281
# Epoch 26/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.9483 - accuracy: 0.2203
# Epoch 27/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.9142 - accuracy: 0.2281
# Epoch 28/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.9038 - accuracy: 0.2281
# Epoch 29/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8870 - accuracy: 0.2156
# Epoch 30/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8717 - accuracy: 0.2328
# Epoch 31/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8576 - accuracy: 0.2375
# Epoch 32/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8784 - accuracy: 0.2203
# Epoch 33/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8593 - accuracy: 0.2172
# Epoch 34/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8194 - accuracy: 0.2391
# Epoch 35/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8589 - accuracy: 0.2359
# Epoch 36/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8539 - accuracy: 0.2406
# Epoch 37/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8496 - accuracy: 0.2391
# Epoch 38/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8288 - accuracy: 0.2453
# Epoch 39/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7978 - accuracy: 0.2750
# Epoch 40/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8155 - accuracy: 0.2391
# Epoch 41/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8085 - accuracy: 0.2578
# Epoch 42/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7922 - accuracy: 0.2625
# Epoch 43/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8019 - accuracy: 0.2406
# Epoch 44/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8032 - accuracy: 0.2562
# Epoch 45/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7830 - accuracy: 0.2625
# Epoch 46/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7763 - accuracy: 0.2750
# Epoch 47/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7561 - accuracy: 0.2844
# Epoch 48/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7497 - accuracy: 0.2828
# Epoch 49/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7681 - accuracy: 0.2500
# Epoch 50/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7682 - accuracy: 0.2734
# Epoch 51/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7840 - accuracy: 0.2281
# Epoch 52/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7443 - accuracy: 0.2781
# Epoch 53/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7488 - accuracy: 0.2750
# Epoch 54/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.7420 - accuracy: 0.2781
# Epoch 55/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7741 - accuracy: 0.2531
# Epoch 56/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7390 - accuracy: 0.2844
# Epoch 57/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7161 - accuracy: 0.2828
# Epoch 58/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8329 - accuracy: 0.2250
# Epoch 59/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7280 - accuracy: 0.2875
# Epoch 60/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7495 - accuracy: 0.2766
# Epoch 61/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7531 - accuracy: 0.2469
# Epoch 62/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7434 - accuracy: 0.2891
# Epoch 63/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7513 - accuracy: 0.2750
# Epoch 64/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7354 - accuracy: 0.2875
# Epoch 65/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7278 - accuracy: 0.2781
# Epoch 66/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7340 - accuracy: 0.2812
# Epoch 67/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7228 - accuracy: 0.2672
# Epoch 68/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7196 - accuracy: 0.3094
# Epoch 69/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6953 - accuracy: 0.2781
# Epoch 70/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6974 - accuracy: 0.3109
# Epoch 71/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7074 - accuracy: 0.2781
# Epoch 72/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7226 - accuracy: 0.2656
# Epoch 73/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7002 - accuracy: 0.2766
# Epoch 74/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6877 - accuracy: 0.3063
# Epoch 75/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7189 - accuracy: 0.2906
# Epoch 76/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7199 - accuracy: 0.3156
# Epoch 77/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6833 - accuracy: 0.3047
# Epoch 78/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6773 - accuracy: 0.3016
# Epoch 79/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7049 - accuracy: 0.2734
# Epoch 80/200
# 7/7 [==============================] - 0s 17ms/step - loss: 1.7073 - accuracy: 0.2891
# Epoch 81/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6996 - accuracy: 0.2937
# Epoch 82/200
# 7/7 [==============================] - 0s 17ms/step - loss: 1.6801 - accuracy: 0.3109
# Epoch 83/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6982 - accuracy: 0.2922
# Epoch 84/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7079 - accuracy: 0.2906
# Epoch 85/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6966 - accuracy: 0.2922
# Epoch 86/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6770 - accuracy: 0.3078
# Epoch 87/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6877 - accuracy: 0.3078
# Epoch 88/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6732 - accuracy: 0.3219
# Epoch 89/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6851 - accuracy: 0.3031
# Epoch 90/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6690 - accuracy: 0.3094
# Epoch 91/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6836 - accuracy: 0.3141
# Epoch 92/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6946 - accuracy: 0.2922
# Epoch 93/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6569 - accuracy: 0.3266
# Epoch 94/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6717 - accuracy: 0.2812
# Epoch 95/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6883 - accuracy: 0.3000
# Epoch 96/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6910 - accuracy: 0.3078
# Epoch 97/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6726 - accuracy: 0.3078
# Epoch 98/200
# 7/7 [==============================] - 0s 17ms/step - loss: 1.6604 - accuracy: 0.3187
# Epoch 99/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6519 - accuracy: 0.3141
# Epoch 100/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6604 - accuracy: 0.3063
# Epoch 101/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6566 - accuracy: 0.3187
# Epoch 102/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6238 - accuracy: 0.3359
# Epoch 103/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6316 - accuracy: 0.3047
# Epoch 104/200
# 7/7 [==============================] - 0s 20ms/step - loss: 1.6722 - accuracy: 0.2906
# Epoch 105/200
# 7/7 [==============================] - 0s 19ms/step - loss: 1.6766 - accuracy: 0.3063
# Epoch 106/200
# 7/7 [==============================] - 0s 21ms/step - loss: 1.6474 - accuracy: 0.3375
# Epoch 107/200
# 7/7 [==============================] - 0s 26ms/step - loss: 1.6504 - accuracy: 0.3297
# Epoch 108/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6293 - accuracy: 0.3391
# Epoch 109/200
# 7/7 [==============================] - 0s 17ms/step - loss: 1.6166 - accuracy: 0.3328
# Epoch 110/200
# 7/7 [==============================] - 0s 18ms/step - loss: 1.6451 - accuracy: 0.3000
# Epoch 111/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6518 - accuracy: 0.3344
# Epoch 112/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6519 - accuracy: 0.2953
# Epoch 113/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6593 - accuracy: 0.3031
# Epoch 114/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6438 - accuracy: 0.3250
# Epoch 115/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6874 - accuracy: 0.3031
# Epoch 116/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6298 - accuracy: 0.3359
# Epoch 117/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6158 - accuracy: 0.3187
# Epoch 118/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6293 - accuracy: 0.3438
# Epoch 119/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6606 - accuracy: 0.3156
# Epoch 120/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6187 - accuracy: 0.3344
# Epoch 121/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6363 - accuracy: 0.3156
# Epoch 122/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6413 - accuracy: 0.3297
# Epoch 123/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6387 - accuracy: 0.3187
# Epoch 124/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6232 - accuracy: 0.3547
# Epoch 125/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6261 - accuracy: 0.3281
# Epoch 126/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6216 - accuracy: 0.3359
# Epoch 127/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6173 - accuracy: 0.3297
# Epoch 128/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6212 - accuracy: 0.3281
# Epoch 129/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6182 - accuracy: 0.3328
# Epoch 130/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6491 - accuracy: 0.3234
# Epoch 131/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6411 - accuracy: 0.3297
# Epoch 132/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6327 - accuracy: 0.3625
# Epoch 133/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6118 - accuracy: 0.3187
# Epoch 134/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5952 - accuracy: 0.3703
# Epoch 135/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.5818 - accuracy: 0.3547
# Epoch 136/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6168 - accuracy: 0.3438
# Epoch 137/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6235 - accuracy: 0.3453
# Epoch 138/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6186 - accuracy: 0.3391
# Epoch 139/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6093 - accuracy: 0.3234
# Epoch 140/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5931 - accuracy: 0.3422
# Epoch 141/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6065 - accuracy: 0.3313
# Epoch 142/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6227 - accuracy: 0.3500
# Epoch 143/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6092 - accuracy: 0.3281
# Epoch 144/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6127 - accuracy: 0.3375
# Epoch 145/200
# 7/7 [==============================] - 0s 18ms/step - loss: 1.6233 - accuracy: 0.3234
# Epoch 146/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6121 - accuracy: 0.3453
# Epoch 147/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6079 - accuracy: 0.3359
# Epoch 148/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6346 - accuracy: 0.3234
# Epoch 149/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5878 - accuracy: 0.3469
# Epoch 150/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6317 - accuracy: 0.3328
# Epoch 151/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.5985 - accuracy: 0.3422
# Epoch 152/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.5929 - accuracy: 0.3531
# Epoch 153/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6114 - accuracy: 0.3391
# Epoch 154/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6052 - accuracy: 0.3266
# Epoch 155/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6139 - accuracy: 0.3531
# Epoch 156/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6003 - accuracy: 0.3344
# Epoch 157/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.5841 - accuracy: 0.3688
# Epoch 158/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5860 - accuracy: 0.3562
# Epoch 159/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5765 - accuracy: 0.3531
# Epoch 160/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.5659 - accuracy: 0.3734
# Epoch 161/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6310 - accuracy: 0.3453
# Epoch 162/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6290 - accuracy: 0.3531
# Epoch 163/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6019 - accuracy: 0.3484
# Epoch 164/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5848 - accuracy: 0.3453
# Epoch 165/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5756 - accuracy: 0.3688
# Epoch 166/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5737 - accuracy: 0.3688
# Epoch 167/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5820 - accuracy: 0.3438
# Epoch 168/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5659 - accuracy: 0.3750
# Epoch 169/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5923 - accuracy: 0.3812
# Epoch 170/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6077 - accuracy: 0.3641
# Epoch 171/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5827 - accuracy: 0.3516
# Epoch 172/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5501 - accuracy: 0.3969
# Epoch 173/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5530 - accuracy: 0.4000
# Epoch 174/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5990 - accuracy: 0.3859
# Epoch 175/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5764 - accuracy: 0.3875
# Epoch 176/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5615 - accuracy: 0.3844
# Epoch 177/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5587 - accuracy: 0.3969
# Epoch 178/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5466 - accuracy: 0.4031
# Epoch 179/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5737 - accuracy: 0.3938
# Epoch 180/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5646 - accuracy: 0.4000
# Epoch 181/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5150 - accuracy: 0.4125
# Epoch 182/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5540 - accuracy: 0.4062
# Epoch 183/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5552 - accuracy: 0.3984
# Epoch 184/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5262 - accuracy: 0.3891
# Epoch 185/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5590 - accuracy: 0.4031
# Epoch 186/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5807 - accuracy: 0.4156
# Epoch 187/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5255 - accuracy: 0.4172
# Epoch 188/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5455 - accuracy: 0.4016
# Epoch 189/200
# 7/7 [==============================] - 0s 18ms/step - loss: 1.5224 - accuracy: 0.4250
# Epoch 190/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5197 - accuracy: 0.3953
# Epoch 191/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5157 - accuracy: 0.4328
# Epoch 192/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5284 - accuracy: 0.4078
# Epoch 193/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5458 - accuracy: 0.4281
# Epoch 194/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5268 - accuracy: 0.4172
# Epoch 195/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5045 - accuracy: 0.4344
# Epoch 196/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4985 - accuracy: 0.4172
# Epoch 197/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.4990 - accuracy: 0.4234
# Epoch 198/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5037 - accuracy: 0.4078
# Epoch 199/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5293 - accuracy: 0.4156
# Epoch 200/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5156 - accuracy: 0.4219

# %%
if TEST_MODEL is True:
    ##########################
    # # get model accuracy # #
    ##########################
    plt.plot(history.history['accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

    ######################
    # # get model loss # #
    ######################
    plt.plot(history.history['loss'])
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

# %%
if TEST_MODEL is True:
    ##########################
    # # view model summary # #
    ##########################
    model.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 256)            361472
#
#  dense (Dense)               (None, 1, 256)            65792
#
#  dropout (Dropout)           (None, 1, 256)            0
#
#  batch_normalization (BatchN  (None, 1, 256)           1024
#  ormalization)
#
#  lstm_1 (LSTM)               (None, 1, 128)            197120
#
#  dense_1 (Dense)             (None, 1, 128)            16512
#
#  dropout_1 (Dropout)         (None, 1, 128)            0
#
#  batch_normalization_1 (Batc  (None, 1, 128)           512
#  hNormalization)
#
#  lstm_2 (LSTM)               (None, 1, 64)             49408
#
#  dense_2 (Dense)             (None, 1, 64)             4160
#
#  dropout_2 (Dropout)         (None, 1, 64)             0
#
#  batch_normalization_2 (Batc  (None, 1, 64)            256
#  hNormalization)
#
#  lstm_3 (LSTM)               (None, 1, 32)             12416
#
#  dense_3 (Dense)             (None, 1, 32)             1056
#
#  dropout_3 (Dropout)         (None, 1, 32)             0
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense_4 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 709,992
# Trainable params: 709,096
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# #### MODEL TESTING
# - Get Model Accuracy on the Test Dataset
# - Generate Confusion Matrix
# - Generate ROC Curves
# - Save the Model if Appropriate

# %%
if TEST_MODEL is True:
    y_pred = model.predict_proba(X_test)

    # evaluate predictions
    acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    print("Testing accuracy: %.3f%%" % (acc*100))
# Out:
# Testing accuracy: 36.875%

# %% [markdown]
# ##### Confusion Matrix

# %%
if TEST_MODEL is True and CON_MATRIX is True:
    # confusion matrix
    print(str(len(y_pred)) + " is the number of test value in kfold_val / train_test_split")
    cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                         columns = [i for i in np.unique(lb.inverse_transform(y_test))])

    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=True, cmap="BuPu")
# Out:
# 160 is the number of test value in kfold_val / train_test_split

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
if TEST_MODEL is True and ROC_GRAPH is True: # compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    for i in range(n_classes):
        plt.figure()
        lw = 2
        plt.plot(
            fpr[i],
            tpr[i],
            color="darkorange",
            lw=lw,
            label="ROC curve (area = %0.2f)" % roc_auc[i],
        )
        plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
        plt.xlim([-0.005, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ##### ROC Curve (Multiclass)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    # compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # first aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    # plt.figure()
    # plt.plot(
    #     fpr["micro"],
    #     tpr["micro"],
    #     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    #     color="deeppink",
    #     linestyle=":",
    #     linewidth=4,
    # )

    # plt.plot(
    #     fpr["macro"],
    #     tpr["macro"],
    #     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    #     color="navy",
    #     linestyle=":",
    #     linewidth=4,
    # )

    colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
        )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Multiclass)")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Average)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

    # calculate equal-error-rate
    eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('Average ROC Curve')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #### FIT AND SAVE MODEL
# - Fitting of model
# - Get Accuracy and Loss of Mdoel
# - Saving Model

# %%
############################
# # reshaping of dataset # #
############################
# loading of dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)

df.head()
dataset = df.values

# divide data into features X and target (classes) Y
# convert target Y to labelbinarizer Y for model
X, Y, lb, class_list = prepare_dataset(df)

# reshaping the dataset to include LSTM Timesteps
X = reshape_dataset(X, TIMESTEPS)
n_classes = Y.shape[1]

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# LabelBinarizer is able to decipher:
# ['adhy' 'andy' 'bryce' 'chris' 'cy' 'hr' 'jc' 'ys']
#
#
# X | Features | Dataset Shape: (800, 96)
# Y | Classes  | Dataset Shape: (800, 8)
# There are a total of 8 classes.
# Epoch 1/200
# 8/8 [==============================] - 13s 16ms/step - loss: 2.2207 - accuracy: 0.1400
# Epoch 2/200
# 8/8 [==============================] - 0s 17ms/step - loss: 2.2001 - accuracy: 0.1125
# Epoch 3/200
# 8/8 [==============================] - 0s 18ms/step - loss: 2.1774 - accuracy: 0.1088
# Epoch 4/200
# 8/8 [==============================] - 0s 18ms/step - loss: 2.1589 - accuracy: 0.1138
# Epoch 5/200
# 8/8 [==============================] - 0s 18ms/step - loss: 2.1380 - accuracy: 0.1312
# Epoch 6/200
# 8/8 [==============================] - 0s 18ms/step - loss: 2.1477 - accuracy: 0.1125
# Epoch 7/200
# 8/8 [==============================] - 0s 18ms/step - loss: 2.1277 - accuracy: 0.1213
# Epoch 8/200
# 8/8 [==============================] - 0s 18ms/step - loss: 2.1192 - accuracy: 0.1338
# Epoch 9/200
# 8/8 [==============================] - 0s 19ms/step - loss: 2.1167 - accuracy: 0.1363
# Epoch 10/200
# 8/8 [==============================] - 0s 18ms/step - loss: 2.1410 - accuracy: 0.1037
# Epoch 11/200
# 8/8 [==============================] - 0s 19ms/step - loss: 2.1326 - accuracy: 0.1025
# Epoch 12/200
# 8/8 [==============================] - 0s 19ms/step - loss: 2.1223 - accuracy: 0.1213
# Epoch 13/200
# 8/8 [==============================] - 0s 18ms/step - loss: 2.0884 - accuracy: 0.1663
# Epoch 14/200
# 8/8 [==============================] - 0s 18ms/step - loss: 2.0807 - accuracy: 0.1437
# Epoch 15/200
# 8/8 [==============================] - 0s 18ms/step - loss: 2.0640 - accuracy: 0.1462
# Epoch 16/200
# 8/8 [==============================] - 0s 18ms/step - loss: 2.0438 - accuracy: 0.1612
# Epoch 17/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.9979 - accuracy: 0.1975
# Epoch 18/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.9835 - accuracy: 0.2100
# Epoch 19/200
# 8/8 [==============================] - 0s 17ms/step - loss: 1.9494 - accuracy: 0.2150
# Epoch 20/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.9253 - accuracy: 0.2188
# Epoch 21/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.9102 - accuracy: 0.2313
# Epoch 22/200
# 8/8 [==============================] - 0s 17ms/step - loss: 1.8832 - accuracy: 0.2138
# Epoch 23/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.8728 - accuracy: 0.2188
# Epoch 24/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.8461 - accuracy: 0.2412
# Epoch 25/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.8119 - accuracy: 0.2812
# Epoch 26/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.8226 - accuracy: 0.2325
# Epoch 27/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.8144 - accuracy: 0.2425
# Epoch 28/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7971 - accuracy: 0.2587
# Epoch 29/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7852 - accuracy: 0.2463
# Epoch 30/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7727 - accuracy: 0.2812
# Epoch 31/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7964 - accuracy: 0.2488
# Epoch 32/200
# 8/8 [==============================] - 0s 17ms/step - loss: 1.7704 - accuracy: 0.2488
# Epoch 33/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7701 - accuracy: 0.2550
# Epoch 34/200
# 8/8 [==============================] - 0s 21ms/step - loss: 1.7780 - accuracy: 0.2525
# Epoch 35/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7556 - accuracy: 0.2625
# Epoch 36/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7539 - accuracy: 0.2663
# Epoch 37/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.7570 - accuracy: 0.2850
# Epoch 38/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.7381 - accuracy: 0.2850
# Epoch 39/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7428 - accuracy: 0.2625
# Epoch 40/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7305 - accuracy: 0.2825
# Epoch 41/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7402 - accuracy: 0.2875
# Epoch 42/200
# 8/8 [==============================] - 0s 17ms/step - loss: 1.7215 - accuracy: 0.2837
# Epoch 43/200
# 8/8 [==============================] - 0s 17ms/step - loss: 1.7179 - accuracy: 0.2725
# Epoch 44/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7315 - accuracy: 0.2675
# Epoch 45/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7162 - accuracy: 0.2812
# Epoch 46/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7091 - accuracy: 0.2988
# Epoch 47/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7088 - accuracy: 0.2850
# Epoch 48/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.6893 - accuracy: 0.2975
# Epoch 49/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.7124 - accuracy: 0.2812
# Epoch 50/200
# 8/8 [==============================] - 0s 20ms/step - loss: 1.7244 - accuracy: 0.2738
# Epoch 51/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7030 - accuracy: 0.2837
# Epoch 52/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.6863 - accuracy: 0.3075
# Epoch 53/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7002 - accuracy: 0.2775
# Epoch 54/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.6932 - accuracy: 0.2800
# Epoch 55/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.6914 - accuracy: 0.2937
# Epoch 56/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.6738 - accuracy: 0.2988
# Epoch 57/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.6960 - accuracy: 0.2750
# Epoch 58/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.6847 - accuracy: 0.2937
# Epoch 59/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.6884 - accuracy: 0.3237
# Epoch 60/200
# 8/8 [==============================] - 0s 17ms/step - loss: 1.6647 - accuracy: 0.3100
# Epoch 61/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6691 - accuracy: 0.3113
# Epoch 62/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6825 - accuracy: 0.3250
# Epoch 63/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6867 - accuracy: 0.2937
# Epoch 64/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6762 - accuracy: 0.2925
# Epoch 65/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6912 - accuracy: 0.3250
# Epoch 66/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6646 - accuracy: 0.3225
# Epoch 67/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6545 - accuracy: 0.3450
# Epoch 68/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6489 - accuracy: 0.3275
# Epoch 69/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6696 - accuracy: 0.3275
# Epoch 70/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6752 - accuracy: 0.3338
# Epoch 71/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6707 - accuracy: 0.3175
# Epoch 72/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6686 - accuracy: 0.3212
# Epoch 73/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6576 - accuracy: 0.3475
# Epoch 74/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6475 - accuracy: 0.3313
# Epoch 75/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6437 - accuracy: 0.3550
# Epoch 76/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6430 - accuracy: 0.3475
# Epoch 77/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6457 - accuracy: 0.3237
# Epoch 78/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6316 - accuracy: 0.3487
# Epoch 79/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6359 - accuracy: 0.3425
# Epoch 80/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6267 - accuracy: 0.3688
# Epoch 81/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6297 - accuracy: 0.3388
# Epoch 82/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6100 - accuracy: 0.3750
# Epoch 83/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6208 - accuracy: 0.3825
# Epoch 84/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6333 - accuracy: 0.3663
# Epoch 85/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6144 - accuracy: 0.3837
# Epoch 86/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6318 - accuracy: 0.3700
# Epoch 87/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6256 - accuracy: 0.3638
# Epoch 88/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6312 - accuracy: 0.3462
# Epoch 89/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6126 - accuracy: 0.3762
# Epoch 90/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6193 - accuracy: 0.3850
# Epoch 91/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5987 - accuracy: 0.3762
# Epoch 92/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5986 - accuracy: 0.3925
# Epoch 93/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6011 - accuracy: 0.4250
# Epoch 94/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6088 - accuracy: 0.3688
# Epoch 95/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6336 - accuracy: 0.3800
# Epoch 96/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5910 - accuracy: 0.4013
# Epoch 97/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6209 - accuracy: 0.3950
# Epoch 98/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6047 - accuracy: 0.3988
# Epoch 99/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5742 - accuracy: 0.4087
# Epoch 100/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6002 - accuracy: 0.3875
# Epoch 101/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5706 - accuracy: 0.4025
# Epoch 102/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6078 - accuracy: 0.3787
# Epoch 103/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5996 - accuracy: 0.3875
# Epoch 104/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5747 - accuracy: 0.4050
# Epoch 105/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5730 - accuracy: 0.3975
# Epoch 106/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5519 - accuracy: 0.3963
# Epoch 107/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5761 - accuracy: 0.3925
# Epoch 108/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5593 - accuracy: 0.3775
# Epoch 109/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5577 - accuracy: 0.4038
# Epoch 110/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5831 - accuracy: 0.3925
# Epoch 111/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5443 - accuracy: 0.4087
# Epoch 112/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5440 - accuracy: 0.4212
# Epoch 113/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5577 - accuracy: 0.4038
# Epoch 114/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5573 - accuracy: 0.4013
# Epoch 115/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5519 - accuracy: 0.4038
# Epoch 116/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5488 - accuracy: 0.4013
# Epoch 117/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5540 - accuracy: 0.3988
# Epoch 118/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5429 - accuracy: 0.3963
# Epoch 119/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5559 - accuracy: 0.3900
# Epoch 120/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5514 - accuracy: 0.3850
# Epoch 121/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5721 - accuracy: 0.4100
# Epoch 122/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5104 - accuracy: 0.4112
# Epoch 123/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5401 - accuracy: 0.4137
# Epoch 124/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5788 - accuracy: 0.4025
# Epoch 125/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5486 - accuracy: 0.4212
# Epoch 126/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5420 - accuracy: 0.4150
# Epoch 127/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5232 - accuracy: 0.4137
# Epoch 128/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5425 - accuracy: 0.3900
# Epoch 129/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5208 - accuracy: 0.4062
# Epoch 130/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5452 - accuracy: 0.3988
# Epoch 131/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5024 - accuracy: 0.4200
# Epoch 132/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5208 - accuracy: 0.4075
# Epoch 133/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5067 - accuracy: 0.4038
# Epoch 134/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5211 - accuracy: 0.4238
# Epoch 135/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5404 - accuracy: 0.3988
# Epoch 136/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5484 - accuracy: 0.4125
# Epoch 137/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5141 - accuracy: 0.4350
# Epoch 138/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5410 - accuracy: 0.4087
# Epoch 139/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5022 - accuracy: 0.4238
# Epoch 140/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5140 - accuracy: 0.4275
# Epoch 141/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5296 - accuracy: 0.4150
# Epoch 142/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5075 - accuracy: 0.4263
# Epoch 143/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5049 - accuracy: 0.4112
# Epoch 144/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5055 - accuracy: 0.4112
# Epoch 145/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5209 - accuracy: 0.4050
# Epoch 146/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5004 - accuracy: 0.4112
# Epoch 147/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5029 - accuracy: 0.4162
# Epoch 148/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5271 - accuracy: 0.4187
# Epoch 149/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5149 - accuracy: 0.4187
# Epoch 150/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5086 - accuracy: 0.4175
# Epoch 151/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.4938 - accuracy: 0.4150
# Epoch 152/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4885 - accuracy: 0.4263
# Epoch 153/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5104 - accuracy: 0.4162
# Epoch 154/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4873 - accuracy: 0.4288
# Epoch 155/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4808 - accuracy: 0.4387
# Epoch 156/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4929 - accuracy: 0.4363
# Epoch 157/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4958 - accuracy: 0.4225
# Epoch 158/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.4979 - accuracy: 0.4412
# Epoch 159/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.4818 - accuracy: 0.4375
# Epoch 160/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4869 - accuracy: 0.4263
# Epoch 161/200
# 8/8 [==============================] - 0s 16ms/step - loss: 1.4712 - accuracy: 0.4375
# Epoch 162/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5042 - accuracy: 0.4075
# Epoch 163/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.4559 - accuracy: 0.4450
# Epoch 164/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.4693 - accuracy: 0.4300
# Epoch 165/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5019 - accuracy: 0.4375
# Epoch 166/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4945 - accuracy: 0.4112
# Epoch 167/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4532 - accuracy: 0.4450
# Epoch 168/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4686 - accuracy: 0.4363
# Epoch 169/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4651 - accuracy: 0.4263
# Epoch 170/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4808 - accuracy: 0.4363
# Epoch 171/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4493 - accuracy: 0.4412
# Epoch 172/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4397 - accuracy: 0.4525
# Epoch 173/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4623 - accuracy: 0.4437
# Epoch 174/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4789 - accuracy: 0.4200
# Epoch 175/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4353 - accuracy: 0.4288
# Epoch 176/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4799 - accuracy: 0.4475
# Epoch 177/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.4790 - accuracy: 0.4363
# Epoch 178/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4758 - accuracy: 0.4175
# Epoch 179/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4761 - accuracy: 0.4225
# Epoch 180/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4540 - accuracy: 0.4512
# Epoch 181/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4438 - accuracy: 0.4400
# Epoch 182/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4400 - accuracy: 0.4313
# Epoch 183/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4378 - accuracy: 0.4412
# Epoch 184/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.4815 - accuracy: 0.4263
# Epoch 185/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4507 - accuracy: 0.4425
# Epoch 186/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4576 - accuracy: 0.4437
# Epoch 187/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4411 - accuracy: 0.4512
# Epoch 188/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4823 - accuracy: 0.4275
# Epoch 189/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4304 - accuracy: 0.4462
# Epoch 190/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4504 - accuracy: 0.4338
# Epoch 191/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4445 - accuracy: 0.4500
# Epoch 192/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4550 - accuracy: 0.4363
# Epoch 193/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4397 - accuracy: 0.4263
# Epoch 194/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4646 - accuracy: 0.4250
# Epoch 195/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4164 - accuracy: 0.4563
# Epoch 196/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4493 - accuracy: 0.4563
# Epoch 197/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.4319 - accuracy: 0.4462
# Epoch 198/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4273 - accuracy: 0.4450
# Epoch 199/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4479 - accuracy: 0.4462
# Epoch 200/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4252 - accuracy: 0.4538

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# #### SAVE MODEL

# %%
##################
# # save model # #
##################
model.model.save(MODEL_PATH)

# %% [markdown]
# # LIVE TESTING
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()
# Out:
#   Subject Sequence    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    adhy    quail  0.119654 -0.024004   0.095650   0.080376   0.200030
# 1    adhy    acute  0.152999  0.336367   0.489367   0.448313   0.601312
# 2    adhy    tidal  0.112180 -0.079886   0.032294   0.032004   0.144184
# 3    adhy    scold  0.120001  0.080002   0.200003   0.224265   0.344265
# 4    adhy    nitro  0.111459  0.015505   0.126965   0.143124   0.254583
#
#      T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T4-RF|VAR  T4-NG|VAR   T4-I|SD  \
# 0  0.104380  0.304264   0.408644  ...   0.000039   0.000290  0.005462
# 1  0.111945 -0.032049   0.079896  ...   0.080180   0.097463  0.271303
# 2  0.111891  0.127658   0.239549  ...   0.000036   0.000034  0.034878
# 3  0.144262  0.552010   0.696273  ...   0.009373   0.006345  0.113785
# 4  0.127619  0.023795   0.151413  ...   0.012563   0.010132  0.061637
#
#    T4-PF|SD  T4-RF|SD  T4-NG|SD  T5-I|0+4  T5-PF|0+4  T5-RF|0+4  T5-NG|0+4
# 0  0.016262  0.006237  0.017037  0.552586   0.672240   0.672467   0.792121
# 1  0.300333  0.283161  0.312191  0.616362   0.769361   0.736033   0.889032
# 2  0.034673  0.005993  0.005788  0.344067   0.456247   0.416209   0.528389
# 3  0.096630  0.096813  0.079658  1.008275   1.128276   1.128039   1.248040
# 4  0.050211  0.112083  0.100657  0.375933   0.487393   0.439950   0.551410
#
# [5 rows x 99 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
actual_np = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

########################
# # predict all rows # #
########################
pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[46:54,FEATURES_COL_NUM:]
# print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

print(class_list)
Y = np.asarray(class_list)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)
# Out:
# ['adhy', 'andy', 'bryce', 'chris', 'cy', 'hr', 'jc', 'ys']

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

# pred_proba = np.sum(pred_proba, axis=0)
# pred_proba = np.reshape(pred_proba, (1, 9))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

match_list = []

for _ in range(actual_np.size):
    if pred[_] == actual_np[_]:
        match_list.append("match")
    else:
        match_list.append("nope")

match_count = match_list.count("match")
total_count = len(match_list)

match_header = str(match_count) + "/" + str(total_count) + " (" + str(match_count/total_count*100)+ "%)"
match_np = np.array(match_list)

exported_output = np.column_stack((actual_np, pred))
exported_output = np.column_stack((exported_output, acc))
exported_output = np.column_stack((exported_output, match_np))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(data=exported_output, index=None, columns=['Actual', 'Prediction', 'Accuracy', match_header])
# print(df)
df.to_csv(RESULT_PATH)

print("Accuracy of the Model is: " + str(match_header))
# Out:
# Accuracy of the Model is: 33/80 (41.25%)
