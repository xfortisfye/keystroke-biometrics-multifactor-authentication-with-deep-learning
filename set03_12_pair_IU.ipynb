# %% [markdown]
# #### IMPORT

# %%
import os, platform
import py7zr

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %% [markdown]
# #### PARAMETERS
# - Set the condition
# > * N_FEATURES: Number of Features
# > * CHECK_BLANKS: Check for blank data. If any blank data is found, the whole row of data will be deleted.
# > * CHECK_CLASS_IMBALANCE: Check for dataset class imbalance. The more balance the dataset, the less biases the model will be.

# %%
##############################
# # deep learning features # #
##############################
SEED = 1005 # random seed for reproducibility

# should make this dynamic
N_FEATURES = 193
TIMESTEPS = 1
EPOCH=200
BATCH_SIZE=100

SPLIT_RATIO=0.2

###############
# # preview # #
###############
f = False
t = True

# checking dataset
CHECK_BLANKS = True
CHECK_CLASS_IMBALANCE = True

# evaluate suitable kfold number and kfold model
MIN_KFOLD = 2
MAX_KFOLD = 11
N_KFOLD = 5
EVAL_KFOLD_NUM = False
EVAL_KFOLD_MODEL = False
PERFORM_KFOLD = False

# model testing
TEST_MODEL = True
CON_MATRIX = True
ROC_GRAPH = True

###############
# # dataset # #
###############
CLASSES_COL_NAME = "Subject"
CLASSES_COL_NUM = 0
FEATURES_COL_NUM = 3

METHOD = "IU"
# METHOD = "DU"

DATASET_DIR_NAME = "dataset\set03\\12_pair_IUDU"
SAMPLE_DATASET_NAME = "pair_train"
ACTUAL_DATASET_NAME = "pair_test_" + METHOD

MODEL_DIR_NAME = "dataset\set03\\12_pair_IUDU"
MODEL_NAME = "model_" + "set03_12_pair_" + METHOD

RESULT_DIR_NAME = "dataset\set03\\12_pair_IUDU"
RESULT_NAME = "result_" + "set03_12_pair_" + METHOD

DATASET_DIR_PATH = os.path.join(os.getcwd(), DATASET_DIR_NAME)
SAMPLE_DATASET_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".csv")
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME + ".csv")

MODEL_DIR_PATH = os.path.join(os.getcwd(), MODEL_DIR_NAME)
MODEL_PATH = os.path.join(MODEL_DIR_PATH, MODEL_NAME + ".h5")

RESULT_DIR_PATH = os.path.join(os.getcwd(), RESULT_DIR_NAME)
RESULT_PATH = os.path.join(RESULT_DIR_PATH, RESULT_NAME + ".csv")

#################
# # sns theme # #
#################
# sns.set_theme(style="darkgrid") # (dark background with white gridlines)
sns.set_theme(style="whitegrid") # (white background with grey gridlines)
# sns.set_theme(style="dark") # (dark background with no gridlines)
# sns.set_theme(style="white") # (white background with no gridlines)
# sns.set_theme(style="ticks") # (white background with axis ticks and no gridlines)

# %%
if os.path.isdir(DATASET_DIR_PATH) is True:
    print(f"Dataset directory exists at: {DATASET_DIR_PATH}")
else:
    try:
        os.mkdir(DATASET_DIR_PATH, 666)
        print(f"Dataset directory have been created at: {DATASET_DIR_PATH}")
    except:
        print("Error: Dataset Directory not created")
        
if os.path.isdir(MODEL_DIR_PATH) is True:
    print(f"Model directory exists at: {MODEL_DIR_PATH}")
else:
    try:
        os.mkdir(MODEL_DIR_PATH, 666)
        print(f"Model directory have been created at: {MODEL_DIR_PATH}")
    except:
        print("Error: Model Directory not created")
    
if os.path.exists(SAMPLE_DATASET_PATH) is True:
    print(f"Training dataset exists at: {SAMPLE_DATASET_PATH}")
else:
    try:
        SAMPLE_7Z_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".7z")
        with py7zr.SevenZipFile(SAMPLE_7Z_PATH, mode='r') as z:
            z.extractall(path=DATASET_DIR_PATH)
        print(f"Decompress 7z file to: {SAMPLE_7Z_PATH}")
    except:
        print("Error: Failed to decompress 7z file.")
# Out:
# Dataset directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set03\12_pair_IUDU
# Model directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set03\12_pair_IUDU
# Decompress 7z file to: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set03\12_pair_IUDU\pair_train.7z

# %% [markdown]
# #### CREATE MODEL
# - Create base model
# - Wrap it with KerasClassifier

# %%
#create base model
def create_base_model():
    model = Sequential()
    model.add(LSTM(units=256, return_sequences=True,
             input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dense(256, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=32, return_sequences=True))
    model.add(Dense(32, activation='sigmoid'))
    model.add(Dropout(0.2))

    # softmax for multi-class classification
    model.add(Flatten())
    print("There are a total of " + str(n_classes) + " classes.")
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=EPOCH, 
                            batch_size=BATCH_SIZE)
    return model

# %%
# divide data into features X and target (classes) Y
def prepare_dataset(df):
    X = df.values[:,FEATURES_COL_NUM:].astype(float)
    Y = df.values[:,CLASSES_COL_NUM].astype(str)

    # convert target Y to labelbinarizer Y for model
    # fit_transform is not used to reuse lb
    Y = Y.reshape(-1, 1)
    lb = LabelBinarizer().fit(Y)
    Y = lb.transform(Y)

    #################################
    # # get all the encoded class # #
    #################################
    print("LabelBinarizer is able to decipher: ")
    print(lb.classes_)
    print("\n")

    ###########################
    # # print X and Y shape # #
    ###########################
    print(f"X | Features | Dataset Shape: {X.shape}")
    print(f"Y | Classes  | Dataset Shape: {Y.shape}")

    return X, Y, lb, lb.classes_.tolist()

# %%
def split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED):

    ##############################################################
    # # split dataset into train and test set of 0.8/0.2 ratio # #
    ##############################################################
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=SPLIT_RATIO, random_state=SEED)

    ############################
    # # reshaping of dataset # #
    ############################

    # reshaping the dataset to include LSTM Timesteps
    print(X_train.dtype)
    X_train = np.asarray(X_train, dtype=np.float32)
    print(X_train.dtype)
    X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
    print(X_test.dtype)
    X_test = np.asarray(X_test, dtype=np.float32)
    print(X_test.dtype)
    X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

    print(f"X train shape: {X_train.shape}")
    print(f"Y train shape: {y_train.shape}")
    print(f"X test shape: {X_test.shape}")
    print(f"Y test shape: {y_test.shape}")
    
    return X_train, X_test, y_train, y_test

def reshape_dataset(X, TIMESTEPS):
    # reshaping the dataset to include LSTM Timesteps
    X = np.asarray(X, dtype=np.float32)
    X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))
    return X

# %% [markdown]
# #### LOAD DATASET

# %%
# load dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)
df.head()
# Out:
#   Subject Sequence    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    adhy    wench  0.152282 -0.073436   0.078847   0.088479   0.240761
# 1    adhy    wench  0.152282 -0.073436   0.078847   0.088479   0.240761
# 2    adhy    wench  0.152282 -0.073436   0.078847   0.088479   0.240761
# 3    adhy    wench  0.152282 -0.073436   0.078847   0.088479   0.240761
# 4    adhy    wench  0.152282 -0.073436   0.078847   0.088479   0.240761
#
#      T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T4-RF|VAR.1   T4-NG|VAR.1  T4-I|SD.1  \
# 0  0.161915   0.10287   0.264785  ...     0.010378  7.121751e-03   0.073101
# 1  0.161915   0.10287   0.264785  ...     0.027081  2.177609e-02   0.159465
# 2  0.161915   0.10287   0.264785  ...     0.000021  2.665160e-04   0.012384
# 3  0.161915   0.10287   0.264785  ...     0.018517  7.202189e-03   0.141381
# 4  0.161915   0.10287   0.264785  ...     0.000297  1.120000e-07   0.080601
#
#    T4-PF|SD.1  T4-RF|SD.1  T4-NG|SD.1  T5-I|0+4.1  T5-PF|0+4.1  T5-RF|0+4.1  \
# 0    0.055621    0.101870    0.084390    0.512567     0.624480     0.608445
# 1    0.142471    0.164562    0.147567    0.343992     0.488168     0.464252
# 2    0.000596    0.004537    0.016325    0.215807     0.368583     0.318909
# 3    0.090169    0.136078    0.084866    0.441357     0.512098     0.553000
# 4    0.063019    0.017246    0.000335    0.456564     0.592843     0.519370
#
#    T5-NG|0+4.1
# 0     0.720359
# 1     0.608427
# 2     0.471685
# 3     0.623741
# 4     0.655649
#
# [5 rows x 196 columns]

# %% [markdown]
# #### CHECK DATASET

# %%
########################
# # check for blanks # #
########################
if CHECK_BLANKS is True:
    # checking for blanks
    print("Checking for blanks...")
    if df.isnull().values.any() is True:
        df = df.dropna(axis=0, how="any")
        print("Blank rows has been dropped.")
    else:
        print("No blank value has been found.")
        
#################################
# # check for class imbalance # #
#################################
if CHECK_CLASS_IMBALANCE is True:
    print("Checking for class imbalance...")
    sns.countplot(x=CLASSES_COL_NAME, data=df).set_title("Class Imbalance")
#     df.loc[(df!=0).any(axis=1)]
    plt.show()

sns.catplot(x="Subject", y="T2-D|0", hue="T2-D|0", data=df, legend=False)
sns.catplot(x="Subject", y="T2-I|0+1", hue="T2-I|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-PF|0+1", hue="T2-PF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-RF|0+1", hue="T2-RF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-D|1", hue="T2-D|1", data=df, legend=False)
# Out:
# Checking for blanks...
# No blank value has been found.
# Checking for class imbalance...

# %% [markdown]
# #### PREPARE DATASET
# - Split data based on X / Features and Y / Classes
# - Binarize Y into binary labels

# %%
X, Y, lb, class_list = prepare_dataset(df)
n_classes = len(class_list)
print(f"Number of Classes: {n_classes}")
# Out:
# LabelBinarizer is able to decipher:
# ['adhy' 'andy' 'bryce' 'chris' 'cy' 'hr' 'jc' 'ys']
#
#
# X | Features | Dataset Shape: (79200, 193)
# Y | Classes  | Dataset Shape: (79200, 8)
# Number of Classes: 8

# %% [markdown]
# #### SPLIT DATASET
# - Split dataset into train set and test set 0.8 / 0.2

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED)
# Out:
# float64
# float32
# float64
# float32
# X train shape: (63360, 1, 193)
# Y train shape: (63360, 8)
# X test shape: (15840, 1, 193)
# Y test shape: (15840, 8)

# %% [markdown]
# #### PERFORM VALIDATION (w KFold Validation)
# - Evaluate best KFold Validation
# - Generate loss and accuracy graph
# - Perform KFold validation

# %% [markdown]
# ##### Evaluate suitable folds for kfold validation

# %%
###############################################
# # evaluate suitable kfold value for model # #
###############################################
def evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD):
    
    # evaluate the model    
    folds = range(MIN_KFOLD, MAX_KFOLD)
    means, mins, maxs = list(), list(), list()
    
    # evaluate each k value
    for k in folds:
        # define the test condition
        kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
        
        # evaluate k value
        model = create_model()
        scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
        k_mean = np.mean(scores)
        k_min = scores.min()
        k_max = scores.max()
        
        # report performance
        print(f"No. of Folds: {k} | Accuracy: {k_mean*100:.3f} | Min: {k_min*100:.3f} | Max: {k_max*100:.3f}")
        
        # store mean accuracy and min and max relative to the mean
        means.append(k_mean)
        mins.append(k_mean - k_min)
        maxs.append(k_max - k_mean)
        
    # line plot of k mean values with min/max error bars
    clear_output(wait=True)
    pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
    # show the plot
    pyplot.show()
    
if EVAL_KFOLD_NUM is True:
    evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD)
else:
    print("EVAL_KFOLD_NUM is not True")
# Out:
# EVAL_KFOLD_NUM is not True

# %% [markdown]
# ##### Generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=50, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print(f"Accuracy | Mean: {np.mean(scores)*100:.3f} | Std: {np.std(scores)*100:.3f} | Length/no.: {len(scores)}")
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    clear_output(wait=True)
    plt.show()
    
if EVAL_KFOLD_MODEL is True:
    evaluate_kfold_model(X_train, y_train, SEED)
else:
    print("EVAL_KFOLD_MODEL is not true")
# Out:
# EVAL_KFOLD_MODEL is not true

# %% [markdown]
# ##### Perform Actual KFold validation

# %%
if PERFORM_KFOLD is True:
    # create model
    model = create_model()
    kfold = KFold(n_splits=N_KFOLD, shuffle=True, random_state=SEED)
    valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# ##### Get Validation Accuracy

# %%
if PERFORM_KFOLD is True:
    print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# #### FIT MODEL FOR TESTING
# - Fit the Model
# - View Accuracy and Loss Graph
# - View Model Summary

# %%
#####################
# # fit the model # #
#####################

if TEST_MODEL is True:
    model = create_model()
    es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                       verbose=1)
    history = model.fit(X_train, y_train, callbacks=es, verbose=1)
# Out:
# There are a total of 8 classes.
# Epoch 1/200
# 634/634 [==============================] - 16s 15ms/step - loss: 1.6975 - accuracy: 0.3066
# Epoch 2/200
# 634/634 [==============================] - 9s 15ms/step - loss: 1.3198 - accuracy: 0.4779
# Epoch 3/200
# 634/634 [==============================] - 9s 15ms/step - loss: 1.2273 - accuracy: 0.5137
# Epoch 4/200
# 634/634 [==============================] - 9s 15ms/step - loss: 1.1820 - accuracy: 0.5298
# Epoch 5/200
# 634/634 [==============================] - 9s 15ms/step - loss: 1.1528 - accuracy: 0.5472
# Epoch 6/200
# 634/634 [==============================] - 9s 15ms/step - loss: 1.1220 - accuracy: 0.5573
# Epoch 7/200
# 634/634 [==============================] - 9s 15ms/step - loss: 1.0830 - accuracy: 0.5780
# Epoch 8/200
# 634/634 [==============================] - 9s 15ms/step - loss: 1.0407 - accuracy: 0.6164
# Epoch 9/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.9850 - accuracy: 0.6472
# Epoch 10/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.9416 - accuracy: 0.6628
# Epoch 11/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.9057 - accuracy: 0.6774
# Epoch 12/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.8735 - accuracy: 0.6913
# Epoch 13/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.8330 - accuracy: 0.7087
# Epoch 14/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.8071 - accuracy: 0.7174
# Epoch 15/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.7732 - accuracy: 0.7309
# Epoch 16/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.7411 - accuracy: 0.7410
# Epoch 17/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.7071 - accuracy: 0.7529
# Epoch 18/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.6767 - accuracy: 0.7625
# Epoch 19/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.6500 - accuracy: 0.7737
# Epoch 20/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.6177 - accuracy: 0.7851
# Epoch 21/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.5909 - accuracy: 0.7939
# Epoch 22/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.5738 - accuracy: 0.8012
# Epoch 23/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.5545 - accuracy: 0.8097
# Epoch 24/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.5227 - accuracy: 0.8188
# Epoch 25/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.5027 - accuracy: 0.8270
# Epoch 26/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.4881 - accuracy: 0.8325
# Epoch 27/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.4678 - accuracy: 0.8388
# Epoch 28/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.4419 - accuracy: 0.8484
# Epoch 29/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.4292 - accuracy: 0.8535
# Epoch 30/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.4071 - accuracy: 0.8609
# Epoch 31/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.3969 - accuracy: 0.8659
# Epoch 32/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.3778 - accuracy: 0.8716
# Epoch 33/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.3643 - accuracy: 0.8770
# Epoch 34/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.3502 - accuracy: 0.8824
# Epoch 35/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.3395 - accuracy: 0.8857
# Epoch 36/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.3237 - accuracy: 0.8912
# Epoch 37/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.3091 - accuracy: 0.8963
# Epoch 38/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.3013 - accuracy: 0.9003
# Epoch 39/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2953 - accuracy: 0.9027
# Epoch 40/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2812 - accuracy: 0.9069
# Epoch 41/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2685 - accuracy: 0.9096
# Epoch 42/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2611 - accuracy: 0.9142
# Epoch 43/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2481 - accuracy: 0.9185
# Epoch 44/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2451 - accuracy: 0.9186
# Epoch 45/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2447 - accuracy: 0.9191
# Epoch 46/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.2265 - accuracy: 0.9257
# Epoch 47/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2196 - accuracy: 0.9281
# Epoch 48/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2103 - accuracy: 0.9318
# Epoch 49/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2008 - accuracy: 0.9344
# Epoch 50/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2137 - accuracy: 0.9309
# Epoch 51/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1890 - accuracy: 0.9384
# Epoch 52/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.1957 - accuracy: 0.9357
# Epoch 53/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1926 - accuracy: 0.9370
# Epoch 54/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1797 - accuracy: 0.9405
# Epoch 55/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1740 - accuracy: 0.9433
# Epoch 56/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.1703 - accuracy: 0.9447
# Epoch 57/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1710 - accuracy: 0.9443
# Epoch 58/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1677 - accuracy: 0.9462
# Epoch 59/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1659 - accuracy: 0.9455
# Epoch 60/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1518 - accuracy: 0.9513
# Epoch 61/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1558 - accuracy: 0.9498
# Epoch 62/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1499 - accuracy: 0.9518
# Epoch 63/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1472 - accuracy: 0.9518
# Epoch 64/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1474 - accuracy: 0.9529
# Epoch 65/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1454 - accuracy: 0.9536
# Epoch 66/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1359 - accuracy: 0.9566
# Epoch 67/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1375 - accuracy: 0.9560
# Epoch 68/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1319 - accuracy: 0.9583
# Epoch 69/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1299 - accuracy: 0.9591
# Epoch 70/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1246 - accuracy: 0.9610
# Epoch 71/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1201 - accuracy: 0.9620
# Epoch 72/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1318 - accuracy: 0.9581
# Epoch 73/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1195 - accuracy: 0.9618
# Epoch 74/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1237 - accuracy: 0.9611
# Epoch 75/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1165 - accuracy: 0.9628
# Epoch 76/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1134 - accuracy: 0.9632
# Epoch 77/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.1098 - accuracy: 0.9655
# Epoch 78/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1173 - accuracy: 0.9634
# Epoch 79/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.1078 - accuracy: 0.9655
# Epoch 80/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1044 - accuracy: 0.9669
# Epoch 81/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1129 - accuracy: 0.9656
# Epoch 82/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1033 - accuracy: 0.9679
# Epoch 83/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1068 - accuracy: 0.9657
# Epoch 84/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0994 - accuracy: 0.9689
# Epoch 85/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.1037 - accuracy: 0.9681
# Epoch 86/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0959 - accuracy: 0.9697
# Epoch 87/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0954 - accuracy: 0.9702
# Epoch 88/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0992 - accuracy: 0.9688
# Epoch 89/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0931 - accuracy: 0.9714
# Epoch 90/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0945 - accuracy: 0.9706
# Epoch 91/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0912 - accuracy: 0.9721
# Epoch 92/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0854 - accuracy: 0.9735
# Epoch 93/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0907 - accuracy: 0.9724
# Epoch 94/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0941 - accuracy: 0.9703
# Epoch 95/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0851 - accuracy: 0.9747
# Epoch 96/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0851 - accuracy: 0.9743
# Epoch 97/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0913 - accuracy: 0.9714
# Epoch 98/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0855 - accuracy: 0.9734
# Epoch 99/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0828 - accuracy: 0.9743
# Epoch 100/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0786 - accuracy: 0.9752
# Epoch 101/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0819 - accuracy: 0.9745
# Epoch 102/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0792 - accuracy: 0.9757
# Epoch 103/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0849 - accuracy: 0.9738
# Epoch 104/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0801 - accuracy: 0.9750
# Epoch 105/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0783 - accuracy: 0.9751
# Epoch 106/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0867 - accuracy: 0.9730
# Epoch 107/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0741 - accuracy: 0.9775
# Epoch 108/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0728 - accuracy: 0.9776
# Epoch 109/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0805 - accuracy: 0.9753
# Epoch 110/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0743 - accuracy: 0.9769
# Epoch 111/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0740 - accuracy: 0.9771
# Epoch 112/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0714 - accuracy: 0.9778
# Epoch 113/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0742 - accuracy: 0.9773
# Epoch 114/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0714 - accuracy: 0.9777
# Epoch 115/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0753 - accuracy: 0.9774
# Epoch 116/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0695 - accuracy: 0.9793
# Epoch 117/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0685 - accuracy: 0.9791
# Epoch 118/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0680 - accuracy: 0.9793
# Epoch 119/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0656 - accuracy: 0.9802
# Epoch 120/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0650 - accuracy: 0.9803
# Epoch 121/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0632 - accuracy: 0.9802
# Epoch 122/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0713 - accuracy: 0.9779
# Epoch 123/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0635 - accuracy: 0.9807
# Epoch 124/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0668 - accuracy: 0.9798
# Epoch 125/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0583 - accuracy: 0.9821
# Epoch 126/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0672 - accuracy: 0.9796
# Epoch 127/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0653 - accuracy: 0.9796
# Epoch 128/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0571 - accuracy: 0.9830
# Epoch 129/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0668 - accuracy: 0.9794
# Epoch 130/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0616 - accuracy: 0.9811
# Epoch 131/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0562 - accuracy: 0.9828
# Epoch 132/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0612 - accuracy: 0.9821
# Epoch 133/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0617 - accuracy: 0.9809
# Epoch 134/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0623 - accuracy: 0.9815
# Epoch 135/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0550 - accuracy: 0.9834
# Epoch 136/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0600 - accuracy: 0.9822
# Epoch 137/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0546 - accuracy: 0.9830
# Epoch 138/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0618 - accuracy: 0.9814
# Epoch 139/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0530 - accuracy: 0.9840
# Epoch 140/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0577 - accuracy: 0.9823
# Epoch 141/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0559 - accuracy: 0.9830
# Epoch 142/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0580 - accuracy: 0.9822
# Epoch 143/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0547 - accuracy: 0.9831
# Epoch 144/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0516 - accuracy: 0.9840
# Epoch 145/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0557 - accuracy: 0.9832
# Epoch 146/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0570 - accuracy: 0.9832
# Epoch 147/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0501 - accuracy: 0.9849
# Epoch 148/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0570 - accuracy: 0.9827
# Epoch 149/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0561 - accuracy: 0.9833
# Epoch 150/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0513 - accuracy: 0.9847
# Epoch 151/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0574 - accuracy: 0.9827
# Epoch 152/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0485 - accuracy: 0.9856
# Epoch 153/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0472 - accuracy: 0.9853
# Epoch 154/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0548 - accuracy: 0.9828
# Epoch 155/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0476 - accuracy: 0.9852
# Epoch 156/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0489 - accuracy: 0.9853
# Epoch 157/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0503 - accuracy: 0.9853
# Epoch 158/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0552 - accuracy: 0.9839
# Epoch 159/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0478 - accuracy: 0.9855
# Epoch 160/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0468 - accuracy: 0.9864
# Epoch 161/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0520 - accuracy: 0.9843
# Epoch 162/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0441 - accuracy: 0.9865
# Epoch 163/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0512 - accuracy: 0.9847
# Epoch 164/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0492 - accuracy: 0.9852
# Epoch 165/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0462 - accuracy: 0.9864
# Epoch 166/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0479 - accuracy: 0.9853
# Epoch 167/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0473 - accuracy: 0.9858
# Epoch 168/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0478 - accuracy: 0.9855
# Epoch 169/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0486 - accuracy: 0.9855
# Epoch 170/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0421 - accuracy: 0.9875
# Epoch 171/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0499 - accuracy: 0.9850
# Epoch 172/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0428 - accuracy: 0.9877
# Epoch 173/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0462 - accuracy: 0.9865
# Epoch 174/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0460 - accuracy: 0.9867
# Epoch 175/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0439 - accuracy: 0.9875
# Epoch 176/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0475 - accuracy: 0.9857
# Epoch 177/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0456 - accuracy: 0.9864
# Epoch 178/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0473 - accuracy: 0.9864
# Epoch 179/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0490 - accuracy: 0.9859
# Epoch 180/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0436 - accuracy: 0.9876
# Epoch 181/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0417 - accuracy: 0.9873
# Epoch 182/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0434 - accuracy: 0.9870
# Epoch 183/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0444 - accuracy: 0.9866
# Epoch 184/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0451 - accuracy: 0.9871
# Epoch 185/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0430 - accuracy: 0.9870
# Epoch 186/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0422 - accuracy: 0.9877
# Epoch 187/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0475 - accuracy: 0.9865
# Epoch 188/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0406 - accuracy: 0.9880
# Epoch 189/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0464 - accuracy: 0.9863
# Epoch 190/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0367 - accuracy: 0.9892
# Epoch 191/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0395 - accuracy: 0.9877
# Epoch 192/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0413 - accuracy: 0.9875
# Epoch 193/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0410 - accuracy: 0.9879
# Epoch 194/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0381 - accuracy: 0.9886
# Epoch 195/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0472 - accuracy: 0.9860
# Epoch 196/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0381 - accuracy: 0.9887
# Epoch 197/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0446 - accuracy: 0.9869
# Epoch 198/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0445 - accuracy: 0.9875
# Epoch 199/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0347 - accuracy: 0.9901
# Epoch 200/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0393 - accuracy: 0.9884

# %%
if TEST_MODEL is True:
    ##########################
    # # get model accuracy # #
    ##########################
    plt.plot(history.history['accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

    ######################
    # # get model loss # #
    ######################
    plt.plot(history.history['loss'])
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

# %%
if TEST_MODEL is True:
    ##########################
    # # view model summary # #
    ##########################
    model.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 256)            460800
#
#  dense (Dense)               (None, 1, 256)            65792
#
#  dropout (Dropout)           (None, 1, 256)            0
#
#  batch_normalization (BatchN  (None, 1, 256)           1024
#  ormalization)
#
#  lstm_1 (LSTM)               (None, 1, 128)            197120
#
#  dense_1 (Dense)             (None, 1, 128)            16512
#
#  dropout_1 (Dropout)         (None, 1, 128)            0
#
#  batch_normalization_1 (Batc  (None, 1, 128)           512
#  hNormalization)
#
#  lstm_2 (LSTM)               (None, 1, 64)             49408
#
#  dense_2 (Dense)             (None, 1, 64)             4160
#
#  dropout_2 (Dropout)         (None, 1, 64)             0
#
#  batch_normalization_2 (Batc  (None, 1, 64)            256
#  hNormalization)
#
#  lstm_3 (LSTM)               (None, 1, 32)             12416
#
#  dense_3 (Dense)             (None, 1, 32)             1056
#
#  dropout_3 (Dropout)         (None, 1, 32)             0
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense_4 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 809,320
# Trainable params: 808,424
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# #### MODEL TESTING
# - Get Model Accuracy on the Test Dataset
# - Generate Confusion Matrix
# - Generate ROC Curves
# - Save the Model if Appropriate

# %%
if TEST_MODEL is True:
    y_pred = model.predict_proba(X_test)

    # evaluate predictions
    acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    print("Testing accuracy: %.3f%%" % (acc*100))
# Out:
# Testing accuracy: 94.173%

# %% [markdown]
# ##### Confusion Matrix

# %%
if TEST_MODEL is True and CON_MATRIX is True:
    # confusion matrix
    print(str(len(y_pred)) + " is the number of test value in kfold_val / train_test_split")
    cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                         columns = [i for i in np.unique(lb.inverse_transform(y_test))])

    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=True, cmap="BuPu")
# Out:
# 15840 is the number of test value in kfold_val / train_test_split

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
if TEST_MODEL is True and ROC_GRAPH is True: # compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    for i in range(n_classes):
        plt.figure()
        lw = 2
        plt.plot(
            fpr[i],
            tpr[i],
            color="darkorange",
            lw=lw,
            label="ROC curve (area = %0.2f)" % roc_auc[i],
        )
        plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
        plt.xlim([-0.005, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ##### ROC Curve (Multiclass)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    # compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # first aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    # plt.figure()
    # plt.plot(
    #     fpr["micro"],
    #     tpr["micro"],
    #     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    #     color="deeppink",
    #     linestyle=":",
    #     linewidth=4,
    # )

    # plt.plot(
    #     fpr["macro"],
    #     tpr["macro"],
    #     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    #     color="navy",
    #     linestyle=":",
    #     linewidth=4,
    # )

    colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
        )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Multiclass)")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Average)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

    # calculate equal-error-rate
    eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('Average ROC Curve')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #### FIT AND SAVE MODEL
# - Fitting of model
# - Get Accuracy and Loss of Mdoel
# - Saving Model

# %%
############################
# # reshaping of dataset # #
############################
# loading of dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)

df.head()
dataset = df.values

# divide data into features X and target (classes) Y
# convert target Y to labelbinarizer Y for model
X, Y, lb, class_list = prepare_dataset(df)

# reshaping the dataset to include LSTM Timesteps
X = reshape_dataset(X, TIMESTEPS)
n_classes = Y.shape[1]

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# LabelBinarizer is able to decipher:
# ['adhy' 'andy' 'bryce' 'chris' 'cy' 'hr' 'jc' 'ys']
#
#
# X | Features | Dataset Shape: (79200, 193)
# Y | Classes  | Dataset Shape: (79200, 8)
# There are a total of 8 classes.
# Epoch 1/200
# 792/792 [==============================] - 14s 12ms/step - loss: 1.6575 - accuracy: 0.3088
# Epoch 2/200
# 792/792 [==============================] - 10s 13ms/step - loss: 1.3141 - accuracy: 0.4694
# Epoch 3/200
# 792/792 [==============================] - 10s 13ms/step - loss: 1.1951 - accuracy: 0.5222
# Epoch 4/200
# 792/792 [==============================] - 10s 13ms/step - loss: 1.1490 - accuracy: 0.5369
# Epoch 5/200
# 792/792 [==============================] - 10s 13ms/step - loss: 1.1044 - accuracy: 0.5624
# Epoch 6/200
# 792/792 [==============================] - 10s 13ms/step - loss: 1.0405 - accuracy: 0.6151
# Epoch 7/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.9776 - accuracy: 0.6453
# Epoch 8/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.9155 - accuracy: 0.6707
# Epoch 9/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.8682 - accuracy: 0.6899
# Epoch 10/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.8171 - accuracy: 0.7103
# Epoch 11/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.7677 - accuracy: 0.7273
# Epoch 12/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.7251 - accuracy: 0.7438
# Epoch 13/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.6845 - accuracy: 0.7588
# Epoch 14/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.6480 - accuracy: 0.7721
# Epoch 15/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.6138 - accuracy: 0.7855
# Epoch 16/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.5843 - accuracy: 0.7956
# Epoch 17/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.5526 - accuracy: 0.8073
# Epoch 18/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.5208 - accuracy: 0.8201
# Epoch 19/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.4956 - accuracy: 0.8288
# Epoch 20/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.4708 - accuracy: 0.8386
# Epoch 21/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.4465 - accuracy: 0.8467
# Epoch 22/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.4225 - accuracy: 0.8564
# Epoch 23/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.3994 - accuracy: 0.8646
# Epoch 24/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.3765 - accuracy: 0.8720
# Epoch 25/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.3697 - accuracy: 0.8753
# Epoch 26/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.3460 - accuracy: 0.8841
# Epoch 27/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.3290 - accuracy: 0.8904
# Epoch 28/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.3118 - accuracy: 0.8949
# Epoch 29/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.3008 - accuracy: 0.9002
# Epoch 30/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.2853 - accuracy: 0.9040
# Epoch 31/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.2724 - accuracy: 0.9096
# Epoch 32/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.2661 - accuracy: 0.9109
# Epoch 33/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.2537 - accuracy: 0.9177
# Epoch 34/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.2441 - accuracy: 0.9203
# Epoch 35/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.2291 - accuracy: 0.9239
# Epoch 36/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.2192 - accuracy: 0.9285
# Epoch 37/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.2137 - accuracy: 0.9297
# Epoch 38/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.2075 - accuracy: 0.9321
# Epoch 39/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1968 - accuracy: 0.9350
# Epoch 40/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.1930 - accuracy: 0.9359
# Epoch 41/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1868 - accuracy: 0.9387
# Epoch 42/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1848 - accuracy: 0.9412
# Epoch 43/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1685 - accuracy: 0.9446
# Epoch 44/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1767 - accuracy: 0.9452
# Epoch 45/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1624 - accuracy: 0.9486
# Epoch 46/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1607 - accuracy: 0.9476
# Epoch 47/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1584 - accuracy: 0.9493
# Epoch 48/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1479 - accuracy: 0.9532
# Epoch 49/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1476 - accuracy: 0.9538
# Epoch 50/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1471 - accuracy: 0.9548
# Epoch 51/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.1365 - accuracy: 0.9566
# Epoch 52/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1380 - accuracy: 0.9566
# Epoch 53/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1336 - accuracy: 0.9586
# Epoch 54/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1295 - accuracy: 0.9585
# Epoch 55/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1271 - accuracy: 0.9602
# Epoch 56/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1231 - accuracy: 0.9610
# Epoch 57/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1178 - accuracy: 0.9625
# Epoch 58/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1160 - accuracy: 0.9640
# Epoch 59/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1124 - accuracy: 0.9648
# Epoch 60/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1102 - accuracy: 0.9662
# Epoch 61/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1132 - accuracy: 0.9644
# Epoch 62/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.1073 - accuracy: 0.9662
# Epoch 63/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.1040 - accuracy: 0.9674
# Epoch 64/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.1061 - accuracy: 0.9673
# Epoch 65/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0989 - accuracy: 0.9694
# Epoch 66/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0990 - accuracy: 0.9698
# Epoch 67/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.0997 - accuracy: 0.9694
# Epoch 68/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0936 - accuracy: 0.9709
# Epoch 69/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0932 - accuracy: 0.9721
# Epoch 70/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0982 - accuracy: 0.9696
# Epoch 71/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0924 - accuracy: 0.9718
# Epoch 72/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0878 - accuracy: 0.9721
# Epoch 73/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0866 - accuracy: 0.9731
# Epoch 74/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0846 - accuracy: 0.9739
# Epoch 75/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0875 - accuracy: 0.9734
# Epoch 76/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0845 - accuracy: 0.9742
# Epoch 77/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.0839 - accuracy: 0.9743
# Epoch 78/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.0771 - accuracy: 0.9761
# Epoch 79/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.0768 - accuracy: 0.9768
# Epoch 80/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0828 - accuracy: 0.9744
# Epoch 81/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0763 - accuracy: 0.9769
# Epoch 82/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0784 - accuracy: 0.9762
# Epoch 83/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0721 - accuracy: 0.9775
# Epoch 84/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0743 - accuracy: 0.9776
# Epoch 85/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0744 - accuracy: 0.9780
# Epoch 86/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0700 - accuracy: 0.9785
# Epoch 87/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0717 - accuracy: 0.9783
# Epoch 88/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0680 - accuracy: 0.9793
# Epoch 89/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0721 - accuracy: 0.9786
# Epoch 90/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0667 - accuracy: 0.9797
# Epoch 91/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0680 - accuracy: 0.9786
# Epoch 92/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0674 - accuracy: 0.9802
# Epoch 93/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0630 - accuracy: 0.9808
# Epoch 94/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0649 - accuracy: 0.9806
# Epoch 95/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0638 - accuracy: 0.9811
# Epoch 96/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0613 - accuracy: 0.9821
# Epoch 97/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0604 - accuracy: 0.9815
# Epoch 98/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0687 - accuracy: 0.9799
# Epoch 99/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.0579 - accuracy: 0.9829
# Epoch 100/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0571 - accuracy: 0.9826
# Epoch 101/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0581 - accuracy: 0.9826
# Epoch 102/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0559 - accuracy: 0.9829
# Epoch 103/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0613 - accuracy: 0.9820
# Epoch 104/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0518 - accuracy: 0.9846
# Epoch 105/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0550 - accuracy: 0.9834
# Epoch 106/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0594 - accuracy: 0.9818
# Epoch 107/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0561 - accuracy: 0.9833
# Epoch 108/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0490 - accuracy: 0.9849
# Epoch 109/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0486 - accuracy: 0.9860
# Epoch 110/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0518 - accuracy: 0.9845
# Epoch 111/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0500 - accuracy: 0.9851
# Epoch 112/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0527 - accuracy: 0.9843
# Epoch 113/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0482 - accuracy: 0.9857
# Epoch 114/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0483 - accuracy: 0.9852
# Epoch 115/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0484 - accuracy: 0.9857
# Epoch 116/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0503 - accuracy: 0.9854
# Epoch 117/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0473 - accuracy: 0.9856
# Epoch 118/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0476 - accuracy: 0.9861
# Epoch 119/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0492 - accuracy: 0.9856
# Epoch 120/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0463 - accuracy: 0.9863
# Epoch 121/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0435 - accuracy: 0.9870
# Epoch 122/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0506 - accuracy: 0.9848
# Epoch 123/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0437 - accuracy: 0.9872
# Epoch 124/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0403 - accuracy: 0.9878
# Epoch 125/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0488 - accuracy: 0.9854
# Epoch 126/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0430 - accuracy: 0.9870
# Epoch 127/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0379 - accuracy: 0.9885
# Epoch 128/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0451 - accuracy: 0.9871
# Epoch 129/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0409 - accuracy: 0.9881
# Epoch 130/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0376 - accuracy: 0.9891
# Epoch 131/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0420 - accuracy: 0.9879
# Epoch 132/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0401 - accuracy: 0.9886
# Epoch 133/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0397 - accuracy: 0.9879
# Epoch 134/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0421 - accuracy: 0.9876
# Epoch 135/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0368 - accuracy: 0.9892
# Epoch 136/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0374 - accuracy: 0.9890
# Epoch 137/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0426 - accuracy: 0.9876
# Epoch 138/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0363 - accuracy: 0.9890
# Epoch 139/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0339 - accuracy: 0.9902
# Epoch 140/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0359 - accuracy: 0.9895
# Epoch 141/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0379 - accuracy: 0.9896
# Epoch 142/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0357 - accuracy: 0.9894
# Epoch 143/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0397 - accuracy: 0.9884
# Epoch 144/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0433 - accuracy: 0.9875
# Epoch 145/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0323 - accuracy: 0.9910
# Epoch 146/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0316 - accuracy: 0.9908
# Epoch 147/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0363 - accuracy: 0.9900
# Epoch 148/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0353 - accuracy: 0.9899
# Epoch 149/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0318 - accuracy: 0.9911
# Epoch 150/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0352 - accuracy: 0.9908
# Epoch 151/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0318 - accuracy: 0.9912
# Epoch 152/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0310 - accuracy: 0.9912
# Epoch 153/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0314 - accuracy: 0.9913
# Epoch 154/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0269 - accuracy: 0.9917
# Epoch 155/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0299 - accuracy: 0.9910
# Epoch 156/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0326 - accuracy: 0.9906
# Epoch 157/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0251 - accuracy: 0.9929
# Epoch 158/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0264 - accuracy: 0.9925
# Epoch 159/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0298 - accuracy: 0.9915
# Epoch 160/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0265 - accuracy: 0.9922
# Epoch 161/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0294 - accuracy: 0.9913
# Epoch 162/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0293 - accuracy: 0.9916
# Epoch 163/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0281 - accuracy: 0.9922
# Epoch 164/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0265 - accuracy: 0.9925
# Epoch 165/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0267 - accuracy: 0.9922
# Epoch 166/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0240 - accuracy: 0.9933
# Epoch 167/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0284 - accuracy: 0.9922
# Epoch 168/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0239 - accuracy: 0.9929
# Epoch 169/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0284 - accuracy: 0.9919
# Epoch 170/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0226 - accuracy: 0.9937
# Epoch 171/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0259 - accuracy: 0.9926
# Epoch 172/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0230 - accuracy: 0.9937
# Epoch 173/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0253 - accuracy: 0.9929
# Epoch 174/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0263 - accuracy: 0.9925
# Epoch 175/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0201 - accuracy: 0.9944
# Epoch 176/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0254 - accuracy: 0.9923
# Epoch 177/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0249 - accuracy: 0.9928
# Epoch 178/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0276 - accuracy: 0.9924
# Epoch 179/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0233 - accuracy: 0.9935
# Epoch 180/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0200 - accuracy: 0.9944
# Epoch 181/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0233 - accuracy: 0.9934
# Epoch 182/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0269 - accuracy: 0.9928
# Epoch 183/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0207 - accuracy: 0.9940
# Epoch 184/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0213 - accuracy: 0.9938
# Epoch 185/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0192 - accuracy: 0.9947
# Epoch 186/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0212 - accuracy: 0.9939
# Epoch 187/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0202 - accuracy: 0.9942
# Epoch 188/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0221 - accuracy: 0.9938
# Epoch 189/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0190 - accuracy: 0.9947
# Epoch 190/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0229 - accuracy: 0.9940
# Epoch 191/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0180 - accuracy: 0.9949
# Epoch 192/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0168 - accuracy: 0.9954
# Epoch 193/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0250 - accuracy: 0.9935
# Epoch 194/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0213 - accuracy: 0.9938
# Epoch 195/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0216 - accuracy: 0.9940
# Epoch 196/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0159 - accuracy: 0.9954
# Epoch 197/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0193 - accuracy: 0.9945
# Epoch 198/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0163 - accuracy: 0.9952
# Epoch 199/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0190 - accuracy: 0.9948
# Epoch 200/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0207 - accuracy: 0.9942

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# #### SAVE MODEL

# %%
##################
# # save model # #
##################
model.model.save(MODEL_PATH)

# %% [markdown]
# # LIVE TESTING
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()
# Out:
#   Subject Sequence    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    adhy    quail  0.119654 -0.024004    0.09565   0.080376    0.20003
# 1    adhy    quail  0.119654 -0.024004    0.09565   0.080376    0.20003
# 2    adhy    quail  0.119654 -0.024004    0.09565   0.080376    0.20003
# 3    adhy    quail  0.119654 -0.024004    0.09565   0.080376    0.20003
# 4    adhy    quail  0.119654 -0.024004    0.09565   0.080376    0.20003
#
#     T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T4-RF|VAR.1  T4-NG|VAR.1  T4-I|SD.1  \
# 0  0.10438  0.304264   0.408644  ...     0.080180     0.097463   0.271303
# 1  0.10438  0.304264   0.408644  ...     0.000036     0.000034   0.034878
# 2  0.10438  0.304264   0.408644  ...     0.009373     0.006345   0.113785
# 3  0.10438  0.304264   0.408644  ...     0.012563     0.010132   0.061637
# 4  0.10438  0.304264   0.408644  ...     0.009327     0.004563   0.079918
#
#    T4-PF|SD.1  T4-RF|SD.1  T4-NG|SD.1  T5-I|0+4.1  T5-PF|0+4.1  T5-RF|0+4.1  \
# 0    0.300333    0.283161    0.312191    0.616362     0.769361     0.736033
# 1    0.034673    0.005993    0.005788    0.344067     0.456247     0.416209
# 2    0.096630    0.096813    0.079658    1.008275     1.128276     1.128039
# 3    0.050211    0.112083    0.100657    0.375933     0.487393     0.439950
# 4    0.050886    0.096579    0.067547    0.423579     0.575900     0.535566
#
#    T5-NG|0+4.1
# 0     0.889032
# 1     0.528389
# 2     1.248040
# 3     0.551410
# 4     0.687887
#
# [5 rows x 196 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
actual_np = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

########################
# # predict all rows # #
########################
pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[46:54,FEATURES_COL_NUM:]
# print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

print(class_list)
Y = np.asarray(class_list)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)
# Out:
# ['adhy', 'andy', 'bryce', 'chris', 'cy', 'hr', 'jc', 'ys']

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

# pred_proba = np.sum(pred_proba, axis=0)
# pred_proba = np.reshape(pred_proba, (1, 9))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

match_list = []

for _ in range(actual_np.size):
    if pred[_] == actual_np[_]:
        match_list.append("match")
    else:
        match_list.append("nope")

match_count = match_list.count("match")
total_count = len(match_list)

match_header = str(match_count) + "/" + str(total_count) + " (" + str(match_count/total_count*100)+ "%)"
match_np = np.array(match_list)

exported_output = np.column_stack((actual_np, pred))
exported_output = np.column_stack((exported_output, acc))
exported_output = np.column_stack((exported_output, match_np))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(data=exported_output, index=None, columns=['Actual', 'Prediction', 'Accuracy', match_header])
# print(df)
df.to_csv(RESULT_PATH)

print("Accuracy of the Model is: " + str(match_header))
# Out:
# Accuracy of the Model is: 380/720 (52.77777777777778%)
