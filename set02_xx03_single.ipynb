# %% [markdown]
# #### IMPORT

# %%
import os, platform
import py7zr

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %% [markdown]
# #### PARAMETERS
# - Set the condition
# > * N_FEATURES: Number of Features
# > * CHECK_BLANKS: Check for blank data. If any blank data is found, the whole row of data will be deleted.
# > * CHECK_CLASS_IMBALANCE: Check for dataset class imbalance. The more balance the dataset, the less biases the model will be.

# %%
##############################
# # deep learning features # #
##############################
SEED = 1005 # random seed for reproducibility

# should make this dynamic
N_FEATURES = 6
TIMESTEPS = 1
EPOCH=200
BATCH_SIZE=100

SPLIT_RATIO=0.2

###############
# # preview # #
###############
f = False
t = True

# checking dataset
CHECK_BLANKS = True
CHECK_CLASS_IMBALANCE = True

# evaluate suitable kfold number and kfold model
MIN_KFOLD = 2
MAX_KFOLD = 11
N_KFOLD = 5
EVAL_KFOLD_NUM = False
EVAL_KFOLD_MODEL = False
PERFORM_KFOLD = True

# model testing
TEST_MODEL = True
CON_MATRIX = True
ROC_GRAPH = True

###############
# # dataset # #
###############
CLASSES_COL_NAME = "Subject"
CLASSES_COL_NUM = 0
FEATURES_COL_NUM = 6

METHOD = "IU"
METHOD = "DU"

DATASET_DIR_NAME = "dataset\set02\\10_single"
SAMPLE_DATASET_NAME = "single_train"
ACTUAL_DATASET_NAME = "single_test_" + METHOD

MODEL_DIR_NAME = "dataset\set02\\10_single"
MODEL_NAME = "model_" + "set02_10_class" + METHOD

RESULT_DIR_NAME = "dataset\set02\\10_single"
RESULT_NAME = "result_" + "set02_10_single" + METHOD

DATASET_DIR_PATH = os.path.join(os.getcwd(), DATASET_DIR_NAME)
SAMPLE_DATASET_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".csv")
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME + ".csv")

MODEL_DIR_PATH = os.path.join(os.getcwd(), MODEL_DIR_NAME)
MODEL_PATH = os.path.join(MODEL_DIR_PATH, MODEL_NAME + ".h5")

RESULT_DIR_PATH = os.path.join(os.getcwd(), RESULT_DIR_NAME)
RESULT_PATH = os.path.join(RESULT_DIR_PATH, RESULT_NAME + ".csv")

#################
# # sns theme # #
#################
# sns.set_theme(style="darkgrid") # (dark background with white gridlines)
sns.set_theme(style="whitegrid") # (white background with grey gridlines)
# sns.set_theme(style="dark") # (dark background with no gridlines)
# sns.set_theme(style="white") # (white background with no gridlines)
# sns.set_theme(style="ticks") # (white background with axis ticks and no gridlines)

# %%
if os.path.isdir(DATASET_DIR_PATH) is True:
    print(f"Dataset directory exists at: {DATASET_DIR_PATH}")
else:
    try:
        os.mkdir(DATASET_DIR_PATH, 666)
        print(f"Dataset directory have been created at: {DATASET_DIR_PATH}")
    except:
        print("Error: Dataset Directory not created")
        
if os.path.isdir(MODEL_DIR_PATH) is True:
    print(f"Model directory exists at: {MODEL_DIR_PATH}")
else:
    try:
        os.mkdir(MODEL_DIR_PATH, 666)
        print(f"Model directory have been created at: {MODEL_DIR_PATH}")
    except:
        print("Error: Model Directory not created")
    
if os.path.exists(SAMPLE_DATASET_PATH) is True:
    print(f"Training dataset exists at: {SAMPLE_DATASET_PATH}")
else:
    try:
        SAMPLE_7Z_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".7z")
        with py7zr.SevenZipFile(SAMPLE_7Z_PATH, mode='r') as z:
            z.extractall(path=DATASET_DIR_PATH)
        print(f"Decompress 7z file to: {SAMPLE_7Z_PATH}")
    except:
        print("Error: Failed to decompress 7z file.")
# Out:
# Dataset directory exists at: C:\Users\andy\Documents\Github\ict4001-cap\dataset\set02\10_single
# Model directory exists at: C:\Users\andy\Documents\Github\ict4001-cap\dataset\set02\10_single
# Training dataset exists at: C:\Users\andy\Documents\Github\ict4001-cap\dataset\set02\10_single\single_train.csv

# %% [markdown]
# #### CREATE MODEL
# - Create base model
# - Wrap it with KerasClassifier

# %%
#create base model
def create_base_model():
    model = Sequential()
    model.add(LSTM(units=256, return_sequences=True,
             input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dense(256, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=32, return_sequences=True))
    model.add(Dense(32, activation='sigmoid'))
    model.add(Dropout(0.2))

    # softmax for multi-class classification
    model.add(Flatten())
    print("There are a total of " + str(n_classes) + " classes.")
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=EPOCH, 
                            batch_size=BATCH_SIZE)
    return model

# %%
# divide data into features X and target (classes) Y
def prepare_dataset(df):
    X = df.values[:,FEATURES_COL_NUM:].astype(float)
    Y = df.values[:,CLASSES_COL_NUM].astype(str)

    # convert target Y to labelbinarizer Y for model
    # fit_transform is not used to reuse lb
    Y = Y.reshape(-1, 1)
    lb = LabelBinarizer().fit(Y)
    Y = lb.transform(Y)

    #################################
    # # get all the encoded class # #
    #################################
    print("LabelBinarizer is able to decipher: ")
    print(lb.classes_)
    print("\n")

    ###########################
    # # print X and Y shape # #
    ###########################
    print(f"X | Features | Dataset Shape: {X.shape}")
    print(f"Y | Classes  | Dataset Shape: {Y.shape}")

    return X, Y, lb, lb.classes_.tolist()

# %%
def split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED):

    ##############################################################
    # # split dataset into train and test set of 0.8/0.2 ratio # #
    ##############################################################
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=SPLIT_RATIO, random_state=SEED)

    ############################
    # # reshaping of dataset # #
    ############################

    # reshaping the dataset to include LSTM Timesteps
    print(X_train.dtype)
    X_train = np.asarray(X_train, dtype=np.float32)
    print(X_train.dtype)
    X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
    print(X_test.dtype)
    X_test = np.asarray(X_test, dtype=np.float32)
    print(X_test.dtype)
    X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

    print(f"X train shape: {X_train.shape}")
    print(f"Y train shape: {y_train.shape}")
    print(f"X test shape: {X_test.shape}")
    print(f"Y test shape: {y_test.shape}")
    
    return X_train, X_test, y_train, y_test

def reshape_dataset(X, TIMESTEPS):
    # reshaping the dataset to include LSTM Timesteps
    X = np.asarray(X, dtype=np.float32)
    X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))
    return X

# %% [markdown]
# #### LOAD DATASET

# %%
# load dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)
df.head()
# Out:
#   Subject Char_Total_Str Char_Total_Int  Char_Init  Char_End  Class  \
# 0    adhy            o_h           15_8         15         8      3
# 1    adhy            h_m           8_13          8        13      3
# 2    adhy            m_~           13_0         13         0      3
# 3    adhy            ~_f            0_6          0         6      3
# 4    adhy            f_i            6_9          6         9      3
#
#    Current_Dwell  Interval  Press_Flight  Release_Flight   Digraph  \
# 0       0.154125  0.093798      0.247924        0.232284  0.386410
# 1       0.138486  0.300717      0.439203        0.485731  0.624217
# 2       0.185014 -0.037734      0.147280        0.115650  0.300664
# 3       0.153384  0.046875      0.200259        0.247607  0.400991
# 4       0.200732 -0.115928      0.084804        0.021764  0.222496
#
#    Later_Dwell
# 0     0.138486
# 1     0.185014
# 2     0.153384
# 3     0.200732
# 4     0.137691

# %% [markdown]
# #### CHECK DATASET

# %%
########################
# # check for blanks # #
########################
if CHECK_BLANKS is True:
    # checking for blanks
    print("Checking for blanks...")
    if df.isnull().values.any() is True:
        df = df.dropna(axis=0, how="any")
        print("Blank rows has been dropped.")
    else:
        print("No blank value has been found.")
        
#################################
# # check for class imbalance # #
#################################
if CHECK_CLASS_IMBALANCE is True:
    print("Checking for class imbalance...")
    sns.countplot(x=CLASSES_COL_NAME, data=df).set_title("Class Imbalance")
#     df.loc[(df!=0).any(axis=1)]
    plt.show()

sns.catplot(x="Subject", y="Current_Dwell", hue="Current_Dwell", data=df, legend=False)
sns.catplot(x="Subject", y="Interval", hue="Interval", data=df, legend=False)
sns.catplot(x="Subject", y="Press_Flight", hue="Press_Flight", data=df, legend=False)
sns.catplot(x="Subject", y="Release_Flight", hue="Release_Flight", data=df, legend=False)
sns.catplot(x="Subject", y="Digraph", hue="Digraph", data=df, legend=False)
sns.catplot(x="Subject", y="Later_Dwell", hue="Later_Dwell", data=df, legend=False)
# Out:
# Checking for blanks...
# No blank value has been found.
# Checking for class imbalance...

# %% [markdown]
# #### PREPARE DATASET
# - Split data based on X / Features and Y / Classes
# - Binarize Y into binary labels

# %%
X, Y, lb, class_list = prepare_dataset(df)
n_classes = len(class_list)
print(f"Number of Classes: {n_classes}")
# Out:
# LabelBinarizer is able to decipher:
# ['adhy' 'alan' 'andy' 'bryce' 'chris' 'cy' 'gerald' 'jc' 'jonah' 'qk']
#
#
# X | Features | Dataset Shape: (8280, 6)
# Y | Classes  | Dataset Shape: (8280, 10)
# Number of Classes: 10

# %% [markdown]
# #### SPLIT DATASET
# - Split dataset into train set and test set 0.8 / 0.2

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED)
# Out:
# float64
# float32
# float64
# float32
# X train shape: (6624, 1, 6)
# Y train shape: (6624, 10)
# X test shape: (1656, 1, 6)
# Y test shape: (1656, 10)

# %% [markdown]
# #### PERFORM VALIDATION (w KFold Validation)
# - Evaluate best KFold Validation
# - Generate loss and accuracy graph
# - Perform KFold validation

# %% [markdown]
# ##### Evaluate suitable folds for kfold validation

# %%
###############################################
# # evaluate suitable kfold value for model # #
###############################################
def evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD):
    
    # evaluate the model    
    folds = range(MIN_KFOLD, MAX_KFOLD)
    means, mins, maxs = list(), list(), list()
    
    # evaluate each k value
    for k in folds:
        # define the test condition
        kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
        
        # evaluate k value
        model = create_model()
        scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
        k_mean = np.mean(scores)
        k_min = scores.min()
        k_max = scores.max()
        
        # report performance
        print(f"No. of Folds: {k} | Accuracy: {k_mean*100:.3f} | Min: {k_min*100:.3f} | Max: {k_max*100:.3f}")
        
        # store mean accuracy and min and max relative to the mean
        means.append(k_mean)
        mins.append(k_mean - k_min)
        maxs.append(k_max - k_mean)
        
    # line plot of k mean values with min/max error bars
    clear_output(wait=True)
    pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
    # show the plot
    pyplot.show()
    
if EVAL_KFOLD_NUM is True:
    evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD)
else:
    print("EVAL_KFOLD_NUM is not True")
# Out:
# EVAL_KFOLD_NUM is not True

# %% [markdown]
# ##### Generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=50, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print(f"Accuracy | Mean: {np.mean(scores)*100:.3f} | Std: {np.std(scores)*100:.3f} | Length/no.: {len(scores)}")
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    clear_output(wait=True)
    plt.show()
    
if EVAL_KFOLD_MODEL is True:
    evaluate_kfold_model(X_train, y_train, SEED)
else:
    print("EVAL_KFOLD_MODEL is not true")
# Out:
# EVAL_KFOLD_MODEL is not true

# %% [markdown]
# ##### Perform Actual KFold validation

# %%
if PERFORM_KFOLD is True:
    # create model
    model = create_model()
    kfold = KFold(n_splits=N_KFOLD, shuffle=True, random_state=SEED)
    valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# There are a total of 10 classes.
# Epoch 1/200
# 53/53 [==============================] - 14s 31ms/step - loss: 2.4173 - accuracy: 0.1015
# Epoch 2/200
# 53/53 [==============================] - 2s 31ms/step - loss: 2.3439 - accuracy: 0.1032
# Epoch 3/200
# 53/53 [==============================] - 2s 31ms/step - loss: 2.3371 - accuracy: 0.0993
# Epoch 4/200
# 53/53 [==============================] - 2s 33ms/step - loss: 2.3341 - accuracy: 0.1038
# Epoch 5/200
# 53/53 [==============================] - 2s 34ms/step - loss: 2.3341 - accuracy: 0.1047
# Epoch 6/200
# 53/53 [==============================] - 2s 37ms/step - loss: 2.3353 - accuracy: 0.0985
# Epoch 7/200
# 53/53 [==============================] - 2s 35ms/step - loss: 2.2884 - accuracy: 0.1244
# Epoch 8/200
# 53/53 [==============================] - 2s 34ms/step - loss: 2.1675 - accuracy: 0.1831
# Epoch 9/200
# 53/53 [==============================] - 2s 34ms/step - loss: 2.0890 - accuracy: 0.1900
# Epoch 10/200
# 53/53 [==============================] - 2s 35ms/step - loss: 2.0440 - accuracy: 0.1961
# Epoch 11/200
# 53/53 [==============================] - 2s 32ms/step - loss: 2.0184 - accuracy: 0.2123
# Epoch 12/200
# 53/53 [==============================] - 2s 30ms/step - loss: 1.9948 - accuracy: 0.2193
# Epoch 13/200
# 53/53 [==============================] - 2s 33ms/step - loss: 2.0001 - accuracy: 0.2172
# Epoch 14/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.9803 - accuracy: 0.2210
# Epoch 15/200
# 53/53 [==============================] - 2s 46ms/step - loss: 1.9808 - accuracy: 0.2199
# Epoch 16/200
# 53/53 [==============================] - 2s 38ms/step - loss: 1.9673 - accuracy: 0.2253
# Epoch 17/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.9585 - accuracy: 0.2314
# Epoch 18/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9623 - accuracy: 0.2251
# Epoch 19/200
# 53/53 [==============================] - 2s 37ms/step - loss: 1.9549 - accuracy: 0.2265
# Epoch 20/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.9517 - accuracy: 0.2278
# Epoch 21/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.9521 - accuracy: 0.2327
# Epoch 22/200
# 53/53 [==============================] - 3s 47ms/step - loss: 1.9530 - accuracy: 0.2393
# Epoch 23/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9418 - accuracy: 0.2344
# Epoch 24/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9410 - accuracy: 0.2385
# Epoch 25/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9295 - accuracy: 0.2351
# Epoch 26/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9389 - accuracy: 0.2408
# Epoch 27/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9397 - accuracy: 0.2474
# Epoch 28/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9324 - accuracy: 0.2504
# Epoch 29/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9343 - accuracy: 0.2378
# Epoch 30/200
# 53/53 [==============================] - 2s 47ms/step - loss: 1.9258 - accuracy: 0.2444
# Epoch 31/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.9281 - accuracy: 0.2436
# Epoch 32/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.9325 - accuracy: 0.2380
# Epoch 33/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9186 - accuracy: 0.2491
# Epoch 34/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9261 - accuracy: 0.2485
# Epoch 35/200
# 53/53 [==============================] - 2s 40ms/step - loss: 1.9215 - accuracy: 0.2504
# Epoch 36/200
# 53/53 [==============================] - 2s 45ms/step - loss: 1.9227 - accuracy: 0.2493
# Epoch 37/200
# 53/53 [==============================] - 2s 35ms/step - loss: 1.9287 - accuracy: 0.2508
# Epoch 38/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9220 - accuracy: 0.2570
# Epoch 39/200
# 53/53 [==============================] - 2s 46ms/step - loss: 1.9110 - accuracy: 0.2533
# Epoch 40/200
# 53/53 [==============================] - 2s 46ms/step - loss: 1.9215 - accuracy: 0.2451
# Epoch 41/200
# 53/53 [==============================] - 2s 43ms/step - loss: 1.9184 - accuracy: 0.2516
# Epoch 42/200
# 53/53 [==============================] - 2s 42ms/step - loss: 1.9169 - accuracy: 0.2538
# Epoch 43/200
# 53/53 [==============================] - 2s 38ms/step - loss: 1.9203 - accuracy: 0.2497
# Epoch 44/200
# 53/53 [==============================] - 2s 39ms/step - loss: 1.9176 - accuracy: 0.2534
# Epoch 45/200
# 53/53 [==============================] - 2s 37ms/step - loss: 1.9249 - accuracy: 0.2470
# Epoch 46/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.9195 - accuracy: 0.2478
# Epoch 47/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9112 - accuracy: 0.2606
# Epoch 48/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9165 - accuracy: 0.2508
# Epoch 49/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9150 - accuracy: 0.2544
# Epoch 50/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9117 - accuracy: 0.2567
# Epoch 51/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9121 - accuracy: 0.2546
# Epoch 52/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9014 - accuracy: 0.2648
# Epoch 53/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9141 - accuracy: 0.2582
# Epoch 54/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9132 - accuracy: 0.2542
# Epoch 55/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9055 - accuracy: 0.2544
# Epoch 56/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9094 - accuracy: 0.2580
# Epoch 57/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9135 - accuracy: 0.2591
# Epoch 58/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9045 - accuracy: 0.2538
# Epoch 59/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9103 - accuracy: 0.2574
# Epoch 60/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9041 - accuracy: 0.2623
# Epoch 61/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8986 - accuracy: 0.2631
# Epoch 62/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9036 - accuracy: 0.2614
# Epoch 63/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8984 - accuracy: 0.2719
# Epoch 64/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9043 - accuracy: 0.2580
# Epoch 65/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9052 - accuracy: 0.2648
# Epoch 66/200
# 53/53 [==============================] - 2s 37ms/step - loss: 1.8995 - accuracy: 0.2682
# Epoch 67/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9047 - accuracy: 0.2670
# Epoch 68/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8943 - accuracy: 0.2801
# Epoch 69/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8959 - accuracy: 0.2736
# Epoch 70/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8969 - accuracy: 0.2668
# Epoch 71/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8945 - accuracy: 0.2699
# Epoch 72/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8971 - accuracy: 0.2676
# Epoch 73/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9005 - accuracy: 0.2663
# Epoch 74/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8908 - accuracy: 0.2697
# Epoch 75/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8984 - accuracy: 0.2636
# Epoch 76/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8978 - accuracy: 0.2638
# Epoch 77/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8946 - accuracy: 0.2644
# Epoch 78/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.8988 - accuracy: 0.2710
# Epoch 79/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8915 - accuracy: 0.2699
# Epoch 80/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8985 - accuracy: 0.2714
# Epoch 81/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8933 - accuracy: 0.2670
# Epoch 82/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8981 - accuracy: 0.2714
# Epoch 83/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8922 - accuracy: 0.2721
# Epoch 84/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8951 - accuracy: 0.2678
# Epoch 85/200
# 53/53 [==============================] - 2s 30ms/step - loss: 1.8950 - accuracy: 0.2712
# Epoch 86/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8868 - accuracy: 0.2729
# Epoch 87/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.9038 - accuracy: 0.2733
# Epoch 88/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8849 - accuracy: 0.2787
# Epoch 89/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8859 - accuracy: 0.2721
# Epoch 90/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8887 - accuracy: 0.2712
# Epoch 91/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8949 - accuracy: 0.2740
# Epoch 92/200
# 53/53 [==============================] - 2s 30ms/step - loss: 1.8965 - accuracy: 0.2680
# Epoch 93/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8949 - accuracy: 0.2672
# Epoch 94/200
# 53/53 [==============================] - 2s 30ms/step - loss: 1.8918 - accuracy: 0.2721
# Epoch 95/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8961 - accuracy: 0.2733
# Epoch 96/200
# 53/53 [==============================] - 2s 39ms/step - loss: 1.8894 - accuracy: 0.2746
# Epoch 97/200
# 53/53 [==============================] - 2s 37ms/step - loss: 1.8873 - accuracy: 0.2734
# Epoch 98/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8902 - accuracy: 0.2699
# Epoch 99/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8804 - accuracy: 0.2746
# Epoch 100/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8816 - accuracy: 0.2761
# Epoch 101/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8820 - accuracy: 0.2791
# Epoch 102/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8804 - accuracy: 0.2780
# Epoch 103/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8894 - accuracy: 0.2757
# Epoch 104/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8859 - accuracy: 0.2816
# Epoch 105/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8810 - accuracy: 0.2761
# Epoch 106/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8852 - accuracy: 0.2804
# Epoch 107/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8798 - accuracy: 0.2744
# Epoch 108/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8914 - accuracy: 0.2836
# Epoch 109/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8773 - accuracy: 0.2827
# Epoch 110/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8853 - accuracy: 0.2804
# Epoch 111/200
# 53/53 [==============================] - 2s 35ms/step - loss: 1.8758 - accuracy: 0.2804
# Epoch 112/200
# 53/53 [==============================] - 2s 41ms/step - loss: 1.8721 - accuracy: 0.2872
# Epoch 113/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8711 - accuracy: 0.2889
# Epoch 114/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8760 - accuracy: 0.2897
# Epoch 115/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8685 - accuracy: 0.2865
# Epoch 116/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.8706 - accuracy: 0.2844
# Epoch 117/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8654 - accuracy: 0.2833
# Epoch 118/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8721 - accuracy: 0.2868
# Epoch 119/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8729 - accuracy: 0.2846
# Epoch 120/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8682 - accuracy: 0.2840
# Epoch 121/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8693 - accuracy: 0.2895
# Epoch 122/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8667 - accuracy: 0.2859
# Epoch 123/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8752 - accuracy: 0.2878
# Epoch 124/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8687 - accuracy: 0.2908
# Epoch 125/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8702 - accuracy: 0.2859
# Epoch 126/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8658 - accuracy: 0.2895
# Epoch 127/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8712 - accuracy: 0.2816
# Epoch 128/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.8680 - accuracy: 0.2895
# Epoch 129/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8676 - accuracy: 0.2865
# Epoch 130/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8625 - accuracy: 0.2859
# Epoch 131/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8659 - accuracy: 0.2942
# Epoch 132/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.8624 - accuracy: 0.2899
# Epoch 133/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8702 - accuracy: 0.2914
# Epoch 134/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8666 - accuracy: 0.2908
# Epoch 135/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8591 - accuracy: 0.2851
# Epoch 136/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8657 - accuracy: 0.2952
# Epoch 137/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8606 - accuracy: 0.2812
# Epoch 138/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8592 - accuracy: 0.2870
# Epoch 139/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8639 - accuracy: 0.2884
# Epoch 140/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.8615 - accuracy: 0.2880
# Epoch 141/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.8595 - accuracy: 0.2940
# Epoch 142/200
# 53/53 [==============================] - 2s 35ms/step - loss: 1.8571 - accuracy: 0.2968
# Epoch 143/200
# 53/53 [==============================] - 2s 35ms/step - loss: 1.8609 - accuracy: 0.2942
# Epoch 144/200
# 53/53 [==============================] - 2s 43ms/step - loss: 1.8623 - accuracy: 0.2893
# Epoch 145/200
# 53/53 [==============================] - 2s 38ms/step - loss: 1.8615 - accuracy: 0.2889
# Epoch 146/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8533 - accuracy: 0.2948
# Epoch 147/200
# 53/53 [==============================] - 2s 35ms/step - loss: 1.8543 - accuracy: 0.2899
# Epoch 148/200
# 53/53 [==============================] - 2s 43ms/step - loss: 1.8572 - accuracy: 0.2955
# Epoch 149/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8630 - accuracy: 0.2882
# Epoch 150/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8563 - accuracy: 0.2916
# Epoch 151/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8609 - accuracy: 0.2884
# Epoch 152/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8557 - accuracy: 0.2976
# Epoch 153/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8507 - accuracy: 0.2927
# Epoch 154/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8560 - accuracy: 0.2923
# Epoch 155/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8459 - accuracy: 0.2950
# Epoch 156/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8493 - accuracy: 0.2927
# Epoch 157/200
# 53/53 [==============================] - 2s 37ms/step - loss: 1.8519 - accuracy: 0.2984
# Epoch 158/200
# 53/53 [==============================] - 2s 35ms/step - loss: 1.8543 - accuracy: 0.2897
# Epoch 159/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8474 - accuracy: 0.2893
# Epoch 160/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8499 - accuracy: 0.3001
# Epoch 161/200
# 53/53 [==============================] - 2s 30ms/step - loss: 1.8486 - accuracy: 0.2902
# Epoch 162/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.8425 - accuracy: 0.2910
# Epoch 163/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.8523 - accuracy: 0.2887
# Epoch 164/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.8509 - accuracy: 0.2902
# Epoch 165/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.8474 - accuracy: 0.2929
# Epoch 166/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.8494 - accuracy: 0.2976
# Epoch 167/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.8506 - accuracy: 0.2952
# Epoch 168/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.8474 - accuracy: 0.2972
# Epoch 169/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8500 - accuracy: 0.2959
# Epoch 170/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8484 - accuracy: 0.2952
# Epoch 171/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8480 - accuracy: 0.2940
# Epoch 172/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8438 - accuracy: 0.2968
# Epoch 173/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8461 - accuracy: 0.2927
# Epoch 174/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8510 - accuracy: 0.2895
# Epoch 175/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8483 - accuracy: 0.2955
# Epoch 176/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8446 - accuracy: 0.2935
# Epoch 177/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8435 - accuracy: 0.2978
# Epoch 178/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8486 - accuracy: 0.2891
# Epoch 179/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8481 - accuracy: 0.2948
# Epoch 180/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8476 - accuracy: 0.2944
# Epoch 181/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8360 - accuracy: 0.3025
# Epoch 182/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8395 - accuracy: 0.2963
# Epoch 183/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8444 - accuracy: 0.2955
# Epoch 184/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8413 - accuracy: 0.2957
# Epoch 185/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8400 - accuracy: 0.2942
# Epoch 186/200
# 53/53 [==============================] - 2s 35ms/step - loss: 1.8458 - accuracy: 0.2957
# Epoch 187/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8426 - accuracy: 0.2963
# Epoch 188/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8432 - accuracy: 0.2921
# Epoch 189/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8463 - accuracy: 0.2938
# Epoch 190/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8444 - accuracy: 0.2952
# Epoch 191/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8343 - accuracy: 0.2997
# Epoch 192/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8361 - accuracy: 0.2989
# Epoch 193/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8357 - accuracy: 0.2987
# Epoch 194/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8386 - accuracy: 0.2936
# Epoch 195/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8367 - accuracy: 0.3033
# Epoch 196/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8434 - accuracy: 0.3001
# Epoch 197/200
# 53/53 [==============================] - 2s 31ms/step - loss: 1.8377 - accuracy: 0.2918
# Epoch 198/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.8385 - accuracy: 0.3029
# Epoch 199/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.8429 - accuracy: 0.3023
# Epoch 200/200
# 53/53 [==============================] - 2s 37ms/step - loss: 1.8450 - accuracy: 0.2965
# 14/14 [==============================] - 4s 15ms/step - loss: 1.8196 - accuracy: 0.3004
# There are a total of 10 classes.
# Epoch 1/200
# 53/53 [==============================] - 14s 33ms/step - loss: 2.4120 - accuracy: 0.0979
# Epoch 2/200
# 53/53 [==============================] - 2s 38ms/step - loss: 2.3451 - accuracy: 0.0976
# Epoch 3/200
# 53/53 [==============================] - 2s 33ms/step - loss: 2.3400 - accuracy: 0.0981
# Epoch 4/200
# 53/53 [==============================] - 2s 34ms/step - loss: 2.3365 - accuracy: 0.1045
# Epoch 5/200
# 53/53 [==============================] - 2s 34ms/step - loss: 2.3372 - accuracy: 0.0959
# Epoch 6/200
# 53/53 [==============================] - 2s 33ms/step - loss: 2.3313 - accuracy: 0.1040
# Epoch 7/200
# 53/53 [==============================] - 2s 33ms/step - loss: 2.3278 - accuracy: 0.1078
# Epoch 8/200
# 53/53 [==============================] - 2s 32ms/step - loss: 2.3331 - accuracy: 0.0995
# Epoch 9/200
# 53/53 [==============================] - 2s 33ms/step - loss: 2.2684 - accuracy: 0.1429
# Epoch 10/200
# 53/53 [==============================] - 2s 32ms/step - loss: 2.1363 - accuracy: 0.1789
# Epoch 11/200
# 53/53 [==============================] - 2s 32ms/step - loss: 2.0610 - accuracy: 0.1978
# Epoch 12/200
# 53/53 [==============================] - 2s 33ms/step - loss: 2.0224 - accuracy: 0.2010
# Epoch 13/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.9990 - accuracy: 0.2165
# Epoch 14/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.9864 - accuracy: 0.2112
# Epoch 15/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9717 - accuracy: 0.2308
# Epoch 16/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.9698 - accuracy: 0.2276
# Epoch 17/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9572 - accuracy: 0.2402
# Epoch 18/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9533 - accuracy: 0.2450
# Epoch 19/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9523 - accuracy: 0.2365
# Epoch 20/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.9346 - accuracy: 0.2453
# Epoch 21/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9448 - accuracy: 0.2434
# Epoch 22/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9357 - accuracy: 0.2461
# Epoch 23/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9399 - accuracy: 0.2442
# Epoch 24/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.9271 - accuracy: 0.2476
# Epoch 25/200
# 53/53 [==============================] - 2s 46ms/step - loss: 1.9347 - accuracy: 0.2425
# Epoch 26/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9247 - accuracy: 0.2468
# Epoch 27/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9330 - accuracy: 0.2521
# Epoch 28/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9287 - accuracy: 0.2400
# Epoch 29/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9198 - accuracy: 0.2531
# Epoch 30/200
# 53/53 [==============================] - 2s 35ms/step - loss: 1.9218 - accuracy: 0.2516
# Epoch 31/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9344 - accuracy: 0.2385
# Epoch 32/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9255 - accuracy: 0.2480
# Epoch 33/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9194 - accuracy: 0.2538
# Epoch 34/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9240 - accuracy: 0.2555
# Epoch 35/200
# 53/53 [==============================] - 2s 33ms/step - loss: 1.9170 - accuracy: 0.2434
# Epoch 36/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9129 - accuracy: 0.2633
# Epoch 37/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9143 - accuracy: 0.2604
# Epoch 38/200
# 53/53 [==============================] - 2s 34ms/step - loss: 1.9066 - accuracy: 0.2625
# Epoch 39/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9058 - accuracy: 0.2648
# Epoch 40/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9120 - accuracy: 0.2559
# Epoch 41/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9028 - accuracy: 0.2625
# Epoch 42/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9046 - accuracy: 0.2657
# Epoch 43/200
# 53/53 [==============================] - 2s 32ms/step - loss: 1.9051 - accuracy: 0.2687
# Epoch 44/200
# 31/53 [================>.............] - ETA: 0s - loss: 1.9061 - accuracy: 0.2648

# %% [markdown]
# ##### Get Validation Accuracy

# %%
if PERFORM_KFOLD is True:
    print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
else:
    print("PERFORM_KFOLD is not true.")

# %% [markdown]
# #### FIT MODEL FOR TESTING
# - Fit the Model
# - View Accuracy and Loss Graph
# - View Model Summary

# %%
#####################
# # fit the model # #
#####################

if TEST_MODEL is True:
    model = create_model()
    es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                       verbose=1)
    history = model.fit(X_train, y_train, callbacks=es, verbose=1)

# %%
if TEST_MODEL is True:
    ##########################
    # # get model accuracy # #
    ##########################
    plt.plot(history.history['accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

    ######################
    # # get model loss # #
    ######################
    plt.plot(history.history['loss'])
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

# %%
if TEST_MODEL is True:
    ##########################
    # # view model summary # #
    ##########################
    model.model.summary()

# %% [markdown]
# #### MODEL TESTING
# - Get Model Accuracy on the Test Dataset
# - Generate Confusion Matrix
# - Generate ROC Curves
# - Save the Model if Appropriate

# %%
if TEST_MODEL is True:
    y_pred = model.predict_proba(X_test)

    # evaluate predictions
    acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    print("Testing accuracy: %.3f%%" % (acc*100))

# %% [markdown]
# ##### Confusion Matrix

# %%
if TEST_MODEL is True and CON_MATRIX is True:
    # confusion matrix
    print(str(len(y_pred)) + " is the number of test value in kfold_val / train_test_split")
    cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                         columns = [i for i in np.unique(lb.inverse_transform(y_test))])

    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=True, cmap="BuPu")

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
if TEST_MODEL is True and ROC_GRAPH is True: # compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    for i in range(n_classes):
        plt.figure()
        lw = 2
        plt.plot(
            fpr[i],
            tpr[i],
            color="darkorange",
            lw=lw,
            label="ROC curve (area = %0.2f)" % roc_auc[i],
        )
        plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
        plt.xlim([-0.005, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ##### ROC Curve (Multiclass)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    # compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # first aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    # plt.figure()
    # plt.plot(
    #     fpr["micro"],
    #     tpr["micro"],
    #     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    #     color="deeppink",
    #     linestyle=":",
    #     linewidth=4,
    # )

    # plt.plot(
    #     fpr["macro"],
    #     tpr["macro"],
    #     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    #     color="navy",
    #     linestyle=":",
    #     linewidth=4,
    # )

    colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
        )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Multiclass)")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Average)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

    # calculate equal-error-rate
    eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('Average ROC Curve')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #### FIT AND SAVE MODEL
# - Fitting of model
# - Get Accuracy and Loss of Mdoel
# - Saving Model

# %%
############################
# # reshaping of dataset # #
############################
# loading of dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)

df.head()
dataset = df.values

# divide data into features X and target (classes) Y
# convert target Y to labelbinarizer Y for model
X, Y, lb, class_list = prepare_dataset(df)

# reshaping the dataset to include LSTM Timesteps
X = reshape_dataset(X, TIMESTEPS)
n_classes = Y.shape[1]

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# #### SAVE MODEL

# %%
##################
# # save model # #
##################
model.model.save(MODEL_PATH)

# %% [markdown]
# # LIVE TESTING
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
actual_np = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

########################
# # predict all rows # #
########################
# pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################

pred_row=pred_df.iloc[46:54,FEATURES_COL_NUM:]
print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

print(class_list)
Y = np.asarray(class_list)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

pred_proba = np.sum(pred_proba, axis=0)
pred_proba = np.reshape(pred_proba, (1, 9))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

match_list = []

for _ in range(actual_np.size):
    if pred[_] == actual_np[_]:
        match_list.append("match")
    else:
        match_list.append("nope")

match_count = match_list.count("match")
total_count = len(match_list)

match_header = str(match_count) + "/" + str(total_count) + " (" + str(match_count/total_count*100)+ "%)"
match_np = np.array(match_list)

exported_output = np.column_stack((actual_np, pred))
exported_output = np.column_stack((exported_output, acc))
exported_output = np.column_stack((exported_output, match_np))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(data=exported_output, index=None, columns=['Actual', 'Prediction', 'Accuracy', match_header])
# print(df)
df.to_csv(RESULT_PATH)

print("Accuracy of the Model is: " + str(match_header))
