# %% [markdown]
# #### IMPORT

# %%
import os, platform
import py7zr

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %% [markdown]
# #### PARAMETERS
# - Set the condition
# > * N_FEATURES: Number of Features
# > * CHECK_BLANKS: Check for blank data. If any blank data is found, the whole row of data will be deleted.
# > * CHECK_CLASS_IMBALANCE: Check for dataset class imbalance. The more balance the dataset, the less biases the model will be.

# %%
##############################
# # deep learning features # #
##############################
SEED = 1005 # random seed for reproducibility

# should make this dynamic
N_FEATURES = 193
TIMESTEPS = 1
EPOCH=200
BATCH_SIZE=100

SPLIT_RATIO=0.2

###############
# # preview # #
###############
f = False
t = True

# checking dataset
CHECK_BLANKS = True
CHECK_CLASS_IMBALANCE = True

# evaluate suitable kfold number and kfold model
MIN_KFOLD = 2
MAX_KFOLD = 11
N_KFOLD = 5
EVAL_KFOLD_NUM = False
EVAL_KFOLD_MODEL = False
PERFORM_KFOLD = False

# model testing
TEST_MODEL = True
CON_MATRIX = True
ROC_GRAPH = True

###############
# # dataset # #
###############
CLASSES_COL_NAME = "Subject"
CLASSES_COL_NUM = 0
FEATURES_COL_NUM = 3

DATASET_DIR_NAME = "dataset\set03\\02_pair_rand"
SAMPLE_DATASET_NAME = "pair_train_rand"
ACTUAL_DATASET_NAME = "pair_test_rand"

MODEL_DIR_NAME = "dataset\set03\\02_pair_rand"
MODEL_NAME = "model_" + "set03_02_pair_rand"

RESULT_DIR_NAME = "dataset\set03\\02_pair_rand"
RESULT_NAME = "result_" + "set03_02_pair_rand"

DATASET_DIR_PATH = os.path.join(os.getcwd(), DATASET_DIR_NAME)
SAMPLE_DATASET_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".csv")
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME + ".csv")

MODEL_DIR_PATH = os.path.join(os.getcwd(), MODEL_DIR_NAME)
MODEL_PATH = os.path.join(MODEL_DIR_PATH, MODEL_NAME + ".h5")

RESULT_DIR_PATH = os.path.join(os.getcwd(), RESULT_DIR_NAME)
RESULT_PATH = os.path.join(RESULT_DIR_PATH, RESULT_NAME + ".csv")

#################
# # sns theme # #
#################
# sns.set_theme(style="darkgrid") # (dark background with white gridlines)
sns.set_theme(style="whitegrid") # (white background with grey gridlines)
# sns.set_theme(style="dark") # (dark background with no gridlines)
# sns.set_theme(style="white") # (white background with no gridlines)
# sns.set_theme(style="ticks") # (white background with axis ticks and no gridlines)

# %%
if os.path.isdir(DATASET_DIR_PATH) is True:
    print(f"Dataset directory exists at: {DATASET_DIR_PATH}")
else:
    try:
        os.mkdir(DATASET_DIR_PATH, 666)
        print(f"Dataset directory have been created at: {DATASET_DIR_PATH}")
    except:
        print("Error: Dataset Directory not created")
        
if os.path.isdir(MODEL_DIR_PATH) is True:
    print(f"Model directory exists at: {MODEL_DIR_PATH}")
else:
    try:
        os.mkdir(MODEL_DIR_PATH, 666)
        print(f"Model directory have been created at: {MODEL_DIR_PATH}")
    except:
        print("Error: Model Directory not created")
    
if os.path.exists(SAMPLE_DATASET_PATH) is True:
    print(f"Training dataset exists at: {SAMPLE_DATASET_PATH}")
else:
    try:
        SAMPLE_7Z_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".7z")
        with py7zr.SevenZipFile(SAMPLE_7Z_PATH, mode='r') as z:
            z.extractall(path=DATASET_DIR_PATH)
        print(f"Decompress 7z file to: {SAMPLE_7Z_PATH}")
    except:
        print("Error: Failed to decompress 7z file.")
# Out:
# Dataset directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set03\02_pair_rand
# Model directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set03\02_pair_rand
# Training dataset exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set03\02_pair_rand\pair_train_rand.csv

# %% [markdown]
# #### CREATE MODEL
# - Create base model
# - Wrap it with KerasClassifier

# %%
#create base model
def create_base_model():
    model = Sequential()
    model.add(LSTM(units=256, return_sequences=True,
             input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dense(256, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=32, return_sequences=True))
    model.add(Dense(32, activation='sigmoid'))
    model.add(Dropout(0.2))

    # softmax for multi-class classification
    model.add(Flatten())
    print("There are a total of " + str(n_classes) + " classes.")
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=EPOCH, 
                            batch_size=BATCH_SIZE)
    return model

# %%
# divide data into features X and target (classes) Y
def prepare_dataset(df):
    X = df.values[:,FEATURES_COL_NUM:].astype(float)
    Y = df.values[:,CLASSES_COL_NUM].astype(str)

    # convert target Y to labelbinarizer Y for model
    # fit_transform is not used to reuse lb
    Y = Y.reshape(-1, 1)
    lb = LabelBinarizer().fit(Y)
    Y = lb.transform(Y)

    #################################
    # # get all the encoded class # #
    #################################
    print("LabelBinarizer is able to decipher: ")
    print(lb.classes_)
    print("\n")

    ###########################
    # # print X and Y shape # #
    ###########################
    print(f"X | Features | Dataset Shape: {X.shape}")
    print(f"Y | Classes  | Dataset Shape: {Y.shape}")

    return X, Y, lb, lb.classes_.tolist()

# %%
def split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED):

    ##############################################################
    # # split dataset into train and test set of 0.8/0.2 ratio # #
    ##############################################################
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=SPLIT_RATIO, random_state=SEED)

    ############################
    # # reshaping of dataset # #
    ############################

    # reshaping the dataset to include LSTM Timesteps
    print(X_train.dtype)
    X_train = np.asarray(X_train, dtype=np.float32)
    print(X_train.dtype)
    X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
    print(X_test.dtype)
    X_test = np.asarray(X_test, dtype=np.float32)
    print(X_test.dtype)
    X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

    print(f"X train shape: {X_train.shape}")
    print(f"Y train shape: {y_train.shape}")
    print(f"X test shape: {X_test.shape}")
    print(f"Y test shape: {y_test.shape}")
    
    return X_train, X_test, y_train, y_test

def reshape_dataset(X, TIMESTEPS):
    # reshaping the dataset to include LSTM Timesteps
    X = np.asarray(X, dtype=np.float32)
    X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))
    return X

# %% [markdown]
# #### LOAD DATASET

# %%
# load dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)
df.head()
# Out:
#   Subject Sequence    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    adhy    apish  0.176624 -0.081235   0.095389   0.054188   0.230811
# 1    adhy    apish  0.176624 -0.081235   0.095389   0.054188   0.230811
# 2    adhy    apish  0.176624 -0.081235   0.095389   0.054188   0.230811
# 3    adhy    apish  0.176624 -0.081235   0.095389   0.054188   0.230811
# 4    adhy    apish  0.176624 -0.081235   0.095389   0.054188   0.230811
#
#      T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T4-RF|VAR.1  T4-NG|VAR.1  T4-I|SD.1  \
# 0  0.135423 -0.079058   0.056365  ...     0.018428     0.010549   0.106929
# 1  0.135423 -0.079058   0.056365  ...     0.009239     0.002546   0.056287
# 2  0.135423 -0.079058   0.056365  ...     0.004547     0.004534   0.078745
# 3  0.135423 -0.079058   0.056365  ...     0.012902     0.014318   0.045071
# 4  0.135423 -0.079058   0.056365  ...     0.000880     0.000853   0.011580
#
#    T4-PF|SD.1  T4-RF|SD.1  T4-NG|SD.1  T5-I|0+4.1  T5-PF|0+4.1  T5-RF|0+4.1  \
# 0    0.073887    0.135748    0.102706    0.568097     0.688471     0.671329
# 1    0.010623    0.096118    0.050453    0.328402     0.431805     0.384529
# 2    0.078653    0.067429    0.067337    0.519806     0.615577     0.648569
# 3    0.051139    0.113588    0.119657    0.448259     0.561053     0.519647
# 4    0.011127    0.029663    0.029210    0.215585     0.335845     0.319089
#
#    T5-NG|0+4.1
# 0     0.791703
# 1     0.487932
# 2     0.744340
# 3     0.632440
# 4     0.439348
#
# [5 rows x 196 columns]

# %% [markdown]
# #### CHECK DATASET

# %%
########################
# # check for blanks # #
########################
if CHECK_BLANKS is True:
    # checking for blanks
    print("Checking for blanks...")
    if df.isnull().values.any() is True:
        df = df.dropna(axis=0, how="any")
        print("Blank rows has been dropped.")
    else:
        print("No blank value has been found.")
        
#################################
# # check for class imbalance # #
#################################
if CHECK_CLASS_IMBALANCE is True:
    print("Checking for class imbalance...")
    sns.countplot(x=CLASSES_COL_NAME, data=df).set_title("Class Imbalance")
#     df.loc[(df!=0).any(axis=1)]
    plt.show()

sns.catplot(x="Subject", y="T2-D|0", hue="T2-D|0", data=df, legend=False)
sns.catplot(x="Subject", y="T2-I|0+1", hue="T2-I|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-PF|0+1", hue="T2-PF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-RF|0+1", hue="T2-RF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-D|1", hue="T2-D|1", data=df, legend=False)
# Out:
# Checking for blanks...
# No blank value has been found.
# Checking for class imbalance...

# %% [markdown]
# #### PREPARE DATASET
# - Split data based on X / Features and Y / Classes
# - Binarize Y into binary labels

# %%
X, Y, lb, class_list = prepare_dataset(df)
n_classes = len(class_list)
print(f"Number of Classes: {n_classes}")
# Out:
# LabelBinarizer is able to decipher:
# ['adhy' 'andy' 'bryce' 'chris' 'cy' 'hr' 'jc' 'ys']
#
#
# X | Features | Dataset Shape: (79200, 193)
# Y | Classes  | Dataset Shape: (79200, 8)
# Number of Classes: 8

# %% [markdown]
# #### SPLIT DATASET
# - Split dataset into train set and test set 0.8 / 0.2

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED)
# Out:
# float64
# float32
# float64
# float32
# X train shape: (63360, 1, 193)
# Y train shape: (63360, 8)
# X test shape: (15840, 1, 193)
# Y test shape: (15840, 8)

# %% [markdown]
# #### PERFORM VALIDATION (w KFold Validation)
# - Evaluate best KFold Validation
# - Generate loss and accuracy graph
# - Perform KFold validation

# %% [markdown]
# ##### Evaluate suitable folds for kfold validation

# %%
###############################################
# # evaluate suitable kfold value for model # #
###############################################
def evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD):
    
    # evaluate the model    
    folds = range(MIN_KFOLD, MAX_KFOLD)
    means, mins, maxs = list(), list(), list()
    
    # evaluate each k value
    for k in folds:
        # define the test condition
        kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
        
        # evaluate k value
        model = create_model()
        scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
        k_mean = np.mean(scores)
        k_min = scores.min()
        k_max = scores.max()
        
        # report performance
        print(f"No. of Folds: {k} | Accuracy: {k_mean*100:.3f} | Min: {k_min*100:.3f} | Max: {k_max*100:.3f}")
        
        # store mean accuracy and min and max relative to the mean
        means.append(k_mean)
        mins.append(k_mean - k_min)
        maxs.append(k_max - k_mean)
        
    # line plot of k mean values with min/max error bars
    clear_output(wait=True)
    pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
    # show the plot
    pyplot.show()
    
if EVAL_KFOLD_NUM is True:
    evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD)
else:
    print("EVAL_KFOLD_NUM is not True")
# Out:
# EVAL_KFOLD_NUM is not True

# %% [markdown]
# ##### Generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=50, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print(f"Accuracy | Mean: {np.mean(scores)*100:.3f} | Std: {np.std(scores)*100:.3f} | Length/no.: {len(scores)}")
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    clear_output(wait=True)
    plt.show()
    
if EVAL_KFOLD_MODEL is True:
    evaluate_kfold_model(X_train, y_train, SEED)
else:
    print("EVAL_KFOLD_MODEL is not true")
# Out:
# EVAL_KFOLD_MODEL is not true

# %% [markdown]
# ##### Perform Actual KFold validation

# %%
if PERFORM_KFOLD is True:
    # create model
    model = create_model()
    kfold = KFold(n_splits=N_KFOLD, shuffle=True, random_state=SEED)
    valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# ##### Get Validation Accuracy

# %%
if PERFORM_KFOLD is True:
    print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# #### FIT MODEL FOR TESTING
# - Fit the Model
# - View Accuracy and Loss Graph
# - View Model Summary

# %%
#####################
# # fit the model # #
#####################

if TEST_MODEL is True:
    model = create_model()
    es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                       verbose=1)
    history = model.fit(X_train, y_train, callbacks=es, verbose=1)
# Out:
# There are a total of 8 classes.
# Epoch 1/200
# 634/634 [==============================] - 15s 15ms/step - loss: 1.7426 - accuracy: 0.2858
# Epoch 2/200
# 634/634 [==============================] - 9s 14ms/step - loss: 1.4416 - accuracy: 0.4120
# Epoch 3/200
# 634/634 [==============================] - 9s 14ms/step - loss: 1.3376 - accuracy: 0.4703
# Epoch 4/200
# 634/634 [==============================] - 9s 14ms/step - loss: 1.2725 - accuracy: 0.4990
# Epoch 5/200
# 634/634 [==============================] - 9s 14ms/step - loss: 1.2281 - accuracy: 0.5217
# Epoch 6/200
# 634/634 [==============================] - 9s 14ms/step - loss: 1.1769 - accuracy: 0.5525
# Epoch 7/200
# 634/634 [==============================] - 9s 14ms/step - loss: 1.1238 - accuracy: 0.5809
# Epoch 8/200
# 634/634 [==============================] - 9s 14ms/step - loss: 1.0689 - accuracy: 0.6105
# Epoch 9/200
# 634/634 [==============================] - 9s 14ms/step - loss: 1.0132 - accuracy: 0.6357
# Epoch 10/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.9767 - accuracy: 0.6529
# Epoch 11/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.9367 - accuracy: 0.6694
# Epoch 12/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.8827 - accuracy: 0.6906
# Epoch 13/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.8386 - accuracy: 0.7075
# Epoch 14/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.7957 - accuracy: 0.7241
# Epoch 15/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.7502 - accuracy: 0.7407
# Epoch 16/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.7211 - accuracy: 0.7506
# Epoch 17/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.6855 - accuracy: 0.7647
# Epoch 18/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.6546 - accuracy: 0.7746
# Epoch 19/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.6230 - accuracy: 0.7863
# Epoch 20/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.5969 - accuracy: 0.7970
# Epoch 21/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.5629 - accuracy: 0.8070
# Epoch 22/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.5404 - accuracy: 0.8169
# Epoch 23/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.5060 - accuracy: 0.8285
# Epoch 24/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.4964 - accuracy: 0.8324
# Epoch 25/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.4665 - accuracy: 0.8428
# Epoch 26/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.4382 - accuracy: 0.8522
# Epoch 27/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.4217 - accuracy: 0.8572
# Epoch 28/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.4072 - accuracy: 0.8620
# Epoch 29/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.3906 - accuracy: 0.8684
# Epoch 30/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.3675 - accuracy: 0.8771
# Epoch 31/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.3519 - accuracy: 0.8797
# Epoch 32/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.3482 - accuracy: 0.8827
# Epoch 33/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.3220 - accuracy: 0.8932
# Epoch 34/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.3120 - accuracy: 0.8958
# Epoch 35/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.3076 - accuracy: 0.8966
# Epoch 36/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.2890 - accuracy: 0.9035
# Epoch 37/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.2773 - accuracy: 0.9071
# Epoch 38/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.2715 - accuracy: 0.9108
# Epoch 39/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.2614 - accuracy: 0.9135
# Epoch 40/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.2519 - accuracy: 0.9164
# Epoch 41/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2402 - accuracy: 0.9211
# Epoch 42/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.2367 - accuracy: 0.9218
# Epoch 43/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.2224 - accuracy: 0.9257
# Epoch 44/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.2247 - accuracy: 0.9263
# Epoch 45/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.2139 - accuracy: 0.9299
# Epoch 46/200
# 634/634 [==============================] - 13s 20ms/step - loss: 0.2116 - accuracy: 0.9302
# Epoch 47/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.2000 - accuracy: 0.9346
# Epoch 48/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.2017 - accuracy: 0.9336
# Epoch 49/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.1934 - accuracy: 0.9370
# Epoch 50/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.1886 - accuracy: 0.9386
# Epoch 51/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.1870 - accuracy: 0.9392
# Epoch 52/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.1813 - accuracy: 0.9409
# Epoch 53/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1712 - accuracy: 0.9438
# Epoch 54/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1673 - accuracy: 0.9450
# Epoch 55/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.1629 - accuracy: 0.9490
# Epoch 56/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1597 - accuracy: 0.9483
# Epoch 57/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1604 - accuracy: 0.9483
# Epoch 58/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.1515 - accuracy: 0.9508
# Epoch 59/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1522 - accuracy: 0.9516
# Epoch 60/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.1447 - accuracy: 0.9543
# Epoch 61/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1539 - accuracy: 0.9502
# Epoch 62/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.1399 - accuracy: 0.9552
# Epoch 63/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1425 - accuracy: 0.9548
# Epoch 64/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1302 - accuracy: 0.9582
# Epoch 65/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1364 - accuracy: 0.9557
# Epoch 66/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.1274 - accuracy: 0.9593
# Epoch 67/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1279 - accuracy: 0.9598
# Epoch 68/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1223 - accuracy: 0.9605
# Epoch 69/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.1262 - accuracy: 0.9605
# Epoch 70/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1221 - accuracy: 0.9609
# Epoch 71/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1169 - accuracy: 0.9620
# Epoch 72/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.1238 - accuracy: 0.9618
# Epoch 73/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1188 - accuracy: 0.9628
# Epoch 74/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1126 - accuracy: 0.9645
# Epoch 75/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1101 - accuracy: 0.9646
# Epoch 76/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1140 - accuracy: 0.9656
# Epoch 77/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1092 - accuracy: 0.9655
# Epoch 78/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1057 - accuracy: 0.9664
# Epoch 79/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1075 - accuracy: 0.9673
# Epoch 80/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0995 - accuracy: 0.9684
# Epoch 81/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1064 - accuracy: 0.9669
# Epoch 82/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.1010 - accuracy: 0.9686
# Epoch 83/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.1060 - accuracy: 0.9670
# Epoch 84/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.0957 - accuracy: 0.9696
# Epoch 85/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.0960 - accuracy: 0.9695
# Epoch 86/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.0921 - accuracy: 0.9709
# Epoch 87/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0956 - accuracy: 0.9685
# Epoch 88/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0959 - accuracy: 0.9704
# Epoch 89/200
# 634/634 [==============================] - 9s 14ms/step - loss: 0.0850 - accuracy: 0.9738
# Epoch 90/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0868 - accuracy: 0.9734
# Epoch 91/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0958 - accuracy: 0.9708
# Epoch 92/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0935 - accuracy: 0.9707
# Epoch 93/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0895 - accuracy: 0.9721
# Epoch 94/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0906 - accuracy: 0.9708
# Epoch 95/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0874 - accuracy: 0.9738
# Epoch 96/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0814 - accuracy: 0.9747
# Epoch 97/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0796 - accuracy: 0.9750
# Epoch 98/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0794 - accuracy: 0.9756
# Epoch 99/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0800 - accuracy: 0.9750
# Epoch 100/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0814 - accuracy: 0.9747
# Epoch 101/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0797 - accuracy: 0.9750
# Epoch 102/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0772 - accuracy: 0.9761
# Epoch 103/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0868 - accuracy: 0.9734
# Epoch 104/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0785 - accuracy: 0.9754
# Epoch 105/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0751 - accuracy: 0.9771
# Epoch 106/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0749 - accuracy: 0.9770
# Epoch 107/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0729 - accuracy: 0.9771
# Epoch 108/200
# 634/634 [==============================] - 12s 18ms/step - loss: 0.0712 - accuracy: 0.9779
# Epoch 109/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0831 - accuracy: 0.9750
# Epoch 110/200
# 634/634 [==============================] - 11s 18ms/step - loss: 0.0690 - accuracy: 0.9789
# Epoch 111/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0697 - accuracy: 0.9792
# Epoch 112/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0713 - accuracy: 0.9775
# Epoch 113/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0697 - accuracy: 0.9787
# Epoch 114/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0719 - accuracy: 0.9788
# Epoch 115/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0665 - accuracy: 0.9797
# Epoch 116/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0642 - accuracy: 0.9798
# Epoch 117/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0721 - accuracy: 0.9775
# Epoch 118/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0644 - accuracy: 0.9798
# Epoch 119/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0647 - accuracy: 0.9798
# Epoch 120/200
# 634/634 [==============================] - 11s 18ms/step - loss: 0.0718 - accuracy: 0.9786
# Epoch 121/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0643 - accuracy: 0.9797
# Epoch 122/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0633 - accuracy: 0.9802
# Epoch 123/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0629 - accuracy: 0.9809
# Epoch 124/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0626 - accuracy: 0.9811
# Epoch 125/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0619 - accuracy: 0.9814
# Epoch 126/200
# 634/634 [==============================] - 10s 17ms/step - loss: 0.0603 - accuracy: 0.9821
# Epoch 127/200
# 634/634 [==============================] - 11s 18ms/step - loss: 0.0645 - accuracy: 0.9807
# Epoch 128/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0589 - accuracy: 0.9820
# Epoch 129/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0547 - accuracy: 0.9827
# Epoch 130/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0580 - accuracy: 0.9825
# Epoch 131/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0664 - accuracy: 0.9801
# Epoch 132/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0564 - accuracy: 0.9825
# Epoch 133/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0565 - accuracy: 0.9824
# Epoch 134/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0569 - accuracy: 0.9818
# Epoch 135/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0586 - accuracy: 0.9818
# Epoch 136/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0591 - accuracy: 0.9824
# Epoch 137/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0617 - accuracy: 0.9816
# Epoch 138/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0552 - accuracy: 0.9824
# Epoch 139/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0566 - accuracy: 0.9827
# Epoch 140/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0586 - accuracy: 0.9821
# Epoch 141/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0528 - accuracy: 0.9838
# Epoch 142/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0533 - accuracy: 0.9837
# Epoch 143/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0592 - accuracy: 0.9818
# Epoch 144/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0534 - accuracy: 0.9838
# Epoch 145/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0453 - accuracy: 0.9852
# Epoch 146/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0556 - accuracy: 0.9833
# Epoch 147/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0527 - accuracy: 0.9837
# Epoch 148/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0559 - accuracy: 0.9833
# Epoch 149/200
# 634/634 [==============================] - 12s 18ms/step - loss: 0.0506 - accuracy: 0.9845
# Epoch 150/200
# 634/634 [==============================] - 11s 18ms/step - loss: 0.0516 - accuracy: 0.9843
# Epoch 151/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0527 - accuracy: 0.9839
# Epoch 152/200
# 634/634 [==============================] - 9s 15ms/step - loss: 0.0494 - accuracy: 0.9849
# Epoch 153/200
# 634/634 [==============================] - 10s 15ms/step - loss: 0.0498 - accuracy: 0.9851
# Epoch 154/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0464 - accuracy: 0.9860
# Epoch 155/200
# 634/634 [==============================] - 14s 22ms/step - loss: 0.0534 - accuracy: 0.9845
# Epoch 156/200
# 634/634 [==============================] - 13s 20ms/step - loss: 0.0527 - accuracy: 0.9841
# Epoch 157/200
# 634/634 [==============================] - 13s 20ms/step - loss: 0.0467 - accuracy: 0.9860
# Epoch 158/200
# 634/634 [==============================] - 13s 21ms/step - loss: 0.0488 - accuracy: 0.9853
# Epoch 159/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0518 - accuracy: 0.9841
# Epoch 160/200
# 634/634 [==============================] - 13s 20ms/step - loss: 0.0479 - accuracy: 0.9860
# Epoch 161/200
# 634/634 [==============================] - 11s 18ms/step - loss: 0.0540 - accuracy: 0.9841
# Epoch 162/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0496 - accuracy: 0.9855
# Epoch 163/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0493 - accuracy: 0.9853
# Epoch 164/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0423 - accuracy: 0.9872
# Epoch 165/200
# 634/634 [==============================] - 13s 20ms/step - loss: 0.0457 - accuracy: 0.9855
# Epoch 166/200
# 634/634 [==============================] - 12s 20ms/step - loss: 0.0474 - accuracy: 0.9857
# Epoch 167/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0513 - accuracy: 0.9848
# Epoch 168/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0454 - accuracy: 0.9861
# Epoch 169/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0473 - accuracy: 0.9857
# Epoch 170/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0463 - accuracy: 0.9862
# Epoch 171/200
# 634/634 [==============================] - 12s 18ms/step - loss: 0.0447 - accuracy: 0.9866
# Epoch 172/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0451 - accuracy: 0.9866
# Epoch 173/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0434 - accuracy: 0.9867
# Epoch 174/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0465 - accuracy: 0.9862
# Epoch 175/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0461 - accuracy: 0.9857
# Epoch 176/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0447 - accuracy: 0.9865
# Epoch 177/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0457 - accuracy: 0.9861
# Epoch 178/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0434 - accuracy: 0.9865
# Epoch 179/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0439 - accuracy: 0.9866
# Epoch 180/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0401 - accuracy: 0.9877
# Epoch 181/200
# 634/634 [==============================] - 12s 20ms/step - loss: 0.0461 - accuracy: 0.9864
# Epoch 182/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0476 - accuracy: 0.9862
# Epoch 183/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0424 - accuracy: 0.9875
# Epoch 184/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0404 - accuracy: 0.9877
# Epoch 185/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0445 - accuracy: 0.9865
# Epoch 186/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0416 - accuracy: 0.9876
# Epoch 187/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0452 - accuracy: 0.9866
# Epoch 188/200
# 634/634 [==============================] - 13s 21ms/step - loss: 0.0419 - accuracy: 0.9869
# Epoch 189/200
# 634/634 [==============================] - 14s 22ms/step - loss: 0.0373 - accuracy: 0.9887
# Epoch 190/200
# 634/634 [==============================] - 12s 20ms/step - loss: 0.0428 - accuracy: 0.9874
# Epoch 191/200
# 634/634 [==============================] - 13s 20ms/step - loss: 0.0390 - accuracy: 0.9876
# Epoch 192/200
# 634/634 [==============================] - 12s 18ms/step - loss: 0.0488 - accuracy: 0.9855
# Epoch 193/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0397 - accuracy: 0.9882
# Epoch 194/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0393 - accuracy: 0.9882
# Epoch 195/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0392 - accuracy: 0.9880
# Epoch 196/200
# 634/634 [==============================] - 12s 19ms/step - loss: 0.0376 - accuracy: 0.9886
# Epoch 197/200
# 634/634 [==============================] - 11s 18ms/step - loss: 0.0405 - accuracy: 0.9878
# Epoch 198/200
# 634/634 [==============================] - 10s 16ms/step - loss: 0.0391 - accuracy: 0.9886
# Epoch 199/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0407 - accuracy: 0.9877
# Epoch 200/200
# 634/634 [==============================] - 11s 17ms/step - loss: 0.0381 - accuracy: 0.9884

# %%
if TEST_MODEL is True:
    ##########################
    # # get model accuracy # #
    ##########################
    plt.plot(history.history['accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

    ######################
    # # get model loss # #
    ######################
    plt.plot(history.history['loss'])
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

# %%
if TEST_MODEL is True:
    ##########################
    # # view model summary # #
    ##########################
    model.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 256)            460800
#
#  dense (Dense)               (None, 1, 256)            65792
#
#  dropout (Dropout)           (None, 1, 256)            0
#
#  batch_normalization (BatchN  (None, 1, 256)           1024
#  ormalization)
#
#  lstm_1 (LSTM)               (None, 1, 128)            197120
#
#  dense_1 (Dense)             (None, 1, 128)            16512
#
#  dropout_1 (Dropout)         (None, 1, 128)            0
#
#  batch_normalization_1 (Batc  (None, 1, 128)           512
#  hNormalization)
#
#  lstm_2 (LSTM)               (None, 1, 64)             49408
#
#  dense_2 (Dense)             (None, 1, 64)             4160
#
#  dropout_2 (Dropout)         (None, 1, 64)             0
#
#  batch_normalization_2 (Batc  (None, 1, 64)            256
#  hNormalization)
#
#  lstm_3 (LSTM)               (None, 1, 32)             12416
#
#  dense_3 (Dense)             (None, 1, 32)             1056
#
#  dropout_3 (Dropout)         (None, 1, 32)             0
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense_4 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 809,320
# Trainable params: 808,424
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# #### MODEL TESTING
# - Get Model Accuracy on the Test Dataset
# - Generate Confusion Matrix
# - Generate ROC Curves
# - Save the Model if Appropriate

# %%
if TEST_MODEL is True:
    y_pred = model.predict_proba(X_test)

    # evaluate predictions
    acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    print("Testing accuracy: %.3f%%" % (acc*100))
# Out:
# Testing accuracy: 93.106%

# %% [markdown]
# ##### Confusion Matrix

# %%
if TEST_MODEL is True and CON_MATRIX is True:
    # confusion matrix
    print(str(len(y_pred)) + " is the number of test value in kfold_val / train_test_split")
    cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                         columns = [i for i in np.unique(lb.inverse_transform(y_test))])

    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=True, cmap="BuPu")
# Out:
# 15840 is the number of test value in kfold_val / train_test_split

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
if TEST_MODEL is True and ROC_GRAPH is True: # compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    for i in range(n_classes):
        plt.figure()
        lw = 2
        plt.plot(
            fpr[i],
            tpr[i],
            color="darkorange",
            lw=lw,
            label="ROC curve (area = %0.2f)" % roc_auc[i],
        )
        plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
        plt.xlim([-0.005, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ##### ROC Curve (Multiclass)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    # compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # first aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    # plt.figure()
    # plt.plot(
    #     fpr["micro"],
    #     tpr["micro"],
    #     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    #     color="deeppink",
    #     linestyle=":",
    #     linewidth=4,
    # )

    # plt.plot(
    #     fpr["macro"],
    #     tpr["macro"],
    #     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    #     color="navy",
    #     linestyle=":",
    #     linewidth=4,
    # )

    colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
        )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Multiclass)")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Average)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

    # calculate equal-error-rate
    eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('Average ROC Curve')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #### FIT AND SAVE MODEL
# - Fitting of model
# - Get Accuracy and Loss of Mdoel
# - Saving Model

# %%
############################
# # reshaping of dataset # #
############################
# loading of dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)

df.head()
dataset = df.values

# divide data into features X and target (classes) Y
# convert target Y to labelbinarizer Y for model
X, Y, lb, class_list = prepare_dataset(df)

# reshaping the dataset to include LSTM Timesteps
X = reshape_dataset(X, TIMESTEPS)
n_classes = Y.shape[1]

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# LabelBinarizer is able to decipher:
# ['adhy' 'andy' 'bryce' 'chris' 'cy' 'hr' 'jc' 'ys']
#
#
# X | Features | Dataset Shape: (79200, 193)
# Y | Classes  | Dataset Shape: (79200, 8)
# There are a total of 8 classes.
# Epoch 1/200
# 792/792 [==============================] - 16s 13ms/step - loss: 1.6840 - accuracy: 0.3149
# Epoch 2/200
# 792/792 [==============================] - 12s 15ms/step - loss: 1.3903 - accuracy: 0.4576
# Epoch 3/200
# 792/792 [==============================] - 11s 14ms/step - loss: 1.2950 - accuracy: 0.4975
# Epoch 4/200
# 792/792 [==============================] - 11s 14ms/step - loss: 1.2361 - accuracy: 0.5224
# Epoch 5/200
# 792/792 [==============================] - 11s 14ms/step - loss: 1.1746 - accuracy: 0.5545
# Epoch 6/200
# 792/792 [==============================] - 11s 13ms/step - loss: 1.1183 - accuracy: 0.5847
# Epoch 7/200
# 792/792 [==============================] - 11s 13ms/step - loss: 1.0518 - accuracy: 0.6142
# Epoch 8/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.9901 - accuracy: 0.6431
# Epoch 9/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.9346 - accuracy: 0.6681
# Epoch 10/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.8863 - accuracy: 0.6898
# Epoch 11/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.8229 - accuracy: 0.7143
# Epoch 12/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.7682 - accuracy: 0.7362
# Epoch 13/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.7201 - accuracy: 0.7526
# Epoch 14/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.6751 - accuracy: 0.7680
# Epoch 15/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.6291 - accuracy: 0.7842
# Epoch 16/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.5897 - accuracy: 0.7978
# Epoch 17/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.5484 - accuracy: 0.8122
# Epoch 18/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.5104 - accuracy: 0.8258
# Epoch 19/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.4824 - accuracy: 0.8374
# Epoch 20/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.4451 - accuracy: 0.8498
# Epoch 21/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.4180 - accuracy: 0.8585
# Epoch 22/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.3979 - accuracy: 0.8670
# Epoch 23/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.3755 - accuracy: 0.8749
# Epoch 24/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.3523 - accuracy: 0.8832
# Epoch 25/200
# 792/792 [==============================] - 10s 13ms/step - loss: 0.3290 - accuracy: 0.8899
# Epoch 26/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.3291 - accuracy: 0.8908
# Epoch 27/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.3030 - accuracy: 0.8983
# Epoch 28/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.2905 - accuracy: 0.9036
# Epoch 29/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.2776 - accuracy: 0.9071
# Epoch 30/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.2656 - accuracy: 0.9132
# Epoch 31/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.2538 - accuracy: 0.9166
# Epoch 32/200
# 792/792 [==============================] - 11s 13ms/step - loss: 0.2419 - accuracy: 0.9206
# Epoch 33/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.2376 - accuracy: 0.9221
# Epoch 34/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.2189 - accuracy: 0.9277
# Epoch 35/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.2113 - accuracy: 0.9305
# Epoch 36/200
# 792/792 [==============================] - 13s 16ms/step - loss: 0.2073 - accuracy: 0.9322
# Epoch 37/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.2022 - accuracy: 0.9349
# Epoch 38/200
# 792/792 [==============================] - 13s 16ms/step - loss: 0.1944 - accuracy: 0.9373
# Epoch 39/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.1857 - accuracy: 0.9383
# Epoch 40/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1795 - accuracy: 0.9412
# Epoch 41/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1798 - accuracy: 0.9413
# Epoch 42/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1720 - accuracy: 0.9439
# Epoch 43/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1640 - accuracy: 0.9463
# Epoch 44/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1608 - accuracy: 0.9482
# Epoch 45/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1606 - accuracy: 0.9482
# Epoch 46/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1594 - accuracy: 0.9490
# Epoch 47/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1459 - accuracy: 0.9541
# Epoch 48/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1455 - accuracy: 0.9524
# Epoch 49/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1437 - accuracy: 0.9539
# Epoch 50/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1377 - accuracy: 0.9561
# Epoch 51/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1373 - accuracy: 0.9557
# Epoch 52/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1302 - accuracy: 0.9580
# Epoch 53/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1268 - accuracy: 0.9595
# Epoch 54/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1241 - accuracy: 0.9601
# Epoch 55/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1192 - accuracy: 0.9611
# Epoch 56/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1225 - accuracy: 0.9601
# Epoch 57/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1202 - accuracy: 0.9622
# Epoch 58/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1159 - accuracy: 0.9627
# Epoch 59/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1138 - accuracy: 0.9636
# Epoch 60/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1101 - accuracy: 0.9652
# Epoch 61/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1121 - accuracy: 0.9649
# Epoch 62/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1087 - accuracy: 0.9658
# Epoch 63/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1130 - accuracy: 0.9639
# Epoch 64/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.1093 - accuracy: 0.9652
# Epoch 65/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0994 - accuracy: 0.9690
# Epoch 66/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0984 - accuracy: 0.9687
# Epoch 67/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1012 - accuracy: 0.9687
# Epoch 68/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.1002 - accuracy: 0.9675
# Epoch 69/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0951 - accuracy: 0.9710
# Epoch 70/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0914 - accuracy: 0.9712
# Epoch 71/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0932 - accuracy: 0.9710
# Epoch 72/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0927 - accuracy: 0.9710
# Epoch 73/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0908 - accuracy: 0.9712
# Epoch 74/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0909 - accuracy: 0.9716
# Epoch 75/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0858 - accuracy: 0.9735
# Epoch 76/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0853 - accuracy: 0.9730
# Epoch 77/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0822 - accuracy: 0.9741
# Epoch 78/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0871 - accuracy: 0.9727
# Epoch 79/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0853 - accuracy: 0.9736
# Epoch 80/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0750 - accuracy: 0.9760
# Epoch 81/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0806 - accuracy: 0.9754
# Epoch 82/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0811 - accuracy: 0.9744
# Epoch 83/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0808 - accuracy: 0.9749
# Epoch 84/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0777 - accuracy: 0.9764
# Epoch 85/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0748 - accuracy: 0.9771
# Epoch 86/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0753 - accuracy: 0.9772
# Epoch 87/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0758 - accuracy: 0.9763
# Epoch 88/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0770 - accuracy: 0.9760
# Epoch 89/200
# 792/792 [==============================] - 13s 16ms/step - loss: 0.0754 - accuracy: 0.9769
# Epoch 90/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0671 - accuracy: 0.9788
# Epoch 91/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0730 - accuracy: 0.9777
# Epoch 92/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0684 - accuracy: 0.9793
# Epoch 93/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0715 - accuracy: 0.9775
# Epoch 94/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0643 - accuracy: 0.9797
# Epoch 95/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0671 - accuracy: 0.9792
# Epoch 96/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0688 - accuracy: 0.9791
# Epoch 97/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0682 - accuracy: 0.9791
# Epoch 98/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0658 - accuracy: 0.9802
# Epoch 99/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0677 - accuracy: 0.9792
# Epoch 100/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0662 - accuracy: 0.9800
# Epoch 101/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0626 - accuracy: 0.9808
# Epoch 102/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0607 - accuracy: 0.9810
# Epoch 103/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0665 - accuracy: 0.9795
# Epoch 104/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0603 - accuracy: 0.9817
# Epoch 105/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0598 - accuracy: 0.9816
# Epoch 106/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0619 - accuracy: 0.9819
# Epoch 107/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0705 - accuracy: 0.9791
# Epoch 108/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0573 - accuracy: 0.9825
# Epoch 109/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0527 - accuracy: 0.9833
# Epoch 110/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0578 - accuracy: 0.9820
# Epoch 111/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0607 - accuracy: 0.9815
# Epoch 112/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0650 - accuracy: 0.9805
# Epoch 113/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0494 - accuracy: 0.9847
# Epoch 114/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0570 - accuracy: 0.9835
# Epoch 115/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0557 - accuracy: 0.9827
# Epoch 116/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0567 - accuracy: 0.9825
# Epoch 117/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0502 - accuracy: 0.9847
# Epoch 118/200
# 792/792 [==============================] - 11s 14ms/step - loss: 0.0544 - accuracy: 0.9837
# Epoch 119/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0518 - accuracy: 0.9846
# Epoch 120/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0600 - accuracy: 0.9817
# Epoch 121/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0544 - accuracy: 0.9830
# Epoch 122/200
# 792/792 [==============================] - 11s 15ms/step - loss: 0.0536 - accuracy: 0.9833
# Epoch 123/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0489 - accuracy: 0.9852
# Epoch 124/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0479 - accuracy: 0.9850
# Epoch 125/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0559 - accuracy: 0.9834
# Epoch 126/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0508 - accuracy: 0.9844
# Epoch 127/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0528 - accuracy: 0.9842
# Epoch 128/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0467 - accuracy: 0.9851
# Epoch 129/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0507 - accuracy: 0.9845
# Epoch 130/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0482 - accuracy: 0.9853
# Epoch 131/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0511 - accuracy: 0.9851
# Epoch 132/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0492 - accuracy: 0.9852
# Epoch 133/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0454 - accuracy: 0.9861
# Epoch 134/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0482 - accuracy: 0.9859
# Epoch 135/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0448 - accuracy: 0.9859
# Epoch 136/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0495 - accuracy: 0.9851
# Epoch 137/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0520 - accuracy: 0.9844
# Epoch 138/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0422 - accuracy: 0.9870
# Epoch 139/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0500 - accuracy: 0.9852
# Epoch 140/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0467 - accuracy: 0.9862
# Epoch 141/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0470 - accuracy: 0.9857
# Epoch 142/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0463 - accuracy: 0.9867
# Epoch 143/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0457 - accuracy: 0.9863
# Epoch 144/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0452 - accuracy: 0.9863
# Epoch 145/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0500 - accuracy: 0.9857
# Epoch 146/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0467 - accuracy: 0.9863
# Epoch 147/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0454 - accuracy: 0.9862
# Epoch 148/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0404 - accuracy: 0.9878
# Epoch 149/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0427 - accuracy: 0.9868
# Epoch 150/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0479 - accuracy: 0.9857
# Epoch 151/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0448 - accuracy: 0.9866
# Epoch 152/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0387 - accuracy: 0.9883
# Epoch 153/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0430 - accuracy: 0.9872
# Epoch 154/200
# 792/792 [==============================] - 12s 16ms/step - loss: 0.0502 - accuracy: 0.9849
# Epoch 155/200
# 792/792 [==============================] - 13s 17ms/step - loss: 0.0426 - accuracy: 0.9876
# Epoch 156/200
# 792/792 [==============================] - 12s 16ms/step - loss: 0.0390 - accuracy: 0.9872
# Epoch 157/200
# 792/792 [==============================] - 13s 16ms/step - loss: 0.0392 - accuracy: 0.9880
# Epoch 158/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0408 - accuracy: 0.9877
# Epoch 159/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0416 - accuracy: 0.9873
# Epoch 160/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0402 - accuracy: 0.9880
# Epoch 161/200
# 792/792 [==============================] - 12s 16ms/step - loss: 0.0394 - accuracy: 0.9880
# Epoch 162/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0364 - accuracy: 0.9890
# Epoch 163/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0385 - accuracy: 0.9886
# Epoch 164/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0395 - accuracy: 0.9886
# Epoch 165/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0412 - accuracy: 0.9880
# Epoch 166/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0396 - accuracy: 0.9881
# Epoch 167/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0398 - accuracy: 0.9880
# Epoch 168/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0392 - accuracy: 0.9882
# Epoch 169/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0398 - accuracy: 0.9883
# Epoch 170/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0383 - accuracy: 0.9882
# Epoch 171/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0380 - accuracy: 0.9888
# Epoch 172/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0381 - accuracy: 0.9890
# Epoch 173/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0355 - accuracy: 0.9895
# Epoch 174/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0389 - accuracy: 0.9882
# Epoch 175/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0379 - accuracy: 0.9885
# Epoch 176/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0351 - accuracy: 0.9896
# Epoch 177/200
# 792/792 [==============================] - 12s 16ms/step - loss: 0.0387 - accuracy: 0.9884
# Epoch 178/200
# 792/792 [==============================] - 12s 16ms/step - loss: 0.0385 - accuracy: 0.9887
# Epoch 179/200
# 792/792 [==============================] - 14s 17ms/step - loss: 0.0353 - accuracy: 0.9892
# Epoch 180/200
# 792/792 [==============================] - 13s 16ms/step - loss: 0.0358 - accuracy: 0.9894
# Epoch 181/200
# 792/792 [==============================] - 12s 16ms/step - loss: 0.0360 - accuracy: 0.9896
# Epoch 182/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0361 - accuracy: 0.9889
# Epoch 183/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0386 - accuracy: 0.9888
# Epoch 184/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0350 - accuracy: 0.9898
# Epoch 185/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0340 - accuracy: 0.9901
# Epoch 186/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0367 - accuracy: 0.9892
# Epoch 187/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0327 - accuracy: 0.9907
# Epoch 188/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0384 - accuracy: 0.9889
# Epoch 189/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0391 - accuracy: 0.9892
# Epoch 190/200
# 792/792 [==============================] - 13s 16ms/step - loss: 0.0307 - accuracy: 0.9902
# Epoch 191/200
# 792/792 [==============================] - 13s 16ms/step - loss: 0.0375 - accuracy: 0.9894
# Epoch 192/200
# 792/792 [==============================] - 12s 16ms/step - loss: 0.0369 - accuracy: 0.9891
# Epoch 193/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0329 - accuracy: 0.9905
# Epoch 194/200
# 792/792 [==============================] - 12s 16ms/step - loss: 0.0341 - accuracy: 0.9898
# Epoch 195/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0296 - accuracy: 0.9910
# Epoch 196/200
# 792/792 [==============================] - 12s 16ms/step - loss: 0.0356 - accuracy: 0.9892
# Epoch 197/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0343 - accuracy: 0.9894
# Epoch 198/200
# 792/792 [==============================] - 12s 15ms/step - loss: 0.0319 - accuracy: 0.9905
# Epoch 199/200
# 792/792 [==============================] - 12s 16ms/step - loss: 0.0310 - accuracy: 0.9906
# Epoch 200/200
# 792/792 [==============================] - 12s 16ms/step - loss: 0.0333 - accuracy: 0.9905

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# #### SAVE MODEL

# %%
##################
# # save model # #
##################
model.model.save(MODEL_PATH)

# %% [markdown]
# # LIVE TESTING
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()
# Out:
#   Subject Sequence    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    adhy    quell  0.120807 -0.024914   0.095893   0.127188   0.247994
# 1    adhy    quell  0.120807 -0.024914   0.095893   0.127188   0.247994
# 2    adhy    quell  0.120807 -0.024914   0.095893   0.127188   0.247994
# 3    adhy    quell  0.120807 -0.024914   0.095893   0.127188   0.247994
# 4    adhy    quell  0.120807 -0.024914   0.095893   0.127188   0.247994
#
#      T2-D|1  T2-I|1+2  T2-PF|1+2  ...   T4-RF|VAR.1  T4-NG|VAR.1  T4-I|SD.1  \
# 0  0.152102 -0.024045   0.128057  ...  9.412329e-03     0.006395   0.062381
# 1  0.152102 -0.024045   0.128057  ...  3.720000e-07     0.000002   0.006328
# 2  0.152102 -0.024045   0.128057  ...  3.322198e-01     0.288946   0.525115
# 3  0.152102 -0.024045   0.128057  ...  3.054200e-04     0.000046   0.034640
# 4  0.152102 -0.024045   0.128057  ...  1.692164e-02     0.011546   0.107475
#
#    T4-PF|SD.1  T4-RF|SD.1  T4-NG|SD.1  T5-I|0+4.1  T5-PF|0+4.1  T5-RF|0+4.1  \
# 0    0.045333    0.097017    0.079969    0.423147     0.582937     0.551112
# 1    0.005632    0.000610    0.001306    0.335316     0.454740     0.408114
# 2    0.486267    0.576385    0.537537    1.078749     1.151358     1.166748
# 3    0.045301    0.017476    0.006815    0.352062     0.472674     0.439222
# 4    0.084844    0.130083    0.107452    0.296025     0.408024     0.384050
#
#    T5-NG|0+4.1
# 0     0.710902
# 1     0.527538
# 2     1.239357
# 3     0.559834
# 4     0.496050
#
# [5 rows x 196 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
actual_np = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

########################
# # predict all rows # #
########################
pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[46:54,FEATURES_COL_NUM:]
# print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

print(class_list)
Y = np.asarray(class_list)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)
# Out:
# ['adhy', 'andy', 'bryce', 'chris', 'cy', 'hr', 'jc', 'ys']

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

# pred_proba = np.sum(pred_proba, axis=0)
# pred_proba = np.reshape(pred_proba, (1, 9))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

match_list = []

for _ in range(actual_np.size):
    if pred[_] == actual_np[_]:
        match_list.append("match")
    else:
        match_list.append("nope")

match_count = match_list.count("match")
total_count = len(match_list)

match_header = str(match_count) + "/" + str(total_count) + " (" + str(match_count/total_count*100)+ "%)"
match_np = np.array(match_list)

exported_output = np.column_stack((actual_np, pred))
exported_output = np.column_stack((exported_output, acc))
exported_output = np.column_stack((exported_output, match_np))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(data=exported_output, index=None, columns=['Actual', 'Prediction', 'Accuracy', match_header])
# print(df)
df.to_csv(RESULT_PATH)

print("Accuracy of the Model is: " + str(match_header))
# Out:
# Accuracy of the Model is: 280/720 (38.88888888888889%)
