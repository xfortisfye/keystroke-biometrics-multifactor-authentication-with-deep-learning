# %% [markdown]
# #### IMPORT

# %%
import os, platform
import py7zr

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %% [markdown]
# #### PARAMETERS
# - Set the condition
# > * N_FEATURES: Number of Features
# > * CHECK_BLANKS: Check for blank data. If any blank data is found, the whole row of data will be deleted.
# > * CHECK_CLASS_IMBALANCE: Check for dataset class imbalance. The more balance the dataset, the less biases the model will be.

# %%
##############################
# # deep learning features # #
##############################
SEED = 1005 # random seed for reproducibility

# should make this dynamic
N_FEATURES = 644
TIMESTEPS = 1
EPOCH=200
BATCH_SIZE=100

SPLIT_RATIO=0.2

###############
# # preview # #
###############
f = False
t = True

# checking dataset
CHECK_BLANKS = True
CHECK_CLASS_IMBALANCE = True

# evaluate suitable kfold number and kfold model
MIN_KFOLD = 2
MAX_KFOLD = 11
N_KFOLD = 5
EVAL_KFOLD_NUM = False
EVAL_KFOLD_MODEL = False
PERFORM_KFOLD = False

# model testing
TEST_MODEL = True
CON_MATRIX = True
ROC_GRAPH = True

###############
# # dataset # #
###############
CLASSES_COL_NAME = "Subject"
CLASSES_COL_NUM = 0
FEATURES_COL_NUM = 3

METHOD = "IU"
# METHOD = "DU"

DATASET_DIR_NAME = "dataset\set02\\02_pair"
SAMPLE_DATASET_NAME = "pair_train"
ACTUAL_DATASET_NAME = "pair_test_" + METHOD

MODEL_DIR_NAME = "dataset\set02\\02_pair"
MODEL_NAME = "model_" + "set02_02_pair_" + METHOD

RESULT_DIR_NAME = "dataset\set02\\02_pair"
RESULT_NAME = "result_" + "set02_02_pair_" + METHOD

DATASET_DIR_PATH = os.path.join(os.getcwd(), DATASET_DIR_NAME)
SAMPLE_DATASET_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".csv")
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME + ".csv")

MODEL_DIR_PATH = os.path.join(os.getcwd(), MODEL_DIR_NAME)
MODEL_PATH = os.path.join(MODEL_DIR_PATH, MODEL_NAME + ".h5")

RESULT_DIR_PATH = os.path.join(os.getcwd(), RESULT_DIR_NAME)
RESULT_PATH = os.path.join(RESULT_DIR_PATH, RESULT_NAME + ".csv")

#################
# # sns theme # #
#################
# sns.set_theme(style="darkgrid") # (dark background with white gridlines)
sns.set_theme(style="whitegrid") # (white background with grey gridlines)
# sns.set_theme(style="dark") # (dark background with no gridlines)
# sns.set_theme(style="white") # (white background with no gridlines)
# sns.set_theme(style="ticks") # (white background with axis ticks and no gridlines)

# %%
if os.path.isdir(DATASET_DIR_PATH) is True:
    print(f"Dataset directory exists at: {DATASET_DIR_PATH}")
else:
    try:
        os.mkdir(DATASET_DIR_PATH, 666)
        print(f"Dataset directory have been created at: {DATASET_DIR_PATH}")
    except:
        print("Error: Dataset Directory not created")
        
if os.path.isdir(MODEL_DIR_PATH) is True:
    print(f"Model directory exists at: {MODEL_DIR_PATH}")
else:
    try:
        os.mkdir(MODEL_DIR_PATH, 666)
        print(f"Model directory have been created at: {MODEL_DIR_PATH}")
    except:
        print("Error: Model Directory not created")
    
if os.path.exists(SAMPLE_DATASET_PATH) is True:
    print(f"Training dataset exists at: {SAMPLE_DATASET_PATH}")
else:
    try:
        SAMPLE_7Z_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".7z")
        with py7zr.SevenZipFile(SAMPLE_7Z_PATH, mode='r') as z:
            z.extractall(path=DATASET_DIR_PATH)
        print(f"Decompress 7z file to: {SAMPLE_7Z_PATH}")
    except:
        print("Error: Failed to decompress 7z file.")
# Out:
# Dataset directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set02\02_pair
# Model directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set02\02_pair
# Training dataset exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set02\02_pair\pair_train.csv

# %% [markdown]
# #### CREATE MODEL
# - Create base model
# - Wrap it with KerasClassifier

# %%
#create base model
def create_base_model():
    model = Sequential()
    model.add(LSTM(units=256, return_sequences=True,
             input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dense(256, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=32, return_sequences=True))
    model.add(Dense(32, activation='sigmoid'))
    model.add(Dropout(0.2))

    # softmax for multi-class classification
    model.add(Flatten())
    print("There are a total of " + str(n_classes) + " classes.")
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=EPOCH, 
                            batch_size=BATCH_SIZE)
    return model

# %%
# divide data into features X and target (classes) Y
def prepare_dataset(df):
    X = df.values[:,FEATURES_COL_NUM:].astype(float)
    Y = df.values[:,CLASSES_COL_NUM].astype(str)

    # convert target Y to labelbinarizer Y for model
    # fit_transform is not used to reuse lb
    Y = Y.reshape(-1, 1)
    lb = LabelBinarizer().fit(Y)
    Y = lb.transform(Y)

    #################################
    # # get all the encoded class # #
    #################################
    print("LabelBinarizer is able to decipher: ")
    print(lb.classes_)
    print("\n")

    ###########################
    # # print X and Y shape # #
    ###########################
    print(f"X | Features | Dataset Shape: {X.shape}")
    print(f"Y | Classes  | Dataset Shape: {Y.shape}")

    return X, Y, lb, lb.classes_.tolist()

# %%
def split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED):

    ##############################################################
    # # split dataset into train and test set of 0.8/0.2 ratio # #
    ##############################################################
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=SPLIT_RATIO, random_state=SEED)

    ############################
    # # reshaping of dataset # #
    ############################

    # reshaping the dataset to include LSTM Timesteps
    print(X_train.dtype)
    X_train = np.asarray(X_train, dtype=np.float32)
    print(X_train.dtype)
    X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
    print(X_test.dtype)
    X_test = np.asarray(X_test, dtype=np.float32)
    print(X_test.dtype)
    X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

    print(f"X train shape: {X_train.shape}")
    print(f"Y train shape: {y_train.shape}")
    print(f"X test shape: {X_test.shape}")
    print(f"Y test shape: {y_test.shape}")
    
    return X_train, X_test, y_train, y_test

def reshape_dataset(X, TIMESTEPS):
    # reshaping the dataset to include LSTM Timesteps
    X = np.asarray(X, dtype=np.float32)
    X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))
    return X

# %% [markdown]
# #### LOAD DATASET

# %%
# load dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)
df.head()
# Out:
#   Subject  Seq_No    Sequence    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  \
# 0    adhy       3  ohm filmed  0.154125  0.093798   0.247924   0.232284
# 1    adhy       3  ohm filmed  0.154125  0.093798   0.247924   0.232284
# 2    adhy       3  ohm filmed  0.154125  0.093798   0.247924   0.232284
# 3    adhy       3  ohm filmed  0.154125  0.093798   0.247924   0.232284
# 4    adhy       3  ohm filmed  0.154125  0.093798   0.247924   0.232284
#
#    T2-NG|0+1    T2-D|1  T2-I|1+2  ...  T9-RF|VAR.1  T9-NG|VAR.1  T9-I|SD.1  \
# 0    0.38641  0.138486  0.300717  ...     0.057276     0.076773   0.190323
# 1    0.38641  0.138486  0.300717  ...     0.009492     0.015453   0.104051
# 2    0.38641  0.138486  0.300717  ...     0.000120     0.000495   0.010872
# 3    0.38641  0.138486  0.300717  ...     0.017052     0.028381   0.103736
# 4    0.38641  0.138486  0.300717  ...     0.005920     0.002835   0.039002
#
#    T9-PF|SD.1  T9-RF|SD.1  T9-NG|SD.1  T10-I|0+9.1  T10-PF|0+9.1  \
# 0    0.228078    0.239324    0.277080     1.389586      1.574769
# 1    0.130934    0.097427    0.124309     1.549967      1.703701
# 2    0.022351    0.010968    0.022256     1.373775      1.521285
# 3    0.141618    0.130585    0.168467     1.520914      1.690571
# 4    0.015306    0.076939    0.053243     1.622926      1.725926
#
#    T10-RF|0+9.1  T10-NG|0+9.1
# 0      1.505635      1.690818
# 1      1.713320      1.867054
# 2      1.489826      1.637336
# 3      1.599130      1.768788
# 4      1.722979      1.825979
#
# [5 rows x 647 columns]

# %% [markdown]
# #### CHECK DATASET

# %%
########################
# # check for blanks # #
########################
if CHECK_BLANKS is True:
    # checking for blanks
    print("Checking for blanks...")
    if df.isnull().values.any() is True:
        df = df.dropna(axis=0, how="any")
        print("Blank rows has been dropped.")
    else:
        print("No blank value has been found.")
        
#################################
# # check for class imbalance # #
#################################
if CHECK_CLASS_IMBALANCE is True:
    print("Checking for class imbalance...")
    sns.countplot(x=CLASSES_COL_NAME, data=df).set_title("Class Imbalance")
#     df.loc[(df!=0).any(axis=1)]
    plt.show()

sns.catplot(x="Subject", y="T2-D|0", hue="T2-D|0", data=df, legend=False)
sns.catplot(x="Subject", y="T2-I|0+1", hue="T2-I|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-PF|0+1", hue="T2-PF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-RF|0+1", hue="T2-RF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-D|1", hue="T2-D|1", data=df, legend=False)
# Out:
# Checking for blanks...
# No blank value has been found.
# Checking for class imbalance...

# %% [markdown]
# #### PREPARE DATASET
# - Split data based on X / Features and Y / Classes
# - Binarize Y into binary labels

# %%
X, Y, lb, class_list = prepare_dataset(df)
n_classes = len(class_list)
print(f"Number of Classes: {n_classes}")
# Out:
# LabelBinarizer is able to decipher:
# ['adhy' 'alan' 'andy' 'bryce' 'chris' 'cy' 'gerald' 'jc' 'jonah' 'qk']
#
#
# X | Features | Dataset Shape: (63480, 644)
# Y | Classes  | Dataset Shape: (63480, 10)
# Number of Classes: 10

# %% [markdown]
# #### SPLIT DATASET
# - Split dataset into train set and test set 0.8 / 0.2

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED)
# Out:
# float64
# float32
# float64
# float32
# X train shape: (50784, 1, 644)
# Y train shape: (50784, 10)
# X test shape: (12696, 1, 644)
# Y test shape: (12696, 10)

# %% [markdown]
# #### PERFORM VALIDATION (w KFold Validation)
# - Evaluate best KFold Validation
# - Generate loss and accuracy graph
# - Perform KFold validation

# %% [markdown]
# ##### Evaluate suitable folds for kfold validation

# %%
###############################################
# # evaluate suitable kfold value for model # #
###############################################
def evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD):
    
    # evaluate the model    
    folds = range(MIN_KFOLD, MAX_KFOLD)
    means, mins, maxs = list(), list(), list()
    
    # evaluate each k value
    for k in folds:
        # define the test condition
        kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
        
        # evaluate k value
        model = create_model()
        scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
        k_mean = np.mean(scores)
        k_min = scores.min()
        k_max = scores.max()
        
        # report performance
        print(f"No. of Folds: {k} | Accuracy: {k_mean*100:.3f} | Min: {k_min*100:.3f} | Max: {k_max*100:.3f}")
        
        # store mean accuracy and min and max relative to the mean
        means.append(k_mean)
        mins.append(k_mean - k_min)
        maxs.append(k_max - k_mean)
        
    # line plot of k mean values with min/max error bars
    clear_output(wait=True)
    pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
    # show the plot
    pyplot.show()
    
if EVAL_KFOLD_NUM is True:
    evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD)
else:
    print("EVAL_KFOLD_NUM is not True")
# Out:
# EVAL_KFOLD_NUM is not True

# %% [markdown]
# ##### Generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=50, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print(f"Accuracy | Mean: {np.mean(scores)*100:.3f} | Std: {np.std(scores)*100:.3f} | Length/no.: {len(scores)}")
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    clear_output(wait=True)
    plt.show()
    
if EVAL_KFOLD_MODEL is True:
    evaluate_kfold_model(X_train, y_train, SEED)
else:
    print("EVAL_KFOLD_MODEL is not true")
# Out:
# EVAL_KFOLD_MODEL is not true

# %% [markdown]
# ##### Perform Actual KFold validation

# %%
if PERFORM_KFOLD is True:
    # create model
    model = create_model()
    kfold = KFold(n_splits=N_KFOLD, shuffle=True, random_state=SEED)
    valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# ##### Get Validation Accuracy

# %%
if PERFORM_KFOLD is True:
    print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# #### FIT MODEL FOR TESTING
# - Fit the Model
# - View Accuracy and Loss Graph
# - View Model Summary

# %%
#####################
# # fit the model # #
#####################

if TEST_MODEL is True:
    model = create_model()
    es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                       verbose=1)
    history = model.fit(X_train, y_train, callbacks=es, verbose=1)
# Out:
# There are a total of 10 classes.
# Epoch 1/200
# 508/508 [==============================] - 18s 20ms/step - loss: 1.9352 - accuracy: 0.2414
# Epoch 2/200
# 508/508 [==============================] - 10s 19ms/step - loss: 1.5050 - accuracy: 0.3564
# Epoch 3/200
# 508/508 [==============================] - 11s 21ms/step - loss: 1.4020 - accuracy: 0.3998
# Epoch 4/200
# 508/508 [==============================] - 10s 20ms/step - loss: 1.3136 - accuracy: 0.4511
# Epoch 5/200
# 508/508 [==============================] - 10s 19ms/step - loss: 1.1893 - accuracy: 0.5072
# Epoch 6/200
# 508/508 [==============================] - 9s 19ms/step - loss: 1.1073 - accuracy: 0.5411
# Epoch 7/200
# 508/508 [==============================] - 10s 19ms/step - loss: 1.0566 - accuracy: 0.5801
# Epoch 8/200
# 508/508 [==============================] - 11s 21ms/step - loss: 1.0126 - accuracy: 0.6081
# Epoch 9/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.9887 - accuracy: 0.6195
# Epoch 10/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.9636 - accuracy: 0.6269
# Epoch 11/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.9381 - accuracy: 0.6371
# Epoch 12/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.9310 - accuracy: 0.6446
# Epoch 13/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.9086 - accuracy: 0.6513
# Epoch 14/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.8973 - accuracy: 0.6572
# Epoch 15/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.8847 - accuracy: 0.6631
# Epoch 16/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.8609 - accuracy: 0.6695
# Epoch 17/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.8533 - accuracy: 0.6746
# Epoch 18/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.8259 - accuracy: 0.6846
# Epoch 19/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.8285 - accuracy: 0.6824
# Epoch 20/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.8036 - accuracy: 0.6930
# Epoch 21/200
# 508/508 [==============================] - 14s 28ms/step - loss: 0.7862 - accuracy: 0.6997
# Epoch 22/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.7775 - accuracy: 0.6986
# Epoch 23/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.7622 - accuracy: 0.7089
# Epoch 24/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.7681 - accuracy: 0.7053
# Epoch 25/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.7473 - accuracy: 0.7152
# Epoch 26/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.7334 - accuracy: 0.7193
# Epoch 27/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.7258 - accuracy: 0.7219
# Epoch 28/200
# 508/508 [==============================] - 10s 21ms/step - loss: 0.7179 - accuracy: 0.7268
# Epoch 29/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.7095 - accuracy: 0.7297
# Epoch 30/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.6924 - accuracy: 0.7346
# Epoch 31/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.6852 - accuracy: 0.7397
# Epoch 32/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.6756 - accuracy: 0.7445
# Epoch 33/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.6613 - accuracy: 0.7489
# Epoch 34/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.6702 - accuracy: 0.7465
# Epoch 35/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.6531 - accuracy: 0.7549
# Epoch 36/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.6418 - accuracy: 0.7608
# Epoch 37/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.6425 - accuracy: 0.7616
# Epoch 38/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.6292 - accuracy: 0.7665
# Epoch 39/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.6594 - accuracy: 0.7573
# Epoch 40/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.6047 - accuracy: 0.7764
# Epoch 41/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.6010 - accuracy: 0.7788
# Epoch 42/200
# 508/508 [==============================] - 13s 25ms/step - loss: 0.5921 - accuracy: 0.7833
# Epoch 43/200
# 508/508 [==============================] - 13s 26ms/step - loss: 0.5812 - accuracy: 0.7875
# Epoch 44/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.5817 - accuracy: 0.7869
# Epoch 45/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.5712 - accuracy: 0.7953
# Epoch 46/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.5496 - accuracy: 0.8004
# Epoch 47/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.5469 - accuracy: 0.8016
# Epoch 48/200
# 508/508 [==============================] - 12s 23ms/step - loss: 0.5478 - accuracy: 0.8035
# Epoch 49/200
# 508/508 [==============================] - 13s 26ms/step - loss: 0.5260 - accuracy: 0.8100
# Epoch 50/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.5178 - accuracy: 0.8123
# Epoch 51/200
# 508/508 [==============================] - 12s 23ms/step - loss: 0.5184 - accuracy: 0.8132
# Epoch 52/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.5062 - accuracy: 0.8192
# Epoch 53/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.5008 - accuracy: 0.8192
# Epoch 54/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.4959 - accuracy: 0.8221
# Epoch 55/200
# 508/508 [==============================] - 12s 24ms/step - loss: 0.4831 - accuracy: 0.8240
# Epoch 56/200
# 508/508 [==============================] - 12s 23ms/step - loss: 0.4881 - accuracy: 0.8262
# Epoch 57/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.4700 - accuracy: 0.8293
# Epoch 58/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.4641 - accuracy: 0.8329
# Epoch 59/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.4720 - accuracy: 0.8307
# Epoch 60/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.4590 - accuracy: 0.8349
# Epoch 61/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.4457 - accuracy: 0.8397
# Epoch 62/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.4471 - accuracy: 0.8400
# Epoch 63/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.4570 - accuracy: 0.8364
# Epoch 64/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.4382 - accuracy: 0.8436
# Epoch 65/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.4349 - accuracy: 0.8451
# Epoch 66/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.4246 - accuracy: 0.8485
# Epoch 67/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.4311 - accuracy: 0.8458
# Epoch 68/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.4160 - accuracy: 0.8515
# Epoch 69/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.4231 - accuracy: 0.8510
# Epoch 70/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.4198 - accuracy: 0.8520
# Epoch 71/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.4241 - accuracy: 0.8483
# Epoch 72/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.3916 - accuracy: 0.8593
# Epoch 73/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.4061 - accuracy: 0.8562
# Epoch 74/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.3818 - accuracy: 0.8632
# Epoch 75/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.3950 - accuracy: 0.8592
# Epoch 76/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.4086 - accuracy: 0.8559
# Epoch 77/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.3796 - accuracy: 0.8649
# Epoch 78/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.3821 - accuracy: 0.8642
# Epoch 79/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.3841 - accuracy: 0.8637
# Epoch 80/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.3827 - accuracy: 0.8643
# Epoch 81/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.3789 - accuracy: 0.8672
# Epoch 82/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.3610 - accuracy: 0.8708
# Epoch 83/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.3544 - accuracy: 0.8727
# Epoch 84/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.3590 - accuracy: 0.8732
# Epoch 85/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.3494 - accuracy: 0.8745
# Epoch 86/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.3337 - accuracy: 0.8816
# Epoch 87/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.3437 - accuracy: 0.8778
# Epoch 88/200
# 508/508 [==============================] - 12s 24ms/step - loss: 0.3593 - accuracy: 0.8737
# Epoch 89/200
# 508/508 [==============================] - 12s 23ms/step - loss: 0.3350 - accuracy: 0.8797
# Epoch 90/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.3304 - accuracy: 0.8818
# Epoch 91/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.3300 - accuracy: 0.8836
# Epoch 92/200
# 508/508 [==============================] - 10s 21ms/step - loss: 0.3299 - accuracy: 0.8832
# Epoch 93/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.3306 - accuracy: 0.8833
# Epoch 94/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.3316 - accuracy: 0.8833
# Epoch 95/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.3254 - accuracy: 0.8839
# Epoch 96/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.3274 - accuracy: 0.8851
# Epoch 97/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.3095 - accuracy: 0.8887
# Epoch 98/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.3107 - accuracy: 0.8907
# Epoch 99/200
# 508/508 [==============================] - 10s 21ms/step - loss: 0.3154 - accuracy: 0.8894
# Epoch 100/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.2999 - accuracy: 0.8930
# Epoch 101/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2946 - accuracy: 0.8972
# Epoch 102/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2929 - accuracy: 0.8967
# Epoch 103/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.2903 - accuracy: 0.8983
# Epoch 104/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.3017 - accuracy: 0.8947
# Epoch 105/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2963 - accuracy: 0.8958
# Epoch 106/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.2800 - accuracy: 0.9018
# Epoch 107/200
# 508/508 [==============================] - 12s 23ms/step - loss: 0.2911 - accuracy: 0.8962
# Epoch 108/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2857 - accuracy: 0.9008
# Epoch 109/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2709 - accuracy: 0.9054
# Epoch 110/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2708 - accuracy: 0.9048
# Epoch 111/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2699 - accuracy: 0.9047
# Epoch 112/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2648 - accuracy: 0.9076
# Epoch 113/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.2707 - accuracy: 0.9055
# Epoch 114/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.3033 - accuracy: 0.8940
# Epoch 115/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2735 - accuracy: 0.9040
# Epoch 116/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.2691 - accuracy: 0.9055
# Epoch 117/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.2943 - accuracy: 0.8990
# Epoch 118/200
# 508/508 [==============================] - 10s 21ms/step - loss: 0.2650 - accuracy: 0.9076
# Epoch 119/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.2613 - accuracy: 0.9096
# Epoch 120/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.2575 - accuracy: 0.9099
# Epoch 121/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.2624 - accuracy: 0.9073
# Epoch 122/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2505 - accuracy: 0.9137
# Epoch 123/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2442 - accuracy: 0.9154
# Epoch 124/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2453 - accuracy: 0.9155
# Epoch 125/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2595 - accuracy: 0.9104
# Epoch 126/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.2325 - accuracy: 0.9190
# Epoch 127/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.2334 - accuracy: 0.9191
# Epoch 128/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2362 - accuracy: 0.9172
# Epoch 129/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.2504 - accuracy: 0.9151
# Epoch 130/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2322 - accuracy: 0.9185
# Epoch 131/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.2266 - accuracy: 0.9194
# Epoch 132/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2287 - accuracy: 0.9198
# Epoch 133/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.2269 - accuracy: 0.9225
# Epoch 134/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2397 - accuracy: 0.9165
# Epoch 135/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2584 - accuracy: 0.9147
# Epoch 136/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.2229 - accuracy: 0.9226
# Epoch 137/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.2158 - accuracy: 0.9249
# Epoch 138/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.2163 - accuracy: 0.9253
# Epoch 139/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.2161 - accuracy: 0.9264
# Epoch 140/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.2251 - accuracy: 0.9233
# Epoch 141/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.2265 - accuracy: 0.9228
# Epoch 142/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.2073 - accuracy: 0.9290
# Epoch 143/200
# 508/508 [==============================] - 12s 24ms/step - loss: 0.2096 - accuracy: 0.9272
# Epoch 144/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.2413 - accuracy: 0.9186
# Epoch 145/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.2101 - accuracy: 0.9286
# Epoch 146/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.2109 - accuracy: 0.9275
# Epoch 147/200
# 508/508 [==============================] - 9s 18ms/step - loss: 0.2014 - accuracy: 0.9309
# Epoch 148/200
# 508/508 [==============================] - 9s 18ms/step - loss: 0.2012 - accuracy: 0.9316
# Epoch 149/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.2083 - accuracy: 0.9292
# Epoch 150/200
# 508/508 [==============================] - 10s 21ms/step - loss: 0.2005 - accuracy: 0.9295
# Epoch 151/200
# 508/508 [==============================] - 11s 21ms/step - loss: 0.2074 - accuracy: 0.9286
# Epoch 152/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2813 - accuracy: 0.9089
# Epoch 153/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.2195 - accuracy: 0.9241
# Epoch 154/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.2130 - accuracy: 0.9259
# Epoch 155/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2012 - accuracy: 0.9310
# Epoch 156/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.2368 - accuracy: 0.9213
# Epoch 157/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.1974 - accuracy: 0.9317
# Epoch 158/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1888 - accuracy: 0.9348
# Epoch 159/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.2034 - accuracy: 0.9314
# Epoch 160/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1850 - accuracy: 0.9375
# Epoch 161/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1978 - accuracy: 0.9322
# Epoch 162/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1965 - accuracy: 0.9344
# Epoch 163/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1852 - accuracy: 0.9368
# Epoch 164/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1755 - accuracy: 0.9394
# Epoch 165/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1872 - accuracy: 0.9365
# Epoch 166/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.1755 - accuracy: 0.9393
# Epoch 167/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.1862 - accuracy: 0.9372
# Epoch 168/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1746 - accuracy: 0.9398
# Epoch 169/200
# 508/508 [==============================] - 9s 18ms/step - loss: 0.1752 - accuracy: 0.9403
# Epoch 170/200
# 508/508 [==============================] - 11s 22ms/step - loss: 0.1893 - accuracy: 0.9362
# Epoch 171/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1711 - accuracy: 0.9417
# Epoch 172/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1805 - accuracy: 0.9390
# Epoch 173/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1730 - accuracy: 0.9413
# Epoch 174/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1639 - accuracy: 0.9441
# Epoch 175/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1850 - accuracy: 0.9379
# Epoch 176/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1703 - accuracy: 0.9427
# Epoch 177/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1780 - accuracy: 0.9399
# Epoch 178/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1795 - accuracy: 0.9408
# Epoch 179/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1831 - accuracy: 0.9387
# Epoch 180/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1670 - accuracy: 0.9434
# Epoch 181/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1623 - accuracy: 0.9450
# Epoch 182/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1651 - accuracy: 0.9437
# Epoch 183/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1569 - accuracy: 0.9460
# Epoch 184/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1666 - accuracy: 0.9449
# Epoch 185/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1596 - accuracy: 0.9464
# Epoch 186/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1687 - accuracy: 0.9442
# Epoch 187/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1830 - accuracy: 0.9396
# Epoch 188/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.1535 - accuracy: 0.9473
# Epoch 189/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1530 - accuracy: 0.9486
# Epoch 190/200
# 508/508 [==============================] - 9s 18ms/step - loss: 0.1514 - accuracy: 0.9488
# Epoch 191/200
# 508/508 [==============================] - 9s 18ms/step - loss: 0.1483 - accuracy: 0.9488
# Epoch 192/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1542 - accuracy: 0.9473
# Epoch 193/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1510 - accuracy: 0.9500
# Epoch 194/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1513 - accuracy: 0.9491
# Epoch 195/200
# 508/508 [==============================] - 9s 19ms/step - loss: 0.1675 - accuracy: 0.9438
# Epoch 196/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.1581 - accuracy: 0.9481
# Epoch 197/200
# 508/508 [==============================] - 10s 20ms/step - loss: 0.1510 - accuracy: 0.9502
# Epoch 198/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1424 - accuracy: 0.9511
# Epoch 199/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1478 - accuracy: 0.9491
# Epoch 200/200
# 508/508 [==============================] - 10s 19ms/step - loss: 0.1436 - accuracy: 0.9514

# %%
if TEST_MODEL is True:
    ##########################
    # # get model accuracy # #
    ##########################
    plt.plot(history.history['accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

    ######################
    # # get model loss # #
    ######################
    plt.plot(history.history['loss'])
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

# %%
if TEST_MODEL is True:
    ##########################
    # # view model summary # #
    ##########################
    model.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 256)            922624
#
#  dense (Dense)               (None, 1, 256)            65792
#
#  dropout (Dropout)           (None, 1, 256)            0
#
#  batch_normalization (BatchN  (None, 1, 256)           1024
#  ormalization)
#
#  lstm_1 (LSTM)               (None, 1, 128)            197120
#
#  dense_1 (Dense)             (None, 1, 128)            16512
#
#  dropout_1 (Dropout)         (None, 1, 128)            0
#
#  batch_normalization_1 (Batc  (None, 1, 128)           512
#  hNormalization)
#
#  lstm_2 (LSTM)               (None, 1, 64)             49408
#
#  dense_2 (Dense)             (None, 1, 64)             4160
#
#  dropout_2 (Dropout)         (None, 1, 64)             0
#
#  batch_normalization_2 (Batc  (None, 1, 64)            256
#  hNormalization)
#
#  lstm_3 (LSTM)               (None, 1, 32)             12416
#
#  dense_3 (Dense)             (None, 1, 32)             1056
#
#  dropout_3 (Dropout)         (None, 1, 32)             0
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense_4 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 1,271,210
# Trainable params: 1,270,314
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# #### MODEL TESTING
# - Get Model Accuracy on the Test Dataset
# - Generate Confusion Matrix
# - Generate ROC Curves
# - Save the Model if Appropriate

# %%
if TEST_MODEL is True:
    y_pred = model.predict_proba(X_test)

    # evaluate predictions
    acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    print("Testing accuracy: %.3f%%" % (acc*100))
# Out:
# Testing accuracy: 87.799%

# %% [markdown]
# ##### Confusion Matrix

# %%
if TEST_MODEL is True and CON_MATRIX is True:
    # confusion matrix
    print(str(len(y_pred)) + " is the number of test value in kfold_val / train_test_split")
    cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                         columns = [i for i in np.unique(lb.inverse_transform(y_test))])

    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=True, cmap="BuPu")
# Out:
# 12696 is the number of test value in kfold_val / train_test_split

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
if TEST_MODEL is True and ROC_GRAPH is True: # compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    for i in range(n_classes):
        plt.figure()
        lw = 2
        plt.plot(
            fpr[i],
            tpr[i],
            color="darkorange",
            lw=lw,
            label="ROC curve (area = %0.2f)" % roc_auc[i],
        )
        plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
        plt.xlim([-0.005, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ##### ROC Curve (Multiclass)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    # compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # first aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    # plt.figure()
    # plt.plot(
    #     fpr["micro"],
    #     tpr["micro"],
    #     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    #     color="deeppink",
    #     linestyle=":",
    #     linewidth=4,
    # )

    # plt.plot(
    #     fpr["macro"],
    #     tpr["macro"],
    #     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    #     color="navy",
    #     linestyle=":",
    #     linewidth=4,
    # )

    colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
        )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Multiclass)")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Average)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

    # calculate equal-error-rate
    eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('Average ROC Curve')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #### FIT AND SAVE MODEL
# - Fitting of model
# - Get Accuracy and Loss of Mdoel
# - Saving Model

# %%
############################
# # reshaping of dataset # #
############################
# loading of dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)

df.head()
dataset = df.values

# divide data into features X and target (classes) Y
# convert target Y to labelbinarizer Y for model
X, Y, lb, class_list = prepare_dataset(df)

# reshaping the dataset to include LSTM Timesteps
X = reshape_dataset(X, TIMESTEPS)
n_classes = Y.shape[1]

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# LabelBinarizer is able to decipher:
# ['adhy' 'alan' 'andy' 'bryce' 'chris' 'cy' 'gerald' 'jc' 'jonah' 'qk']
#
#
# X | Features | Dataset Shape: (63480, 644)
# Y | Classes  | Dataset Shape: (63480, 10)
# There are a total of 10 classes.
# Epoch 1/200
# 635/635 [==============================] - 18s 18ms/step - loss: 1.7356 - accuracy: 0.3237
# Epoch 2/200
# 635/635 [==============================] - 12s 18ms/step - loss: 1.2009 - accuracy: 0.5189
# Epoch 3/200
# 635/635 [==============================] - 11s 18ms/step - loss: 1.0850 - accuracy: 0.5805
# Epoch 4/200
# 635/635 [==============================] - 11s 18ms/step - loss: 1.0408 - accuracy: 0.5982
# Epoch 5/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.9927 - accuracy: 0.6142
# Epoch 6/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.9720 - accuracy: 0.6247
# Epoch 7/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.9623 - accuracy: 0.6278
# Epoch 8/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.9360 - accuracy: 0.6372
# Epoch 9/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.9113 - accuracy: 0.6450
# Epoch 10/200
# 635/635 [==============================] - 11s 17ms/step - loss: 0.8992 - accuracy: 0.6515
# Epoch 11/200
# 635/635 [==============================] - 11s 17ms/step - loss: 0.8750 - accuracy: 0.6592
# Epoch 12/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.8742 - accuracy: 0.6609
# Epoch 13/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.8493 - accuracy: 0.6735
# Epoch 14/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.8216 - accuracy: 0.6850
# Epoch 15/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.8332 - accuracy: 0.6801
# Epoch 16/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.8001 - accuracy: 0.6940
# Epoch 17/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.7889 - accuracy: 0.6984
# Epoch 18/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.7776 - accuracy: 0.7057
# Epoch 19/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.7563 - accuracy: 0.7098
# Epoch 20/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.7521 - accuracy: 0.7108
# Epoch 21/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.7386 - accuracy: 0.7155
# Epoch 22/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.7151 - accuracy: 0.7263
# Epoch 23/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.7010 - accuracy: 0.7315
# Epoch 24/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.7075 - accuracy: 0.7330
# Epoch 25/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.6846 - accuracy: 0.7387
# Epoch 26/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.6773 - accuracy: 0.7432
# Epoch 27/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.6617 - accuracy: 0.7491
# Epoch 28/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.6560 - accuracy: 0.7529
# Epoch 29/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.6719 - accuracy: 0.7490
# Epoch 30/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.6342 - accuracy: 0.7617
# Epoch 31/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.6310 - accuracy: 0.7641
# Epoch 32/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.6208 - accuracy: 0.7700
# Epoch 33/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.6005 - accuracy: 0.7770
# Epoch 34/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.6001 - accuracy: 0.7787
# Epoch 35/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.6108 - accuracy: 0.7764
# Epoch 36/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.5865 - accuracy: 0.7854
# Epoch 37/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.5675 - accuracy: 0.7937
# Epoch 38/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.5654 - accuracy: 0.7971
# Epoch 39/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.5427 - accuracy: 0.8032
# Epoch 40/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.5647 - accuracy: 0.7982
# Epoch 41/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.5420 - accuracy: 0.8043
# Epoch 42/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.5294 - accuracy: 0.8108
# Epoch 43/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.4965 - accuracy: 0.8221
# Epoch 44/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.4957 - accuracy: 0.8257
# Epoch 45/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.4974 - accuracy: 0.8216
# Epoch 46/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.4740 - accuracy: 0.8307
# Epoch 47/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.4692 - accuracy: 0.8335
# Epoch 48/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.4579 - accuracy: 0.8378
# Epoch 49/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.4582 - accuracy: 0.8375
# Epoch 50/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.4445 - accuracy: 0.8422
# Epoch 51/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.4381 - accuracy: 0.8451
# Epoch 52/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.4337 - accuracy: 0.8438
# Epoch 53/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.4491 - accuracy: 0.8402
# Epoch 54/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.4152 - accuracy: 0.8510
# Epoch 55/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.4079 - accuracy: 0.8548
# Epoch 56/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.3962 - accuracy: 0.8579
# Epoch 57/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.4143 - accuracy: 0.8536
# Epoch 58/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.3858 - accuracy: 0.8608
# Epoch 59/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.3806 - accuracy: 0.8639
# Epoch 60/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.3907 - accuracy: 0.8604
# Epoch 61/200
# 635/635 [==============================] - 14s 22ms/step - loss: 0.3774 - accuracy: 0.8657
# Epoch 62/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.3682 - accuracy: 0.8690
# Epoch 63/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.3625 - accuracy: 0.8716
# Epoch 64/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.3645 - accuracy: 0.8721
# Epoch 65/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.3557 - accuracy: 0.8708
# Epoch 66/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.3502 - accuracy: 0.8763
# Epoch 67/200
# 635/635 [==============================] - 15s 24ms/step - loss: 0.3538 - accuracy: 0.8756
# Epoch 68/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.3536 - accuracy: 0.8769
# Epoch 69/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.3422 - accuracy: 0.8787
# Epoch 70/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.3332 - accuracy: 0.8836
# Epoch 71/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.3691 - accuracy: 0.8719
# Epoch 72/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.3185 - accuracy: 0.8881
# Epoch 73/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.3193 - accuracy: 0.8877
# Epoch 74/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.3175 - accuracy: 0.8878
# Epoch 75/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.3153 - accuracy: 0.8894
# Epoch 76/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.3187 - accuracy: 0.8890
# Epoch 77/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.3075 - accuracy: 0.8909
# Epoch 78/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.3011 - accuracy: 0.8945
# Epoch 79/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.3001 - accuracy: 0.8948
# Epoch 80/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.2989 - accuracy: 0.8968
# Epoch 81/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2884 - accuracy: 0.8994
# Epoch 82/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2965 - accuracy: 0.8966
# Epoch 83/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.2836 - accuracy: 0.9020
# Epoch 84/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.2871 - accuracy: 0.9024
# Epoch 85/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2704 - accuracy: 0.9053
# Epoch 86/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2935 - accuracy: 0.8988
# Epoch 87/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.2707 - accuracy: 0.9059
# Epoch 88/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2966 - accuracy: 0.8974
# Epoch 89/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.2689 - accuracy: 0.9077
# Epoch 90/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.2748 - accuracy: 0.9043
# Epoch 91/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2626 - accuracy: 0.9089
# Epoch 92/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.2755 - accuracy: 0.9058
# Epoch 93/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2948 - accuracy: 0.8999
# Epoch 94/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2667 - accuracy: 0.9092
# Epoch 95/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2577 - accuracy: 0.9115
# Epoch 96/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.2420 - accuracy: 0.9161
# Epoch 97/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.2457 - accuracy: 0.9146
# Epoch 98/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.2786 - accuracy: 0.9060
# Epoch 99/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.2396 - accuracy: 0.9189
# Epoch 100/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.2429 - accuracy: 0.9176
# Epoch 101/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2309 - accuracy: 0.9207
# Epoch 102/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.2360 - accuracy: 0.9183
# Epoch 103/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.2335 - accuracy: 0.9189
# Epoch 104/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2337 - accuracy: 0.9191
# Epoch 105/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2289 - accuracy: 0.9223
# Epoch 106/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.2179 - accuracy: 0.9245
# Epoch 107/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.2158 - accuracy: 0.9252
# Epoch 108/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2424 - accuracy: 0.9193
# Epoch 109/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2218 - accuracy: 0.9246
# Epoch 110/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.2041 - accuracy: 0.9297
# Epoch 111/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.2079 - accuracy: 0.9290
# Epoch 112/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.2481 - accuracy: 0.9162
# Epoch 113/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.1991 - accuracy: 0.9318
# Epoch 114/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2014 - accuracy: 0.9307
# Epoch 115/200
# 635/635 [==============================] - 12s 18ms/step - loss: 0.2026 - accuracy: 0.9301
# Epoch 116/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.2142 - accuracy: 0.9270
# Epoch 117/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2052 - accuracy: 0.9302
# Epoch 118/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1894 - accuracy: 0.9336
# Epoch 119/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.1967 - accuracy: 0.9330
# Epoch 120/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1905 - accuracy: 0.9358
# Epoch 121/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.2030 - accuracy: 0.9316
# Epoch 122/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.2056 - accuracy: 0.9308
# Epoch 123/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1813 - accuracy: 0.9374
# Epoch 124/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1878 - accuracy: 0.9358
# Epoch 125/200
# 635/635 [==============================] - 11s 18ms/step - loss: 0.1948 - accuracy: 0.9336
# Epoch 126/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.1843 - accuracy: 0.9380
# Epoch 127/200
# 635/635 [==============================] - 14s 21ms/step - loss: 0.1790 - accuracy: 0.9387
# Epoch 128/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1887 - accuracy: 0.9358
# Epoch 129/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.1683 - accuracy: 0.9436
# Epoch 130/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1767 - accuracy: 0.9402
# Epoch 131/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1717 - accuracy: 0.9417
# Epoch 132/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1776 - accuracy: 0.9407
# Epoch 133/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1687 - accuracy: 0.9428
# Epoch 134/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1671 - accuracy: 0.9434
# Epoch 135/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1695 - accuracy: 0.9434
# Epoch 136/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1699 - accuracy: 0.9425
# Epoch 137/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.1625 - accuracy: 0.9448
# Epoch 138/200
# 635/635 [==============================] - 14s 22ms/step - loss: 0.1599 - accuracy: 0.9459
# Epoch 139/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1670 - accuracy: 0.9444
# Epoch 140/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1688 - accuracy: 0.9448
# Epoch 141/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1639 - accuracy: 0.9455
# Epoch 142/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.1696 - accuracy: 0.9438
# Epoch 143/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.1899 - accuracy: 0.9392
# Epoch 144/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1726 - accuracy: 0.9433
# Epoch 145/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1487 - accuracy: 0.9499
# Epoch 146/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1565 - accuracy: 0.9478
# Epoch 147/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.1661 - accuracy: 0.9449
# Epoch 148/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1547 - accuracy: 0.9485
# Epoch 149/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1528 - accuracy: 0.9482
# Epoch 150/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1524 - accuracy: 0.9491
# Epoch 151/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1456 - accuracy: 0.9503
# Epoch 152/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1495 - accuracy: 0.9501
# Epoch 153/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1457 - accuracy: 0.9514
# Epoch 154/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1519 - accuracy: 0.9487
# Epoch 155/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.1358 - accuracy: 0.9550
# Epoch 156/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1548 - accuracy: 0.9494
# Epoch 157/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.1534 - accuracy: 0.9485
# Epoch 158/200
# 635/635 [==============================] - 14s 22ms/step - loss: 0.1375 - accuracy: 0.9542
# Epoch 159/200
# 635/635 [==============================] - 14s 22ms/step - loss: 0.1425 - accuracy: 0.9532
# Epoch 160/200
# 635/635 [==============================] - 14s 22ms/step - loss: 0.1447 - accuracy: 0.9525
# Epoch 161/200
# 635/635 [==============================] - 14s 22ms/step - loss: 0.1448 - accuracy: 0.9519
# Epoch 162/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1571 - accuracy: 0.9485
# Epoch 163/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1424 - accuracy: 0.9528
# Epoch 164/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1447 - accuracy: 0.9516
# Epoch 165/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1377 - accuracy: 0.9542
# Epoch 166/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.1216 - accuracy: 0.9586
# Epoch 167/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1333 - accuracy: 0.9553
# Epoch 168/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1272 - accuracy: 0.9577
# Epoch 169/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1392 - accuracy: 0.9534
# Epoch 170/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1525 - accuracy: 0.9500
# Epoch 171/200
# 635/635 [==============================] - 14s 21ms/step - loss: 0.1249 - accuracy: 0.9579
# Epoch 172/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1496 - accuracy: 0.9513
# Epoch 173/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.1228 - accuracy: 0.9586
# Epoch 174/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1368 - accuracy: 0.9547
# Epoch 175/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1527 - accuracy: 0.9503
# Epoch 176/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1449 - accuracy: 0.9528
# Epoch 177/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.1208 - accuracy: 0.9600
# Epoch 178/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1260 - accuracy: 0.9584
# Epoch 179/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1252 - accuracy: 0.9585
# Epoch 180/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1262 - accuracy: 0.9579
# Epoch 181/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1237 - accuracy: 0.9594
# Epoch 182/200
# 635/635 [==============================] - 14s 22ms/step - loss: 0.1420 - accuracy: 0.9536
# Epoch 183/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1254 - accuracy: 0.9575
# Epoch 184/200
# 635/635 [==============================] - 12s 20ms/step - loss: 0.1218 - accuracy: 0.9597
# Epoch 185/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1245 - accuracy: 0.9587
# Epoch 186/200
# 635/635 [==============================] - 12s 19ms/step - loss: 0.1187 - accuracy: 0.9605
# Epoch 187/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1281 - accuracy: 0.9570
# Epoch 188/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.1194 - accuracy: 0.9615
# Epoch 189/200
# 635/635 [==============================] - 14s 21ms/step - loss: 0.1224 - accuracy: 0.9598
# Epoch 190/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1202 - accuracy: 0.9604
# Epoch 191/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1191 - accuracy: 0.9611
# Epoch 192/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1093 - accuracy: 0.9630
# Epoch 193/200
# 635/635 [==============================] - 14s 22ms/step - loss: 0.1228 - accuracy: 0.9598
# Epoch 194/200
# 635/635 [==============================] - 19s 30ms/step - loss: 0.1150 - accuracy: 0.9615
# Epoch 195/200
# 635/635 [==============================] - 13s 21ms/step - loss: 0.1136 - accuracy: 0.9623
# Epoch 196/200
# 635/635 [==============================] - 14s 22ms/step - loss: 0.1232 - accuracy: 0.9606
# Epoch 197/200
# 635/635 [==============================] - 15s 24ms/step - loss: 0.1111 - accuracy: 0.9637
# Epoch 198/200
# 635/635 [==============================] - 14s 22ms/step - loss: 0.1138 - accuracy: 0.9611
# Epoch 199/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1215 - accuracy: 0.9605
# Epoch 200/200
# 635/635 [==============================] - 13s 20ms/step - loss: 0.1190 - accuracy: 0.9620

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# #### SAVE MODEL

# %%
##################
# # save model # #
##################
model.model.save(MODEL_PATH)

# %% [markdown]
# # LIVE TESTING
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()
# Out:
#   Subject  Class    Sequence    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  \
# 0    adhy      3  use volume  0.138573 -0.084819   0.053754   0.084257
# 1    adhy      3  use volume  0.138573 -0.084819   0.053754   0.084257
# 2    adhy      3  use volume  0.138573 -0.084819   0.053754   0.084257
# 3    adhy      3  use volume  0.138573 -0.084819   0.053754   0.084257
# 4    adhy      3  use volume  0.138573 -0.084819   0.053754   0.084257
#
#    T2-NG|0+1    T2-D|1  T2-I|1+2  ...  T9-RF|VAR.1   T9-NG|VAR.1  T9-I|SD.1  \
# 0    0.22283  0.169076 -0.100031  ...     0.000478  3.870000e-09   0.022083
# 1    0.22283  0.169076 -0.100031  ...     0.001097  4.876180e-04   0.044149
# 2    0.22283  0.169076 -0.100031  ...     0.003094  5.096550e-04   0.011010
# 3    0.22283  0.169076 -0.100031  ...     0.040961  4.824167e-02   0.179768
# 4    0.22283  0.169076 -0.100031  ...     0.018903  1.890288e-02   0.093657
#
#    T9-PF|SD.1  T9-RF|SD.1  T9-NG|SD.1  T10-I|0+9.1  T10-PF|0+9.1  \
# 0    0.043876    0.021856    0.000062     0.802144      0.871402
# 1    0.011049    0.033116    0.022082     1.119966      1.267125
# 2    0.022040    0.055626    0.022576     0.904103      0.989002
# 3    0.197020    0.202387    0.219640     1.311359      1.489939
# 4    0.093656    0.137488    0.137488     1.119189      1.219711
#
#    T10-RF|0+9.1  T10-NG|0+9.1
# 0      0.871176      0.940435
# 1      1.220308      1.367467
# 2      0.988245      1.073144
# 3      1.411038      1.589618
# 4      1.203950      1.304473
#
# [5 rows x 647 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
actual_np = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

########################
# # predict all rows # #
########################
pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[46:54,FEATURES_COL_NUM:]
# print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

print(class_list)
Y = np.asarray(class_list)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)
# Out:
# ['adhy', 'alan', 'andy', 'bryce', 'chris', 'cy', 'gerald', 'jc', 'jonah', 'qk']

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

# pred_proba = np.sum(pred_proba, axis=0)
# pred_proba = np.reshape(pred_proba, (1, 9))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

match_list = []

for _ in range(actual_np.size):
    if pred[_] == actual_np[_]:
        match_list.append("match")
    else:
        match_list.append("nope")

match_count = match_list.count("match")
total_count = len(match_list)

match_header = str(match_count) + "/" + str(total_count) + " (" + str(match_count/total_count*100)+ "%)"
match_np = np.array(match_list)

exported_output = np.column_stack((actual_np, pred))
exported_output = np.column_stack((exported_output, acc))
exported_output = np.column_stack((exported_output, match_np))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(data=exported_output, index=None, columns=['Actual', 'Prediction', 'Accuracy', match_header])
# print(df)
df.to_csv(RESULT_PATH)

print("Accuracy of the Model is: " + str(match_header))
# Out:
# Accuracy of the Model is: 306/480 (63.74999999999999%)
