# %% [markdown]
# #### IMPORT

# %%
import os, platform

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from matplotlib import pyplot


from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc


from sklearn.metrics import roc_curve, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %% [markdown]
# #### PARAMETERS
# - Set the condition
# > * N_FEATURES: Number of Features
# > * CHECK_BLANKS: Check for blank data. If any blank data is found, the whole row of data will be deleted.
# > * CHECK_CLASS_IMBALANCE: Check for dataset class imbalance. The more balance the dataset, the less biases the model will be.

# %%
##############################
# # deep learning features # #
##############################
SEED = 1005 # random seed for reproducibility

# should make this dynamic
N_FEATURES = 6 #37 #98 #190 #61 #37 #46
# N_CLASSES= 9
TIMESTEPS = 1
EPOCH=200
BATCH_SIZE=200

###############
# # dataset # #
###############
DATASET_DIR_NAME = "dataset"
SAMPLE_DATASET_NAME = "five_train" + ".csv"
ACTUAL_DATASET_NAME = "five_test_fixed" + ".csv"

# SAMPLE_DATASET_NAME = "train_m2m_tengraph" + ".csv"
# ACTUAL_DATASET_NAME = "test_m2m_tengraph" + ".csv"

# SAMPLE_DATASET_NAME = "andy" + ".csv"
# ACTUAL_DATASET_NAME = "andy" + ".csv"

MODEL_DIR_NAME = "model"
MODEL_NAME = "classifier" + ".h5"

DATASET_DIR_PATH = os.path.join(os.getcwd(), DATASET_DIR_NAME)
SAMPLE_DATASET_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME)
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME)

MODEL_DIR_PATH = os.path.join(os.getcwd(), MODEL_DIR_NAME)
MODEL_PATH = os.path.join(MODEL_DIR_PATH, MODEL_NAME)

CLASSES_COL_NAME = "Subject"
CLASSES_COL_NUM = 0
FEATURES_COL_NUM = 6 #4
CLASS_LIST = ['adhy', 'alan', 'andy', 'bryce', 'chris', 'cy', 'gerald', 'jc', 'jonah', 'qk']
# CLASS_LIST = ['andy', 'azfar', 'gerald', 'jonah', 'ys']

#################
# # sns theme # #
#################
# sns.set_theme(style="darkgrid") # (dark background with white gridlines)
sns.set_theme(style="whitegrid") # (white background with grey gridlines)
# sns.set_theme(style="dark") # (dark background with no gridlines)
# sns.set_theme(style="white") # (white background with no gridlines)
# sns.set_theme(style="ticks") # (white background with axis ticks and no gridlines)

def df_drop(df):
    # df.drop(df[df['Subject']=='andy'].index, inplace=True)
    # df.drop(df[df['Subject']=='azfar'].index, inplace=True)
    df.drop(df[df['Subject']=='ch'].index, inplace=True)
    # df.drop(df[df['Subject']=='cy'].index, inplace=True)
    df.drop(df[df['Subject']=='gerald'].index, inplace=True)
    df.drop(df[df['Subject']=='jc'].index, inplace=True)
    df.drop(df[df['Subject']=='jonah'].index, inplace=True)
    df.drop(df[df['Subject']=='qikai'].index, inplace=True)
    df.drop(df[df['Subject']=='ys'].index, inplace=True)
    df.drop(df[df['Subject']=='zen'].index, inplace=True)
    
    return df

# %%
if os.path.isdir(DATASET_DIR_PATH) is True:
    print(f"Dataset directory exists at: {DATASET_DIR_PATH}")
    pass
else:
    try:
        os.mkdir(DATASET_DIR_PATH, 666)
        print(f"Dataset directory have been created at: {DATASET_DIR_PATH}")
    except:
        print("Error: Dataset Directory not created")
        
if os.path.isdir(MODEL_DIR_PATH) is True:
    print(f"Model directory exists at: {MODEL_DIR_PATH}")
    pass
else:
    try:
        os.mkdir(MODEL_DIR_PATH, 666)
        print(f"Model directory have been created at: {MODEL_DIR_PATH}")
    except:
        print("Error: Model Directory not created")
# Out:
# Dataset directory exists at: C:\Users\spencer\Documents\Github\deep-captcha\dataset
# Model directory exists at: C:\Users\spencer\Documents\Github\deep-captcha\model

# %% [markdown]
# #### CREATE MODEL
# - Create base model
# - Wrap it with KerasClassifier

# %%
# create base model
def create_base_model():
    model = Sequential()
#     model.add(LSTM(units=128, return_sequences=True, 
#                  input_shape=(TIMESTEPS,N_FEATURES)))
#     model.add(Dropout(0.2))
#     model.add(BatchNormalization())
    model.add(LSTM(units=1024, return_sequences=True,
             input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=512, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=256, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=128, return_sequences=True))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=32, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    # softmax for multi-class classification
    model.add(Flatten())
    print(n_classes)
    model.add(Dense(n_classes, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=EPOCH, 
                            batch_size=BATCH_SIZE)
    return model

# %%
# divide data into features X and target (classes) Y
def prepare_dataset(df):
    X = df.values[:,FEATURES_COL_NUM:].astype(float)
    Y = df.values[:,CLASSES_COL_NUM].astype(str)

    # convert target Y to labelbinarizer Y for model
    # fit_transform is not used to reuse lb
    Y = Y.reshape(-1, 1)
    lb = LabelBinarizer().fit(Y)
    Y = lb.transform(Y)


    #################################
    # # get all the encoded class # #
    #################################
    print("LabelBinarizer is able to decipher: ")
    print(lb.classes_)
    print("\n")

    ###########################
    # # print X and Y shape # #
    ###########################
    print(f"X | Features | Dataset Shape: {X.shape}")
    print(f"Y | Classes  | Dataset Shape: {Y.shape}")

    return X, Y, lb

# %%
def split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED):

    ##############################################################
    # # split dataset into train and test set of 0.8/0.2 ratio # #
    ##############################################################
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=SPLIT_RATIO, random_state=SEED)

    ############################
    # # reshaping of dataset # #
    ############################

    # reshaping the dataset to include LSTM Timesteps
    print(X_train.dtype)
    X_train = np.asarray(X_train, dtype=np.float32)
    print(X_train.dtype)
    X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
    print(X_test.dtype)
    X_test = np.asarray(X_test, dtype=np.float32)
    print(X_test.dtype)
    X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

    # retrieve number of classes
    n_classes = y_train.shape[1]

    print(f"X train shape: {X_train.shape}")
    print(f"Y train shape: {y_train.shape}")
    print(f"X test shape: {X_test.shape}")
    print(f"Y test shape: {y_test.shape}")
    print(f"Number of Classes: {n_classes}")

    return X_train, X_test, y_train, y_test, n_classes

def reshape_dataset(X, TIMESTEPS):
    # reshaping the dataset to include LSTM Timesteps
    X = np.asarray(X, dtype=np.float32)
    X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))
    return X

# %% [markdown]
# #### CHECK DATASET

# %%
#     sns.catplot(x="Subject", y="D|0", data=df)

    
#     sns.catplot(x="Subject", y="D|1", hue="D|1", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|3", hue="D|3", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|4", hue="D|4", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|5", hue="D|5", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|6", hue="D|6", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|7", hue="D|7", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|8", hue="D|8", data=df, legend=False)

#     sns.catplot(x="Subject", y="D|1", hue="D|1", data=df, legend=False)
#     sns.catplot(x="Subject", y="I|1+2", hue="I|1+2", data=df, legend=False)
#     sns.catplot(x="Subject", y="PF|1+2", hue="PF|1+2", data=df, legend=False)
#     sns.catplot(x="Subject", y="RF|1+2", hue="RF|1+2", data=df, legend=False)
#     sns.catplot(x="Subject", y="DT|1+2", hue="DT|1+2", data=df, legend=False)
#     sns.catplot(x="Subject", y="D|9", hue="D|9", data=df, legend=False)


#     sns.catplot(x="Subject", y="TT|1+3", hue="TT|1+3", data=df, legend=False)
#     sns.catplot(x="Subject", y="QT|1+4", hue="QT|1+4", data=df, legend=False)

# %% [markdown]
# #### FIT AND SAVE MODEL
# - Fitting of model
# - Get Accuracy and Loss of Mdoel
# - Saving Model

# %%
############################
# # reshaping of dataset # #
############################
# loading of dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)
df.head()

# df = df_drop(df)
dataset = df.values

# divide data into features X and target (classes) Y
# convert target Y to labelbinarizer Y for model
X, Y, lb = prepare_dataset(df)

# reshaping the dataset to include LSTM Timesteps
X = reshape_dataset(X, TIMESTEPS)
n_classes = Y.shape[1]

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# LabelBinarizer is able to decipher:
# ['adhy' 'alan' 'andy' 'bryce' 'chris' 'cy' 'gerald' 'jc' 'jonah' 'qk']
#
#
# X | Features | Dataset Shape: (8280, 6)
# Y | Classes  | Dataset Shape: (8280, 10)
# 10
# Epoch 1/200
# 42/42 [==============================] - 54s 151ms/step - loss: 2.1094 - accuracy: 0.1978
# Epoch 2/200
# 42/42 [==============================] - 6s 153ms/step - loss: 1.9651 - accuracy: 0.2527
# Epoch 3/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.9375 - accuracy: 0.2595
# Epoch 4/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.9190 - accuracy: 0.2653
# Epoch 5/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.9078 - accuracy: 0.2694
# Epoch 6/200
# 42/42 [==============================] - 6s 154ms/step - loss: 1.9030 - accuracy: 0.2699
# Epoch 7/200
# 42/42 [==============================] - 6s 154ms/step - loss: 1.8917 - accuracy: 0.2716
# Epoch 8/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.8911 - accuracy: 0.2752
# Epoch 9/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.8820 - accuracy: 0.2786
# Epoch 10/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.8710 - accuracy: 0.2841
# Epoch 11/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.8603 - accuracy: 0.2949
# Epoch 12/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.8630 - accuracy: 0.2822
# Epoch 13/200
# 42/42 [==============================] - 6s 153ms/step - loss: 1.8605 - accuracy: 0.2860
# Epoch 14/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.8489 - accuracy: 0.2936
# Epoch 15/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.8491 - accuracy: 0.2981
# Epoch 16/200
# 42/42 [==============================] - 6s 153ms/step - loss: 1.8455 - accuracy: 0.3010
# Epoch 17/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.8478 - accuracy: 0.2937
# Epoch 18/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.8412 - accuracy: 0.3036
# Epoch 19/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.8339 - accuracy: 0.3024
# Epoch 20/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.8328 - accuracy: 0.3043
# Epoch 21/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.8371 - accuracy: 0.2993
# Epoch 22/200
# 42/42 [==============================] - 6s 154ms/step - loss: 1.8305 - accuracy: 0.3064
# Epoch 23/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.8222 - accuracy: 0.3077
# Epoch 24/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.8237 - accuracy: 0.3014
# Epoch 25/200
# 42/42 [==============================] - 6s 155ms/step - loss: 1.8272 - accuracy: 0.3098
# Epoch 26/200
# 42/42 [==============================] - 7s 155ms/step - loss: 1.8173 - accuracy: 0.3128
# Epoch 27/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.8156 - accuracy: 0.3085
# Epoch 28/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.8147 - accuracy: 0.3134
# Epoch 29/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.8126 - accuracy: 0.3054
# Epoch 30/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.8070 - accuracy: 0.3130
# Epoch 31/200
# 42/42 [==============================] - 6s 153ms/step - loss: 1.8117 - accuracy: 0.3089
# Epoch 32/200
# 42/42 [==============================] - 6s 153ms/step - loss: 1.8102 - accuracy: 0.3126
# Epoch 33/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.8069 - accuracy: 0.3197
# Epoch 34/200
# 42/42 [==============================] - 6s 153ms/step - loss: 1.8041 - accuracy: 0.3190
# Epoch 35/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.8079 - accuracy: 0.3123
# Epoch 36/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.8029 - accuracy: 0.3156
# Epoch 37/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.8060 - accuracy: 0.3139
# Epoch 38/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.8016 - accuracy: 0.3186
# Epoch 39/200
# 42/42 [==============================] - 6s 147ms/step - loss: 1.7981 - accuracy: 0.3182
# Epoch 40/200
# 42/42 [==============================] - 6s 153ms/step - loss: 1.7973 - accuracy: 0.3192
# Epoch 41/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.8016 - accuracy: 0.3156
# Epoch 42/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7966 - accuracy: 0.3167
# Epoch 43/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7898 - accuracy: 0.3262
# Epoch 44/200
# 42/42 [==============================] - 6s 153ms/step - loss: 1.7882 - accuracy: 0.3223
# Epoch 45/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7922 - accuracy: 0.3198
# Epoch 46/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7897 - accuracy: 0.3217
# Epoch 47/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7859 - accuracy: 0.3314
# Epoch 48/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7910 - accuracy: 0.3252
# Epoch 49/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7932 - accuracy: 0.3251
# Epoch 50/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7901 - accuracy: 0.3210
# Epoch 51/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7927 - accuracy: 0.3237
# Epoch 52/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7843 - accuracy: 0.3290
# Epoch 53/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7896 - accuracy: 0.3258
# Epoch 54/200
# 42/42 [==============================] - 6s 154ms/step - loss: 1.7859 - accuracy: 0.3285
# Epoch 55/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7850 - accuracy: 0.3251
# Epoch 56/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7851 - accuracy: 0.3278
# Epoch 57/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7803 - accuracy: 0.3300
# Epoch 58/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7798 - accuracy: 0.3361
# Epoch 59/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7800 - accuracy: 0.3316
# Epoch 60/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7717 - accuracy: 0.3362
# Epoch 61/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7762 - accuracy: 0.3306
# Epoch 62/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7756 - accuracy: 0.3280
# Epoch 63/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7792 - accuracy: 0.3338
# Epoch 64/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7726 - accuracy: 0.3343
# Epoch 65/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7776 - accuracy: 0.3306
# Epoch 66/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7810 - accuracy: 0.3255
# Epoch 67/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7762 - accuracy: 0.3339
# Epoch 68/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7741 - accuracy: 0.3349
# Epoch 69/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7700 - accuracy: 0.3362
# Epoch 70/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7732 - accuracy: 0.3318
# Epoch 71/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7707 - accuracy: 0.3356
# Epoch 72/200
# 42/42 [==============================] - 7s 155ms/step - loss: 1.7676 - accuracy: 0.3308
# Epoch 73/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7621 - accuracy: 0.3341
# Epoch 74/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7730 - accuracy: 0.3332
# Epoch 75/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7689 - accuracy: 0.3373
# Epoch 76/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7593 - accuracy: 0.3324
# Epoch 77/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7649 - accuracy: 0.3397
# Epoch 78/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7665 - accuracy: 0.3407
# Epoch 79/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7724 - accuracy: 0.3339
# Epoch 80/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7637 - accuracy: 0.3345
# Epoch 81/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7641 - accuracy: 0.3351
# Epoch 82/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.7622 - accuracy: 0.3413
# Epoch 83/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7591 - accuracy: 0.3401
# Epoch 84/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.7579 - accuracy: 0.3436
# Epoch 85/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7690 - accuracy: 0.3331
# Epoch 86/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7651 - accuracy: 0.3321
# Epoch 87/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7530 - accuracy: 0.3349
# Epoch 88/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7613 - accuracy: 0.3349
# Epoch 89/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7578 - accuracy: 0.3435
# Epoch 90/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.7651 - accuracy: 0.3432
# Epoch 91/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7642 - accuracy: 0.3342
# Epoch 92/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.7571 - accuracy: 0.3400
# Epoch 93/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.7543 - accuracy: 0.3359
# Epoch 94/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7487 - accuracy: 0.3393
# Epoch 95/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7482 - accuracy: 0.3477
# Epoch 96/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.7545 - accuracy: 0.3389
# Epoch 97/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7535 - accuracy: 0.3501
# Epoch 98/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7555 - accuracy: 0.3393
# Epoch 99/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7507 - accuracy: 0.3424
# Epoch 100/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.7551 - accuracy: 0.3397
# Epoch 101/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7503 - accuracy: 0.3409
# Epoch 102/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7570 - accuracy: 0.3380
# Epoch 103/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7535 - accuracy: 0.3395
# Epoch 104/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7427 - accuracy: 0.3455
# Epoch 105/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7401 - accuracy: 0.3440
# Epoch 106/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7418 - accuracy: 0.3479
# Epoch 107/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.7421 - accuracy: 0.3415
# Epoch 108/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7501 - accuracy: 0.3434
# Epoch 109/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7332 - accuracy: 0.3479
# Epoch 110/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7404 - accuracy: 0.3490
# Epoch 111/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7418 - accuracy: 0.3418
# Epoch 112/200
# 42/42 [==============================] - 6s 153ms/step - loss: 1.7412 - accuracy: 0.3420
# Epoch 113/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7436 - accuracy: 0.3430
# Epoch 114/200
# 42/42 [==============================] - 6s 154ms/step - loss: 1.7478 - accuracy: 0.3420
# Epoch 115/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7424 - accuracy: 0.3436
# Epoch 116/200
# 42/42 [==============================] - 6s 153ms/step - loss: 1.7386 - accuracy: 0.3436
# Epoch 117/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7384 - accuracy: 0.3443
# Epoch 118/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7298 - accuracy: 0.3505
# Epoch 119/200
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7327 - accuracy: 0.3447
# Epoch 120/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7418 - accuracy: 0.3465
# Epoch 121/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7417 - accuracy: 0.3486
# Epoch 122/200
# 42/42 [==============================] - 6s 147ms/step - loss: 1.7327 - accuracy: 0.3419
# Epoch 123/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7271 - accuracy: 0.3504
# Epoch 124/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7330 - accuracy: 0.3446
# Epoch 125/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7347 - accuracy: 0.3490
# Epoch 126/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.7290 - accuracy: 0.3487
# Epoch 127/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7297 - accuracy: 0.3500
# Epoch 128/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7225 - accuracy: 0.3512
# Epoch 129/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7265 - accuracy: 0.3420
# Epoch 130/200
# 42/42 [==============================] - 6s 147ms/step - loss: 1.7253 - accuracy: 0.3512
# Epoch 131/200
# 42/42 [==============================] - 6s 142ms/step - loss: 1.7262 - accuracy: 0.3516
# Epoch 132/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.7246 - accuracy: 0.3552
# Epoch 133/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.7295 - accuracy: 0.3463
# Epoch 134/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7274 - accuracy: 0.3499
# Epoch 135/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7245 - accuracy: 0.3477
# Epoch 136/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7267 - accuracy: 0.3454
# Epoch 137/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7298 - accuracy: 0.3492
# Epoch 138/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7215 - accuracy: 0.3545
# Epoch 139/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7183 - accuracy: 0.3529
# Epoch 140/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7195 - accuracy: 0.3486
# Epoch 141/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7237 - accuracy: 0.3530
# Epoch 142/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7249 - accuracy: 0.3512
# Epoch 143/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7166 - accuracy: 0.3473
# Epoch 144/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7113 - accuracy: 0.3557
# Epoch 145/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7250 - accuracy: 0.3470
# Epoch 146/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7153 - accuracy: 0.3579
# Epoch 147/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7096 - accuracy: 0.3517
# Epoch 148/200
# 42/42 [==============================] - 6s 151ms/step - loss: 1.7151 - accuracy: 0.3535
# Epoch 149/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7075 - accuracy: 0.3558
# Epoch 150/200
# 42/42 [==============================] - 6s 153ms/step - loss: 1.7141 - accuracy: 0.3513
# Epoch 151/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7143 - accuracy: 0.3528
# Epoch 152/200
# 42/42 [==============================] - 6s 150ms/step - loss: 1.7160 - accuracy: 0.3533
# Epoch 153/200
# 42/42 [==============================] - 6s 149ms/step - loss: 1.7159 - accuracy: 0.3518
# Epoch 154/200
# 42/42 [==============================] - 6s 147ms/step - loss: 1.6987 - accuracy: 0.3611
# Epoch 155/200
# 42/42 [==============================] - 6s 147ms/step - loss: 1.7028 - accuracy: 0.3554
# Epoch 156/200
# 42/42 [==============================] - 6s 148ms/step - loss: 1.7120 - accuracy: 0.3477
# Epoch 157/200
# 42/42 [==============================] - 6s 147ms/step - loss: 1.7130 - accuracy: 0.3534
# Epoch 158/200
# 42/42 [==============================] - 6s 147ms/step - loss: 1.6993 - accuracy: 0.3534
# Epoch 159/200
# 42/42 [==============================] - 6s 147ms/step - loss: 1.7018 - accuracy: 0.3595
# Epoch 160/200
# 42/42 [==============================] - 6s 137ms/step - loss: 1.7003 - accuracy: 0.3621
# Epoch 161/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.7041 - accuracy: 0.3600
# Epoch 162/200
# 42/42 [==============================] - 6s 132ms/step - loss: 1.6999 - accuracy: 0.3577
# Epoch 163/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.7075 - accuracy: 0.3513
# Epoch 164/200
# 42/42 [==============================] - 6s 141ms/step - loss: 1.7057 - accuracy: 0.3559
# Epoch 165/200
# 42/42 [==============================] - 6s 142ms/step - loss: 1.6914 - accuracy: 0.3618
# Epoch 166/200
# 42/42 [==============================] - 6s 140ms/step - loss: 1.6990 - accuracy: 0.3664
# Epoch 167/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.7080 - accuracy: 0.3548
# Epoch 168/200
# 42/42 [==============================] - 6s 139ms/step - loss: 1.7021 - accuracy: 0.3593
# Epoch 169/200
# 42/42 [==============================] - 6s 137ms/step - loss: 1.7011 - accuracy: 0.3594
# Epoch 170/200
# 42/42 [==============================] - 6s 137ms/step - loss: 1.7020 - accuracy: 0.3588
# Epoch 171/200
# 42/42 [==============================] - 6s 137ms/step - loss: 1.7063 - accuracy: 0.3521
# Epoch 172/200
# 42/42 [==============================] - 6s 137ms/step - loss: 1.7063 - accuracy: 0.3570
# Epoch 173/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.6890 - accuracy: 0.3607
# Epoch 174/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.6979 - accuracy: 0.3621
# Epoch 175/200
# 42/42 [==============================] - 6s 139ms/step - loss: 1.7027 - accuracy: 0.3598
# Epoch 176/200
# 42/42 [==============================] - 6s 141ms/step - loss: 1.6872 - accuracy: 0.3621
# Epoch 177/200
# 42/42 [==============================] - 6s 137ms/step - loss: 1.6865 - accuracy: 0.3638
# Epoch 178/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.6836 - accuracy: 0.3673
# Epoch 179/200
# 42/42 [==============================] - 6s 140ms/step - loss: 1.6982 - accuracy: 0.3624
# Epoch 180/200
# 42/42 [==============================] - 6s 141ms/step - loss: 1.6898 - accuracy: 0.3639
# Epoch 181/200
# 42/42 [==============================] - 6s 140ms/step - loss: 1.6918 - accuracy: 0.3627
# Epoch 182/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.6824 - accuracy: 0.3638
# Epoch 183/200
# 42/42 [==============================] - 6s 139ms/step - loss: 1.6804 - accuracy: 0.3661
# Epoch 184/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.6892 - accuracy: 0.3597
# Epoch 185/200
# 42/42 [==============================] - 6s 139ms/step - loss: 1.6819 - accuracy: 0.3607
# Epoch 186/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.6835 - accuracy: 0.3690
# Epoch 187/200
# 42/42 [==============================] - 6s 136ms/step - loss: 1.6779 - accuracy: 0.3661
# Epoch 188/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.6900 - accuracy: 0.3675
# Epoch 189/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.6880 - accuracy: 0.3597
# Epoch 190/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.7016 - accuracy: 0.3564
# Epoch 191/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.6832 - accuracy: 0.3682
# Epoch 192/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.6638 - accuracy: 0.3687
# Epoch 193/200
# 42/42 [==============================] - 6s 138ms/step - loss: 1.6895 - accuracy: 0.3598
# Epoch 194/200
# 42/42 [==============================] - 6s 140ms/step - loss: 1.6722 - accuracy: 0.3696
# Epoch 195/200
# 42/42 [==============================] - 6s 140ms/step - loss: 1.6680 - accuracy: 0.3766
# Epoch 196/200
# 42/42 [==============================] - 6s 141ms/step - loss: 1.6663 - accuracy: 0.3751
# Epoch 197/200
# 42/42 [==============================] - 6s 143ms/step - loss: 1.6756 - accuracy: 0.3669
# Epoch 198/200
# 42/42 [==============================] - 6s 140ms/step - loss: 1.6698 - accuracy: 0.3629
# Epoch 199/200
# 42/42 [==============================] - 6s 141ms/step - loss: 1.6766 - accuracy: 0.3662
# Epoch 200/200
# 42/42 [==============================] - 6s 141ms/step - loss: 1.6727 - accuracy: 0.3647

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# #### SAVE MODEL

# %%
##################
# # save model # #
##################
model.model.save(MODEL_PATH)

# %% [markdown]
# # LIVE TESTING
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()
# pred_df = df_drop(pred_df)
# Out:
#   Subject Char_Total_Str Char_Total_Int  Char_Init  Char_End  Seq_No  \
# 0    adhy            u_s          21_19         21        19       3
# 1    adhy            s_e           19_5         19         5       3
# 2    adhy            e_~            5_0          5         0       3
# 3    adhy            ~_v           0_22          0        22       3
# 4    adhy            v_o          22_15         22        15       3
#
#    Current_Dwell  Interval  Press_Flight  Release_Flight   Digraph  \
# 0       0.138573 -0.084819      0.053754        0.084257  0.222830
# 1       0.169076 -0.100031      0.069045        0.093889  0.262965
# 2       0.193920 -0.031251      0.162669        0.107062  0.300982
# 3       0.138313  0.464183      0.602497        0.602466  0.740780
# 4       0.138283 -0.084802      0.053481       -0.022194  0.116089
#
#    Later_Dwell
# 0     0.169076
# 1     0.193920
# 2     0.138313
# 3     0.138283
# 4     0.062608

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
results = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

########################
# # predict all rows # #
########################
pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################
num = 2
start = 0 + num * 9
end = 9 + num * 9
pred_row=pred_df.iloc[start:end,FEATURES_COL_NUM:]
print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

Y = CLASS_LIST
print(Y)
Y = np.asarray(Y)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)
# Out:
#     Current_Dwell  Interval  Press_Flight  Release_Flight   Digraph  \
# 18       0.084898 -0.015655      0.069243        0.115984  0.200882
# 19       0.131639 -0.015518      0.116120        0.084795  0.216434
# 20       0.100313  0.015729      0.116042        0.147283  0.247597
# 21       0.131554 -0.031156      0.100398        0.116240  0.247794
# 22       0.147396 -0.015732      0.131665        0.069137  0.216533
# 23       0.084868  0.069270      0.154139        0.210027  0.294895
# 24       0.140757 -0.024715      0.116042        0.107034  0.247790
# 25       0.131748 -0.046809      0.084939        0.100429  0.232178
# 26       0.147238 -0.046826      0.100413        0.037317  0.184555
#
#     Later_Dwell
# 18     0.131639
# 19     0.100313
# 20     0.131554
# 21     0.147396
# 22     0.084868
# 23     0.140757
# 24     0.131748
# 25     0.147238
# 26     0.084142
# ['adhy', 'alan', 'andy', 'bryce', 'chris', 'cy', 'gerald', 'jc', 'jonah', 'qk']

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

pred_proba = np.sum(pred_proba, axis=0)
pred_proba = np.reshape(pred_proba, (1, 10))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

pred_results = np.column_stack((pred, acc))
# pred_results = np.column_stack((results, pred_results))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# df = pd.DataFrame(data=pred_results, index=None, columns=['Results', 'Prediction', 'Accuracy'])
df = pd.DataFrame(data=pred_results, index=None, columns=['Prediction', 'Accuracy'])
print(df)

df.to_csv("results_five.csv")
# Out:
#   Prediction   Accuracy
# 0       andy  1.6267316
