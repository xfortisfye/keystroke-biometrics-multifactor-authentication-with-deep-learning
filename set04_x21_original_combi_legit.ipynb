# %% [markdown]
# #### IMPORT

# %%
import os, platform
import py7zr

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %% [markdown]
# #### PARAMETERS
# - Set the condition
# > * N_FEATURES: Number of Features
# > * CHECK_BLANKS: Check for blank data. If any blank data is found, the whole row of data will be deleted.
# > * CHECK_CLASS_IMBALANCE: Check for dataset class imbalance. The more balance the dataset, the less biases the model will be.

# %%
##############################
# # deep learning features # #
##############################
SEED = 1005 # random seed for reproducibility

# should make this dynamic
N_FEATURES = 220
TIMESTEPS = 1
EPOCH=200
BATCH_SIZE=100

SPLIT_RATIO=0.2

###############
# # preview # #
###############
f = False
t = True

# checking dataset
CHECK_BLANKS = True
CHECK_CLASS_IMBALANCE = True

# evaluate suitable kfold number and kfold model
MIN_KFOLD = 2
MAX_KFOLD = 11
N_KFOLD = 5
EVAL_KFOLD_NUM = False
EVAL_KFOLD_MODEL = False
PERFORM_KFOLD = False

# model testing
TEST_MODEL = True
CON_MATRIX = True
ROC_GRAPH = True

###############
# # dataset # #
###############
CLASSES_COL_NAME = "Subject"
CLASSES_COL_NUM = 0
FEATURES_COL_NUM = 2

DATASET_DIR_NAME = "dataset\set04\\21_combi"
SAMPLE_DATASET_NAME = "own_train"
ACTUAL_DATASET_NAME = "combi_legit"

MODEL_DIR_NAME = "dataset\set04\\21_combi"
MODEL_NAME = "model_" + "set04_21_combi_legit"

RESULT_DIR_NAME = "dataset\set04\\21_combi"
RESULT_NAME = "result_" + "set04_21_combi_legit"

DATASET_DIR_PATH = os.path.join(os.getcwd(), DATASET_DIR_NAME)
SAMPLE_DATASET_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".csv")
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME + ".csv")

MODEL_DIR_PATH = os.path.join(os.getcwd(), MODEL_DIR_NAME)
MODEL_PATH = os.path.join(MODEL_DIR_PATH, MODEL_NAME + ".h5")

RESULT_DIR_PATH = os.path.join(os.getcwd(), RESULT_DIR_NAME)
RESULT_PATH = os.path.join(RESULT_DIR_PATH, RESULT_NAME + ".csv")

#################
# # sns theme # #
#################
# sns.set_theme(style="darkgrid") # (dark background with white gridlines)
sns.set_theme(style="whitegrid") # (white background with grey gridlines)
# sns.set_theme(style="dark") # (dark background with no gridlines)
# sns.set_theme(style="white") # (white background with no gridlines)
# sns.set_theme(style="ticks") # (white background with axis ticks and no gridlines)

# %%
if os.path.isdir(DATASET_DIR_PATH) is True:
    print(f"Dataset directory exists at: {DATASET_DIR_PATH}")
else:
    try:
        os.mkdir(DATASET_DIR_PATH, 666)
        print(f"Dataset directory have been created at: {DATASET_DIR_PATH}")
    except:
        print("Error: Dataset Directory not created")
        
if os.path.isdir(MODEL_DIR_PATH) is True:
    print(f"Model directory exists at: {MODEL_DIR_PATH}")
else:
    try:
        os.mkdir(MODEL_DIR_PATH, 666)
        print(f"Model directory have been created at: {MODEL_DIR_PATH}")
    except:
        print("Error: Model Directory not created")
    
if os.path.exists(SAMPLE_DATASET_PATH) is True:
    print(f"Training dataset exists at: {SAMPLE_DATASET_PATH}")
else:
    try:
        SAMPLE_7Z_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".7z")
        with py7zr.SevenZipFile(SAMPLE_7Z_PATH, mode='r') as z:
            z.extractall(path=DATASET_DIR_PATH)
        print(f"Decompress 7z file to: {SAMPLE_7Z_PATH}")
    except:
        print("Error: Failed to decompress 7z file.")
# Out:
# Dataset directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set04\21_combi
# Model directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set04\21_combi
# Training dataset exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set04\21_combi\own_train.csv

# %% [markdown]
# #### CREATE MODEL
# - Create base model
# - Wrap it with KerasClassifier

# %%
#create base model
def create_base_model():
    model = Sequential()
    model.add(LSTM(units=256, return_sequences=True,
             input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dense(256, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=32, return_sequences=True))
    model.add(Dense(32, activation='sigmoid'))
    model.add(Dropout(0.2))

    # softmax for multi-class classification
    model.add(Flatten())
    print("There are a total of " + str(n_classes) + " classes.")
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=EPOCH, 
                            batch_size=BATCH_SIZE)
    return model

# %%
# divide data into features X and target (classes) Y
def prepare_dataset(df):
    X = df.values[:,FEATURES_COL_NUM:].astype(float)
    Y = df.values[:,CLASSES_COL_NUM].astype(str)

    # convert target Y to labelbinarizer Y for model
    # fit_transform is not used to reuse lb
    Y = Y.reshape(-1, 1)
    lb = LabelBinarizer().fit(Y)
    Y = lb.transform(Y)

    #################################
    # # get all the encoded class # #
    #################################
    print("LabelBinarizer is able to decipher: ")
    print(lb.classes_)
    print("\n")

    ###########################
    # # print X and Y shape # #
    ###########################
    print(f"X | Features | Dataset Shape: {X.shape}")
    print(f"Y | Classes  | Dataset Shape: {Y.shape}")

    return X, Y, lb, lb.classes_.tolist()

# %%
def split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED):

    ##############################################################
    # # split dataset into train and test set of 0.8/0.2 ratio # #
    ##############################################################
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=SPLIT_RATIO, random_state=SEED)

    ############################
    # # reshaping of dataset # #
    ############################

    # reshaping the dataset to include LSTM Timesteps
    print(X_train.dtype)
    X_train = np.asarray(X_train, dtype=np.float32)
    print(X_train.dtype)
    X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
    print(X_test.dtype)
    X_test = np.asarray(X_test, dtype=np.float32)
    print(X_test.dtype)
    X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

    print(f"X train shape: {X_train.shape}")
    print(f"Y train shape: {y_train.shape}")
    print(f"X test shape: {X_test.shape}")
    print(f"Y test shape: {y_test.shape}")
    
    return X_train, X_test, y_train, y_test

def reshape_dataset(X, TIMESTEPS):
    # reshaping the dataset to include LSTM Timesteps
    X = np.asarray(X, dtype=np.float32)
    X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))
    return X

# %% [markdown]
# #### LOAD DATASET

# %%
# load dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)
df.head()
# Out:
#   Subject  Password    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    andy  Co5mical  0.124989  0.000000   0.124989   0.123640   0.248628
# 1    andy  Co5mical  0.101935  0.011014   0.112950   0.133594   0.235529
# 2    andy  Co5mical  0.090341 -0.012504   0.077837   0.090850   0.181191
# 3    andy  Co5mical  0.102711  0.011565   0.114277   0.110634   0.213346
# 4    andy  Co5mical  0.127922  0.063317   0.191239   0.188074   0.315996
#
#      T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T7-RF|VAR  T7-NG|VAR   T7-I|SD  \
# 0  0.123640  0.011015   0.134655  ...   0.005318   0.005458  0.055285
# 1  0.122580  0.046207   0.168787  ...   0.006047   0.003990  0.047034
# 2  0.103354  0.054714   0.158068  ...   0.003187   0.002233  0.024718
# 3  0.099069  0.033884   0.132953  ...   0.004878   0.005244  0.046083
# 4  0.124757  0.023144   0.147900  ...   0.016760   0.017344  0.101889
#
#    T7-PF|SD  T7-RF|SD  T7-NG|SD  T8-I|0+7  T8-PF|0+7  T8-RF|0+7  T8-NG|0+7
# 0  0.056239  0.072921  0.073875  0.606169   0.731157   0.718543   0.843531
# 1  0.032436  0.077762  0.063164  0.616391   0.718327   0.697449   0.799384
# 2  0.015517  0.056457  0.047256  0.550968   0.641309   0.628636   0.718976
# 3  0.048659  0.069841  0.072416  0.562252   0.664963   0.652923   0.755634
# 4  0.104127  0.129459  0.131697  0.638064   0.765986   0.722751   0.850673
#
# [5 rows x 222 columns]

# %% [markdown]
# #### CHECK DATASET

# %%
########################
# # check for blanks # #
########################
if CHECK_BLANKS is True:
    # checking for blanks
    print("Checking for blanks...")
    if df.isnull().values.any() is True:
        df = df.dropna(axis=0, how="any")
        print("Blank rows has been dropped.")
    else:
        print("No blank value has been found.")
        
#################################
# # check for class imbalance # #
#################################
if CHECK_CLASS_IMBALANCE is True:
    print("Checking for class imbalance...")
    sns.countplot(x=CLASSES_COL_NAME, data=df).set_title("Class Imbalance")
#     df.loc[(df!=0).any(axis=1)]
    plt.show()

sns.catplot(x="Subject", y="T2-D|0", hue="T2-D|0", data=df, legend=False)
sns.catplot(x="Subject", y="T2-I|0+1", hue="T2-I|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-PF|0+1", hue="T2-PF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-RF|0+1", hue="T2-RF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-D|1", hue="T2-D|1", data=df, legend=False)
# Out:
# Checking for blanks...
# No blank value has been found.
# Checking for class imbalance...

# %% [markdown]
# #### PREPARE DATASET
# - Split data based on X / Features and Y / Classes
# - Binarize Y into binary labels

# %%
X, Y, lb, class_list = prepare_dataset(df)
n_classes = len(class_list)
print(f"Number of Classes: {n_classes}")
# Out:
# LabelBinarizer is able to decipher:
# ['andy' 'azfar' 'bryce' 'chris' 'cy' 'gerald' 'ken' 'qk' 'sz' 'vale' 'ye'
#  'ys']
#
#
# X | Features | Dataset Shape: (1200, 220)
# Y | Classes  | Dataset Shape: (1200, 12)
# Number of Classes: 12

# %% [markdown]
# #### SPLIT DATASET
# - Split dataset into train set and test set 0.8 / 0.2

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED)
# Out:
# float64
# float32
# float64
# float32
# X train shape: (960, 1, 220)
# Y train shape: (960, 12)
# X test shape: (240, 1, 220)
# Y test shape: (240, 12)

# %% [markdown]
# #### PERFORM VALIDATION (w KFold Validation)
# - Evaluate best KFold Validation
# - Generate loss and accuracy graph
# - Perform KFold validation

# %% [markdown]
# ##### Evaluate suitable folds for kfold validation

# %%
###############################################
# # evaluate suitable kfold value for model # #
###############################################
def evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD):
    
    # evaluate the model    
    folds = range(MIN_KFOLD, MAX_KFOLD)
    means, mins, maxs = list(), list(), list()
    
    # evaluate each k value
    for k in folds:
        # define the test condition
        kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
        
        # evaluate k value
        model = create_model()
        scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
        k_mean = np.mean(scores)
        k_min = scores.min()
        k_max = scores.max()
        
        # report performance
        print(f"No. of Folds: {k} | Accuracy: {k_mean*100:.3f} | Min: {k_min*100:.3f} | Max: {k_max*100:.3f}")
        
        # store mean accuracy and min and max relative to the mean
        means.append(k_mean)
        mins.append(k_mean - k_min)
        maxs.append(k_max - k_mean)
        
    # line plot of k mean values with min/max error bars
    clear_output(wait=True)
    pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
    # show the plot
    pyplot.show()
    
if EVAL_KFOLD_NUM is True:
    evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD)
else:
    print("EVAL_KFOLD_NUM is not True")
# Out:
# EVAL_KFOLD_NUM is not True

# %% [markdown]
# ##### Generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=50, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print(f"Accuracy | Mean: {np.mean(scores)*100:.3f} | Std: {np.std(scores)*100:.3f} | Length/no.: {len(scores)}")
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    clear_output(wait=True)
    plt.show()
    
if EVAL_KFOLD_MODEL is True:
    evaluate_kfold_model(X_train, y_train, SEED)
else:
    print("EVAL_KFOLD_MODEL is not true")
# Out:
# EVAL_KFOLD_MODEL is not true

# %% [markdown]
# ##### Perform Actual KFold validation

# %%
if PERFORM_KFOLD is True:
    # create model
    model = create_model()
    kfold = KFold(n_splits=N_KFOLD, shuffle=True, random_state=SEED)
    valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# ##### Get Validation Accuracy

# %%
if PERFORM_KFOLD is True:
    print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# #### FIT MODEL FOR TESTING
# - Fit the Model
# - View Accuracy and Loss Graph
# - View Model Summary

# %%
#####################
# # fit the model # #
#####################

if TEST_MODEL is True:
    model = create_model()
    es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                       verbose=1)
    history = model.fit(X_train, y_train, callbacks=es, verbose=1)
# Out:
# There are a total of 12 classes.
# Epoch 1/200
# 10/10 [==============================] - 7s 15ms/step - loss: 2.6458 - accuracy: 0.0875
# Epoch 2/200
# 10/10 [==============================] - 0s 14ms/step - loss: 2.5863 - accuracy: 0.0865
# Epoch 3/200
# 10/10 [==============================] - 0s 18ms/step - loss: 2.5663 - accuracy: 0.0844
# Epoch 4/200
# 10/10 [==============================] - 0s 16ms/step - loss: 2.5407 - accuracy: 0.0802
# Epoch 5/200
# 10/10 [==============================] - 0s 16ms/step - loss: 2.5203 - accuracy: 0.0990
# Epoch 6/200
# 10/10 [==============================] - 0s 15ms/step - loss: 2.5043 - accuracy: 0.0979
# Epoch 7/200
# 10/10 [==============================] - 0s 17ms/step - loss: 2.4877 - accuracy: 0.1063
# Epoch 8/200
# 10/10 [==============================] - 0s 20ms/step - loss: 2.4672 - accuracy: 0.1052
# Epoch 9/200
# 10/10 [==============================] - 0s 16ms/step - loss: 2.4369 - accuracy: 0.1240
# Epoch 10/200
# 10/10 [==============================] - 0s 16ms/step - loss: 2.3909 - accuracy: 0.1375
# Epoch 11/200
# 10/10 [==============================] - 0s 15ms/step - loss: 2.3509 - accuracy: 0.1625
# Epoch 12/200
# 10/10 [==============================] - 0s 15ms/step - loss: 2.3151 - accuracy: 0.1833
# Epoch 13/200
# 10/10 [==============================] - 0s 15ms/step - loss: 2.2597 - accuracy: 0.1760
# Epoch 14/200
# 10/10 [==============================] - 0s 17ms/step - loss: 2.2115 - accuracy: 0.1865
# Epoch 15/200
# 10/10 [==============================] - 0s 15ms/step - loss: 2.1606 - accuracy: 0.1885
# Epoch 16/200
# 10/10 [==============================] - 0s 15ms/step - loss: 2.1197 - accuracy: 0.2073
# Epoch 17/200
# 10/10 [==============================] - 0s 15ms/step - loss: 2.0547 - accuracy: 0.2333
# Epoch 18/200
# 10/10 [==============================] - 0s 15ms/step - loss: 2.0404 - accuracy: 0.2292
# Epoch 19/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.9858 - accuracy: 0.2406
# Epoch 20/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.9554 - accuracy: 0.2271
# Epoch 21/200
# 10/10 [==============================] - 0s 19ms/step - loss: 1.9411 - accuracy: 0.2313
# Epoch 22/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.8805 - accuracy: 0.2552
# Epoch 23/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.8678 - accuracy: 0.2677
# Epoch 24/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.8177 - accuracy: 0.2677
# Epoch 25/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.7788 - accuracy: 0.2927
# Epoch 26/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.7619 - accuracy: 0.3073
# Epoch 27/200
# 10/10 [==============================] - 0s 19ms/step - loss: 1.7371 - accuracy: 0.3167
# Epoch 28/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.7174 - accuracy: 0.3375
# Epoch 29/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.6988 - accuracy: 0.3229
# Epoch 30/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.6917 - accuracy: 0.3313
# Epoch 31/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.6578 - accuracy: 0.3458
# Epoch 32/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.6097 - accuracy: 0.3740
# Epoch 33/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.6252 - accuracy: 0.3760
# Epoch 34/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.6327 - accuracy: 0.3708
# Epoch 35/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.6170 - accuracy: 0.3625
# Epoch 36/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.6089 - accuracy: 0.3552
# Epoch 37/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5764 - accuracy: 0.3740
# Epoch 38/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.5427 - accuracy: 0.3615
# Epoch 39/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.5289 - accuracy: 0.3781
# Epoch 40/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4901 - accuracy: 0.4052
# Epoch 41/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4937 - accuracy: 0.4021
# Epoch 42/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5101 - accuracy: 0.3896
# Epoch 43/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5199 - accuracy: 0.4042
# Epoch 44/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.4739 - accuracy: 0.3927
# Epoch 45/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.4648 - accuracy: 0.4031
# Epoch 46/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4258 - accuracy: 0.4115
# Epoch 47/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4131 - accuracy: 0.4417
# Epoch 48/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4096 - accuracy: 0.4344
# Epoch 49/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4446 - accuracy: 0.4062
# Epoch 50/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.4064 - accuracy: 0.4115
# Epoch 51/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.3663 - accuracy: 0.4615
# Epoch 52/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.4089 - accuracy: 0.4167
# Epoch 53/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.3903 - accuracy: 0.4604
# Epoch 54/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.4687 - accuracy: 0.4354
# Epoch 55/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.3616 - accuracy: 0.4969
# Epoch 56/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.3268 - accuracy: 0.4875
# Epoch 57/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.3829 - accuracy: 0.4500
# Epoch 58/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.3296 - accuracy: 0.4854
# Epoch 59/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.2962 - accuracy: 0.5083
# Epoch 60/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.2719 - accuracy: 0.5406
# Epoch 61/200
# 10/10 [==============================] - 0s 18ms/step - loss: 1.2564 - accuracy: 0.5083
# Epoch 62/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.2609 - accuracy: 0.5167
# Epoch 63/200
# 10/10 [==============================] - 0s 18ms/step - loss: 1.3002 - accuracy: 0.5240
# Epoch 64/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.2573 - accuracy: 0.5198
# Epoch 65/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.2915 - accuracy: 0.5042
# Epoch 66/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.2455 - accuracy: 0.5312
# Epoch 67/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.2390 - accuracy: 0.5177
# Epoch 68/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.2400 - accuracy: 0.5542
# Epoch 69/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.2543 - accuracy: 0.5229
# Epoch 70/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.1768 - accuracy: 0.5635
# Epoch 71/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.1875 - accuracy: 0.5708
# Epoch 72/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.2086 - accuracy: 0.5396
# Epoch 73/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.1928 - accuracy: 0.5604
# Epoch 74/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.1828 - accuracy: 0.5490
# Epoch 75/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.1447 - accuracy: 0.5719
# Epoch 76/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.1566 - accuracy: 0.5635
# Epoch 77/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.1214 - accuracy: 0.5875
# Epoch 78/200
# 10/10 [==============================] - 0s 18ms/step - loss: 1.1174 - accuracy: 0.6062
# Epoch 79/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.0776 - accuracy: 0.5927
# Epoch 80/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.0701 - accuracy: 0.6052
# Epoch 81/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.0978 - accuracy: 0.5948
# Epoch 82/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.0897 - accuracy: 0.5885
# Epoch 83/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.1029 - accuracy: 0.5969
# Epoch 84/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.0786 - accuracy: 0.5969
# Epoch 85/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.0207 - accuracy: 0.6187
# Epoch 86/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.0413 - accuracy: 0.6250
# Epoch 87/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9973 - accuracy: 0.6281
# Epoch 88/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.0160 - accuracy: 0.6344
# Epoch 89/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.0046 - accuracy: 0.6260
# Epoch 90/200
# 10/10 [==============================] - 0s 14ms/step - loss: 1.0103 - accuracy: 0.6490
# Epoch 91/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9489 - accuracy: 0.6604
# Epoch 92/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9609 - accuracy: 0.6500
# Epoch 93/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9498 - accuracy: 0.6469
# Epoch 94/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9017 - accuracy: 0.6604
# Epoch 95/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9363 - accuracy: 0.6562
# Epoch 96/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9440 - accuracy: 0.6427
# Epoch 97/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9170 - accuracy: 0.6521
# Epoch 98/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9512 - accuracy: 0.6427
# Epoch 99/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9387 - accuracy: 0.6615
# Epoch 100/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.8971 - accuracy: 0.6719
# Epoch 101/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.8837 - accuracy: 0.6615
# Epoch 102/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9148 - accuracy: 0.6479
# Epoch 103/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.8675 - accuracy: 0.6812
# Epoch 104/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.8801 - accuracy: 0.6760
# Epoch 105/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.8790 - accuracy: 0.6687
# Epoch 106/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.8344 - accuracy: 0.6698
# Epoch 107/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8788 - accuracy: 0.6667
# Epoch 108/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8779 - accuracy: 0.6604
# Epoch 109/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.8326 - accuracy: 0.6698
# Epoch 110/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.8508 - accuracy: 0.6760
# Epoch 111/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.8679 - accuracy: 0.6656
# Epoch 112/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9169 - accuracy: 0.6531
# Epoch 113/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7951 - accuracy: 0.6948
# Epoch 114/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8823 - accuracy: 0.6552
# Epoch 115/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.8542 - accuracy: 0.6552
# Epoch 116/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7879 - accuracy: 0.6896
# Epoch 117/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.8301 - accuracy: 0.6833
# Epoch 118/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.8193 - accuracy: 0.6729
# Epoch 119/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7757 - accuracy: 0.6792
# Epoch 120/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.8486 - accuracy: 0.6729
# Epoch 121/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.8103 - accuracy: 0.6792
# Epoch 122/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.8025 - accuracy: 0.6854
# Epoch 123/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7681 - accuracy: 0.7135
# Epoch 124/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7852 - accuracy: 0.7094
# Epoch 125/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7858 - accuracy: 0.6708
# Epoch 126/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7818 - accuracy: 0.6896
# Epoch 127/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7548 - accuracy: 0.7188
# Epoch 128/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7685 - accuracy: 0.7094
# Epoch 129/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7978 - accuracy: 0.6958
# Epoch 130/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7391 - accuracy: 0.7292
# Epoch 131/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7855 - accuracy: 0.7094
# Epoch 132/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7610 - accuracy: 0.7104
# Epoch 133/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7868 - accuracy: 0.7115
# Epoch 134/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7816 - accuracy: 0.7146
# Epoch 135/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7178 - accuracy: 0.7281
# Epoch 136/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7587 - accuracy: 0.7177
# Epoch 137/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7461 - accuracy: 0.7156
# Epoch 138/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7099 - accuracy: 0.7385
# Epoch 139/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7559 - accuracy: 0.7365
# Epoch 140/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7190 - accuracy: 0.7281
# Epoch 141/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7595 - accuracy: 0.7281
# Epoch 142/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6764 - accuracy: 0.7542
# Epoch 143/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6308 - accuracy: 0.7823
# Epoch 144/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6253 - accuracy: 0.7760
# Epoch 145/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6534 - accuracy: 0.7615
# Epoch 146/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6616 - accuracy: 0.7781
# Epoch 147/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6266 - accuracy: 0.7604
# Epoch 148/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6070 - accuracy: 0.7927
# Epoch 149/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6489 - accuracy: 0.7719
# Epoch 150/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6175 - accuracy: 0.7896
# Epoch 151/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6468 - accuracy: 0.7792
# Epoch 152/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6289 - accuracy: 0.7729
# Epoch 153/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5878 - accuracy: 0.7802
# Epoch 154/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6172 - accuracy: 0.7823
# Epoch 155/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6296 - accuracy: 0.7719
# Epoch 156/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5917 - accuracy: 0.7844
# Epoch 157/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5823 - accuracy: 0.7917
# Epoch 158/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6434 - accuracy: 0.7823
# Epoch 159/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6406 - accuracy: 0.7719
# Epoch 160/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5668 - accuracy: 0.7917
# Epoch 161/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5773 - accuracy: 0.7781
# Epoch 162/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5954 - accuracy: 0.7750
# Epoch 163/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5729 - accuracy: 0.8010
# Epoch 164/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5795 - accuracy: 0.7969
# Epoch 165/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6167 - accuracy: 0.7844
# Epoch 166/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5941 - accuracy: 0.7760
# Epoch 167/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5672 - accuracy: 0.7760
# Epoch 168/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5563 - accuracy: 0.7833
# Epoch 169/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6188 - accuracy: 0.7552
# Epoch 170/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5825 - accuracy: 0.7937
# Epoch 171/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.5586 - accuracy: 0.7896
# Epoch 172/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5575 - accuracy: 0.7875
# Epoch 173/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5654 - accuracy: 0.7958
# Epoch 174/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5797 - accuracy: 0.7802
# Epoch 175/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5271 - accuracy: 0.7885
# Epoch 176/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4945 - accuracy: 0.7990
# Epoch 177/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5230 - accuracy: 0.8073
# Epoch 178/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.5161 - accuracy: 0.8062
# Epoch 179/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5211 - accuracy: 0.7896
# Epoch 180/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4775 - accuracy: 0.7927
# Epoch 181/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4963 - accuracy: 0.7958
# Epoch 182/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4891 - accuracy: 0.7937
# Epoch 183/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5087 - accuracy: 0.7979
# Epoch 184/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5529 - accuracy: 0.7969
# Epoch 185/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5305 - accuracy: 0.7917
# Epoch 186/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4807 - accuracy: 0.8010
# Epoch 187/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4705 - accuracy: 0.8125
# Epoch 188/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4932 - accuracy: 0.8073
# Epoch 189/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4823 - accuracy: 0.7865
# Epoch 190/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5128 - accuracy: 0.7833
# Epoch 191/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5005 - accuracy: 0.7740
# Epoch 192/200
# 10/10 [==============================] - 0s 23ms/step - loss: 0.5098 - accuracy: 0.7740
# Epoch 193/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5131 - accuracy: 0.7792
# Epoch 194/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5337 - accuracy: 0.7917
# Epoch 195/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5103 - accuracy: 0.7885
# Epoch 196/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.4706 - accuracy: 0.8146
# Epoch 197/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.4714 - accuracy: 0.7937
# Epoch 198/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.4744 - accuracy: 0.7927
# Epoch 199/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.4533 - accuracy: 0.7875
# Epoch 200/200
# 10/10 [==============================] - 0s 23ms/step - loss: 0.4548 - accuracy: 0.7979

# %%
if TEST_MODEL is True:
    ##########################
    # # get model accuracy # #
    ##########################
    plt.plot(history.history['accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

    ######################
    # # get model loss # #
    ######################
    plt.plot(history.history['loss'])
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

# %%
if TEST_MODEL is True:
    ##########################
    # # view model summary # #
    ##########################
    model.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 256)            488448
#
#  dense (Dense)               (None, 1, 256)            65792
#
#  dropout (Dropout)           (None, 1, 256)            0
#
#  batch_normalization (BatchN  (None, 1, 256)           1024
#  ormalization)
#
#  lstm_1 (LSTM)               (None, 1, 128)            197120
#
#  dense_1 (Dense)             (None, 1, 128)            16512
#
#  dropout_1 (Dropout)         (None, 1, 128)            0
#
#  batch_normalization_1 (Batc  (None, 1, 128)           512
#  hNormalization)
#
#  lstm_2 (LSTM)               (None, 1, 64)             49408
#
#  dense_2 (Dense)             (None, 1, 64)             4160
#
#  dropout_2 (Dropout)         (None, 1, 64)             0
#
#  batch_normalization_2 (Batc  (None, 1, 64)            256
#  hNormalization)
#
#  lstm_3 (LSTM)               (None, 1, 32)             12416
#
#  dense_3 (Dense)             (None, 1, 32)             1056
#
#  dropout_3 (Dropout)         (None, 1, 32)             0
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense_4 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 837,100
# Trainable params: 836,204
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# #### MODEL TESTING
# - Get Model Accuracy on the Test Dataset
# - Generate Confusion Matrix
# - Generate ROC Curves
# - Save the Model if Appropriate

# %%
if TEST_MODEL is True:
    y_pred = model.predict_proba(X_test)

    # evaluate predictions
    acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    print("Testing accuracy: %.3f%%" % (acc*100))
# Out:
# Testing accuracy: 75.833%

# %% [markdown]
# ##### Confusion Matrix

# %%
if TEST_MODEL is True and CON_MATRIX is True:
    # confusion matrix
    print(str(len(y_pred)) + " is the number of test value in kfold_val / train_test_split")
    cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                         columns = [i for i in np.unique(lb.inverse_transform(y_test))])

    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=True, cmap="BuPu")
# Out:
# 240 is the number of test value in kfold_val / train_test_split

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
if TEST_MODEL is True and ROC_GRAPH is True: # compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    for i in range(n_classes):
        plt.figure()
        lw = 2
        plt.plot(
            fpr[i],
            tpr[i],
            color="darkorange",
            lw=lw,
            label="ROC curve (area = %0.2f)" % roc_auc[i],
        )
        plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
        plt.xlim([-0.005, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ##### ROC Curve (Multiclass)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    # compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # first aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    # plt.figure()
    # plt.plot(
    #     fpr["micro"],
    #     tpr["micro"],
    #     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    #     color="deeppink",
    #     linestyle=":",
    #     linewidth=4,
    # )

    # plt.plot(
    #     fpr["macro"],
    #     tpr["macro"],
    #     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    #     color="navy",
    #     linestyle=":",
    #     linewidth=4,
    # )

    colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
        )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Multiclass)")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Average)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

    # calculate equal-error-rate
    eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('Average ROC Curve')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #### FIT AND SAVE MODEL
# - Fitting of model
# - Get Accuracy and Loss of Mdoel
# - Saving Model

# %%
############################
# # reshaping of dataset # #
############################
# loading of dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)

df.head()
dataset = df.values

# divide data into features X and target (classes) Y
# convert target Y to labelbinarizer Y for model
X, Y, lb, class_list = prepare_dataset(df)

# reshaping the dataset to include LSTM Timesteps
X = reshape_dataset(X, TIMESTEPS)
n_classes = Y.shape[1]

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# LabelBinarizer is able to decipher:
# ['andy' 'azfar' 'bryce' 'chris' 'cy' 'gerald' 'ken' 'qk' 'sz' 'vale' 'ye'
#  'ys']
#
#
# X | Features | Dataset Shape: (1200, 220)
# Y | Classes  | Dataset Shape: (1200, 12)
# There are a total of 12 classes.
# Epoch 1/200
# 12/12 [==============================] - 5s 12ms/step - loss: 2.6650 - accuracy: 0.0833
# Epoch 2/200
# 12/12 [==============================] - 0s 10ms/step - loss: 2.6026 - accuracy: 0.0892
# Epoch 3/200
# 12/12 [==============================] - 0s 11ms/step - loss: 2.5597 - accuracy: 0.0850
# Epoch 4/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.5259 - accuracy: 0.0875
# Epoch 5/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.5250 - accuracy: 0.0858
# Epoch 6/200
# 12/12 [==============================] - 0s 13ms/step - loss: 2.4900 - accuracy: 0.0967
# Epoch 7/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.4064 - accuracy: 0.1458
# Epoch 8/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.3527 - accuracy: 0.1567
# Epoch 9/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.2805 - accuracy: 0.1608
# Epoch 10/200
# 12/12 [==============================] - 0s 13ms/step - loss: 2.2501 - accuracy: 0.1575
# Epoch 11/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.1954 - accuracy: 0.1558
# Epoch 12/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.1288 - accuracy: 0.1825
# Epoch 13/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.1062 - accuracy: 0.1608
# Epoch 14/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.0696 - accuracy: 0.1775
# Epoch 15/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.0398 - accuracy: 0.1692
# Epoch 16/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.0344 - accuracy: 0.1692
# Epoch 17/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.0078 - accuracy: 0.1758
# Epoch 18/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.9868 - accuracy: 0.2042
# Epoch 19/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.9717 - accuracy: 0.1958
# Epoch 20/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.9379 - accuracy: 0.2058
# Epoch 21/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.9181 - accuracy: 0.2200
# Epoch 22/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.9001 - accuracy: 0.2267
# Epoch 23/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.8971 - accuracy: 0.2183
# Epoch 24/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.8978 - accuracy: 0.2200
# Epoch 25/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.8658 - accuracy: 0.2350
# Epoch 26/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.8611 - accuracy: 0.2242
# Epoch 27/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.8679 - accuracy: 0.2283
# Epoch 28/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.8609 - accuracy: 0.2325
# Epoch 29/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.8439 - accuracy: 0.2308
# Epoch 30/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.8011 - accuracy: 0.2450
# Epoch 31/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.8130 - accuracy: 0.2283
# Epoch 32/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.8301 - accuracy: 0.2258
# Epoch 33/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.7939 - accuracy: 0.2425
# Epoch 34/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.7864 - accuracy: 0.2442
# Epoch 35/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.7745 - accuracy: 0.2600
# Epoch 36/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.7633 - accuracy: 0.2500
# Epoch 37/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.7596 - accuracy: 0.2725
# Epoch 38/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.7593 - accuracy: 0.2600
# Epoch 39/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.7297 - accuracy: 0.2717
# Epoch 40/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.7061 - accuracy: 0.2817
# Epoch 41/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.7005 - accuracy: 0.2767
# Epoch 42/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6846 - accuracy: 0.2958
# Epoch 43/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6804 - accuracy: 0.2867
# Epoch 44/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6626 - accuracy: 0.3042
# Epoch 45/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6553 - accuracy: 0.3067
# Epoch 46/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6540 - accuracy: 0.3033
# Epoch 47/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6407 - accuracy: 0.3075
# Epoch 48/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6627 - accuracy: 0.3075
# Epoch 49/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6215 - accuracy: 0.3133
# Epoch 50/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6179 - accuracy: 0.3008
# Epoch 51/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6269 - accuracy: 0.2908
# Epoch 52/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6331 - accuracy: 0.2783
# Epoch 53/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6086 - accuracy: 0.3125
# Epoch 54/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6116 - accuracy: 0.3000
# Epoch 55/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6303 - accuracy: 0.3033
# Epoch 56/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6245 - accuracy: 0.2958
# Epoch 57/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.6024 - accuracy: 0.2942
# Epoch 58/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5687 - accuracy: 0.3367
# Epoch 59/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5745 - accuracy: 0.3100
# Epoch 60/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5607 - accuracy: 0.3208
# Epoch 61/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5516 - accuracy: 0.3183
# Epoch 62/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5686 - accuracy: 0.3283
# Epoch 63/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5332 - accuracy: 0.3292
# Epoch 64/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5487 - accuracy: 0.3375
# Epoch 65/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5422 - accuracy: 0.3433
# Epoch 66/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5130 - accuracy: 0.3517
# Epoch 67/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5349 - accuracy: 0.3317
# Epoch 68/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5073 - accuracy: 0.3567
# Epoch 69/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5151 - accuracy: 0.3525
# Epoch 70/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4956 - accuracy: 0.3425
# Epoch 71/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5013 - accuracy: 0.3792
# Epoch 72/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5146 - accuracy: 0.3500
# Epoch 73/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4612 - accuracy: 0.3683
# Epoch 74/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4426 - accuracy: 0.3750
# Epoch 75/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4697 - accuracy: 0.3833
# Epoch 76/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4461 - accuracy: 0.3817
# Epoch 77/200
# 12/12 [==============================] - 0s 11ms/step - loss: 1.4601 - accuracy: 0.3775
# Epoch 78/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4475 - accuracy: 0.3933
# Epoch 79/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4107 - accuracy: 0.3942
# Epoch 80/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4067 - accuracy: 0.3942
# Epoch 81/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4229 - accuracy: 0.4042
# Epoch 82/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.3975 - accuracy: 0.4083
# Epoch 83/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.4019 - accuracy: 0.3967
# Epoch 84/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.3405 - accuracy: 0.4425
# Epoch 85/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.3615 - accuracy: 0.4233
# Epoch 86/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.3434 - accuracy: 0.4375
# Epoch 87/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.3064 - accuracy: 0.4450
# Epoch 88/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.3171 - accuracy: 0.4692
# Epoch 89/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.3048 - accuracy: 0.4617
# Epoch 90/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.2738 - accuracy: 0.4525
# Epoch 91/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.2653 - accuracy: 0.4642
# Epoch 92/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.2144 - accuracy: 0.4925
# Epoch 93/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.1990 - accuracy: 0.5083
# Epoch 94/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.1859 - accuracy: 0.5225
# Epoch 95/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.1858 - accuracy: 0.5133
# Epoch 96/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.1616 - accuracy: 0.5225
# Epoch 97/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.1492 - accuracy: 0.5217
# Epoch 98/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.1609 - accuracy: 0.5258
# Epoch 99/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.1107 - accuracy: 0.5633
# Epoch 100/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0943 - accuracy: 0.5742
# Epoch 101/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0598 - accuracy: 0.5808
# Epoch 102/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0813 - accuracy: 0.5658
# Epoch 103/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.1095 - accuracy: 0.5617
# Epoch 104/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0819 - accuracy: 0.5783
# Epoch 105/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0931 - accuracy: 0.5575
# Epoch 106/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0226 - accuracy: 0.5792
# Epoch 107/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0446 - accuracy: 0.6000
# Epoch 108/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0390 - accuracy: 0.5958
# Epoch 109/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0082 - accuracy: 0.6025
# Epoch 110/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9984 - accuracy: 0.6050
# Epoch 111/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0055 - accuracy: 0.6092
# Epoch 112/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9943 - accuracy: 0.6450
# Epoch 113/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9790 - accuracy: 0.6475
# Epoch 114/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9405 - accuracy: 0.6508
# Epoch 115/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9060 - accuracy: 0.6708
# Epoch 116/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0473 - accuracy: 0.6617
# Epoch 117/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0036 - accuracy: 0.6525
# Epoch 118/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0270 - accuracy: 0.6400
# Epoch 119/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9564 - accuracy: 0.6917
# Epoch 120/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0139 - accuracy: 0.6508
# Epoch 121/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9427 - accuracy: 0.7075
# Epoch 122/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9125 - accuracy: 0.7017
# Epoch 123/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8933 - accuracy: 0.7350
# Epoch 124/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8360 - accuracy: 0.7342
# Epoch 125/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8499 - accuracy: 0.7392
# Epoch 126/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8526 - accuracy: 0.7350
# Epoch 127/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8150 - accuracy: 0.7550
# Epoch 128/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8144 - accuracy: 0.7542
# Epoch 129/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8003 - accuracy: 0.7525
# Epoch 130/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8085 - accuracy: 0.7500
# Epoch 131/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8220 - accuracy: 0.7392
# Epoch 132/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7736 - accuracy: 0.7558
# Epoch 133/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7356 - accuracy: 0.7842
# Epoch 134/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7480 - accuracy: 0.7767
# Epoch 135/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7069 - accuracy: 0.8025
# Epoch 136/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7281 - accuracy: 0.7808
# Epoch 137/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6705 - accuracy: 0.8133
# Epoch 138/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6991 - accuracy: 0.7842
# Epoch 139/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6921 - accuracy: 0.7825
# Epoch 140/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6746 - accuracy: 0.8125
# Epoch 141/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7048 - accuracy: 0.7908
# Epoch 142/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6695 - accuracy: 0.8117
# Epoch 143/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6988 - accuracy: 0.7917
# Epoch 144/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7283 - accuracy: 0.7883
# Epoch 145/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6602 - accuracy: 0.8208
# Epoch 146/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6375 - accuracy: 0.8125
# Epoch 147/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5978 - accuracy: 0.8275
# Epoch 148/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6611 - accuracy: 0.7908
# Epoch 149/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7037 - accuracy: 0.7683
# Epoch 150/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6923 - accuracy: 0.7842
# Epoch 151/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6785 - accuracy: 0.8000
# Epoch 152/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.6070 - accuracy: 0.8250
# Epoch 153/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6520 - accuracy: 0.8075
# Epoch 154/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6282 - accuracy: 0.8158
# Epoch 155/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5934 - accuracy: 0.8367
# Epoch 156/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5908 - accuracy: 0.8267
# Epoch 157/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5541 - accuracy: 0.8333
# Epoch 158/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5538 - accuracy: 0.8450
# Epoch 159/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5285 - accuracy: 0.8475
# Epoch 160/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5389 - accuracy: 0.8400
# Epoch 161/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5367 - accuracy: 0.8308
# Epoch 162/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6746 - accuracy: 0.8192
# Epoch 163/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6366 - accuracy: 0.8250
# Epoch 164/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5881 - accuracy: 0.8175
# Epoch 165/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5830 - accuracy: 0.8233
# Epoch 166/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6084 - accuracy: 0.8067
# Epoch 167/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5837 - accuracy: 0.8342
# Epoch 168/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5404 - accuracy: 0.8283
# Epoch 169/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5390 - accuracy: 0.8325
# Epoch 170/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6175 - accuracy: 0.8167
# Epoch 171/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5841 - accuracy: 0.8175
# Epoch 172/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5473 - accuracy: 0.8400
# Epoch 173/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.5342 - accuracy: 0.8375
# Epoch 174/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.5258 - accuracy: 0.8208
# Epoch 175/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5101 - accuracy: 0.8417
# Epoch 176/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5421 - accuracy: 0.8200
# Epoch 177/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5949 - accuracy: 0.8100
# Epoch 178/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.5475 - accuracy: 0.8375
# Epoch 179/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.5477 - accuracy: 0.8267
# Epoch 180/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5779 - accuracy: 0.8325
# Epoch 181/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5876 - accuracy: 0.8175
# Epoch 182/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5374 - accuracy: 0.8392
# Epoch 183/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4832 - accuracy: 0.8450
# Epoch 184/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4803 - accuracy: 0.8450
# Epoch 185/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4668 - accuracy: 0.8683
# Epoch 186/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4729 - accuracy: 0.8417
# Epoch 187/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4531 - accuracy: 0.8550
# Epoch 188/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4390 - accuracy: 0.8483
# Epoch 189/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4267 - accuracy: 0.8683
# Epoch 190/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4532 - accuracy: 0.8633
# Epoch 191/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4390 - accuracy: 0.8642
# Epoch 192/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4133 - accuracy: 0.8767
# Epoch 193/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4261 - accuracy: 0.8642
# Epoch 194/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4096 - accuracy: 0.8758
# Epoch 195/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4136 - accuracy: 0.8792
# Epoch 196/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4140 - accuracy: 0.8775
# Epoch 197/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3800 - accuracy: 0.8833
# Epoch 198/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3903 - accuracy: 0.8725
# Epoch 199/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3797 - accuracy: 0.8692
# Epoch 200/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4176 - accuracy: 0.8767

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# #### SAVE MODEL

# %%
##################
# # save model # #
##################
model.model.save(MODEL_PATH)

# %% [markdown]
# # LIVE TESTING
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()
# Out:
#   Subject Actual  Password    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  \
# 0    andy   andy  C05mical  0.135995  0.280076   0.416071   0.417544
# 1    andy   andy  C05mical  0.127320 -0.022938   0.104383   0.151995
# 2    andy   andy  C05mical  0.153290  0.062498   0.215788   0.238489
# 3    andy   andy  C05mical  0.143564  0.120750   0.264313   0.344796
# 4    andy   andy  C05mical  0.151355  0.127971   0.279326   0.273084
#
#    T2-NG|0+1    T2-D|1  T2-I|1+2  ...  T7-RF|VAR  T7-NG|VAR   T7-I|SD  \
# 0   0.553540  0.137469  0.022989  ...   0.097954   0.097303  0.255337
# 1   0.279315  0.174932 -0.015584  ...   0.016906   0.009284  0.067609
# 2   0.391778  0.175990  0.201464  ...   0.018170   0.014100  0.117639
# 3   0.488359  0.224046  0.024298  ...   0.029047   0.012887  0.142320
# 4   0.424439  0.145113  0.078891  ...   0.041763   0.043587  0.154391
#
#    T7-PF|SD  T7-RF|SD  T7-NG|SD  T8-I|0+7  T8-PF|0+7  T8-RF|0+7  T8-NG|0+7
# 0  0.254295  0.312977  0.311935  0.896913   1.032908   0.984040   1.120035
# 1  0.033943  0.130022  0.096355  0.640388   0.767709   0.792011   0.919332
# 2  0.101587  0.134797  0.118745  0.983009   1.136299   1.143205   1.296495
# 3  0.085410  0.170430  0.113521  1.008607   1.152170   1.136941   1.280505
# 4  0.158805  0.204360  0.208774  0.847978   0.999333   0.919979   1.071334
#
# [5 rows x 223 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
actual_np = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

FEATURES_COL_NUM = 3

########################
# # predict all rows # #
########################
pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[46:54,FEATURES_COL_NUM:]
# print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

print(class_list)
Y = np.asarray(class_list)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)
# Out:
# ['andy', 'azfar', 'bryce', 'chris', 'cy', 'gerald', 'ken', 'qk', 'sz', 'vale', 'ye', 'ys']

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

# pred_proba = np.sum(pred_proba, axis=0)
# pred_proba = np.reshape(pred_proba, (1, 9))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

match_list = []

for _ in range(actual_np.size):
    if pred[_] == actual_np[_]:
        match_list.append("match")
    else:
        match_list.append("nope")

match_count = match_list.count("match")
total_count = len(match_list)

match_header = str(match_count) + "/" + str(total_count) + " (" + str(match_count/total_count*100)+ "%)"
match_np = np.array(match_list)

exported_output = np.column_stack((actual_np, pred))
exported_output = np.column_stack((exported_output, acc))
exported_output = np.column_stack((exported_output, match_np))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(data=exported_output, index=None, columns=['Actual', 'Prediction', 'Accuracy', match_header])
# print(df)
df.to_csv(RESULT_PATH)

print("Accuracy of the Model is: " + str(match_header))
# Out:
# Accuracy of the Model is: 46/60 (76.66666666666667%)
