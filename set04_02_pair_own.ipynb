# %%
# calculate elapsed time
import time
start_time = time.time()

# %% [markdown]
# #### IMPORT

# %%
import os, platform
import py7zr

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %% [markdown]
# #### PARAMETERS
# - Set the condition
# > * N_FEATURES: Number of Features
# > * CHECK_BLANKS: Check for blank data. If any blank data is found, the whole row of data will be deleted.
# > * CHECK_CLASS_IMBALANCE: Check for dataset class imbalance. The more balance the dataset, the less biases the model will be.

# %%
##############################
# # deep learning features # #
##############################
SEED = 1005 # random seed for reproducibility

# should make this dynamic
N_FEATURES = 440
TIMESTEPS = 1
EPOCH=20
BATCH_SIZE=20

SPLIT_RATIO=0.2

###############
# # preview # #
###############
f = False
t = True

# checking dataset
CHECK_BLANKS = True
CHECK_CLASS_IMBALANCE = True

# evaluate suitable kfold number and kfold model
MIN_KFOLD = 2
MAX_KFOLD = 11
N_KFOLD = 5
EVAL_KFOLD_NUM = False
EVAL_KFOLD_MODEL = False
PERFORM_KFOLD = True

# model testing
TEST_MODEL = True
CON_MATRIX = True
ROC_GRAPH = True

###############
# # dataset # #
###############
CLASSES_COL_NAME = "Subject"
CLASSES_COL_NUM = 0
FEATURES_COL_NUM = 2

DATASET_DIR_NAME = "dataset\set04\\02_pair_own"
SAMPLE_DATASET_NAME = "pair_train_own"
ACTUAL_DATASET_NAME = "pair_test_own"

MODEL_DIR_NAME = "dataset\set04\\02_pair_own"
MODEL_NAME = "model_" + "set04_02_pair_own"

RESULT_DIR_NAME = "dataset\set04\\02_pair_own"
RESULT_NAME = "result_" + "set04_02_pair_own"

DATASET_DIR_PATH = os.path.join(os.getcwd(), DATASET_DIR_NAME)
SAMPLE_DATASET_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".csv")
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME + ".csv")

MODEL_DIR_PATH = os.path.join(os.getcwd(), MODEL_DIR_NAME)
MODEL_PATH = os.path.join(MODEL_DIR_PATH, MODEL_NAME + ".h5")

RESULT_DIR_PATH = os.path.join(os.getcwd(), RESULT_DIR_NAME)
RESULT_PATH = os.path.join(RESULT_DIR_PATH, RESULT_NAME + ".csv")

#################
# # sns theme # #
#################
# sns.set_theme(style="darkgrid") # (dark background with white gridlines)
sns.set_theme(style="whitegrid") # (white background with grey gridlines)
# sns.set_theme(style="dark") # (dark background with no gridlines)
# sns.set_theme(style="white") # (white background with no gridlines)
# sns.set_theme(style="ticks") # (white background with axis ticks and no gridlines)

# %%
if os.path.isdir(DATASET_DIR_PATH) is True:
    print(f"Dataset directory exists at: {DATASET_DIR_PATH}")
else:
    try:
        os.mkdir(DATASET_DIR_PATH, 666)
        print(f"Dataset directory have been created at: {DATASET_DIR_PATH}")
    except:
        print("Error: Dataset Directory not created")
        
if os.path.isdir(MODEL_DIR_PATH) is True:
    print(f"Model directory exists at: {MODEL_DIR_PATH}")
else:
    try:
        os.mkdir(MODEL_DIR_PATH, 666)
        print(f"Model directory have been created at: {MODEL_DIR_PATH}")
    except:
        print("Error: Model Directory not created")
    
if os.path.exists(SAMPLE_DATASET_PATH) is True:
    print(f"Training dataset exists at: {SAMPLE_DATASET_PATH}")
else:
    try:
        SAMPLE_7Z_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".7z")
        with py7zr.SevenZipFile(SAMPLE_7Z_PATH, mode='r') as z:
            z.extractall(path=DATASET_DIR_PATH)
        print(f"Decompress 7z file to: {SAMPLE_7Z_PATH}")
    except:
        print("Error: Failed to decompress 7z file.")
# Out:
# Dataset directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set04\02_pair_own
# Model directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set04\02_pair_own
# Decompress 7z file to: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set04\02_pair_own\pair_train_own.7z

# %% [markdown]
# #### CREATE MODEL
# - Create base model
# - Wrap it with KerasClassifier

# %%
#create base model
def create_base_model():
    model = Sequential()
    model.add(LSTM(units=256, return_sequences=True,
             input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dense(256, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=32, return_sequences=True))
    model.add(Dense(32, activation='sigmoid'))
    model.add(Dropout(0.2))

    # softmax for multi-class classification
    model.add(Flatten())
    print("There are a total of " + str(n_classes) + " classes.")
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=EPOCH, 
                            batch_size=BATCH_SIZE)
    return model

# %%
# divide data into features X and target (classes) Y
def prepare_dataset(df):
    X = df.values[:,FEATURES_COL_NUM:].astype(float)
    Y = df.values[:,CLASSES_COL_NUM].astype(str)

    # convert target Y to labelbinarizer Y for model
    # fit_transform is not used to reuse lb
    Y = Y.reshape(-1, 1)
    lb = LabelBinarizer().fit(Y)
    Y = lb.transform(Y)

    #################################
    # # get all the encoded class # #
    #################################
    print("LabelBinarizer is able to decipher: ")
    print(lb.classes_)
    print("\n")

    ###########################
    # # print X and Y shape # #
    ###########################
    print(f"X | Features | Dataset Shape: {X.shape}")
    print(f"Y | Classes  | Dataset Shape: {Y.shape}")

    return X, Y, lb, lb.classes_.tolist()

# %%
def split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED):

    ##############################################################
    # # split dataset into train and test set of 0.8/0.2 ratio # #
    ##############################################################
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=SPLIT_RATIO, random_state=SEED)

    ############################
    # # reshaping of dataset # #
    ############################

    # reshaping the dataset to include LSTM Timesteps
    print(X_train.dtype)
    X_train = np.asarray(X_train, dtype=np.float32)
    print(X_train.dtype)
    X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
    print(X_test.dtype)
    X_test = np.asarray(X_test, dtype=np.float32)
    print(X_test.dtype)
    X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

    print(f"X train shape: {X_train.shape}")
    print(f"Y train shape: {y_train.shape}")
    print(f"X test shape: {X_test.shape}")
    print(f"Y test shape: {y_test.shape}")
    
    return X_train, X_test, y_train, y_test

def reshape_dataset(X, TIMESTEPS):
    # reshaping the dataset to include LSTM Timesteps
    X = np.asarray(X, dtype=np.float32)
    X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))
    return X

# %% [markdown]
# #### LOAD DATASET

# %%
# load dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)
df.head()
# Out:
#   Subject  Password    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    andy  Co5mical  0.124989       0.0   0.124989    0.12364   0.248628
# 1    andy  Co5mical  0.124989       0.0   0.124989    0.12364   0.248628
# 2    andy  Co5mical  0.124989       0.0   0.124989    0.12364   0.248628
# 3    andy  Co5mical  0.124989       0.0   0.124989    0.12364   0.248628
# 4    andy  Co5mical  0.124989       0.0   0.124989    0.12364   0.248628
#
#     T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T7-RF|VAR.1  T7-NG|VAR.1  T7-I|SD.1  \
# 0  0.12364  0.011015   0.134655  ...     0.006047     0.003990   0.047034
# 1  0.12364  0.011015   0.134655  ...     0.003187     0.002233   0.024718
# 2  0.12364  0.011015   0.134655  ...     0.004878     0.005244   0.046083
# 3  0.12364  0.011015   0.134655  ...     0.016760     0.017344   0.101889
# 4  0.12364  0.011015   0.134655  ...     0.002298     0.003914   0.022615
#
#    T7-PF|SD.1  T7-RF|SD.1  T7-NG|SD.1  T8-I|0+7.1  T8-PF|0+7.1  T8-RF|0+7.1  \
# 0    0.032436    0.077762    0.063164    0.616391     0.718327     0.697449
# 1    0.015517    0.056457    0.047256    0.550968     0.641309     0.628636
# 2    0.048659    0.069841    0.072416    0.562252     0.664963     0.652923
# 3    0.104127    0.129459    0.131697    0.638064     0.765986     0.722751
# 4    0.037240    0.047934    0.062559    0.508190     0.630242     0.585637
#
#    T8-NG|0+7.1
# 0     0.799384
# 1     0.718976
# 2     0.755634
# 3     0.850673
# 4     0.707689
#
# [5 rows x 442 columns]

# %% [markdown]
# #### CHECK DATASET

# %%
########################
# # check for blanks # #
########################
if CHECK_BLANKS is True:
    # checking for blanks
    print("Checking for blanks...")
    if df.isnull().values.any() is True:
        df = df.dropna(axis=0, how="any")
        print("Blank rows has been dropped.")
    else:
        print("No blank value has been found.")
        
#################################
# # check for class imbalance # #
#################################
if CHECK_CLASS_IMBALANCE is True:
    print("Checking for class imbalance...")
    sns.countplot(x=CLASSES_COL_NAME, data=df).set_title("Class Imbalance")
#     df.loc[(df!=0).any(axis=1)]
    plt.show()

# sns.catplot(x="Subject", y="T2-D|0", hue="T2-D|0", data=df, legend=False)
# sns.catplot(x="Subject", y="T2-I|0+1", hue="T2-I|0+1", data=df, legend=False)
# sns.catplot(x="Subject", y="T2-PF|0+1", hue="T2-PF|0+1", data=df, legend=False)
# sns.catplot(x="Subject", y="T2-RF|0+1", hue="T2-RF|0+1", data=df, legend=False)
# sns.catplot(x="Subject", y="T2-D|1", hue="T2-D|1", data=df, legend=False)
# Out:
# Checking for blanks...
# No blank value has been found.
# Checking for class imbalance...

# %% [markdown]
# #### PREPARE DATASET
# - Split data based on X / Features and Y / Classes
# - Binarize Y into binary labels

# %%
X, Y, lb, class_list = prepare_dataset(df)
n_classes = len(class_list)
print(f"Number of Classes: {n_classes}")
# Out:
# LabelBinarizer is able to decipher:
# ['andy' 'azfar' 'chris' 'cy' 'gerald' 'ken' 'qk' 'sz' 'vale' 'ye' 'ys']
#
#
# X | Features | Dataset Shape: (108900, 440)
# Y | Classes  | Dataset Shape: (108900, 11)
# Number of Classes: 11

# %% [markdown]
# #### SPLIT DATASET
# - Split dataset into train set and test set 0.8 / 0.2

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED)
# Out:
# float64
# float32
# float64
# float32
# X train shape: (87120, 1, 440)
# Y train shape: (87120, 11)
# X test shape: (21780, 1, 440)
# Y test shape: (21780, 11)

# %% [markdown]
# #### PERFORM VALIDATION (w KFold Validation)
# - Evaluate best KFold Validation
# - Generate loss and accuracy graph
# - Perform KFold validation

# %% [markdown]
# ##### Evaluate suitable folds for kfold validation

# %%
###############################################
# # evaluate suitable kfold value for model # #
###############################################
def evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD):
    
    # evaluate the model    
    folds = range(MIN_KFOLD, MAX_KFOLD)
    means, mins, maxs = list(), list(), list()
    
    # evaluate each k value
    for k in folds:
        # define the test condition
        kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
        
        # evaluate k value
        model = create_model()
        scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
        k_mean = np.mean(scores)
        k_min = scores.min()
        k_max = scores.max()
        
        # report performance
        print(f"No. of Folds: {k} | Accuracy: {k_mean*100:.3f} | Min: {k_min*100:.3f} | Max: {k_max*100:.3f}")
        
        # store mean accuracy and min and max relative to the mean
        means.append(k_mean)
        mins.append(k_mean - k_min)
        maxs.append(k_max - k_mean)
        
    # line plot of k mean values with min/max error bars
    clear_output(wait=True)
    pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
    # show the plot
    pyplot.show()
    
if EVAL_KFOLD_NUM is True:
    evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD)
else:
    print("EVAL_KFOLD_NUM is not True")
# Out:
# EVAL_KFOLD_NUM is not True

# %% [markdown]
# ##### Generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=50, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print(f"Accuracy | Mean: {np.mean(scores)*100:.3f} | Std: {np.std(scores)*100:.3f} | Length/no.: {len(scores)}")
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    clear_output(wait=True)
    plt.show()
    
if EVAL_KFOLD_MODEL is True:
    evaluate_kfold_model(X_train, y_train, SEED)
else:
    print("EVAL_KFOLD_MODEL is not true")
# Out:
# EVAL_KFOLD_MODEL is not true

# %% [markdown]
# ##### Perform Actual KFold validation

# %%
if PERFORM_KFOLD is True:
    # create model
    model = create_model()
    kfold = KFold(n_splits=N_KFOLD, shuffle=True, random_state=SEED)
    valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# There are a total of 11 classes.
# Epoch 1/20
# 3485/3485 [==============================] - 49s 12ms/step - loss: 1.2695 - accuracy: 0.4848
# Epoch 2/20
# 3485/3485 [==============================] - 40s 11ms/step - loss: 0.6216 - accuracy: 0.7808
# Epoch 3/20
# 3485/3485 [==============================] - 40s 11ms/step - loss: 0.3982 - accuracy: 0.8749
# Epoch 4/20
# 3485/3485 [==============================] - 40s 11ms/step - loss: 0.2585 - accuracy: 0.9395
# Epoch 5/20
# 3485/3485 [==============================] - 40s 12ms/step - loss: 0.2206 - accuracy: 0.9489
# Epoch 6/20
# 3485/3485 [==============================] - 41s 12ms/step - loss: 0.1648 - accuracy: 0.9627
# Epoch 7/20
# 3485/3485 [==============================] - 41s 12ms/step - loss: 0.1369 - accuracy: 0.9703
# Epoch 8/20
# 3485/3485 [==============================] - 40s 12ms/step - loss: 0.1162 - accuracy: 0.9740
# Epoch 9/20
# 3485/3485 [==============================] - 40s 12ms/step - loss: 0.1247 - accuracy: 0.9734
# Epoch 10/20
# 3485/3485 [==============================] - 41s 12ms/step - loss: 0.1029 - accuracy: 0.9773
# Epoch 11/20
# 3485/3485 [==============================] - 41s 12ms/step - loss: 0.1123 - accuracy: 0.9745
# Epoch 12/20
# 3485/3485 [==============================] - 41s 12ms/step - loss: 0.0827 - accuracy: 0.9813
# Epoch 13/20
# 3485/3485 [==============================] - 42s 12ms/step - loss: 0.0785 - accuracy: 0.9828
# Epoch 14/20
# 3485/3485 [==============================] - 41s 12ms/step - loss: 0.0818 - accuracy: 0.9820
# Epoch 15/20
# 3485/3485 [==============================] - 42s 12ms/step - loss: 0.0815 - accuracy: 0.9825
# Epoch 16/20
# 3485/3485 [==============================] - 41s 12ms/step - loss: 0.0676 - accuracy: 0.9846
# Epoch 17/20
# 3485/3485 [==============================] - 41s 12ms/step - loss: 0.0962 - accuracy: 0.9785
# Epoch 18/20
# 3485/3485 [==============================] - 41s 12ms/step - loss: 0.0842 - accuracy: 0.9794
# Epoch 19/20
# 3485/3485 [==============================] - 41s 12ms/step - loss: 0.1304 - accuracy: 0.9698
# Epoch 20/20
# 3485/3485 [==============================] - 41s 12ms/step - loss: 0.0661 - accuracy: 0.9851
# 872/872 [==============================] - 5s 4ms/step - loss: 0.0298 - accuracy: 0.9913
# There are a total of 11 classes.
# Epoch 1/20
# 3485/3485 [==============================] - 49s 12ms/step - loss: 1.2795 - accuracy: 0.4384
# Epoch 2/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.7156 - accuracy: 0.6905
# Epoch 3/20
# 3485/3485 [==============================] - 42s 12ms/step - loss: 0.4679 - accuracy: 0.8662
# Epoch 4/20
# 3485/3485 [==============================] - 42s 12ms/step - loss: 0.2762 - accuracy: 0.9342
# Epoch 5/20
# 3485/3485 [==============================] - 44s 13ms/step - loss: 0.2161 - accuracy: 0.9489
# Epoch 6/20
# 3485/3485 [==============================] - 45s 13ms/step - loss: 0.1807 - accuracy: 0.9600
# Epoch 7/20
# 3485/3485 [==============================] - 44s 13ms/step - loss: 0.1652 - accuracy: 0.9628
# Epoch 8/20
# 3485/3485 [==============================] - 44s 13ms/step - loss: 0.1303 - accuracy: 0.9705
# Epoch 9/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.1004 - accuracy: 0.9786
# Epoch 10/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.1099 - accuracy: 0.9770
# Epoch 11/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.1019 - accuracy: 0.9773
# Epoch 12/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.0931 - accuracy: 0.9803
# Epoch 13/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.0932 - accuracy: 0.9793
# Epoch 14/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.0692 - accuracy: 0.9851
# Epoch 15/20
# 3485/3485 [==============================] - 46s 13ms/step - loss: 0.0838 - accuracy: 0.9807
# Epoch 16/20
# 3485/3485 [==============================] - 44s 12ms/step - loss: 0.0746 - accuracy: 0.9839
# Epoch 17/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.0810 - accuracy: 0.9830
# Epoch 18/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.0776 - accuracy: 0.9820
# Epoch 19/20
# 3485/3485 [==============================] - 44s 13ms/step - loss: 0.0726 - accuracy: 0.9845
# Epoch 20/20
# 3485/3485 [==============================] - 44s 13ms/step - loss: 0.0514 - accuracy: 0.9889
# 872/872 [==============================] - 5s 4ms/step - loss: 0.0171 - accuracy: 0.9966
# There are a total of 11 classes.
# Epoch 1/20
# 3485/3485 [==============================] - 48s 12ms/step - loss: 1.3494 - accuracy: 0.4086
# Epoch 2/20
# 3485/3485 [==============================] - 42s 12ms/step - loss: 0.8022 - accuracy: 0.6533
# Epoch 3/20
# 3485/3485 [==============================] - 42s 12ms/step - loss: 0.6187 - accuracy: 0.7145
# Epoch 4/20
# 3485/3485 [==============================] - 42s 12ms/step - loss: 0.4638 - accuracy: 0.8168
# Epoch 5/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.3410 - accuracy: 0.8795
# Epoch 6/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.2549 - accuracy: 0.9319
# Epoch 7/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.1969 - accuracy: 0.9567
# Epoch 8/20
# 3485/3485 [==============================] - 42s 12ms/step - loss: 0.1577 - accuracy: 0.9644
# Epoch 9/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.1223 - accuracy: 0.9737
# Epoch 10/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.1324 - accuracy: 0.9711
# Epoch 11/20
# 3485/3485 [==============================] - 42s 12ms/step - loss: 0.1150 - accuracy: 0.9745
# Epoch 12/20
# 3485/3485 [==============================] - 42s 12ms/step - loss: 0.1024 - accuracy: 0.9771
# Epoch 13/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.0969 - accuracy: 0.9791
# Epoch 14/20
# 3485/3485 [==============================] - 42s 12ms/step - loss: 0.0933 - accuracy: 0.9785
# Epoch 15/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.0818 - accuracy: 0.9820
# Epoch 16/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.0915 - accuracy: 0.9799
# Epoch 17/20
# 3485/3485 [==============================] - 42s 12ms/step - loss: 0.0667 - accuracy: 0.9853
# Epoch 18/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.0959 - accuracy: 0.9791
# Epoch 19/20
# 3485/3485 [==============================] - 43s 12ms/step - loss: 0.0795 - accuracy: 0.9831
# Epoch 20/20
# 3485/3485 [==============================] - 46s 13ms/step - loss: 0.0777 - accuracy: 0.9827
# 872/872 [==============================] - 7s 6ms/step - loss: 0.0310 - accuracy: 0.9917
# There are a total of 11 classes.
# Epoch 1/20
# 3485/3485 [==============================] - 55s 14ms/step - loss: 1.3335 - accuracy: 0.4365
# Epoch 2/20
# 3485/3485 [==============================] - 49s 14ms/step - loss: 0.6013 - accuracy: 0.7841
# Epoch 3/20
# 3485/3485 [==============================] - 50s 14ms/step - loss: 0.3686 - accuracy: 0.8971
# Epoch 4/20
# 3485/3485 [==============================] - 51s 14ms/step - loss: 0.2505 - accuracy: 0.9425
# Epoch 5/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.2630 - accuracy: 0.9389
# Epoch 6/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.1976 - accuracy: 0.9535
# Epoch 7/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.1692 - accuracy: 0.9602
# Epoch 8/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.1607 - accuracy: 0.9631
# Epoch 9/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.1253 - accuracy: 0.9710
# Epoch 10/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.1353 - accuracy: 0.9670
# Epoch 11/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.1011 - accuracy: 0.9777
# Epoch 12/20
# 3485/3485 [==============================] - 52s 15ms/step - loss: 0.1266 - accuracy: 0.9686
# Epoch 13/20
# 3485/3485 [==============================] - 52s 15ms/step - loss: 0.1170 - accuracy: 0.9721
# Epoch 14/20
# 3485/3485 [==============================] - 54s 15ms/step - loss: 0.1051 - accuracy: 0.9746
# Epoch 15/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.1095 - accuracy: 0.9749
# Epoch 16/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.0921 - accuracy: 0.9782
# Epoch 17/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.0903 - accuracy: 0.9778
# Epoch 18/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.0826 - accuracy: 0.9821
# Epoch 19/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.0881 - accuracy: 0.9798
# Epoch 20/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.1159 - accuracy: 0.9710
# 872/872 [==============================] - 6s 5ms/step - loss: 0.7925 - accuracy: 0.8400
# There are a total of 11 classes.
# Epoch 1/20
# 3485/3485 [==============================] - 57s 15ms/step - loss: 1.4392 - accuracy: 0.3743
# Epoch 2/20
# 3485/3485 [==============================] - 51s 15ms/step - loss: 0.7152 - accuracy: 0.7372
# Epoch 3/20
# 3485/3485 [==============================] - 52s 15ms/step - loss: 0.3823 - accuracy: 0.8976
# Epoch 4/20
# 3485/3485 [==============================] - 53s 15ms/step - loss: 0.2927 - accuracy: 0.9338
# Epoch 5/20
# 3485/3485 [==============================] - 53s 15ms/step - loss: 0.2406 - accuracy: 0.9443
# Epoch 6/20
# 3485/3485 [==============================] - 54s 15ms/step - loss: 0.2129 - accuracy: 0.9484
# Epoch 7/20
# 3485/3485 [==============================] - 54s 15ms/step - loss: 0.1832 - accuracy: 0.9566
# Epoch 8/20
# 3485/3485 [==============================] - 53s 15ms/step - loss: 0.1634 - accuracy: 0.9628
# Epoch 9/20
# 3485/3485 [==============================] - 53s 15ms/step - loss: 0.1486 - accuracy: 0.9655
# Epoch 10/20
# 3485/3485 [==============================] - 53s 15ms/step - loss: 0.1242 - accuracy: 0.9715
# Epoch 11/20
# 3485/3485 [==============================] - 54s 15ms/step - loss: 0.1173 - accuracy: 0.9714
# Epoch 12/20
# 3485/3485 [==============================] - 53s 15ms/step - loss: 0.1012 - accuracy: 0.9766
# Epoch 13/20
# 3485/3485 [==============================] - 53s 15ms/step - loss: 0.0923 - accuracy: 0.9784
# Epoch 14/20
# 3485/3485 [==============================] - 54s 15ms/step - loss: 0.1279 - accuracy: 0.9697
# Epoch 15/20
# 3485/3485 [==============================] - 54s 15ms/step - loss: 0.0906 - accuracy: 0.9801
# Epoch 16/20
# 3485/3485 [==============================] - 54s 15ms/step - loss: 0.0906 - accuracy: 0.9790
# Epoch 17/20
# 3485/3485 [==============================] - 54s 15ms/step - loss: 0.0798 - accuracy: 0.9817
# Epoch 18/20
# 3485/3485 [==============================] - 54s 15ms/step - loss: 0.0959 - accuracy: 0.9774
# Epoch 19/20
# 3485/3485 [==============================] - 54s 15ms/step - loss: 0.1164 - accuracy: 0.9713
# Epoch 20/20
# 3485/3485 [==============================] - 56s 16ms/step - loss: 0.0857 - accuracy: 0.9794
# 872/872 [==============================] - 6s 5ms/step - loss: 0.0115 - accuracy: 0.9967

# %% [markdown]
# ##### Get Validation Accuracy

# %%
if PERFORM_KFOLD is True:
    print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# Validation Accuracy of 96.33% (with standard deviation of 6.17%)

# %% [markdown]
# #### FIT MODEL FOR TESTING
# - Fit the Model
# - View Accuracy and Loss Graph
# - View Model Summary

# %%
#####################
# # fit the model # #
#####################

if TEST_MODEL is True:
    model = create_model()
    es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                       verbose=1)
    history = model.fit(X_train, y_train, callbacks=es, verbose=1)
# Out:
# There are a total of 11 classes.
# Epoch 1/20
# 4356/4356 [==============================] - 69s 15ms/step - loss: 1.3235 - accuracy: 0.4382
# Epoch 2/20
# 4356/4356 [==============================] - 61s 14ms/step - loss: 0.6703 - accuracy: 0.7598
# Epoch 3/20
# 4356/4356 [==============================] - 61s 14ms/step - loss: 0.4072 - accuracy: 0.8714
# Epoch 4/20
# 4356/4356 [==============================] - 61s 14ms/step - loss: 0.2465 - accuracy: 0.9416
# Epoch 5/20
# 4356/4356 [==============================] - 62s 14ms/step - loss: 0.1713 - accuracy: 0.9617
# Epoch 6/20
# 4356/4356 [==============================] - 62s 14ms/step - loss: 0.1446 - accuracy: 0.9677
# Epoch 7/20
# 4356/4356 [==============================] - 62s 14ms/step - loss: 0.1202 - accuracy: 0.9720
# Epoch 8/20
# 4356/4356 [==============================] - 62s 14ms/step - loss: 0.1195 - accuracy: 0.9721
# Epoch 9/20
# 4356/4356 [==============================] - 62s 14ms/step - loss: 0.1191 - accuracy: 0.9720
# Epoch 10/20
# 4356/4356 [==============================] - 62s 14ms/step - loss: 0.0877 - accuracy: 0.9792
# Epoch 11/20
# 4356/4356 [==============================] - 62s 14ms/step - loss: 0.0855 - accuracy: 0.9805
# Epoch 12/20
# 4356/4356 [==============================] - 62s 14ms/step - loss: 0.0779 - accuracy: 0.9827
# Epoch 13/20
# 4356/4356 [==============================] - 63s 14ms/step - loss: 0.0846 - accuracy: 0.9808
# Epoch 14/20
# 4356/4356 [==============================] - 64s 15ms/step - loss: 0.0650 - accuracy: 0.9851
# Epoch 15/20
# 4356/4356 [==============================] - 63s 14ms/step - loss: 0.0706 - accuracy: 0.9833
# Epoch 16/20
# 4356/4356 [==============================] - 64s 15ms/step - loss: 0.0783 - accuracy: 0.9825
# Epoch 17/20
# 4356/4356 [==============================] - 63s 14ms/step - loss: 0.0664 - accuracy: 0.9857
# Epoch 18/20
# 4356/4356 [==============================] - 63s 14ms/step - loss: 0.0648 - accuracy: 0.9860
# Epoch 19/20
# 4356/4356 [==============================] - 63s 15ms/step - loss: 0.0733 - accuracy: 0.9834
# Epoch 20/20
# 4356/4356 [==============================] - 64s 15ms/step - loss: 0.0498 - accuracy: 0.9886

# %%
if TEST_MODEL is True:
    ##########################
    # # get model accuracy # #
    ##########################
    plt.plot(history.history['accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

    ######################
    # # get model loss # #
    ######################
    plt.plot(history.history['loss'])
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

# %%
if TEST_MODEL is True:
    ##########################
    # # view model summary # #
    ##########################
    model.model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 1, 256)            713728
#
#  dense_25 (Dense)            (None, 1, 256)            65792
#
#  dropout_20 (Dropout)        (None, 1, 256)            0
#
#  batch_normalization_15 (Bat  (None, 1, 256)           1024
#  chNormalization)
#
#  lstm_21 (LSTM)              (None, 1, 128)            197120
#
#  dense_26 (Dense)            (None, 1, 128)            16512
#
#  dropout_21 (Dropout)        (None, 1, 128)            0
#
#  batch_normalization_16 (Bat  (None, 1, 128)           512
#  chNormalization)
#
#  lstm_22 (LSTM)              (None, 1, 64)             49408
#
#  dense_27 (Dense)            (None, 1, 64)             4160
#
#  dropout_22 (Dropout)        (None, 1, 64)             0
#
#  batch_normalization_17 (Bat  (None, 1, 64)            256
#  chNormalization)
#
#  lstm_23 (LSTM)              (None, 1, 32)             12416
#
#  dense_28 (Dense)            (None, 1, 32)             1056
#
#  dropout_23 (Dropout)        (None, 1, 32)             0
#
#  flatten_5 (Flatten)         (None, 32)                0
#
#  dense_29 (Dense)            (None, 11)                363
#
# =================================================================
# Total params: 1,062,347
# Trainable params: 1,061,451
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# #### MODEL TESTING
# - Get Model Accuracy on the Test Dataset
# - Generate Confusion Matrix
# - Generate ROC Curves
# - Save the Model if Appropriate

# %%
if TEST_MODEL is True:
    y_pred = model.predict_proba(X_test)

    # evaluate predictions
    acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    print("Testing accuracy: %.3f%%" % (acc*100))
# Out:
# Testing accuracy: 99.242%

# %% [markdown]
# ##### Confusion Matrix

# %%
if TEST_MODEL is True and CON_MATRIX is True:
    # confusion matrix
    print(str(len(y_pred)) + " is the number of test value in kfold_val / train_test_split")
    cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                         columns = [i for i in np.unique(lb.inverse_transform(y_test))])

    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=True, cmap="BuPu")
# Out:
# 21780 is the number of test value in kfold_val / train_test_split

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
if TEST_MODEL is True and ROC_GRAPH is True: # compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    for i in range(n_classes):
        plt.figure()
        lw = 2
        plt.plot(
            fpr[i],
            tpr[i],
            color="darkorange",
            lw=lw,
            label="ROC curve (area = %0.2f)" % roc_auc[i],
        )
        plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
        plt.xlim([-0.005, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ##### ROC Curve (Multiclass)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    # compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # first aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    # plt.figure()
    # plt.plot(
    #     fpr["micro"],
    #     tpr["micro"],
    #     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    #     color="deeppink",
    #     linestyle=":",
    #     linewidth=4,
    # )

    # plt.plot(
    #     fpr["macro"],
    #     tpr["macro"],
    #     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    #     color="navy",
    #     linestyle=":",
    #     linewidth=4,
    # )

    colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
        )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Multiclass)")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Average)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

    # calculate equal-error-rate
    eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('Average ROC Curve')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #### FIT AND SAVE MODEL
# - Fitting of model
# - Get Accuracy and Loss of Mdoel
# - Saving Model

# %%
############################
# # reshaping of dataset # #
############################
# loading of dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)

df.head()
dataset = df.values

# divide data into features X and target (classes) Y
# convert target Y to labelbinarizer Y for model
X, Y, lb, class_list = prepare_dataset(df)

# reshaping the dataset to include LSTM Timesteps
X = reshape_dataset(X, TIMESTEPS)
n_classes = Y.shape[1]

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# LabelBinarizer is able to decipher:
# ['andy' 'azfar' 'chris' 'cy' 'gerald' 'ken' 'qk' 'sz' 'vale' 'ye' 'ys']
#
#
# X | Features | Dataset Shape: (108900, 440)
# Y | Classes  | Dataset Shape: (108900, 11)
# There are a total of 11 classes.
# Epoch 1/20
# 5445/5445 [==============================] - 78s 13ms/step - loss: 1.0669 - accuracy: 0.5793
# Epoch 2/20
# 5445/5445 [==============================] - 73s 13ms/step - loss: 0.4280 - accuracy: 0.8892
# Epoch 3/20
# 5445/5445 [==============================] - 74s 14ms/step - loss: 0.2451 - accuracy: 0.9422
# Epoch 4/20
# 5445/5445 [==============================] - 73s 13ms/step - loss: 0.1911 - accuracy: 0.9559
# Epoch 5/20
# 5445/5445 [==============================] - 74s 14ms/step - loss: 0.1505 - accuracy: 0.9648
# Epoch 6/20
# 5445/5445 [==============================] - 73s 13ms/step - loss: 0.1380 - accuracy: 0.9693
# Epoch 7/20
# 5445/5445 [==============================] - 74s 13ms/step - loss: 0.1036 - accuracy: 0.9769
# Epoch 8/20
# 5445/5445 [==============================] - 74s 14ms/step - loss: 0.0888 - accuracy: 0.9802
# Epoch 9/20
# 5445/5445 [==============================] - 74s 14ms/step - loss: 0.0874 - accuracy: 0.9809
# Epoch 10/20
# 5445/5445 [==============================] - 74s 14ms/step - loss: 0.0892 - accuracy: 0.9800
# Epoch 11/20
# 5445/5445 [==============================] - 75s 14ms/step - loss: 0.0784 - accuracy: 0.9825
# Epoch 12/20
# 5445/5445 [==============================] - 74s 14ms/step - loss: 0.0937 - accuracy: 0.9766
# Epoch 13/20
# 5445/5445 [==============================] - 74s 14ms/step - loss: 0.0737 - accuracy: 0.9834
# Epoch 14/20
# 5445/5445 [==============================] - 74s 14ms/step - loss: 0.0757 - accuracy: 0.9836
# Epoch 15/20
# 5445/5445 [==============================] - 75s 14ms/step - loss: 0.0874 - accuracy: 0.9792
# Epoch 16/20
# 5445/5445 [==============================] - 75s 14ms/step - loss: 0.0588 - accuracy: 0.9870
# Epoch 17/20
# 5445/5445 [==============================] - 74s 14ms/step - loss: 0.0614 - accuracy: 0.9867
# Epoch 18/20
# 5445/5445 [==============================] - 75s 14ms/step - loss: 0.0556 - accuracy: 0.9882
# Epoch 19/20
# 5445/5445 [==============================] - 75s 14ms/step - loss: 0.0573 - accuracy: 0.9877
# Epoch 20/20
# 5445/5445 [==============================] - 75s 14ms/step - loss: 0.0534 - accuracy: 0.9878

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# #### SAVE MODEL

# %%
##################
# # save model # #
##################
model.model.save(MODEL_PATH)

# %% [markdown]
# # LIVE TESTING
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()
# Out:
#   Subject  Password    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    andy  Co5mical  0.073992  0.003000   0.076992   0.094482   0.168474
# 1    andy  Co5mical  0.073992  0.003000   0.076992   0.094482   0.168474
# 2    andy  Co5mical  0.073992  0.003000   0.076992   0.094482   0.168474
# 3    andy  Co5mical  0.073992  0.003000   0.076992   0.094482   0.168474
# 4    andy  Co5mical  0.100974  0.012187   0.113161   0.101644   0.202618
#
#      T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T7-RF|VAR.1  T7-NG|VAR.1  T7-I|SD.1  \
# 0  0.091483  0.045362   0.136844  ...     0.004042     0.005144   0.048238
# 1  0.091483  0.045362   0.136844  ...     0.009055     0.005173   0.087968
# 2  0.091483  0.045362   0.136844  ...     0.007376     0.004978   0.081239
# 3  0.091483  0.045362   0.136844  ...     0.002313     0.003616   0.024290
# 4  0.089456  0.033577   0.123034  ...     0.002609     0.001499   0.042155
#
#    T7-PF|SD.1  T7-RF|SD.1  T7-NG|SD.1  T8-I|0+7.1  T8-PF|0+7.1  T8-RF|0+7.1  \
# 0    0.056383    0.063579    0.071723    0.518507     0.619481     0.597307
# 1    0.064734    0.095156    0.071922    0.504553     0.594277     0.596016
# 2    0.065912    0.085884    0.070557    0.477528     0.545525     0.563112
# 3    0.036328    0.048092    0.060130    0.470455     0.572712     0.537894
# 4    0.029788    0.051080    0.038712    0.499024     0.573016     0.566388
#
#    T8-NG|0+7.1
# 0     0.698281
# 1     0.685741
# 2     0.631109
# 3     0.640151
# 4     0.640380
#
# [5 rows x 442 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
actual_np = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

########################
# # predict all rows # #
########################
pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[46:54,FEATURES_COL_NUM:]
# print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

print(class_list)
Y = np.asarray(class_list)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)
# Out:
# ['andy', 'azfar', 'chris', 'cy', 'gerald', 'ken', 'qk', 'sz', 'vale', 'ye', 'ys']

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

# pred_proba = np.sum(pred_proba, axis=0)
# pred_proba = np.reshape(pred_proba, (1, 9))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

match_list = []

for _ in range(actual_np.size):
    if pred[_] == actual_np[_]:
        match_list.append("match")
    else:
        match_list.append("nope")

match_count = match_list.count("match")
total_count = len(match_list)

match_header = str(match_count) + "/" + str(total_count) + " (" + str(match_count/total_count*100)+ "%)"
match_np = np.array(match_list)

exported_output = np.column_stack((actual_np, pred))
exported_output = np.column_stack((exported_output, acc))
exported_output = np.column_stack((exported_output, match_np))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(data=exported_output, index=None, columns=['Actual', 'Prediction', 'Accuracy', match_header])
# print(df)
df.to_csv(RESULT_PATH)

print("Accuracy of the Model is: " + str(match_header))
# Out:
# Accuracy of the Model is: 211/220 (95.9090909090909%)

# %%
# print elapsed time
elapsed_time = time.time() - start_time
print('Execution time:', time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# Execution time: 02:04:58
