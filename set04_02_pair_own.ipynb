# %%
# calculate elapsed time
import time
start_time = time.time()

# %% [markdown]
# #### IMPORT

# %%
import os, platform
import py7zr

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %% [markdown]
# #### PARAMETERS
# - Set the condition
# > * N_FEATURES: Number of Features
# > * CHECK_BLANKS: Check for blank data. If any blank data is found, the whole row of data will be deleted.
# > * CHECK_CLASS_IMBALANCE: Check for dataset class imbalance. The more balance the dataset, the less biases the model will be.

# %%
##############################
# # deep learning features # #
##############################
SEED = 1005 # random seed for reproducibility

# should make this dynamic
N_FEATURES = 440
TIMESTEPS = 1
EPOCH=200
BATCH_SIZE=100

SPLIT_RATIO=0.2

###############
# # preview # #
###############
f = False
t = True

# checking dataset
CHECK_BLANKS = True
CHECK_CLASS_IMBALANCE = True

# evaluate suitable kfold number and kfold model
MIN_KFOLD = 2
MAX_KFOLD = 11
N_KFOLD = 5
EVAL_KFOLD_NUM = False
EVAL_KFOLD_MODEL = False
PERFORM_KFOLD = True

# model testing
TEST_MODEL = True
CON_MATRIX = True
ROC_GRAPH = True

###############
# # dataset # #
###############
CLASSES_COL_NAME = "Subject"
CLASSES_COL_NUM = 0
FEATURES_COL_NUM = 2

DATASET_DIR_NAME = "dataset\set04\\02_pair_own"
SAMPLE_DATASET_NAME = "pair_train_own"
ACTUAL_DATASET_NAME = "pair_test_own"

MODEL_DIR_NAME = "dataset\set04\\02_pair_own"
MODEL_NAME = "model_" + "set04_02_pair_own"

RESULT_DIR_NAME = "dataset\set04\\02_pair_own"
RESULT_NAME = "result_" + "set04_02_pair_own"

DATASET_DIR_PATH = os.path.join(os.getcwd(), DATASET_DIR_NAME)
SAMPLE_DATASET_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".csv")
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME + ".csv")

MODEL_DIR_PATH = os.path.join(os.getcwd(), MODEL_DIR_NAME)
MODEL_PATH = os.path.join(MODEL_DIR_PATH, MODEL_NAME + ".h5")

RESULT_DIR_PATH = os.path.join(os.getcwd(), RESULT_DIR_NAME)
RESULT_PATH = os.path.join(RESULT_DIR_PATH, RESULT_NAME + ".csv")

#################
# # sns theme # #
#################
# sns.set_theme(style="darkgrid") # (dark background with white gridlines)
sns.set_theme(style="whitegrid") # (white background with grey gridlines)
# sns.set_theme(style="dark") # (dark background with no gridlines)
# sns.set_theme(style="white") # (white background with no gridlines)
# sns.set_theme(style="ticks") # (white background with axis ticks and no gridlines)

# %%
if os.path.isdir(DATASET_DIR_PATH) is True:
    print(f"Dataset directory exists at: {DATASET_DIR_PATH}")
else:
    try:
        os.mkdir(DATASET_DIR_PATH, 666)
        print(f"Dataset directory have been created at: {DATASET_DIR_PATH}")
    except:
        print("Error: Dataset Directory not created")
        
if os.path.isdir(MODEL_DIR_PATH) is True:
    print(f"Model directory exists at: {MODEL_DIR_PATH}")
else:
    try:
        os.mkdir(MODEL_DIR_PATH, 666)
        print(f"Model directory have been created at: {MODEL_DIR_PATH}")
    except:
        print("Error: Model Directory not created")
    
if os.path.exists(SAMPLE_DATASET_PATH) is True:
    print(f"Training dataset exists at: {SAMPLE_DATASET_PATH}")
else:
    try:
        SAMPLE_7Z_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".7z")
        with py7zr.SevenZipFile(SAMPLE_7Z_PATH, mode='r') as z:
            z.extractall(path=DATASET_DIR_PATH)
        print(f"Decompress 7z file to: {SAMPLE_7Z_PATH}")
    except:
        print("Error: Failed to decompress 7z file.")
# Out:
# Dataset directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set04\05_pair_own
# Model directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set04\05_pair_own
# Training dataset exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set04\05_pair_own\pair_train_own.csv

# %% [markdown]
# #### CREATE MODEL
# - Create base model
# - Wrap it with KerasClassifier

# %%
#create base model
def create_base_model():
    model = Sequential()
    model.add(LSTM(units=256, return_sequences=True,
             input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dense(256, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=32, return_sequences=True))
    model.add(Dense(32, activation='sigmoid'))
    model.add(Dropout(0.2))

    # softmax for multi-class classification
    model.add(Flatten())
    print("There are a total of " + str(n_classes) + " classes.")
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=EPOCH, 
                            batch_size=BATCH_SIZE)
    return model

# %%
# divide data into features X and target (classes) Y
def prepare_dataset(df):
    X = df.values[:,FEATURES_COL_NUM:].astype(float)
    Y = df.values[:,CLASSES_COL_NUM].astype(str)

    # convert target Y to labelbinarizer Y for model
    # fit_transform is not used to reuse lb
    Y = Y.reshape(-1, 1)
    lb = LabelBinarizer().fit(Y)
    Y = lb.transform(Y)

    #################################
    # # get all the encoded class # #
    #################################
    print("LabelBinarizer is able to decipher: ")
    print(lb.classes_)
    print("\n")

    ###########################
    # # print X and Y shape # #
    ###########################
    print(f"X | Features | Dataset Shape: {X.shape}")
    print(f"Y | Classes  | Dataset Shape: {Y.shape}")

    return X, Y, lb, lb.classes_.tolist()

# %%
def split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED):

    ##############################################################
    # # split dataset into train and test set of 0.8/0.2 ratio # #
    ##############################################################
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=SPLIT_RATIO, random_state=SEED)

    ############################
    # # reshaping of dataset # #
    ############################

    # reshaping the dataset to include LSTM Timesteps
    print(X_train.dtype)
    X_train = np.asarray(X_train, dtype=np.float32)
    print(X_train.dtype)
    X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
    print(X_test.dtype)
    X_test = np.asarray(X_test, dtype=np.float32)
    print(X_test.dtype)
    X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

    print(f"X train shape: {X_train.shape}")
    print(f"Y train shape: {y_train.shape}")
    print(f"X test shape: {X_test.shape}")
    print(f"Y test shape: {y_test.shape}")
    
    return X_train, X_test, y_train, y_test

def reshape_dataset(X, TIMESTEPS):
    # reshaping the dataset to include LSTM Timesteps
    X = np.asarray(X, dtype=np.float32)
    X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))
    return X

# %% [markdown]
# #### LOAD DATASET

# %%
# load dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)
df.head()
# Out:
#   Subject  Password    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    andy  Co5mical  0.124989       0.0   0.124989    0.12364   0.248628
# 1    andy  Co5mical  0.124989       0.0   0.124989    0.12364   0.248628
# 2    andy  Co5mical  0.124989       0.0   0.124989    0.12364   0.248628
# 3    andy  Co5mical  0.124989       0.0   0.124989    0.12364   0.248628
# 4    andy  Co5mical  0.124989       0.0   0.124989    0.12364   0.248628
#
#     T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T7-RF|VAR.1  T7-NG|VAR.1  T7-I|SD.1  \
# 0  0.12364  0.011015   0.134655  ...     0.006047     0.003990   0.047034
# 1  0.12364  0.011015   0.134655  ...     0.003187     0.002233   0.024718
# 2  0.12364  0.011015   0.134655  ...     0.004878     0.005244   0.046083
# 3  0.12364  0.011015   0.134655  ...     0.016760     0.017344   0.101889
# 4  0.12364  0.011015   0.134655  ...     0.002298     0.003914   0.022615
#
#    T7-PF|SD.1  T7-RF|SD.1  T7-NG|SD.1  T8-I|0+7.1  T8-PF|0+7.1  T8-RF|0+7.1  \
# 0    0.032436    0.077762    0.063164    0.616391     0.718327     0.697449
# 1    0.015517    0.056457    0.047256    0.550968     0.641309     0.628636
# 2    0.048659    0.069841    0.072416    0.562252     0.664963     0.652923
# 3    0.104127    0.129459    0.131697    0.638064     0.765986     0.722751
# 4    0.037240    0.047934    0.062559    0.508190     0.630242     0.585637
#
#    T8-NG|0+7.1
# 0     0.799384
# 1     0.718976
# 2     0.755634
# 3     0.850673
# 4     0.707689
#
# [5 rows x 442 columns]

# %% [markdown]
# #### CHECK DATASET

# %%
########################
# # check for blanks # #
########################
if CHECK_BLANKS is True:
    # checking for blanks
    print("Checking for blanks...")
    if df.isnull().values.any() is True:
        df = df.dropna(axis=0, how="any")
        print("Blank rows has been dropped.")
    else:
        print("No blank value has been found.")
        
#################################
# # check for class imbalance # #
#################################
if CHECK_CLASS_IMBALANCE is True:
    print("Checking for class imbalance...")
    sns.countplot(x=CLASSES_COL_NAME, data=df).set_title("Class Imbalance")
#     df.loc[(df!=0).any(axis=1)]
    plt.show()

sns.catplot(x="Subject", y="T2-D|0", hue="T2-D|0", data=df, legend=False)
sns.catplot(x="Subject", y="T2-I|0+1", hue="T2-I|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-PF|0+1", hue="T2-PF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-RF|0+1", hue="T2-RF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-D|1", hue="T2-D|1", data=df, legend=False)
# Out:
# Checking for blanks...
# No blank value has been found.
# Checking for class imbalance...

# %% [markdown]
# #### PREPARE DATASET
# - Split data based on X / Features and Y / Classes
# - Binarize Y into binary labels

# %%
X, Y, lb, class_list = prepare_dataset(df)
n_classes = len(class_list)
print(f"Number of Classes: {n_classes}")
# Out:
# LabelBinarizer is able to decipher:
# ['andy' 'azfar' 'bryce' 'chris' 'cy' 'gerald' 'ken' 'qk' 'sz' 'vale' 'ye'
#  'ys']
#
#
# X | Features | Dataset Shape: (118800, 440)
# Y | Classes  | Dataset Shape: (118800, 12)
# Number of Classes: 12

# %% [markdown]
# #### SPLIT DATASET
# - Split dataset into train set and test set 0.8 / 0.2

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED)
# Out:
# float64
# float32
# float64
# float32
# X train shape: (95040, 1, 440)
# Y train shape: (95040, 12)
# X test shape: (23760, 1, 440)
# Y test shape: (23760, 12)

# %% [markdown]
# #### PERFORM VALIDATION (w KFold Validation)
# - Evaluate best KFold Validation
# - Generate loss and accuracy graph
# - Perform KFold validation

# %% [markdown]
# ##### Evaluate suitable folds for kfold validation

# %%
###############################################
# # evaluate suitable kfold value for model # #
###############################################
def evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD):
    
    # evaluate the model    
    folds = range(MIN_KFOLD, MAX_KFOLD)
    means, mins, maxs = list(), list(), list()
    
    # evaluate each k value
    for k in folds:
        # define the test condition
        kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
        
        # evaluate k value
        model = create_model()
        scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
        k_mean = np.mean(scores)
        k_min = scores.min()
        k_max = scores.max()
        
        # report performance
        print(f"No. of Folds: {k} | Accuracy: {k_mean*100:.3f} | Min: {k_min*100:.3f} | Max: {k_max*100:.3f}")
        
        # store mean accuracy and min and max relative to the mean
        means.append(k_mean)
        mins.append(k_mean - k_min)
        maxs.append(k_max - k_mean)
        
    # line plot of k mean values with min/max error bars
    clear_output(wait=True)
    pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
    # show the plot
    pyplot.show()
    
if EVAL_KFOLD_NUM is True:
    evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD)
else:
    print("EVAL_KFOLD_NUM is not True")
# Out:
# EVAL_KFOLD_NUM is not True

# %% [markdown]
# ##### Generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=50, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print(f"Accuracy | Mean: {np.mean(scores)*100:.3f} | Std: {np.std(scores)*100:.3f} | Length/no.: {len(scores)}")
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    clear_output(wait=True)
    plt.show()
    
if EVAL_KFOLD_MODEL is True:
    evaluate_kfold_model(X_train, y_train, SEED)
else:
    print("EVAL_KFOLD_MODEL is not true")
# Out:
# EVAL_KFOLD_MODEL is not true

# %% [markdown]
# ##### Perform Actual KFold validation

# %%
if PERFORM_KFOLD is True:
    # create model
    model = create_model()
    kfold = KFold(n_splits=N_KFOLD, shuffle=True, random_state=SEED)
    valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# There are a total of 12 classes.
# Epoch 1/200
# 761/761 [==============================] - 18s 16ms/step - loss: 1.7848 - accuracy: 0.2482
# Epoch 2/200
# 761/761 [==============================] - 13s 17ms/step - loss: 1.1014 - accuracy: 0.5078
# Epoch 3/200
# 761/761 [==============================] - 13s 16ms/step - loss: 0.6797 - accuracy: 0.6978
# Epoch 4/200
# 761/761 [==============================] - 13s 17ms/step - loss: 0.5247 - accuracy: 0.7572
# Epoch 5/200
# 761/761 [==============================] - 13s 16ms/step - loss: 0.2831 - accuracy: 0.9185
# Epoch 6/200
# 761/761 [==============================] - 13s 17ms/step - loss: 0.1895 - accuracy: 0.9589
# Epoch 7/200
# 761/761 [==============================] - 13s 16ms/step - loss: 0.1216 - accuracy: 0.9755
# Epoch 8/200
# 761/761 [==============================] - 13s 17ms/step - loss: 0.0940 - accuracy: 0.9812
# Epoch 9/200
# 761/761 [==============================] - 15s 19ms/step - loss: 0.0808 - accuracy: 0.9835
# Epoch 10/200
# 761/761 [==============================] - 13s 16ms/step - loss: 0.0576 - accuracy: 0.9886
# Epoch 11/200
# 761/761 [==============================] - 12s 16ms/step - loss: 0.0524 - accuracy: 0.9893
# Epoch 12/200
# 761/761 [==============================] - 13s 18ms/step - loss: 0.0606 - accuracy: 0.9879
# Epoch 13/200
# 761/761 [==============================] - 13s 18ms/step - loss: 0.0612 - accuracy: 0.9865
# Epoch 14/200
# 761/761 [==============================] - 13s 17ms/step - loss: 0.0551 - accuracy: 0.9890
# Epoch 15/200
# 761/761 [==============================] - 14s 18ms/step - loss: 0.0624 - accuracy: 0.9872
# Epoch 16/200
# 761/761 [==============================] - 15s 20ms/step - loss: 0.0406 - accuracy: 0.9914
# Epoch 17/200
# 761/761 [==============================] - 15s 20ms/step - loss: 0.0454 - accuracy: 0.9909
# Epoch 18/200
# 761/761 [==============================] - 13s 18ms/step - loss: 0.0253 - accuracy: 0.9949
# Epoch 19/200
# 761/761 [==============================] - 13s 17ms/step - loss: 0.0324 - accuracy: 0.9931
# Epoch 20/200
# 761/761 [==============================] - 14s 18ms/step - loss: 0.0329 - accuracy: 0.9931
# Epoch 21/200
# 761/761 [==============================] - 15s 20ms/step - loss: 0.0444 - accuracy: 0.9905
# Epoch 22/200
# 761/761 [==============================] - 14s 18ms/step - loss: 0.0358 - accuracy: 0.9924
# Epoch 23/200
# 761/761 [==============================] - 14s 19ms/step - loss: 0.0301 - accuracy: 0.9934
# Epoch 24/200
# 761/761 [==============================] - 13s 17ms/step - loss: 0.0185 - accuracy: 0.9963
# Epoch 25/200
# 761/761 [==============================] - 13s 18ms/step - loss: 0.0319 - accuracy: 0.9927
# Epoch 26/200
# 761/761 [==============================] - 14s 19ms/step - loss: 0.0371 - accuracy: 0.9924
# Epoch 27/200
# 761/761 [==============================] - 14s 19ms/step - loss: 0.0223 - accuracy: 0.9950
# Epoch 28/200
# 761/761 [==============================] - 14s 18ms/step - loss: 0.0269 - accuracy: 0.9941
# Epoch 29/200
# 761/761 [==============================] - 14s 18ms/step - loss: 0.0341 - accuracy: 0.9923
# Epoch 30/200
# 761/761 [==============================] - 14s 18ms/step - loss: 0.0165 - accuracy: 0.9967
# Epoch 31/200
# 761/761 [==============================] - 15s 20ms/step - loss: 0.0249 - accuracy: 0.9944
# Epoch 32/200
# 761/761 [==============================] - 14s 19ms/step - loss: 0.0386 - accuracy: 0.9918
# Epoch 33/200
# 761/761 [==============================] - 13s 18ms/step - loss: 0.
200
# 761/761 [==============================] - 34s 44ms/step - loss: 0.0105 - accuracy: 0.9976
# Epoch 164/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0051 - accuracy: 0.9988
# Epoch 165/200
# 761/761 [==============================] - 34s 44ms/step - loss: 0.0045 - accuracy: 0.9991
# Epoch 166/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0090 - accuracy: 0.9980
# Epoch 167/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0253 - accuracy: 0.9954
# Epoch 168/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0083 - accuracy: 0.9982
# Epoch 169/200
# 761/761 [==============================] - 35s 45ms/step - loss: 0.0054 - accuracy: 0.9986
# Epoch 170/200
# 761/761 [==============================] - 36s 47ms/step - loss: 0.0056 - accuracy: 0.9986
# Epoch 171/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0076 - accuracy: 0.9983
# Epoch 172/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0077 - accuracy: 0.9982
# Epoch 173/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0074 - accuracy: 0.9985
# Epoch 174/200
# 761/761 [==============================] - 35s 45ms/step - loss: 0.0061 - accuracy: 0.9987
# Epoch 175/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0063 - accuracy: 0.9986
# Epoch 176/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0078 - accuracy: 0.9981
# Epoch 177/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0029 - accuracy: 0.9994
# Epoch 178/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0196 - accuracy: 0.9958
# Epoch 179/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0084 - accuracy: 0.9982
# Epoch 180/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0035 - accuracy: 0.9991
# Epoch 181/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0080 - accuracy: 0.9983
# Epoch 182/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0041 - accuracy: 0.9990
# Epoch 183/200
# 761/761 [==============================] - 35s 45ms/step - loss: 0.0131 - accuracy: 0.9974
# Epoch 184/200
# 761/761 [==============================] - 35s 45ms/step - loss: 0.0094 - accuracy: 0.9979
# Epoch 185/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0028 - accuracy: 0.9993
# Epoch 186/200
# 761/761 [==============================] - 35s 45ms/step - loss: 0.0088 - accuracy: 0.9979
# Epoch 187/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0037 - accuracy: 0.9993
# Epoch 188/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0134 - accuracy: 0.9975
# Epoch 189/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0054 - accuracy: 0.9987
# Epoch 190/200
# 761/761 [==============================] - 36s 47ms/step - loss: 0.0086 - accuracy: 0.9982
# Epoch 191/200
# 761/761 [==============================] - 34s 45ms/step - loss: 0.0105 - accuracy: 0.9978
# Epoch 192/200
# 761/761 [==============================] - 35s 45ms/step - loss: 0.0098 - accuracy: 0.9979
# Epoch 193/200
# 761/761 [==============================] - 35s 45ms/step - loss: 0.0039 - accuracy: 0.9993
# Epoch 194/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0090 - accuracy: 0.9982
# Epoch 195/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0039 - accuracy: 0.9993
# Epoch 196/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0112 - accuracy: 0.9979
# Epoch 197/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0077 - accuracy: 0.9983
# Epoch 198/200
# 761/761 [==============================] - 35s 47ms/step - loss: 0.0038 - accuracy: 0.9991
# Epoch 199/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0225 - accuracy: 0.9960
# Epoch 200/200
# 761/761 [==============================] - 35s 46ms/step - loss: 0.0063 - accuracy: 0.9988
# 191/191 [==============================] - 5s 17ms/step - loss: 1.0157e-04 - accuracy: 0.9999

# %% [markdown]
# ##### Get Validation Accuracy

# %%
if PERFORM_KFOLD is True:
    print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# Validation Accuracy of 99.46% (with standard deviation of 0.99%)

# %% [markdown]
# #### FIT MODEL FOR TESTING
# - Fit the Model
# - View Accuracy and Loss Graph
# - View Model Summary

# %%
#####################
# # fit the model # #
#####################

if TEST_MODEL is True:
    model = create_model()
    es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                       verbose=1)
    history = model.fit(X_train, y_train, callbacks=es, verbose=1)
# Out:
# There are a total of 12 classes.
# Epoch 1/200
# 951/951 [==============================] - 52s 48ms/step - loss: 1.7002 - accuracy: 0.2934
# Epoch 2/200
# 951/951 [==============================] - 46s 48ms/step - loss: 1.1703 - accuracy: 0.4756
# Epoch 3/200
# 951/951 [==============================] - 46s 48ms/step - loss: 0.7891 - accuracy: 0.6583
# Epoch 4/200
# 951/951 [==============================] - 46s 48ms/step - loss: 0.5311 - accuracy: 0.7465
# Epoch 5/200
# 951/951 [==============================] - 45s 47ms/step - loss: 0.3850 - accuracy: 0.8138
# Epoch 6/200
# 951/951 [==============================] - 45s 47ms/step - loss: 0.3159 - accuracy: 0.8629
# Epoch 7/200
# 951/951 [==============================] - 45s 47ms/step - loss: 0.1836 - accuracy: 0.9522
# Epoch 8/200
# 951/951 [==============================] - 46s 48ms/step - loss: 0
200
# 951/951 [==============================] - 50s 53ms/step - loss: 0.0193 - accuracy: 0.9959
# Epoch 125/200
# 951/951 [==============================] - 50s 52ms/step - loss: 0.0141 - accuracy: 0.9967
# Epoch 126/200
# 951/951 [==============================] - 50s 53ms/step - loss: 0.0090 - accuracy: 0.9980
# Epoch 127/200
# 951/951 [==============================] - 50s 52ms/step - loss: 0.0108 - accuracy: 0.9975
# Epoch 128/200
# 951/951 [==============================] - 51s 54ms/step - loss: 0.0085 - accuracy: 0.9982
# Epoch 129/200
# 951/951 [==============================] - 54s 57ms/step - loss: 0.0116 - accuracy: 0.9975
# Epoch 130/200
# 951/951 [==============================] - 53s 56ms/step - loss: 0.0129 - accuracy: 0.9970
# Epoch 131/200
# 951/951 [==============================] - 52s 54ms/step - loss: 0.0081 - accuracy: 0.9983
# Epoch 132/200
# 951/951 [==============================] - 51s 53ms/step - loss: 0.0072 - accuracy: 0.9984
# Epoch 133/200
# 951/951 [==============================] - 51s 53ms/step - loss: 0.0227 - accuracy: 0.9949
# Epoch 134/200
# 951/951 [==============================] - 51s 54ms/step - loss: 0.0066 - accuracy: 0.9985
# Epoch 135/200
# 951/951 [==============================] - 51s 53ms/step - loss: 0.0042 - accuracy: 0.9990
# Epoch 136/200
# 951/951 [==============================] - 52s 55ms/step - loss: 0.0109 - accuracy: 0.9977
# Epoch 137/200
# 951/951 [==============================] - 51s 53ms/step - loss: 0.0143 - accuracy: 0.9969
# Epoch 138/200
# 951/951 [==============================] - 51s 54ms/step - loss: 0.0127 - accuracy: 0.9970
# Epoch 139/200
# 951/951 [==============================] - 50s 53ms/step - loss: 0.0061 - accuracy: 0.9988
# Epoch 140/200
# 951/951 [==============================] - 53s 55ms/step - loss: 0.0085 - accuracy: 0.9979
# Epoch 141/200
# 951/951 [==============================] - 51s 54ms/step - loss: 0.0080 - accuracy: 0.9981
# Epoch 142/200
# 951/951 [==============================] - 51s 54ms/step - loss: 0.0107 - accuracy: 0.9971
# Epoch 143/200
# 951/951 [==============================] - 51s 53ms/step - loss: 0.0154 - accuracy: 0.9969
# Epoch 144/200
# 951/951 [==============================] - 51s 54ms/step - loss: 0.0087 - accuracy: 0.9980
# Epoch 145/200
# 951/951 [==============================] - 51s 54ms/step - loss: 0.0062 - accuracy: 0.9986
# Epoch 146/200
# 951/951 [==============================] - 52s 55ms/step - loss: 0.0083 - accuracy: 0.9981
# Epoch 147/200
# 951/951 [==============================] - 51s 54ms/step - loss: 0.0099 - accuracy: 0.9980
# Epoch 148/200
# 951/951 [==============================] - 51s 54ms/step - loss: 0.0050 - accuracy: 0.9989
# Epoch 149/200
# 951/951 [==============================] - 50s 53ms/step - loss: 0.0066 - accuracy: 0.9987
# Epoch 150/200
# 951/951 [==============================] - 50s 53ms/step - loss: 0.0117 - accuracy: 0.9976
# Epoch 151/200
# 951/951 [==============================] - 53s 56ms/step - loss: 0.0059 - accuracy: 0.9986
# Epoch 152/200
# 951/951 [==============================] - 52s 55ms/step - loss: 0.0162 - accuracy: 0.9965
# Epoch 153/200
# 951/951 [==============================] - 52s 55ms/step - loss: 0.0107 - accuracy: 0.9976
# Epoch 154/200
# 951/951 [==============================] - 52s 54ms/step - loss: 0.0037 - accuracy: 0.9992
# Epoch 155/200
# 951/951 [==============================] - 52s 54ms/step - loss: 0.0095 - accuracy: 0.9979
# Epoch 156/200
# 951/951 [==============================] - 51s 54ms/step - loss: 0.0096 - accuracy: 0.9977
# Epoch 156: early stopping

# %%
if TEST_MODEL is True:
    ##########################
    # # get model accuracy # #
    ##########################
    plt.plot(history.history['accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

    ######################
    # # get model loss # #
    ######################
    plt.plot(history.history['loss'])
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

# %%
if TEST_MODEL is True:
    ##########################
    # # view model summary # #
    ##########################
    model.model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 1, 256)            713728
#
#  dense_25 (Dense)            (None, 1, 256)            65792
#
#  dropout_20 (Dropout)        (None, 1, 256)            0
#
#  batch_normalization_15 (Bat  (None, 1, 256)           1024
#  chNormalization)
#
#  lstm_21 (LSTM)              (None, 1, 128)            197120
#
#  dense_26 (Dense)            (None, 1, 128)            16512
#
#  dropout_21 (Dropout)        (None, 1, 128)            0
#
#  batch_normalization_16 (Bat  (None, 1, 128)           512
#  chNormalization)
#
#  lstm_22 (LSTM)              (None, 1, 64)             49408
#
#  dense_27 (Dense)            (None, 1, 64)             4160
#
#  dropout_22 (Dropout)        (None, 1, 64)             0
#
#  batch_normalization_17 (Bat  (None, 1, 64)            256
#  chNormalization)
#
#  lstm_23 (LSTM)              (None, 1, 32)             12416
#
#  dense_28 (Dense)            (None, 1, 32)             1056
#
#  dropout_23 (Dropout)        (None, 1, 32)             0
#
#  flatten_5 (Flatten)         (None, 32)                0
#
#  dense_29 (Dense)            (None, 12)                396
#
# =================================================================
# Total params: 1,062,380
# Trainable params: 1,061,484
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# #### MODEL TESTING
# - Get Model Accuracy on the Test Dataset
# - Generate Confusion Matrix
# - Generate ROC Curves
# - Save the Model if Appropriate

# %%
if TEST_MODEL is True:
    y_pred = model.predict_proba(X_test)

    # evaluate predictions
    acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    print("Testing accuracy: %.3f%%" % (acc*100))
# Out:
# Testing accuracy: 93.990%

# %% [markdown]
# ##### Confusion Matrix

# %%
if TEST_MODEL is True and CON_MATRIX is True:
    # confusion matrix
    print(str(len(y_pred)) + " is the number of test value in kfold_val / train_test_split")
    cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                         columns = [i for i in np.unique(lb.inverse_transform(y_test))])

    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=True, cmap="BuPu")
# Out:
# 23760 is the number of test value in kfold_val / train_test_split

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
if TEST_MODEL is True and ROC_GRAPH is True: # compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    for i in range(n_classes):
        plt.figure()
        lw = 2
        plt.plot(
            fpr[i],
            tpr[i],
            color="darkorange",
            lw=lw,
            label="ROC curve (area = %0.2f)" % roc_auc[i],
        )
        plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
        plt.xlim([-0.005, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ##### ROC Curve (Multiclass)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    # compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # first aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    # plt.figure()
    # plt.plot(
    #     fpr["micro"],
    #     tpr["micro"],
    #     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    #     color="deeppink",
    #     linestyle=":",
    #     linewidth=4,
    # )

    # plt.plot(
    #     fpr["macro"],
    #     tpr["macro"],
    #     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    #     color="navy",
    #     linestyle=":",
    #     linewidth=4,
    # )

    colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
        )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Multiclass)")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Average)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

    # calculate equal-error-rate
    eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('Average ROC Curve')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #### FIT AND SAVE MODEL
# - Fitting of model
# - Get Accuracy and Loss of Mdoel
# - Saving Model

# %%
############################
# # reshaping of dataset # #
############################
# loading of dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)

df.head()
dataset = df.values

# divide data into features X and target (classes) Y
# convert target Y to labelbinarizer Y for model
X, Y, lb, class_list = prepare_dataset(df)

# reshaping the dataset to include LSTM Timesteps
X = reshape_dataset(X, TIMESTEPS)
n_classes = Y.shape[1]

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# LabelBinarizer is able to decipher:
# ['andy' 'azfar' 'bryce' 'chris' 'cy' 'gerald' 'ken' 'qk' 'sz' 'vale' 'ye'
#  'ys']
#
#
# X | Features | Dataset Shape: (118800, 440)
# Y | Classes  | Dataset Shape: (118800, 12)
# There are a total of 12 classes.
# Epoch 1/200
# 1188/1188 [==============================] - 64s 48ms/step - loss: 1.6879 - accuracy: 0.2871
# Epoch 2/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 1.0704 - accuracy: 0.4916
# Epoch 3/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.5872 - accuracy: 0.7380
# Epoch 4/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.3424 - accuracy: 0.8466
# Epoch 5/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.1749 - accuracy: 0.9561
# Epoch 6/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.1003 - accuracy: 0.9762
# Epoch 7/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0758 - accuracy: 0.9822
# Epoch 8/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0692 - accuracy: 0.9837
# Epoch 9/200
# 1188/1188 [==============================] - 53s 44ms/step - loss: 0.0602 - accuracy: 0.9867
# Epoch 10/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.0453 - accuracy: 0.9896
# Epoch 11/200
# 1188/1188 [==============================] - 53s 44ms/step - loss: 0.0589 - accuracy: 0.9865
# Epoch 12/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0446 - accuracy: 0.9899
# Epoch 13/200
# 1188/1188 [==============================] - 53s 44ms/step - loss: 0.0381 - accuracy: 0.9916
# Epoch 14/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.0342 - accuracy: 0.9923
# Epoch 15/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.0349 - accuracy: 0.9923
# Epoch 16/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.0273 - accuracy: 0.9942
# Epoch 17/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.0419 - accuracy: 0.9905
# Epoch 18/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0360 - accuracy: 0.9923
# Epoch 19/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0347 - accuracy: 0.9923
# Epoch 20/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.0253 - accuracy: 0.9943
# Epoch 21/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.0218 - accuracy: 0.9953
# Epoch 22/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0230 - accuracy: 0.9950
# Epoch 23/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0286 - accuracy: 0.9939
# Epoch 24/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.0240 - accuracy: 0.9947
# Epoch 25/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0175 - accuracy: 0.9966
# Epoch 26/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.0271 - accuracy: 0.9941
# Epoch 27/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.0217 - accuracy: 0.9953
# Epoch 28/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0248 - accuracy: 0.9945
# Epoch 29/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0161 - accuracy: 0.9966
# Epoch 30/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0182 - accuracy: 0.9960
# Epoch 31/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0243 - accuracy: 0.9947
# Epoch 32/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0147 - accuracy: 0.9968
# Epoch 33/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.0189 - accuracy: 0.9956
# Epoch 34/200
# 1188/1188 [==============================] - 53s 45ms/step - loss: 0.0143 - accuracy: 0.9970
# Epoch 35/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0195 - accuracy: 0.9957
# Epoch 36/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0245 - accuracy: 0.9950
# Epoch 37/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0230 - accuracy: 0.9951
# Epoch 38/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0166 - accuracy: 0.9965
# Epoch 39/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0200 - accuracy: 0.9957
# Epoch 40/200
# 1188/1188 [==============================] - 56s 47ms/step - loss: 0.0109 - accuracy: 0.9978
# Epoch 41/200
# 1188/1188 [==============================] - 56s 47ms/step - loss: 0.0145 - accuracy: 0.9967
# Epoch 42/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0119 - accuracy: 0.9974
# Epoch 43/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0122 - accuracy: 0.9972
# Epoch 44/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0302 - accuracy: 0.9940
# Epoch 45/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0312 - accuracy: 0.9932
# Epoch 46/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0081 - accuracy: 0.9984
# Epoch 47/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0146 - accuracy: 0.9965
# Epoch 48/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0093 - accuracy: 0.9982
# Epoch 49/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0151 - accuracy: 0.9969
# Epoch 50/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0235 - accuracy: 0.9950
# Epoch 51/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0150 - accuracy: 0.9965
# Epoch 52/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0148 - accuracy: 0.9966
# Epoch 53/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0241 - accuracy: 0.9943
# Epoch 54/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0131 - accuracy: 0.9972
# Epoch 55/200
# 1188/1188 [==============================] - 54s 45ms/step - loss: 0.0114 - accuracy: 0.9977
# Epoch 56/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0132 - accuracy: 0.9972
# Epoch 57/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0232 - accuracy: 0.9948
# Epoch 58/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0086 - accuracy: 0.9980
# Epoch 59/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0096 - accuracy: 0.9977
# Epoch 60/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0207 - accuracy: 0.9954
# Epoch 61/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0102 - accuracy: 0.9979
# Epoch 62/200
# 1188/1188 [==============================] - 55s 47ms/step - loss: 0.0078 - accuracy: 0.9984
# Epoch 63/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0115 - accuracy: 0.9977
# Epoch 64/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0092 - accuracy: 0.9981
# Epoch 65/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0139 - accuracy: 0.9971
# Epoch 66/200
# 1188/1188 [==============================] - 55s 47ms/step - loss: 0.0119 - accuracy: 0.9976
# Epoch 67/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0137 - accuracy: 0.9971
# Epoch 68/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.0087 - accuracy: 0.9979
# Epoch 69/200
# 1188/1188 [==============================] - 55s 47ms/step - loss: 0.0190 - accuracy: 0.9958
# Epoch 70/200
# 1188/1188 [==============================] - 56s 47ms/step - loss: 0.0083 - accuracy: 0.9984
# Epoch 71/200
# 1188/1188 [==============================] - 54s 46ms/step - loss: 0.0069 - accuracy: 0.9985
# Epoch 72/200
# 1188/1188 [==============================] - 55s 47ms/step - loss: 0.0179 - accuracy: 0.9959
# Epoch 73/200
# 1188/1188 [==============================] - 55s 47ms/step - loss: 0.0106 - accuracy: 0.9977
# Epoch 74/200
# 1188/1188 [==============================] - 55s 47ms/step - loss: 0.0161 - accuracy: 0.9967
# Epoch 75/200
# 1188/1188 [==============================] - 55s 46ms/step - loss: 0.
# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# #### SAVE MODEL

# %%
##################
# # save model # #
##################
model.model.save(MODEL_PATH)

# %% [markdown]
# # LIVE TESTING
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()
# Out:
#   Subject  Password    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    andy  Co5mical  0.073992  0.003000   0.076992   0.094482   0.168474
# 1    andy  Co5mical  0.073992  0.003000   0.076992   0.094482   0.168474
# 2    andy  Co5mical  0.073992  0.003000   0.076992   0.094482   0.168474
# 3    andy  Co5mical  0.073992  0.003000   0.076992   0.094482   0.168474
# 4    andy  Co5mical  0.100974  0.012187   0.113161   0.101644   0.202618
#
#      T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T7-RF|VAR.1  T7-NG|VAR.1  T7-I|SD.1  \
# 0  0.091483  0.045362   0.136844  ...     0.004042     0.005144   0.048238
# 1  0.091483  0.045362   0.136844  ...     0.009055     0.005173   0.087968
# 2  0.091483  0.045362   0.136844  ...     0.007376     0.004978   0.081239
# 3  0.091483  0.045362   0.136844  ...     0.002313     0.003616   0.024290
# 4  0.089456  0.033577   0.123034  ...     0.002609     0.001499   0.042155
#
#    T7-PF|SD.1  T7-RF|SD.1  T7-NG|SD.1  T8-I|0+7.1  T8-PF|0+7.1  T8-RF|0+7.1  \
# 0    0.056383    0.063579    0.071723    0.518507     0.619481     0.597307
# 1    0.064734    0.095156    0.071922    0.504553     0.594277     0.596016
# 2    0.065912    0.085884    0.070557    0.477528     0.545525     0.563112
# 3    0.036328    0.048092    0.060130    0.470455     0.572712     0.537894
# 4    0.029788    0.051080    0.038712    0.499024     0.573016     0.566388
#
#    T8-NG|0+7.1
# 0     0.698281
# 1     0.685741
# 2     0.631109
# 3     0.640151
# 4     0.640380
#
# [5 rows x 442 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
actual_np = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

########################
# # predict all rows # #
########################
pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[46:54,FEATURES_COL_NUM:]
# print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

print(class_list)
Y = np.asarray(class_list)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)
# Out:
# ['andy', 'azfar', 'bryce', 'chris', 'cy', 'gerald', 'ken', 'qk', 'sz', 'vale', 'ye', 'ys']

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

# pred_proba = np.sum(pred_proba, axis=0)
# pred_proba = np.reshape(pred_proba, (1, 9))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

match_list = []

for _ in range(actual_np.size):
    if pred[_] == actual_np[_]:
        match_list.append("match")
    else:
        match_list.append("nope")

match_count = match_list.count("match")
total_count = len(match_list)

match_header = str(match_count) + "/" + str(total_count) + " (" + str(match_count/total_count*100)+ "%)"
match_np = np.array(match_list)

exported_output = np.column_stack((actual_np, pred))
exported_output = np.column_stack((exported_output, acc))
exported_output = np.column_stack((exported_output, match_np))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(data=exported_output, index=None, columns=['Actual', 'Prediction', 'Accuracy', match_header])
# print(df)
df.to_csv(RESULT_PATH)

print("Accuracy of the Model is: " + str(match_header))
# Out:
# Accuracy of the Model is: 209/240 (87.08333333333333%)

# %%
# print elapsed time
elapsed_time = time.time() - start_time
print('Execution time:', time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# Execution time: 10:37:33
