# %%
# calculate elapsed time
import time
start_time = time.time()

# %% [markdown]
# #### IMPORT

# %%
import os, platform
import py7zr

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %% [markdown]
# #### PARAMETERS
# - Set the condition
# > * N_FEATURES: Number of Features
# > * CHECK_BLANKS: Check for blank data. If any blank data is found, the whole row of data will be deleted.
# > * CHECK_CLASS_IMBALANCE: Check for dataset class imbalance. The more balance the dataset, the less biases the model will be.

# %%
##############################
# # deep learning features # #
##############################
SEED = 1005 # random seed for reproducibility

# should make this dynamic
N_FEATURES = 96
TIMESTEPS = 1
EPOCH=200
BATCH_SIZE=100

SPLIT_RATIO=0.2

###############
# # preview # #
###############
f = False
t = True

# checking dataset
CHECK_BLANKS = True
CHECK_CLASS_IMBALANCE = True

# evaluate suitable kfold number and kfold model
MIN_KFOLD = 2
MAX_KFOLD = 11
N_KFOLD = 5
EVAL_KFOLD_NUM = False
EVAL_KFOLD_MODEL = False
PERFORM_KFOLD = True

# model testing
TEST_MODEL = True
CON_MATRIX = True
ROC_GRAPH = True

###############
# # dataset # #
###############
CLASSES_COL_NAME = "Subject"
CLASSES_COL_NUM = 0
FEATURES_COL_NUM = 3

# METHOD = "IR" # identical_random
# METHOD = "DR" # different_random

DATASET_DIR_NAME = "dataset\set03\\11_original_IRDR"
SAMPLE_DATASET_NAME = "original_train"
# ACTUAL_DATASET_NAME = "original_test_" + METHOD

MODEL_DIR_NAME = "dataset\set03\\11_original_IRDR"
MODEL_NAME = "model_" + "set11_original"

# RESULT_DIR_NAME = "dataset\set03\\11_original_IRDR"
# RESULT_NAME = "result_" + "set11_original_" + METHOD

DATASET_DIR_PATH = os.path.join(os.getcwd(), DATASET_DIR_NAME)
SAMPLE_DATASET_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".csv")
# ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME + ".csv")

MODEL_DIR_PATH = os.path.join(os.getcwd(), MODEL_DIR_NAME)
MODEL_PATH = os.path.join(MODEL_DIR_PATH, MODEL_NAME + ".h5")

# RESULT_DIR_PATH = os.path.join(os.getcwd(), RESULT_DIR_NAME)
# RESULT_PATH = os.path.join(RESULT_DIR_PATH, RESULT_NAME + ".csv")

#################
# # sns theme # #
#################
# sns.set_theme(style="darkgrid") # (dark background with white gridlines)
sns.set_theme(style="whitegrid") # (white background with grey gridlines)
# sns.set_theme(style="dark") # (dark background with no gridlines)
# sns.set_theme(style="white") # (white background with no gridlines)
# sns.set_theme(style="ticks") # (white background with axis ticks and no gridlines)

# %%
if os.path.isdir(DATASET_DIR_PATH) is True:
    print(f"Dataset directory exists at: {DATASET_DIR_PATH}")
else:
    try:
        os.mkdir(DATASET_DIR_PATH, 666)
        print(f"Dataset directory have been created at: {DATASET_DIR_PATH}")
    except:
        print("Error: Dataset Directory not created")
        
if os.path.isdir(MODEL_DIR_PATH) is True:
    print(f"Model directory exists at: {MODEL_DIR_PATH}")
else:
    try:
        os.mkdir(MODEL_DIR_PATH, 666)
        print(f"Model directory have been created at: {MODEL_DIR_PATH}")
    except:
        print("Error: Model Directory not created")
    
if os.path.exists(SAMPLE_DATASET_PATH) is True:
    print(f"Training dataset exists at: {SAMPLE_DATASET_PATH}")
else:
    try:
        SAMPLE_7Z_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".7z")
        with py7zr.SevenZipFile(SAMPLE_7Z_PATH, mode='r') as z:
            z.extractall(path=DATASET_DIR_PATH)
        print(f"Decompress 7z file to: {SAMPLE_7Z_PATH}")
    except:
        print("Error: Failed to decompress 7z file.")
# Out:
# Dataset directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set03\11_original_IRDR
# Model directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set03\11_original_IRDR
# Training dataset exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set03\11_original_IRDR\original_train.csv

# %% [markdown]
# #### CREATE MODEL
# - Create base model
# - Wrap it with KerasClassifier

# %%
#create base model
def create_base_model():
    model = Sequential()
    model.add(LSTM(units=256, return_sequences=True,
             input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dense(256, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=32, return_sequences=True))
    model.add(Dense(32, activation='sigmoid'))
    model.add(Dropout(0.2))

    # softmax for multi-class classification
    model.add(Flatten())
    print("There are a total of " + str(n_classes) + " classes.")
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=EPOCH, 
                            batch_size=BATCH_SIZE)
    return model

# %%
# divide data into features X and target (classes) Y
def prepare_dataset(df):
    X = df.values[:,FEATURES_COL_NUM:].astype(float)
    Y = df.values[:,CLASSES_COL_NUM].astype(str)

    # convert target Y to labelbinarizer Y for model
    # fit_transform is not used to reuse lb
    Y = Y.reshape(-1, 1)
    lb = LabelBinarizer().fit(Y)
    Y = lb.transform(Y)

    #################################
    # # get all the encoded class # #
    #################################
    print("LabelBinarizer is able to decipher: ")
    print(lb.classes_)
    print("\n")

    ###########################
    # # print X and Y shape # #
    ###########################
    print(f"X | Features | Dataset Shape: {X.shape}")
    print(f"Y | Classes  | Dataset Shape: {Y.shape}")

    return X, Y, lb, lb.classes_.tolist()

# %%
def split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED):

    ##############################################################
    # # split dataset into train and test set of 0.8/0.2 ratio # #
    ##############################################################
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=SPLIT_RATIO, random_state=SEED)

    ############################
    # # reshaping of dataset # #
    ############################

    # reshaping the dataset to include LSTM Timesteps
    print(X_train.dtype)
    X_train = np.asarray(X_train, dtype=np.float32)
    print(X_train.dtype)
    X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
    print(X_test.dtype)
    X_test = np.asarray(X_test, dtype=np.float32)
    print(X_test.dtype)
    X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

    print(f"X train shape: {X_train.shape}")
    print(f"Y train shape: {y_train.shape}")
    print(f"X test shape: {X_test.shape}")
    print(f"Y test shape: {y_test.shape}")
    
    return X_train, X_test, y_train, y_test

def reshape_dataset(X, TIMESTEPS):
    # reshaping the dataset to include LSTM Timesteps
    X = np.asarray(X, dtype=np.float32)
    X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))
    return X

# %% [markdown]
# #### LOAD DATASET

# %%
# load dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)
df.head()
# Out:
#   Subject Sequence    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    adhy    wench  0.152282 -0.073436   0.078847   0.088479   0.240761
# 1    adhy    early  0.111913  0.151502   0.263416   0.288136   0.400049
# 2    adhy    relax  0.144175 -0.088621   0.055554   0.031521   0.175696
# 3    adhy    quick  0.152776 -0.081124   0.071653   0.054981   0.207758
# 4    adhy    xerus  0.070740  0.145027   0.215768   0.288192   0.358933
#
#      T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T4-RF|VAR  T4-NG|VAR   T4-I|SD  \
# 0  0.161915  0.102870   0.264785  ...   0.000301   0.000111  0.000517
# 1  0.136634 -0.016052   0.120582  ...   0.010378   0.007122  0.073101
# 2  0.120141  0.024040   0.144181  ...   0.027081   0.021776  0.159465
# 3  0.136105 -0.079724   0.056381  ...   0.000021   0.000267  0.012384
# 4  0.143165 -0.015681   0.127484  ...   0.018517   0.007202  0.141381
#
#    T4-PF|SD  T4-RF|SD  T4-NG|SD  T5-I|0+4  T5-PF|0+4  T5-RF|0+4  T5-NG|0+4
# 0  0.006294  0.017362  0.010551  0.447594   0.599876   0.575588   0.727871
# 1  0.055621  0.101870  0.084390  0.512567   0.624480   0.608445   0.720359
# 2  0.142471  0.164562  0.147567  0.343992   0.488168   0.464252   0.608427
# 3  0.000596  0.004537  0.016325  0.215807   0.368583   0.318909   0.471685
# 4  0.090169  0.136078  0.084866  0.441357   0.512098   0.553000   0.623741
#
# [5 rows x 99 columns]

# %% [markdown]
# #### CHECK DATASET

# %%
########################
# # check for blanks # #
########################
if CHECK_BLANKS is True:
    # checking for blanks
    print("Checking for blanks...")
    if df.isnull().values.any() is True:
        df = df.dropna(axis=0, how="any")
        print("Blank rows has been dropped.")
    else:
        print("No blank value has been found.")
        
#################################
# # check for class imbalance # #
#################################
if CHECK_CLASS_IMBALANCE is True:
    print("Checking for class imbalance...")
    sns.countplot(x=CLASSES_COL_NAME, data=df).set_title("Class Imbalance")
#     df.loc[(df!=0).any(axis=1)]
    plt.show()

sns.catplot(x="Subject", y="T2-D|0", hue="T2-D|0", data=df, legend=False)
sns.catplot(x="Subject", y="T2-I|0+1", hue="T2-I|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-PF|0+1", hue="T2-PF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-RF|0+1", hue="T2-RF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-D|1", hue="T2-D|1", data=df, legend=False)
# Out:
# Checking for blanks...
# No blank value has been found.
# Checking for class imbalance...

# %% [markdown]
# #### PREPARE DATASET
# - Split data based on X / Features and Y / Classes
# - Binarize Y into binary labels

# %%
X, Y, lb, class_list = prepare_dataset(df)
n_classes = len(class_list)
print(f"Number of Classes: {n_classes}")
# Out:
# LabelBinarizer is able to decipher:
# ['adhy' 'andy' 'bryce' 'chris' 'cy' 'hr' 'jc' 'ys']
#
#
# X | Features | Dataset Shape: (800, 96)
# Y | Classes  | Dataset Shape: (800, 8)
# Number of Classes: 8

# %% [markdown]
# #### SPLIT DATASET
# - Split dataset into train set and test set 0.8 / 0.2

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED)
# Out:
# float64
# float32
# float64
# float32
# X train shape: (640, 1, 96)
# Y train shape: (640, 8)
# X test shape: (160, 1, 96)
# Y test shape: (160, 8)

# %% [markdown]
# #### PERFORM VALIDATION (w KFold Validation)
# - Evaluate best KFold Validation
# - Generate loss and accuracy graph
# - Perform KFold validation

# %% [markdown]
# ##### Evaluate suitable folds for kfold validation

# %%
###############################################
# # evaluate suitable kfold value for model # #
###############################################
def evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD):
    
    # evaluate the model    
    folds = range(MIN_KFOLD, MAX_KFOLD)
    means, mins, maxs = list(), list(), list()
    
    # evaluate each k value
    for k in folds:
        # define the test condition
        kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
        
        # evaluate k value
        model = create_model()
        scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
        k_mean = np.mean(scores)
        k_min = scores.min()
        k_max = scores.max()
        
        # report performance
        print(f"No. of Folds: {k} | Accuracy: {k_mean*100:.3f} | Min: {k_min*100:.3f} | Max: {k_max*100:.3f}")
        
        # store mean accuracy and min and max relative to the mean
        means.append(k_mean)
        mins.append(k_mean - k_min)
        maxs.append(k_max - k_mean)
        
    # line plot of k mean values with min/max error bars
    clear_output(wait=True)
    pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
    # show the plot
    pyplot.show()
    
if EVAL_KFOLD_NUM is True:
    evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD)
else:
    print("EVAL_KFOLD_NUM is not True")
# Out:
# EVAL_KFOLD_NUM is not True

# %% [markdown]
# ##### Generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=50, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print(f"Accuracy | Mean: {np.mean(scores)*100:.3f} | Std: {np.std(scores)*100:.3f} | Length/no.: {len(scores)}")
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    clear_output(wait=True)
    plt.show()
    
if EVAL_KFOLD_MODEL is True:
    evaluate_kfold_model(X_train, y_train, SEED)
else:
    print("EVAL_KFOLD_MODEL is not true")
# Out:
# EVAL_KFOLD_MODEL is not true

# %% [markdown]
# ##### Perform Actual KFold validation

# %%
if PERFORM_KFOLD is True:
    # create model
    model = create_model()
    kfold = KFold(n_splits=N_KFOLD, shuffle=True, random_state=SEED)
    valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# ##### Get Validation Accuracy

# %%
if PERFORM_KFOLD is True:
    print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# #### FIT MODEL FOR TESTING
# - Fit the Model
# - View Accuracy and Loss Graph
# - View Model Summary

# %%
#####################
# # fit the model # #
#####################

if TEST_MODEL is True:
    model = create_model()
    es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                       verbose=1)
    history = model.fit(X_train, y_train, callbacks=es, verbose=1)
# Out:
# There are a total of 8 classes.
# Epoch 1/200
# 7/7 [==============================] - 7s 15ms/step - loss: 2.3522 - accuracy: 0.1281
# Epoch 2/200
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2802 - accuracy: 0.1172
# Epoch 3/200
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2646 - accuracy: 0.1266
# Epoch 4/200
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2244 - accuracy: 0.1359
# Epoch 5/200
# 7/7 [==============================] - 0s 13ms/step - loss: 2.1925 - accuracy: 0.1187
# Epoch 6/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1721 - accuracy: 0.1141
# Epoch 7/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1504 - accuracy: 0.1219
# Epoch 8/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1492 - accuracy: 0.1000
# Epoch 9/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1461 - accuracy: 0.1359
# Epoch 10/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1220 - accuracy: 0.1516
# Epoch 11/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1308 - accuracy: 0.1266
# Epoch 12/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1199 - accuracy: 0.1125
# Epoch 13/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1124 - accuracy: 0.1391
# Epoch 14/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1212 - accuracy: 0.1266
# Epoch 15/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1171 - accuracy: 0.1250
# Epoch 16/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.1050 - accuracy: 0.1297
# Epoch 17/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.0658 - accuracy: 0.1516
# Epoch 18/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.0686 - accuracy: 0.1625
# Epoch 19/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.0436 - accuracy: 0.1922
# Epoch 20/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9991 - accuracy: 0.1891
# Epoch 21/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9858 - accuracy: 0.2094
# Epoch 22/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.9543 - accuracy: 0.2219
# Epoch 23/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9326 - accuracy: 0.2188
# Epoch 24/200
# 7/7 [==============================] - 0s 18ms/step - loss: 1.9271 - accuracy: 0.2016
# Epoch 25/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9067 - accuracy: 0.2406
# Epoch 26/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.8858 - accuracy: 0.2547
# Epoch 27/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9059 - accuracy: 0.2266
# Epoch 28/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9068 - accuracy: 0.2141
# Epoch 29/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8600 - accuracy: 0.2500
# Epoch 30/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.8648 - accuracy: 0.2062
# Epoch 31/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.8447 - accuracy: 0.2516
# Epoch 32/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.8393 - accuracy: 0.2391
# Epoch 33/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.8474 - accuracy: 0.2297
# Epoch 34/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7974 - accuracy: 0.2672
# Epoch 35/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.8341 - accuracy: 0.2313
# Epoch 36/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7889 - accuracy: 0.2625
# Epoch 37/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.8050 - accuracy: 0.2484
# Epoch 38/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7814 - accuracy: 0.2828
# Epoch 39/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.7906 - accuracy: 0.2672
# Epoch 40/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7810 - accuracy: 0.2500
# Epoch 41/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7614 - accuracy: 0.2875
# Epoch 42/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.7767 - accuracy: 0.2641
# Epoch 43/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.8013 - accuracy: 0.2531
# Epoch 44/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7694 - accuracy: 0.2703
# Epoch 45/200
# 7/7 [==============================] - 0s 16ms/step - loss: 1.7590 - accuracy: 0.2688
# Epoch 46/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7700 - accuracy: 0.2703
# Epoch 47/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7393 - accuracy: 0.2672
# Epoch 48/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7436 - accuracy: 0.2875
# Epoch 49/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7558 - accuracy: 0.2672
# Epoch 50/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7685 - accuracy: 0.2812
# Epoch 51/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.7391 - accuracy: 0.2672
# Epoch 52/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7242 - accuracy: 0.3000
# Epoch 53/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7406 - accuracy: 0.2875
# Epoch 54/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7483 - accuracy: 0.3016
# Epoch 55/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7283 - accuracy: 0.2656
# Epoch 56/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7406 - accuracy: 0.2766
# Epoch 57/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7030 - accuracy: 0.3016
# Epoch 58/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7051 - accuracy: 0.3031
# Epoch 59/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7284 - accuracy: 0.2641
# Epoch 60/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7292 - accuracy: 0.2672
# Epoch 61/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7082 - accuracy: 0.3016
# Epoch 62/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.7353 - accuracy: 0.2812
# Epoch 63/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7262 - accuracy: 0.2891
# Epoch 64/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6984 - accuracy: 0.2922
# Epoch 65/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7184 - accuracy: 0.3031
# Epoch 66/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.7118 - accuracy: 0.2844
# Epoch 67/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7437 - accuracy: 0.2781
# Epoch 68/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7161 - accuracy: 0.2969
# Epoch 69/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6993 - accuracy: 0.2922
# Epoch 70/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.7035 - accuracy: 0.2969
# Epoch 71/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6900 - accuracy: 0.2844
# Epoch 72/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6979 - accuracy: 0.3141
# Epoch 73/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6826 - accuracy: 0.3047
# Epoch 74/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.7079 - accuracy: 0.3016
# Epoch 75/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6767 - accuracy: 0.3313
# Epoch 76/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6859 - accuracy: 0.3219
# Epoch 77/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6946 - accuracy: 0.3297
# Epoch 78/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6976 - accuracy: 0.3063
# Epoch 79/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6946 - accuracy: 0.2875
# Epoch 80/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6777 - accuracy: 0.3172
# Epoch 81/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6666 - accuracy: 0.3063
# Epoch 82/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6765 - accuracy: 0.3125
# Epoch 83/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6649 - accuracy: 0.3328
# Epoch 84/200
# 7/7 [==============================] - 0s 17ms/step - loss: 1.6884 - accuracy: 0.3250
# Epoch 85/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6429 - accuracy: 0.3516
# Epoch 86/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6609 - accuracy: 0.3172
# Epoch 87/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6657 - accuracy: 0.3297
# Epoch 88/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6685 - accuracy: 0.3391
# Epoch 89/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6702 - accuracy: 0.2984
# Epoch 90/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6648 - accuracy: 0.3266
# Epoch 91/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6791 - accuracy: 0.3250
# Epoch 92/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6347 - accuracy: 0.3359
# Epoch 93/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6609 - accuracy: 0.3438
# Epoch 94/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6441 - accuracy: 0.3609
# Epoch 95/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6421 - accuracy: 0.3531
# Epoch 96/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.6477 - accuracy: 0.3703
# Epoch 97/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6306 - accuracy: 0.3641
# Epoch 98/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.6404 - accuracy: 0.3672
# Epoch 99/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6387 - accuracy: 0.3609
# Epoch 100/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6131 - accuracy: 0.3547
# Epoch 101/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6232 - accuracy: 0.3703
# Epoch 102/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6345 - accuracy: 0.3812
# Epoch 103/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.6135 - accuracy: 0.3750
# Epoch 104/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6199 - accuracy: 0.3453
# Epoch 105/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6128 - accuracy: 0.3844
# Epoch 106/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6417 - accuracy: 0.3391
# Epoch 107/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6278 - accuracy: 0.3422
# Epoch 108/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6251 - accuracy: 0.3797
# Epoch 109/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.6331 - accuracy: 0.3656
# Epoch 110/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6140 - accuracy: 0.3891
# Epoch 111/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.6209 - accuracy: 0.3734
# Epoch 112/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.6058 - accuracy: 0.3844
# Epoch 113/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.6142 - accuracy: 0.3641
# Epoch 114/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6051 - accuracy: 0.3859
# Epoch 115/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.6188 - accuracy: 0.3797
# Epoch 116/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6145 - accuracy: 0.3719
# Epoch 117/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.6002 - accuracy: 0.3875
# Epoch 118/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5873 - accuracy: 0.3984
# Epoch 119/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6038 - accuracy: 0.3750
# Epoch 120/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5811 - accuracy: 0.3797
# Epoch 121/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6197 - accuracy: 0.3703
# Epoch 122/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5931 - accuracy: 0.3891
# Epoch 123/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5837 - accuracy: 0.4062
# Epoch 124/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6258 - accuracy: 0.3672
# Epoch 125/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5661 - accuracy: 0.3984
# Epoch 126/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5686 - accuracy: 0.3969
# Epoch 127/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5762 - accuracy: 0.3906
# Epoch 128/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5407 - accuracy: 0.4234
# Epoch 129/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5672 - accuracy: 0.3938
# Epoch 130/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5756 - accuracy: 0.4281
# Epoch 131/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5677 - accuracy: 0.4047
# Epoch 132/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5522 - accuracy: 0.3984
# Epoch 133/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5766 - accuracy: 0.4078
# Epoch 134/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5750 - accuracy: 0.3891
# Epoch 135/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5779 - accuracy: 0.3953
# Epoch 136/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5704 - accuracy: 0.4031
# Epoch 137/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5740 - accuracy: 0.4031
# Epoch 138/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5449 - accuracy: 0.4031
# Epoch 139/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5602 - accuracy: 0.4000
# Epoch 140/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.5681 - accuracy: 0.3938
# Epoch 141/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5483 - accuracy: 0.4016
# Epoch 142/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5280 - accuracy: 0.4016
# Epoch 143/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.5724 - accuracy: 0.3953
# Epoch 144/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.6004 - accuracy: 0.3844
# Epoch 145/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5528 - accuracy: 0.3984
# Epoch 146/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.5704 - accuracy: 0.3828
# Epoch 147/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5432 - accuracy: 0.3922
# Epoch 148/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5167 - accuracy: 0.4313
# Epoch 149/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5674 - accuracy: 0.4016
# Epoch 150/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.5380 - accuracy: 0.4000
# Epoch 151/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5358 - accuracy: 0.4000
# Epoch 152/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5171 - accuracy: 0.4328
# Epoch 153/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5388 - accuracy: 0.4156
# Epoch 154/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5493 - accuracy: 0.3891
# Epoch 155/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.5116 - accuracy: 0.4125
# Epoch 156/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5078 - accuracy: 0.4313
# Epoch 157/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5183 - accuracy: 0.4313
# Epoch 158/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5215 - accuracy: 0.4297
# Epoch 159/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5426 - accuracy: 0.4016
# Epoch 160/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5361 - accuracy: 0.4219
# Epoch 161/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5470 - accuracy: 0.4109
# Epoch 162/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.5487 - accuracy: 0.4125
# Epoch 163/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.5340 - accuracy: 0.4141
# Epoch 164/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5197 - accuracy: 0.4266
# Epoch 165/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5046 - accuracy: 0.4187
# Epoch 166/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.5209 - accuracy: 0.4125
# Epoch 167/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5247 - accuracy: 0.4109
# Epoch 168/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5049 - accuracy: 0.4422
# Epoch 169/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5464 - accuracy: 0.4047
# Epoch 170/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5030 - accuracy: 0.4250
# Epoch 171/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5389 - accuracy: 0.4141
# Epoch 172/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4896 - accuracy: 0.4453
# Epoch 173/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.5174 - accuracy: 0.4172
# Epoch 174/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5044 - accuracy: 0.4406
# Epoch 175/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5066 - accuracy: 0.4422
# Epoch 176/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5456 - accuracy: 0.4125
# Epoch 177/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.5093 - accuracy: 0.4313
# Epoch 178/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5161 - accuracy: 0.4203
# Epoch 179/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5031 - accuracy: 0.4078
# Epoch 180/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1.4970 - accuracy: 0.4313
# Epoch 181/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5101 - accuracy: 0.4328
# Epoch 182/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5087 - accuracy: 0.4187
# Epoch 183/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.5099 - accuracy: 0.4234
# Epoch 184/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5316 - accuracy: 0.4266
# Epoch 185/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5007 - accuracy: 0.4391
# Epoch 186/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5043 - accuracy: 0.4062
# Epoch 187/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4732 - accuracy: 0.4500
# Epoch 188/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4903 - accuracy: 0.4203
# Epoch 189/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.5017 - accuracy: 0.4375
# Epoch 190/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4783 - accuracy: 0.4391
# Epoch 191/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4801 - accuracy: 0.4297
# Epoch 192/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4709 - accuracy: 0.4422
# Epoch 193/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.4788 - accuracy: 0.4344
# Epoch 194/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4742 - accuracy: 0.4484
# Epoch 195/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4571 - accuracy: 0.4625
# Epoch 196/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4375 - accuracy: 0.4484
# Epoch 197/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4805 - accuracy: 0.4344
# Epoch 198/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4516 - accuracy: 0.4500
# Epoch 199/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4776 - accuracy: 0.4406
# Epoch 200/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4826 - accuracy: 0.4266

# %%
if TEST_MODEL is True:
    ##########################
    # # get model accuracy # #
    ##########################
    plt.plot(history.history['accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

    ######################
    # # get model loss # #
    ######################
    plt.plot(history.history['loss'])
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

# %%
if TEST_MODEL is True:
    ##########################
    # # view model summary # #
    ##########################
    model.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 256)            361472
#
#  dense (Dense)               (None, 1, 256)            65792
#
#  dropout (Dropout)           (None, 1, 256)            0
#
#  batch_normalization (BatchN  (None, 1, 256)           1024
#  ormalization)
#
#  lstm_1 (LSTM)               (None, 1, 128)            197120
#
#  dense_1 (Dense)             (None, 1, 128)            16512
#
#  dropout_1 (Dropout)         (None, 1, 128)            0
#
#  batch_normalization_1 (Batc  (None, 1, 128)           512
#  hNormalization)
#
#  lstm_2 (LSTM)               (None, 1, 64)             49408
#
#  dense_2 (Dense)             (None, 1, 64)             4160
#
#  dropout_2 (Dropout)         (None, 1, 64)             0
#
#  batch_normalization_2 (Batc  (None, 1, 64)            256
#  hNormalization)
#
#  lstm_3 (LSTM)               (None, 1, 32)             12416
#
#  dense_3 (Dense)             (None, 1, 32)             1056
#
#  dropout_3 (Dropout)         (None, 1, 32)             0
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense_4 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 709,992
# Trainable params: 709,096
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# #### MODEL TESTING
# - Get Model Accuracy on the Test Dataset
# - Generate Confusion Matrix
# - Generate ROC Curves
# - Save the Model if Appropriate

# %%
if TEST_MODEL is True:
    y_pred = model.predict_proba(X_test)

    # evaluate predictions
    acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    print("Testing accuracy: %.3f%%" % (acc*100))
# Out:
# Testing accuracy: 39.375%

# %% [markdown]
# ##### Confusion Matrix

# %%
if TEST_MODEL is True and CON_MATRIX is True:
    # confusion matrix
    print(str(len(y_pred)) + " is the number of test value in kfold_val / train_test_split")
    cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                         columns = [i for i in np.unique(lb.inverse_transform(y_test))])

    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=True, cmap="BuPu")
# Out:
# 160 is the number of test value in kfold_val / train_test_split

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
if TEST_MODEL is True and ROC_GRAPH is True: # compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    for i in range(n_classes):
        plt.figure()
        lw = 2
        plt.plot(
            fpr[i],
            tpr[i],
            color="darkorange",
            lw=lw,
            label="ROC curve (area = %0.2f)" % roc_auc[i],
        )
        plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
        plt.xlim([-0.005, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ##### ROC Curve (Multiclass)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    # compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # first aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    # plt.figure()
    # plt.plot(
    #     fpr["micro"],
    #     tpr["micro"],
    #     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    #     color="deeppink",
    #     linestyle=":",
    #     linewidth=4,
    # )

    # plt.plot(
    #     fpr["macro"],
    #     tpr["macro"],
    #     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    #     color="navy",
    #     linestyle=":",
    #     linewidth=4,
    # )

    colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
        )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Multiclass)")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Average)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

    # calculate equal-error-rate
    eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('Average ROC Curve')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #### FIT AND SAVE MODEL
# - Fitting of model
# - Get Accuracy and Loss of Mdoel
# - Saving Model

# %%
############################
# # reshaping of dataset # #
############################
# loading of dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)

df.head()
dataset = df.values

# divide data into features X and target (classes) Y
# convert target Y to labelbinarizer Y for model
X, Y, lb, class_list = prepare_dataset(df)

# reshaping the dataset to include LSTM Timesteps
X = reshape_dataset(X, TIMESTEPS)
n_classes = Y.shape[1]

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# LabelBinarizer is able to decipher:
# ['adhy' 'andy' 'bryce' 'chris' 'cy' 'hr' 'jc' 'ys']
#
#
# X | Features | Dataset Shape: (800, 96)
# Y | Classes  | Dataset Shape: (800, 8)
# There are a total of 8 classes.
# Epoch 1/200
# 8/8 [==============================] - 5s 13ms/step - loss: 2.3461 - accuracy: 0.1125
# Epoch 2/200
# 8/8 [==============================] - 0s 11ms/step - loss: 2.2803 - accuracy: 0.1138
# Epoch 3/200
# 8/8 [==============================] - 0s 12ms/step - loss: 2.2300 - accuracy: 0.1300
# Epoch 4/200
# 8/8 [==============================] - 0s 12ms/step - loss: 2.2054 - accuracy: 0.1150
# Epoch 5/200
# 8/8 [==============================] - 0s 13ms/step - loss: 2.1586 - accuracy: 0.1325
# Epoch 6/200
# 8/8 [==============================] - 0s 13ms/step - loss: 2.1452 - accuracy: 0.1338
# Epoch 7/200
# 8/8 [==============================] - 0s 13ms/step - loss: 2.1657 - accuracy: 0.1050
# Epoch 8/200
# 8/8 [==============================] - 0s 13ms/step - loss: 2.1456 - accuracy: 0.1175
# Epoch 9/200
# 8/8 [==============================] - 0s 12ms/step - loss: 2.1320 - accuracy: 0.1238
# Epoch 10/200
# 8/8 [==============================] - 0s 12ms/step - loss: 2.1209 - accuracy: 0.1213
# Epoch 11/200
# 8/8 [==============================] - 0s 12ms/step - loss: 2.1238 - accuracy: 0.1262
# Epoch 12/200
# 8/8 [==============================] - 0s 12ms/step - loss: 2.1116 - accuracy: 0.1275
# Epoch 13/200
# 8/8 [==============================] - 0s 13ms/step - loss: 2.1177 - accuracy: 0.1350
# Epoch 14/200
# 8/8 [==============================] - 0s 14ms/step - loss: 2.1033 - accuracy: 0.1338
# Epoch 15/200
# 8/8 [==============================] - 0s 13ms/step - loss: 2.1008 - accuracy: 0.1363
# Epoch 16/200
# 8/8 [==============================] - 0s 14ms/step - loss: 2.0770 - accuracy: 0.1600
# Epoch 17/200
# 8/8 [==============================] - 0s 14ms/step - loss: 2.0482 - accuracy: 0.1937
# Epoch 18/200
# 8/8 [==============================] - 0s 13ms/step - loss: 2.0180 - accuracy: 0.2188
# Epoch 19/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.9869 - accuracy: 0.2250
# Epoch 20/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.9701 - accuracy: 0.2338
# Epoch 21/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.9474 - accuracy: 0.2225
# Epoch 22/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.9356 - accuracy: 0.2200
# Epoch 23/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.9273 - accuracy: 0.2237
# Epoch 24/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.9020 - accuracy: 0.2212
# Epoch 25/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.8966 - accuracy: 0.2250
# Epoch 26/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.8884 - accuracy: 0.2288
# Epoch 27/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.8543 - accuracy: 0.2488
# Epoch 28/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.8590 - accuracy: 0.2463
# Epoch 29/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.8253 - accuracy: 0.2525
# Epoch 30/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.8431 - accuracy: 0.2675
# Epoch 31/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.8174 - accuracy: 0.2738
# Epoch 32/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.8176 - accuracy: 0.2700
# Epoch 33/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.7898 - accuracy: 0.2562
# Epoch 34/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.8078 - accuracy: 0.2650
# Epoch 35/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7891 - accuracy: 0.2488
# Epoch 36/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7861 - accuracy: 0.2575
# Epoch 37/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7841 - accuracy: 0.2525
# Epoch 38/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7729 - accuracy: 0.2812
# Epoch 39/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7632 - accuracy: 0.2775
# Epoch 40/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.7873 - accuracy: 0.2375
# Epoch 41/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7583 - accuracy: 0.2637
# Epoch 42/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7495 - accuracy: 0.2663
# Epoch 43/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7344 - accuracy: 0.2800
# Epoch 44/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7482 - accuracy: 0.2850
# Epoch 45/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7247 - accuracy: 0.2862
# Epoch 46/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7524 - accuracy: 0.2812
# Epoch 47/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7438 - accuracy: 0.2688
# Epoch 48/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.7299 - accuracy: 0.2763
# Epoch 49/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7173 - accuracy: 0.3075
# Epoch 50/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7105 - accuracy: 0.2850
# Epoch 51/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7164 - accuracy: 0.2788
# Epoch 52/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7322 - accuracy: 0.2675
# Epoch 53/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6932 - accuracy: 0.2912
# Epoch 54/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7330 - accuracy: 0.2775
# Epoch 55/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7185 - accuracy: 0.2675
# Epoch 56/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7086 - accuracy: 0.2988
# Epoch 57/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6897 - accuracy: 0.3025
# Epoch 58/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6941 - accuracy: 0.2800
# Epoch 59/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.7114 - accuracy: 0.2875
# Epoch 60/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6890 - accuracy: 0.3038
# Epoch 61/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6774 - accuracy: 0.3237
# Epoch 62/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6957 - accuracy: 0.2738
# Epoch 63/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6918 - accuracy: 0.2788
# Epoch 64/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6720 - accuracy: 0.3075
# Epoch 65/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6949 - accuracy: 0.3200
# Epoch 66/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6839 - accuracy: 0.3137
# Epoch 67/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6803 - accuracy: 0.2988
# Epoch 68/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6822 - accuracy: 0.2950
# Epoch 69/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.6910 - accuracy: 0.3063
# Epoch 70/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6665 - accuracy: 0.3063
# Epoch 71/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6727 - accuracy: 0.3100
# Epoch 72/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6479 - accuracy: 0.3187
# Epoch 73/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6911 - accuracy: 0.3150
# Epoch 74/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6508 - accuracy: 0.3050
# Epoch 75/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6613 - accuracy: 0.2975
# Epoch 76/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6732 - accuracy: 0.3212
# Epoch 77/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6778 - accuracy: 0.3013
# Epoch 78/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6679 - accuracy: 0.3113
# Epoch 79/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6685 - accuracy: 0.3275
# Epoch 80/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6679 - accuracy: 0.2962
# Epoch 81/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6690 - accuracy: 0.3200
# Epoch 82/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6529 - accuracy: 0.3225
# Epoch 83/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6459 - accuracy: 0.3288
# Epoch 84/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6514 - accuracy: 0.3200
# Epoch 85/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6470 - accuracy: 0.3325
# Epoch 86/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6463 - accuracy: 0.3150
# Epoch 87/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6481 - accuracy: 0.3237
# Epoch 88/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6429 - accuracy: 0.3338
# Epoch 89/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6679 - accuracy: 0.3013
# Epoch 90/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6399 - accuracy: 0.3088
# Epoch 91/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6447 - accuracy: 0.3100
# Epoch 92/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6475 - accuracy: 0.2975
# Epoch 93/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6362 - accuracy: 0.3150
# Epoch 94/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6545 - accuracy: 0.3388
# Epoch 95/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6438 - accuracy: 0.3137
# Epoch 96/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6574 - accuracy: 0.3025
# Epoch 97/200
# 8/8 [==============================] - 0s 16ms/step - loss: 1.6327 - accuracy: 0.3025
# Epoch 98/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6232 - accuracy: 0.3137
# Epoch 99/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6474 - accuracy: 0.3187
# Epoch 100/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6379 - accuracy: 0.3275
# Epoch 101/200
# 8/8 [==============================] - 0s 16ms/step - loss: 1.6183 - accuracy: 0.3338
# Epoch 102/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.6370 - accuracy: 0.3038
# Epoch 103/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6522 - accuracy: 0.3262
# Epoch 104/200
# 8/8 [==============================] - 0s 16ms/step - loss: 1.6344 - accuracy: 0.3162
# Epoch 105/200
# 8/8 [==============================] - 0s 16ms/step - loss: 1.6382 - accuracy: 0.3300
# Epoch 106/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6140 - accuracy: 0.3363
# Epoch 107/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6073 - accuracy: 0.3625
# Epoch 108/200
# 8/8 [==============================] - 0s 16ms/step - loss: 1.6439 - accuracy: 0.3500
# Epoch 109/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6118 - accuracy: 0.3350
# Epoch 110/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6088 - accuracy: 0.3575
# Epoch 111/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6029 - accuracy: 0.3537
# Epoch 112/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5855 - accuracy: 0.3650
# Epoch 113/200
# 8/8 [==============================] - 0s 16ms/step - loss: 1.6083 - accuracy: 0.3487
# Epoch 114/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5890 - accuracy: 0.3825
# Epoch 115/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5955 - accuracy: 0.3700
# Epoch 116/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6174 - accuracy: 0.3725
# Epoch 117/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.6255 - accuracy: 0.3600
# Epoch 118/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5864 - accuracy: 0.3725
# Epoch 119/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5646 - accuracy: 0.3900
# Epoch 120/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5501 - accuracy: 0.4025
# Epoch 121/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5665 - accuracy: 0.3950
# Epoch 122/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5487 - accuracy: 0.4137
# Epoch 123/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5474 - accuracy: 0.3950
# Epoch 124/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5592 - accuracy: 0.4087
# Epoch 125/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5583 - accuracy: 0.3913
# Epoch 126/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5471 - accuracy: 0.4038
# Epoch 127/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5497 - accuracy: 0.3988
# Epoch 128/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5255 - accuracy: 0.4062
# Epoch 129/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5530 - accuracy: 0.4075
# Epoch 130/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5636 - accuracy: 0.3862
# Epoch 131/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5436 - accuracy: 0.3975
# Epoch 132/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5218 - accuracy: 0.4137
# Epoch 133/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.5457 - accuracy: 0.4000
# Epoch 134/200
# 8/8 [==============================] - 0s 17ms/step - loss: 1.5085 - accuracy: 0.4175
# Epoch 135/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5259 - accuracy: 0.4100
# Epoch 136/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5196 - accuracy: 0.4212
# Epoch 137/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5240 - accuracy: 0.4100
# Epoch 138/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5053 - accuracy: 0.4212
# Epoch 139/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5281 - accuracy: 0.4013
# Epoch 140/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5263 - accuracy: 0.3938
# Epoch 141/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5026 - accuracy: 0.4125
# Epoch 142/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5213 - accuracy: 0.4162
# Epoch 143/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4722 - accuracy: 0.4412
# Epoch 144/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5296 - accuracy: 0.4150
# Epoch 145/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4831 - accuracy: 0.4225
# Epoch 146/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4882 - accuracy: 0.4112
# Epoch 147/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4758 - accuracy: 0.4363
# Epoch 148/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4980 - accuracy: 0.4288
# Epoch 149/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4990 - accuracy: 0.4112
# Epoch 150/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4953 - accuracy: 0.4300
# Epoch 151/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4969 - accuracy: 0.4212
# Epoch 152/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4814 - accuracy: 0.4375
# Epoch 153/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4800 - accuracy: 0.4487
# Epoch 154/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4895 - accuracy: 0.4313
# Epoch 155/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4844 - accuracy: 0.4200
# Epoch 156/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4690 - accuracy: 0.4412
# Epoch 157/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4899 - accuracy: 0.4300
# Epoch 158/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4842 - accuracy: 0.4300
# Epoch 159/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4923 - accuracy: 0.4275
# Epoch 160/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4815 - accuracy: 0.4238
# Epoch 161/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4705 - accuracy: 0.4263
# Epoch 162/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4461 - accuracy: 0.4325
# Epoch 163/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5108 - accuracy: 0.4212
# Epoch 164/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4985 - accuracy: 0.4225
# Epoch 165/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4659 - accuracy: 0.4412
# Epoch 166/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4881 - accuracy: 0.4350
# Epoch 167/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4636 - accuracy: 0.4175
# Epoch 168/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4723 - accuracy: 0.4313
# Epoch 169/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4800 - accuracy: 0.4313
# Epoch 170/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4732 - accuracy: 0.4350
# Epoch 171/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4646 - accuracy: 0.4437
# Epoch 172/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4873 - accuracy: 0.4150
# Epoch 173/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5532 - accuracy: 0.4050
# Epoch 174/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4868 - accuracy: 0.4250
# Epoch 175/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4884 - accuracy: 0.4162
# Epoch 176/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5002 - accuracy: 0.4200
# Epoch 177/200
# 8/8 [==============================] - 0s 13ms/step - loss: 1.4673 - accuracy: 0.4100
# Epoch 178/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5132 - accuracy: 0.4187
# Epoch 179/200
# 8/8 [==============================] - 0s 17ms/step - loss: 1.4552 - accuracy: 0.4250
# Epoch 180/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.4295 - accuracy: 0.4500
# Epoch 181/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.4501 - accuracy: 0.4263
# Epoch 182/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.4504 - accuracy: 0.4313
# Epoch 183/200
# 8/8 [==============================] - 0s 16ms/step - loss: 1.4463 - accuracy: 0.4538
# Epoch 184/200
# 8/8 [==============================] - 0s 16ms/step - loss: 1.4407 - accuracy: 0.4525
# Epoch 185/200
# 8/8 [==============================] - 0s 16ms/step - loss: 1.4405 - accuracy: 0.4550
# Epoch 186/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.4445 - accuracy: 0.4450
# Epoch 187/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.4569 - accuracy: 0.4487
# Epoch 188/200
# 8/8 [==============================] - 0s 17ms/step - loss: 1.4345 - accuracy: 0.4387
# Epoch 189/200
# 8/8 [==============================] - 0s 17ms/step - loss: 1.4309 - accuracy: 0.4437
# Epoch 190/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.4500 - accuracy: 0.4625
# Epoch 191/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.4375 - accuracy: 0.4550
# Epoch 192/200
# 8/8 [==============================] - 0s 16ms/step - loss: 1.4558 - accuracy: 0.4500
# Epoch 193/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.4515 - accuracy: 0.4288
# Epoch 194/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.4335 - accuracy: 0.4500
# Epoch 195/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.4246 - accuracy: 0.4338
# Epoch 196/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.4579 - accuracy: 0.4300
# Epoch 197/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.4436 - accuracy: 0.4288
# Epoch 198/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.4374 - accuracy: 0.4462
# Epoch 199/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.4637 - accuracy: 0.4250
# Epoch 200/200
# 8/8 [==============================] - 0s 14ms/step - loss: 1.4097 - accuracy: 0.4450

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# #### SAVE MODEL

# %%
##################
# # save model # #
##################
model.model.save(MODEL_PATH)

# %% [markdown]
# # LIVE TESTING FOR IR
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
METHOD = "IR" # identical_random
# METHOD = "DR" # different_random

ACTUAL_DATASET_NAME = "original_test_" + METHOD
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME + ".csv")

RESULT_DIR_NAME = "dataset\set03\\11_original_IRDR"
RESULT_NAME = "result_" + "set11_original_" + METHOD
RESULT_DIR_PATH = os.path.join(os.getcwd(), RESULT_DIR_NAME)
RESULT_PATH = os.path.join(RESULT_DIR_PATH, RESULT_NAME + ".csv")

# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()
# Out:
#   Subject Sequence    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    adhy    quail  0.119654 -0.024004   0.095650   0.080376   0.200030
# 1    adhy    acute  0.152999  0.336367   0.489367   0.448313   0.601312
# 2    adhy    tidal  0.112180 -0.079886   0.032294   0.032004   0.144184
# 3    adhy    scold  0.120001  0.080002   0.200003   0.224265   0.344265
# 4    adhy    nitro  0.111459  0.015505   0.126965   0.143124   0.254583
#
#      T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T4-RF|VAR  T4-NG|VAR   T4-I|SD  \
# 0  0.104380  0.304264   0.408644  ...   0.000039   0.000290  0.005462
# 1  0.111945 -0.032049   0.079896  ...   0.080180   0.097463  0.271303
# 2  0.111891  0.127658   0.239549  ...   0.000036   0.000034  0.034878
# 3  0.144262  0.552010   0.696273  ...   0.009373   0.006345  0.113785
# 4  0.127619  0.023795   0.151413  ...   0.012563   0.010132  0.061637
#
#    T4-PF|SD  T4-RF|SD  T4-NG|SD  T5-I|0+4  T5-PF|0+4  T5-RF|0+4  T5-NG|0+4
# 0  0.016262  0.006237  0.017037  0.552586   0.672240   0.672467   0.792121
# 1  0.300333  0.283161  0.312191  0.616362   0.769361   0.736033   0.889032
# 2  0.034673  0.005993  0.005788  0.344067   0.456247   0.416209   0.528389
# 3  0.096630  0.096813  0.079658  1.008275   1.128276   1.128039   1.248040
# 4  0.050211  0.112083  0.100657  0.375933   0.487393   0.439950   0.551410
#
# [5 rows x 99 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
actual_np = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

########################
# # predict all rows # #
########################
pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[46:54,FEATURES_COL_NUM:]
# print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

print(class_list)
Y = np.asarray(class_list)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)
# Out:
# ['adhy', 'andy', 'bryce', 'chris', 'cy', 'hr', 'jc', 'ys']

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

# pred_proba = np.sum(pred_proba, axis=0)
# pred_proba = np.reshape(pred_proba, (1, 9))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

match_list = []

for _ in range(actual_np.size):
    if pred[_] == actual_np[_]:
        match_list.append("match")
    else:
        match_list.append("nope")

match_count = match_list.count("match")
total_count = len(match_list)

match_header = str(match_count) + "/" + str(total_count) + " (" + str(match_count/total_count*100)+ "%)"
match_np = np.array(match_list)

exported_output = np.column_stack((actual_np, pred))
exported_output = np.column_stack((exported_output, acc))
exported_output = np.column_stack((exported_output, match_np))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(data=exported_output, index=None, columns=['Actual', 'Prediction', 'Accuracy', match_header])
# print(df)
df.to_csv(RESULT_PATH)

ir_result = "Accuracy of the Model for IR dataset: " + str(match_header)
print(ir_result)
# Out:
# Accuracy of the Model is: 35/80 (43.75%)

# %% [markdown]
# # LIVE TESTING FOR DR
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
# METHOD = "IR" # identical_random
METHOD = "DR" # different_random

ACTUAL_DATASET_NAME = "original_test_" + METHOD
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME + ".csv")

RESULT_DIR_NAME = "dataset\set03\\11_original_IRDR"
RESULT_NAME = "result_" + "set11_original_" + METHOD
RESULT_DIR_PATH = os.path.join(os.getcwd(), RESULT_DIR_NAME)
RESULT_PATH = os.path.join(RESULT_DIR_PATH, RESULT_NAME + ".csv")

# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()
# Out:
#   Subject Sequence    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    adhy    locos  0.104157  0.119091   0.223248   0.199206   0.303363
# 1    adhy    tesla  0.152463 -0.064295   0.088169   0.063572   0.216036
# 2    adhy    rooms  0.120094 -0.032019   0.088076   0.031269   0.151363
# 3    adhy    depot  0.094630  0.079847   0.174476   0.159830   0.254459
# 4    adhy    wiled  0.113404 -0.056720   0.056684   0.024002   0.137407
#
#      T2-D|1  T2-I|1+2  T2-PF|1+2  T2-RF|1+2  T2-NG|1+2    T2-D|2  T2-I|2+3  \
# 0  0.080115  0.151554   0.231669   0.264561   0.344676  0.113006 -0.041006
# 1  0.127867  0.063834   0.191701   0.191828   0.319695  0.127994 -0.016001
# 2  0.063287  0.080553   0.143840   0.191303   0.254590  0.110750 -0.015019
# 3  0.079983  0.015955   0.095938   0.127708   0.207691  0.111753 -0.072017
# 4  0.080723  0.078986   0.159709   0.199495   0.280217  0.120509  0.176663
#
#    T2-PF|2+3  T2-RF|2+3  T2-NG|2+3    T2-D|3  T2-I|3+4  T2-PF|3+4  T2-RF|3+4  \
# 0   0.072001   0.039679   0.152686  0.080685  0.039524   0.120209   0.159066
# 1   0.111994   0.080047   0.208041  0.096048 -0.024611   0.071437   0.104409
# 2   0.095731   0.080992   0.191743  0.096011 -0.023640   0.072371   0.087879
# 3   0.039736   0.080012   0.191766  0.152029 -0.048021   0.104008   0.064648
# 4   0.297171   0.240326   0.360834  0.063663  0.071979   0.135642   0.182892
#
#    T2-NG|3+4    T2-D|4    T2-D|S    T2-I|S   T2-PF|S   T2-RF|S   T2-NG|S  \
# 0   0.239751  0.119543  0.497506  0.269163  0.647126  0.662512  1.040475
# 1   0.200457  0.129020  0.633393 -0.041072  0.463300  0.439857  0.944229
# 2   0.183891  0.111519  0.501662  0.009875  0.400018  0.391443  0.781587
# 3   0.216678  0.112670  0.551065 -0.024236  0.414159  0.432199  0.870594
# 4   0.246555  0.110913  0.489212  0.270907  0.649205  0.646714  1.025013
#
#      T2-D|M    T2-I|M   T2-PF|M   T2-RF|M   T2-DT-M  T2-D|VAR  T2-I|VAR  \
# 0  0.099501  0.067291  0.161782  0.165628  0.260119  0.000334  0.007428
# 1  0.126679 -0.010268  0.115825  0.109964  0.236057  0.000403  0.002883
# 2  0.100332  0.002469  0.100005  0.097861  0.195397  0.000504  0.002758
# 3  0.110213 -0.006059  0.103540  0.108050  0.217649  0.000728  0.004659
# 4  0.097842  0.067727  0.162301  0.161679  0.256253  0.000597  0.009166
#
#    T2-PF|VAR  T2-RF|VAR  T2-DT-VAR   T2-D|SD   T2-I|SD  T2-PF|SD  T2-RF|SD  \
# 0   0.006150   0.008940   0.006992  0.018273  0.086183  0.078425  0.094554
# 1   0.002836   0.003260   0.003149  0.020073  0.053693  0.053251  0.057096
# 2   0.000949   0.004517   0.001863  0.022446  0.052516  0.030799  0.067207
# 3   0.003054   0.001912   0.000708  0.026989  0.068254  0.055260  0.043732
# 4   0.010021   0.009007   0.008577  0.024434  0.095741  0.100104  0.094904
#
#    T2-NG|SD  T3-I|0+2  T3-PF|0+2  T3-RF|0+2  T3-NG|0+2  T3-I|1+3  T3-PF|1+3  \
# 0  0.083619  0.350760   0.454917   0.463766   0.567924  0.223555   0.303670
# 1  0.056120  0.127407   0.279870   0.255401   0.407864  0.175828   0.303695
# 2  0.043161  0.111821   0.231915   0.222572   0.342666  0.176284   0.239571
# 3  0.026615  0.175785   0.270415   0.287538   0.382168  0.055691   0.135674
# 4  0.092610  0.102988   0.216393   0.223497   0.336901  0.376157   0.456880
#
#    T3-RF|1+3  T3-NG|1+3  T3-I|2+4  T3-PF|2+4  T3-RF|2+4  T3-NG|2+4    T3-I|S  \
# 0   0.304240   0.384355  0.079203   0.192209   0.198745   0.311752  0.653518
# 1   0.271876   0.399743  0.055436   0.183430   0.184456   0.312450  0.358671
# 2   0.272295   0.335583  0.057353   0.168103   0.168872   0.279622  0.345458
# 3   0.207721   0.287704  0.031991   0.143744   0.144661   0.256414  0.263468
# 4   0.439820   0.520543  0.312304   0.432813   0.423218   0.543726  0.791450
#
#     T3-PF|S   T3-RF|S   T3-NG|S    T3-I|M   T3-PF|M   T3-RF|M   T3-NG|M  \
# 0  0.950796  0.966752  1.264030  0.217839  0.316932  0.322251  0.421343
# 1  0.766995  0.711733  1.120057  0.119557  0.255665  0.237244  0.373352
# 2  0.639590  0.663739  0.957871  0.115153  0.213197  0.221246  0.319290
# 3  0.549833  0.639920  0.926286  0.087823  0.183278  0.213307  0.308762
# 4  1.106086  1.086535  1.401170  0.263817  0.368695  0.362178  0.467057
#
#    T3-I|VAR  T3-PF|VAR  T3-RF|VAR  T3-NG|VAR   T3-I|SD  T3-PF|SD  T3-RF|SD  \
# 0  0.018460   0.017386   0.017802   0.017432  0.135869  0.131855  0.133425
# 1  0.003670   0.004055   0.002158   0.002798  0.060579  0.063681  0.046452
# 2  0.003545   0.001540   0.002675   0.001193  0.059536  0.039239  0.051725
# 3  0.005943   0.005711   0.005127   0.004286  0.077094  0.075570  0.071602
# 4  0.020419   0.017542   0.014493   0.012840  0.142894  0.132446  0.120388
#
#    T3-NG|SD  T4-I|0+3  T4-PF|0+3  T4-RF|0+3  T4-NG|0+3  T4-I|1+4  T4-PF|1+4  \
# 0  0.132031  0.422761   0.526918   0.503446   0.607603  0.343764   0.423878
# 1  0.052899  0.239400   0.391864   0.335448   0.487911  0.247265   0.375132
# 2  0.034536  0.207553   0.327647   0.303564   0.423658  0.248656   0.311943
# 3  0.065468  0.215521   0.310151   0.367551   0.462180  0.159699   0.239682
# 4  0.113313  0.400160   0.513564   0.463823   0.577227  0.511799   0.592522
#
#    T4-RF|1+4  T4-NG|1+4    T4-I|S   T4-PF|S   T4-RF|S   T4-NG|S    T4-I|M  \
# 0   0.463306   0.543421  0.766524  0.950796  0.966752  1.151024  0.383262
# 1   0.376285   0.504152  0.486665  0.766995  0.711733  0.992063  0.243332
# 2   0.360175   0.423462  0.456208  0.639590  0.663739  0.847120  0.228104
# 3   0.272369   0.352352  0.375221  0.549833  0.639920  0.814532  0.187610
# 4   0.622712   0.703435  0.911958  1.106086  1.086535  1.280662  0.455979
#
#     T4-PF|M   T4-RF|M   T4-NG|M  T4-I|VAR  T4-PF|VAR  T4-RF|VAR     T4-NG|VAR  \
# 0  0.475398  0.483376  0.575512  0.003120   0.005309   0.000806  2.059652e-03
# 1  0.383498  0.355866  0.496032  0.000031   0.000140   0.000834  1.318750e-04
# 2  0.319795  0.331869  0.423560  0.000845   0.000123   0.001602  1.930000e-08
# 3  0.274917  0.319960  0.407266  0.001558   0.002483   0.004530  6.031094e-03
# 4  0.553043  0.543267  0.640331  0.006232   0.003117   0.012623  7.964238e-03
#
#     T4-I|SD  T4-PF|SD  T4-RF|SD  T4-NG|SD  T5-I|0+4  T5-PF|0+4  T5-RF|0+4  \
# 0  0.055859  0.072860  0.028383  0.045383  0.542969   0.647126   0.662512
# 1  0.005561  0.011831  0.028876  0.011484  0.310837   0.463300   0.439857
# 2  0.029064  0.011105  0.040030  0.000139  0.279924   0.400018   0.391443
# 3  0.039472  0.049829  0.067303  0.077660  0.319529   0.414159   0.432199
# 4  0.078941  0.055832  0.112352  0.089243  0.535801   0.649205   0.646714
#
#    T5-NG|0+4
# 0   0.766669
# 1   0.592320
# 2   0.511538
# 3   0.526829
# 4   0.760119

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
actual_np = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

########################
# # predict all rows # #
########################
pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[46:54,FEATURES_COL_NUM:]
# print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

print(class_list)
Y = np.asarray(class_list)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)
# Out:
# ['adhy', 'andy', 'bryce', 'chris', 'cy', 'hr', 'jc', 'ys']

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

# pred_proba = np.sum(pred_proba, axis=0)
# pred_proba = np.reshape(pred_proba, (1, 9))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

match_list = []

for _ in range(actual_np.size):
    if pred[_] == actual_np[_]:
        match_list.append("match")
    else:
        match_list.append("nope")

match_count = match_list.count("match")
total_count = len(match_list)

match_header = str(match_count) + "/" + str(total_count) + " (" + str(match_count/total_count*100)+ "%)"
match_np = np.array(match_list)

exported_output = np.column_stack((actual_np, pred))
exported_output = np.column_stack((exported_output, acc))
exported_output = np.column_stack((exported_output, match_np))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(data=exported_output, index=None, columns=['Actual', 'Prediction', 'Accuracy', match_header])
# print(df)
df.to_csv(RESULT_PATH)

dr_result = "Accuracy of the Model for DR dataset: " + str(match_header)
print(dr_result)
# Out:
# Accuracy of the Model is: 29/80 (36.25%)

# %% [markdown]
# #### RESULT

# %%
print(ir_result)
print(dr_result)

# %%
# print elapsed time
elapsed_time = time.time() - start_time
print('Execution time:', time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# Execution time: 00:07:04
