# %% [markdown]
# #### IMPORT

# %%
import os, platform
import py7zr

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %% [markdown]
# #### PARAMETERS
# - Set the condition
# > * N_FEATURES: Number of Features
# > * CHECK_BLANKS: Check for blank data. If any blank data is found, the whole row of data will be deleted.
# > * CHECK_CLASS_IMBALANCE: Check for dataset class imbalance. The more balance the dataset, the less biases the model will be.

# %%
##############################
# # deep learning features # #
##############################
SEED = 1005 # random seed for reproducibility

# should make this dynamic
N_FEATURES = 220
TIMESTEPS = 1
EPOCH=200
BATCH_SIZE=100

SPLIT_RATIO=0.2

###############
# # preview # #
###############
f = False
t = True

# checking dataset
CHECK_BLANKS = True
CHECK_CLASS_IMBALANCE = True

# evaluate suitable kfold number and kfold model
MIN_KFOLD = 2
MAX_KFOLD = 11
N_KFOLD = 5
EVAL_KFOLD_NUM = False
EVAL_KFOLD_MODEL = False
PERFORM_KFOLD = False

# model testing
TEST_MODEL = True
CON_MATRIX = True
ROC_GRAPH = True

###############
# # dataset # #
###############
CLASSES_COL_NAME = "Subject"
CLASSES_COL_NUM = 0
FEATURES_COL_NUM = 2

DATASET_DIR_NAME = "dataset\set04\\21_combi"
SAMPLE_DATASET_NAME = "own_train"
ACTUAL_DATASET_NAME = "combi_fake"

MODEL_DIR_NAME = "dataset\set04\\21_combi"
MODEL_NAME = "model_" + "set04_21_combi_fake"

RESULT_DIR_NAME = "dataset\set04\\21_combi"
RESULT_NAME = "result_" + "set04_21_combi_fake"

DATASET_DIR_PATH = os.path.join(os.getcwd(), DATASET_DIR_NAME)
SAMPLE_DATASET_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".csv")
ACTUAL_DATASET_PATH = os.path.join(DATASET_DIR_PATH, ACTUAL_DATASET_NAME + ".csv")

MODEL_DIR_PATH = os.path.join(os.getcwd(), MODEL_DIR_NAME)
MODEL_PATH = os.path.join(MODEL_DIR_PATH, MODEL_NAME + ".h5")

RESULT_DIR_PATH = os.path.join(os.getcwd(), RESULT_DIR_NAME)
RESULT_PATH = os.path.join(RESULT_DIR_PATH, RESULT_NAME + ".csv")

#################
# # sns theme # #
#################
# sns.set_theme(style="darkgrid") # (dark background with white gridlines)
sns.set_theme(style="whitegrid") # (white background with grey gridlines)
# sns.set_theme(style="dark") # (dark background with no gridlines)
# sns.set_theme(style="white") # (white background with no gridlines)
# sns.set_theme(style="ticks") # (white background with axis ticks and no gridlines)

# %%
if os.path.isdir(DATASET_DIR_PATH) is True:
    print(f"Dataset directory exists at: {DATASET_DIR_PATH}")
else:
    try:
        os.mkdir(DATASET_DIR_PATH, 666)
        print(f"Dataset directory have been created at: {DATASET_DIR_PATH}")
    except:
        print("Error: Dataset Directory not created")
        
if os.path.isdir(MODEL_DIR_PATH) is True:
    print(f"Model directory exists at: {MODEL_DIR_PATH}")
else:
    try:
        os.mkdir(MODEL_DIR_PATH, 666)
        print(f"Model directory have been created at: {MODEL_DIR_PATH}")
    except:
        print("Error: Model Directory not created")
    
if os.path.exists(SAMPLE_DATASET_PATH) is True:
    print(f"Training dataset exists at: {SAMPLE_DATASET_PATH}")
else:
    try:
        SAMPLE_7Z_PATH = os.path.join(DATASET_DIR_PATH, SAMPLE_DATASET_NAME + ".7z")
        with py7zr.SevenZipFile(SAMPLE_7Z_PATH, mode='r') as z:
            z.extractall(path=DATASET_DIR_PATH)
        print(f"Decompress 7z file to: {SAMPLE_7Z_PATH}")
    except:
        print("Error: Failed to decompress 7z file.")
# Out:
# Dataset directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set04\21_combi
# Model directory exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set04\21_combi
# Training dataset exists at: C:\Users\andyc\Documents\GitHub\ict4001-cap\dataset\set04\21_combi\own_train.csv

# %% [markdown]
# #### CREATE MODEL
# - Create base model
# - Wrap it with KerasClassifier

# %%
#create base model
def create_base_model():
    model = Sequential()
    model.add(LSTM(units=256, return_sequences=True,
             input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dense(256, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=32, return_sequences=True))
    model.add(Dense(32, activation='sigmoid'))
    model.add(Dropout(0.2))

    # softmax for multi-class classification
    model.add(Flatten())
    print("There are a total of " + str(n_classes) + " classes.")
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=EPOCH, 
                            batch_size=BATCH_SIZE)
    return model

# %%
# divide data into features X and target (classes) Y
def prepare_dataset(df):
    X = df.values[:,FEATURES_COL_NUM:].astype(float)
    Y = df.values[:,CLASSES_COL_NUM].astype(str)

    # convert target Y to labelbinarizer Y for model
    # fit_transform is not used to reuse lb
    Y = Y.reshape(-1, 1)
    lb = LabelBinarizer().fit(Y)
    Y = lb.transform(Y)

    #################################
    # # get all the encoded class # #
    #################################
    print("LabelBinarizer is able to decipher: ")
    print(lb.classes_)
    print("\n")

    ###########################
    # # print X and Y shape # #
    ###########################
    print(f"X | Features | Dataset Shape: {X.shape}")
    print(f"Y | Classes  | Dataset Shape: {Y.shape}")

    return X, Y, lb, lb.classes_.tolist()

# %%
def split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED):

    ##############################################################
    # # split dataset into train and test set of 0.8/0.2 ratio # #
    ##############################################################
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=SPLIT_RATIO, random_state=SEED)

    ############################
    # # reshaping of dataset # #
    ############################

    # reshaping the dataset to include LSTM Timesteps
    print(X_train.dtype)
    X_train = np.asarray(X_train, dtype=np.float32)
    print(X_train.dtype)
    X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
    print(X_test.dtype)
    X_test = np.asarray(X_test, dtype=np.float32)
    print(X_test.dtype)
    X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

    print(f"X train shape: {X_train.shape}")
    print(f"Y train shape: {y_train.shape}")
    print(f"X test shape: {X_test.shape}")
    print(f"Y test shape: {y_test.shape}")
    
    return X_train, X_test, y_train, y_test

def reshape_dataset(X, TIMESTEPS):
    # reshaping the dataset to include LSTM Timesteps
    X = np.asarray(X, dtype=np.float32)
    X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))
    return X

# %% [markdown]
# #### LOAD DATASET

# %%
# load dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)
df.head()
# Out:
#   Subject  Password    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  T2-NG|0+1  \
# 0    andy  Co5mical  0.124989  0.000000   0.124989   0.123640   0.248628
# 1    andy  Co5mical  0.101935  0.011014   0.112950   0.133594   0.235529
# 2    andy  Co5mical  0.090341 -0.012504   0.077837   0.090850   0.181191
# 3    andy  Co5mical  0.102711  0.011565   0.114277   0.110634   0.213346
# 4    andy  Co5mical  0.127922  0.063317   0.191239   0.188074   0.315996
#
#      T2-D|1  T2-I|1+2  T2-PF|1+2  ...  T7-RF|VAR  T7-NG|VAR   T7-I|SD  \
# 0  0.123640  0.011015   0.134655  ...   0.005318   0.005458  0.055285
# 1  0.122580  0.046207   0.168787  ...   0.006047   0.003990  0.047034
# 2  0.103354  0.054714   0.158068  ...   0.003187   0.002233  0.024718
# 3  0.099069  0.033884   0.132953  ...   0.004878   0.005244  0.046083
# 4  0.124757  0.023144   0.147900  ...   0.016760   0.017344  0.101889
#
#    T7-PF|SD  T7-RF|SD  T7-NG|SD  T8-I|0+7  T8-PF|0+7  T8-RF|0+7  T8-NG|0+7
# 0  0.056239  0.072921  0.073875  0.606169   0.731157   0.718543   0.843531
# 1  0.032436  0.077762  0.063164  0.616391   0.718327   0.697449   0.799384
# 2  0.015517  0.056457  0.047256  0.550968   0.641309   0.628636   0.718976
# 3  0.048659  0.069841  0.072416  0.562252   0.664963   0.652923   0.755634
# 4  0.104127  0.129459  0.131697  0.638064   0.765986   0.722751   0.850673
#
# [5 rows x 222 columns]

# %% [markdown]
# #### CHECK DATASET

# %%
########################
# # check for blanks # #
########################
if CHECK_BLANKS is True:
    # checking for blanks
    print("Checking for blanks...")
    if df.isnull().values.any() is True:
        df = df.dropna(axis=0, how="any")
        print("Blank rows has been dropped.")
    else:
        print("No blank value has been found.")
        
#################################
# # check for class imbalance # #
#################################
if CHECK_CLASS_IMBALANCE is True:
    print("Checking for class imbalance...")
    sns.countplot(x=CLASSES_COL_NAME, data=df).set_title("Class Imbalance")
#     df.loc[(df!=0).any(axis=1)]
    plt.show()

sns.catplot(x="Subject", y="T2-D|0", hue="T2-D|0", data=df, legend=False)
sns.catplot(x="Subject", y="T2-I|0+1", hue="T2-I|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-PF|0+1", hue="T2-PF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-RF|0+1", hue="T2-RF|0+1", data=df, legend=False)
sns.catplot(x="Subject", y="T2-D|1", hue="T2-D|1", data=df, legend=False)
# Out:
# Checking for blanks...
# No blank value has been found.
# Checking for class imbalance...

# %% [markdown]
# #### PREPARE DATASET
# - Split data based on X / Features and Y / Classes
# - Binarize Y into binary labels

# %%
X, Y, lb, class_list = prepare_dataset(df)
n_classes = len(class_list)
print(f"Number of Classes: {n_classes}")
# Out:
# LabelBinarizer is able to decipher:
# ['andy' 'azfar' 'bryce' 'chris' 'cy' 'gerald' 'ken' 'qk' 'sz' 'vale' 'ye'
#  'ys']
#
#
# X | Features | Dataset Shape: (1200, 220)
# Y | Classes  | Dataset Shape: (1200, 12)
# Number of Classes: 12

# %% [markdown]
# #### SPLIT DATASET
# - Split dataset into train set and test set 0.8 / 0.2

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = split_shape_dataset(X, Y, SPLIT_RATIO, TIMESTEPS, SEED)
# Out:
# float64
# float32
# float64
# float32
# X train shape: (960, 1, 220)
# Y train shape: (960, 12)
# X test shape: (240, 1, 220)
# Y test shape: (240, 12)

# %% [markdown]
# #### PERFORM VALIDATION (w KFold Validation)
# - Evaluate best KFold Validation
# - Generate loss and accuracy graph
# - Perform KFold validation

# %% [markdown]
# ##### Evaluate suitable folds for kfold validation

# %%
###############################################
# # evaluate suitable kfold value for model # #
###############################################
def evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD):
    
    # evaluate the model    
    folds = range(MIN_KFOLD, MAX_KFOLD)
    means, mins, maxs = list(), list(), list()
    
    # evaluate each k value
    for k in folds:
        # define the test condition
        kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
        
        # evaluate k value
        model = create_model()
        scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
        k_mean = np.mean(scores)
        k_min = scores.min()
        k_max = scores.max()
        
        # report performance
        print(f"No. of Folds: {k} | Accuracy: {k_mean*100:.3f} | Min: {k_min*100:.3f} | Max: {k_max*100:.3f}")
        
        # store mean accuracy and min and max relative to the mean
        means.append(k_mean)
        mins.append(k_mean - k_min)
        maxs.append(k_max - k_mean)
        
    # line plot of k mean values with min/max error bars
    clear_output(wait=True)
    pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
    # show the plot
    pyplot.show()
    
if EVAL_KFOLD_NUM is True:
    evaluate_kfold(X_train, y_train, SEED, MIN_KFOLD, MAX_KFOLD)
else:
    print("EVAL_KFOLD_NUM is not True")
# Out:
# EVAL_KFOLD_NUM is not True

# %% [markdown]
# ##### Generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=50, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print(f"Accuracy | Mean: {np.mean(scores)*100:.3f} | Std: {np.std(scores)*100:.3f} | Length/no.: {len(scores)}")
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    clear_output(wait=True)
    plt.show()
    
if EVAL_KFOLD_MODEL is True:
    evaluate_kfold_model(X_train, y_train, SEED)
else:
    print("EVAL_KFOLD_MODEL is not true")
# Out:
# EVAL_KFOLD_MODEL is not true

# %% [markdown]
# ##### Perform Actual KFold validation

# %%
if PERFORM_KFOLD is True:
    # create model
    model = create_model()
    kfold = KFold(n_splits=N_KFOLD, shuffle=True, random_state=SEED)
    valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# ##### Get Validation Accuracy

# %%
if PERFORM_KFOLD is True:
    print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
else:
    print("PERFORM_KFOLD is not true.")
# Out:
# PERFORM_KFOLD is not true.

# %% [markdown]
# #### FIT MODEL FOR TESTING
# - Fit the Model
# - View Accuracy and Loss Graph
# - View Model Summary

# %%
#####################
# # fit the model # #
#####################

if TEST_MODEL is True:
    model = create_model()
    es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                       verbose=1)
    history = model.fit(X_train, y_train, callbacks=es, verbose=1)
# Out:
# There are a total of 12 classes.
# Epoch 1/200
# 10/10 [==============================] - 8s 20ms/step - loss: 2.9421 - accuracy: 0.0823
# Epoch 2/200
# 10/10 [==============================] - 0s 20ms/step - loss: 2.8271 - accuracy: 0.0802
# Epoch 3/200
# 10/10 [==============================] - 0s 19ms/step - loss: 2.7169 - accuracy: 0.0823
# Epoch 4/200
# 10/10 [==============================] - 0s 19ms/step - loss: 2.6737 - accuracy: 0.0833
# Epoch 5/200
# 10/10 [==============================] - 0s 17ms/step - loss: 2.6033 - accuracy: 0.0875
# Epoch 6/200
# 10/10 [==============================] - 0s 18ms/step - loss: 2.5547 - accuracy: 0.0875
# Epoch 7/200
# 10/10 [==============================] - 0s 19ms/step - loss: 2.4847 - accuracy: 0.1031
# Epoch 8/200
# 10/10 [==============================] - 0s 18ms/step - loss: 2.4460 - accuracy: 0.1031
# Epoch 9/200
# 10/10 [==============================] - 0s 18ms/step - loss: 2.3623 - accuracy: 0.1271
# Epoch 10/200
# 10/10 [==============================] - 0s 17ms/step - loss: 2.2955 - accuracy: 0.1500
# Epoch 11/200
# 10/10 [==============================] - 0s 17ms/step - loss: 2.2441 - accuracy: 0.1708
# Epoch 12/200
# 10/10 [==============================] - 0s 16ms/step - loss: 2.1773 - accuracy: 0.1937
# Epoch 13/200
# 10/10 [==============================] - 0s 16ms/step - loss: 2.1523 - accuracy: 0.1844
# Epoch 14/200
# 10/10 [==============================] - 0s 17ms/step - loss: 2.1078 - accuracy: 0.1698
# Epoch 15/200
# 10/10 [==============================] - 0s 18ms/step - loss: 2.0617 - accuracy: 0.2135
# Epoch 16/200
# 10/10 [==============================] - 0s 18ms/step - loss: 2.0220 - accuracy: 0.2396
# Epoch 17/200
# 10/10 [==============================] - 0s 16ms/step - loss: 2.0151 - accuracy: 0.2240
# Epoch 18/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.9790 - accuracy: 0.2385
# Epoch 19/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.9361 - accuracy: 0.2240
# Epoch 20/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.9160 - accuracy: 0.2427
# Epoch 21/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.8989 - accuracy: 0.2354
# Epoch 22/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.8748 - accuracy: 0.2365
# Epoch 23/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.8537 - accuracy: 0.2552
# Epoch 24/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.8503 - accuracy: 0.2573
# Epoch 25/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.8353 - accuracy: 0.2562
# Epoch 26/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.8420 - accuracy: 0.2250
# Epoch 27/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.8048 - accuracy: 0.2448
# Epoch 28/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.8100 - accuracy: 0.2490
# Epoch 29/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.8042 - accuracy: 0.2500
# Epoch 30/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.7934 - accuracy: 0.2469
# Epoch 31/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.7729 - accuracy: 0.2573
# Epoch 32/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.7793 - accuracy: 0.2740
# Epoch 33/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.7475 - accuracy: 0.2781
# Epoch 34/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.7408 - accuracy: 0.2927
# Epoch 35/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.7317 - accuracy: 0.2740
# Epoch 36/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.7251 - accuracy: 0.2979
# Epoch 37/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.7085 - accuracy: 0.3063
# Epoch 38/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.6683 - accuracy: 0.3240
# Epoch 39/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.6966 - accuracy: 0.2927
# Epoch 40/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.6670 - accuracy: 0.3052
# Epoch 41/200
# 10/10 [==============================] - 0s 21ms/step - loss: 1.6576 - accuracy: 0.3198
# Epoch 42/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.6383 - accuracy: 0.3104
# Epoch 43/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.6395 - accuracy: 0.3063
# Epoch 44/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.6419 - accuracy: 0.3177
# Epoch 45/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.6364 - accuracy: 0.3146
# Epoch 46/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.6265 - accuracy: 0.3260
# Epoch 47/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.5708 - accuracy: 0.3313
# Epoch 48/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.5939 - accuracy: 0.3229
# Epoch 49/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.6017 - accuracy: 0.3208
# Epoch 50/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.5945 - accuracy: 0.3240
# Epoch 51/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.5914 - accuracy: 0.3365
# Epoch 52/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.6006 - accuracy: 0.3198
# Epoch 53/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.5830 - accuracy: 0.3198
# Epoch 54/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5528 - accuracy: 0.3125
# Epoch 55/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5510 - accuracy: 0.3167
# Epoch 56/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5534 - accuracy: 0.3375
# Epoch 57/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.5471 - accuracy: 0.3292
# Epoch 58/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.5614 - accuracy: 0.3281
# Epoch 59/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.5154 - accuracy: 0.3375
# Epoch 60/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.5157 - accuracy: 0.3260
# Epoch 61/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5371 - accuracy: 0.3198
# Epoch 62/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5381 - accuracy: 0.3156
# Epoch 63/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5288 - accuracy: 0.3281
# Epoch 64/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5298 - accuracy: 0.3271
# Epoch 65/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5325 - accuracy: 0.3458
# Epoch 66/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5666 - accuracy: 0.3187
# Epoch 67/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5475 - accuracy: 0.3292
# Epoch 68/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.5161 - accuracy: 0.3313
# Epoch 69/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.5412 - accuracy: 0.3302
# Epoch 70/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.5258 - accuracy: 0.3448
# Epoch 71/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.4944 - accuracy: 0.3490
# Epoch 72/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.5084 - accuracy: 0.3208
# Epoch 73/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.5232 - accuracy: 0.3313
# Epoch 74/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4995 - accuracy: 0.3333
# Epoch 75/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4883 - accuracy: 0.3625
# Epoch 76/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.4666 - accuracy: 0.3615
# Epoch 77/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4731 - accuracy: 0.3385
# Epoch 78/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.4723 - accuracy: 0.3354
# Epoch 79/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4598 - accuracy: 0.3542
# Epoch 80/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.4680 - accuracy: 0.3625
# Epoch 81/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.4694 - accuracy: 0.3531
# Epoch 82/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4559 - accuracy: 0.3646
# Epoch 83/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4512 - accuracy: 0.3677
# Epoch 84/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.4419 - accuracy: 0.3865
# Epoch 85/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.4139 - accuracy: 0.4104
# Epoch 86/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.4329 - accuracy: 0.4010
# Epoch 87/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.4445 - accuracy: 0.4208
# Epoch 88/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.3884 - accuracy: 0.4333
# Epoch 89/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.3698 - accuracy: 0.4458
# Epoch 90/200
# 10/10 [==============================] - 0s 17ms/step - loss: 1.3444 - accuracy: 0.4688
# Epoch 91/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.3535 - accuracy: 0.4510
# Epoch 92/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.3559 - accuracy: 0.4646
# Epoch 93/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.3523 - accuracy: 0.4563
# Epoch 94/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.3127 - accuracy: 0.4583
# Epoch 95/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.2854 - accuracy: 0.4979
# Epoch 96/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.2791 - accuracy: 0.4750
# Epoch 97/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.2798 - accuracy: 0.4865
# Epoch 98/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.2987 - accuracy: 0.4875
# Epoch 99/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.2546 - accuracy: 0.4906
# Epoch 100/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.2531 - accuracy: 0.5010
# Epoch 101/200
# 10/10 [==============================] - 0s 21ms/step - loss: 1.2307 - accuracy: 0.5146
# Epoch 102/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.2181 - accuracy: 0.5344
# Epoch 103/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.1967 - accuracy: 0.5354
# Epoch 104/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.2060 - accuracy: 0.5198
# Epoch 105/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.2051 - accuracy: 0.5208
# Epoch 106/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.1852 - accuracy: 0.5552
# Epoch 107/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.1785 - accuracy: 0.5396
# Epoch 108/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.1378 - accuracy: 0.5667
# Epoch 109/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.1363 - accuracy: 0.5708
# Epoch 110/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.1194 - accuracy: 0.5750
# Epoch 111/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.1033 - accuracy: 0.5792
# Epoch 112/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.0946 - accuracy: 0.5917
# Epoch 113/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.0826 - accuracy: 0.6031
# Epoch 114/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.0831 - accuracy: 0.5938
# Epoch 115/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.0432 - accuracy: 0.6333
# Epoch 116/200
# 10/10 [==============================] - 0s 15ms/step - loss: 1.0597 - accuracy: 0.5979
# Epoch 117/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9974 - accuracy: 0.6385
# Epoch 118/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9958 - accuracy: 0.6208
# Epoch 119/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9988 - accuracy: 0.6260
# Epoch 120/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9939 - accuracy: 0.6385
# Epoch 121/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9998 - accuracy: 0.6219
# Epoch 122/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.0309 - accuracy: 0.6052
# Epoch 123/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9765 - accuracy: 0.6292
# Epoch 124/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9416 - accuracy: 0.6417
# Epoch 125/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9084 - accuracy: 0.6531
# Epoch 126/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9253 - accuracy: 0.6521
# Epoch 127/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.9160 - accuracy: 0.6458
# Epoch 128/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.9230 - accuracy: 0.6354
# Epoch 129/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9208 - accuracy: 0.6458
# Epoch 130/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.8979 - accuracy: 0.6552
# Epoch 131/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9046 - accuracy: 0.6521
# Epoch 132/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9177 - accuracy: 0.6427
# Epoch 133/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9157 - accuracy: 0.6458
# Epoch 134/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.9046 - accuracy: 0.6552
# Epoch 135/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.9076 - accuracy: 0.6531
# Epoch 136/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.8685 - accuracy: 0.6917
# Epoch 137/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.8319 - accuracy: 0.6729
# Epoch 138/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8286 - accuracy: 0.6875
# Epoch 139/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8372 - accuracy: 0.6948
# Epoch 140/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8673 - accuracy: 0.6740
# Epoch 141/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8131 - accuracy: 0.6958
# Epoch 142/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8961 - accuracy: 0.6771
# Epoch 143/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9216 - accuracy: 0.6594
# Epoch 144/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.8677 - accuracy: 0.6760
# Epoch 145/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8417 - accuracy: 0.6896
# Epoch 146/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.8433 - accuracy: 0.6844
# Epoch 147/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.8254 - accuracy: 0.6802
# Epoch 148/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7868 - accuracy: 0.7104
# Epoch 149/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7492 - accuracy: 0.7177
# Epoch 150/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8202 - accuracy: 0.6750
# Epoch 151/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.7698 - accuracy: 0.7188
# Epoch 152/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.7551 - accuracy: 0.7167
# Epoch 153/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7614 - accuracy: 0.7000
# Epoch 154/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.7759 - accuracy: 0.7156
# Epoch 155/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7883 - accuracy: 0.6885
# Epoch 156/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.7427 - accuracy: 0.7146
# Epoch 157/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.7288 - accuracy: 0.7385
# Epoch 158/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.7889 - accuracy: 0.7229
# Epoch 159/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7211 - accuracy: 0.7385
# Epoch 160/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7950 - accuracy: 0.6917
# Epoch 161/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.7959 - accuracy: 0.6969
# Epoch 162/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7667 - accuracy: 0.7281
# Epoch 163/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7584 - accuracy: 0.7250
# Epoch 164/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.7728 - accuracy: 0.7042
# Epoch 165/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7329 - accuracy: 0.7469
# Epoch 166/200
# 10/10 [==============================] - 0s 21ms/step - loss: 0.7225 - accuracy: 0.7427
# Epoch 167/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.6786 - accuracy: 0.7729
# Epoch 168/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7211 - accuracy: 0.7417
# Epoch 169/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6830 - accuracy: 0.7646
# Epoch 170/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7830 - accuracy: 0.7427
# Epoch 171/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6774 - accuracy: 0.7615
# Epoch 172/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.6609 - accuracy: 0.7698
# Epoch 173/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6672 - accuracy: 0.7802
# Epoch 174/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6518 - accuracy: 0.7750
# Epoch 175/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6581 - accuracy: 0.7927
# Epoch 176/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6093 - accuracy: 0.8052
# Epoch 177/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6278 - accuracy: 0.7990
# Epoch 178/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6091 - accuracy: 0.8104
# Epoch 179/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7069 - accuracy: 0.7729
# Epoch 180/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6051 - accuracy: 0.8031
# Epoch 181/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6270 - accuracy: 0.7969
# Epoch 182/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.6107 - accuracy: 0.8052
# Epoch 183/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6596 - accuracy: 0.8073
# Epoch 184/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5557 - accuracy: 0.8135
# Epoch 185/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6403 - accuracy: 0.7948
# Epoch 186/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5734 - accuracy: 0.8333
# Epoch 187/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5754 - accuracy: 0.8177
# Epoch 188/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5921 - accuracy: 0.8104
# Epoch 189/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.5696 - accuracy: 0.8240
# Epoch 190/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.6103 - accuracy: 0.8156
# Epoch 191/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5500 - accuracy: 0.8188
# Epoch 192/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5894 - accuracy: 0.8135
# Epoch 193/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.5305 - accuracy: 0.8365
# Epoch 194/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5664 - accuracy: 0.8281
# Epoch 195/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.5414 - accuracy: 0.8125
# Epoch 196/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.5299 - accuracy: 0.8271
# Epoch 197/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5092 - accuracy: 0.8385
# Epoch 198/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5194 - accuracy: 0.8458
# Epoch 199/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5622 - accuracy: 0.8229
# Epoch 200/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5256 - accuracy: 0.8240

# %%
if TEST_MODEL is True:
    ##########################
    # # get model accuracy # #
    ##########################
    plt.plot(history.history['accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

    ######################
    # # get model loss # #
    ######################
    plt.plot(history.history['loss'])
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train'], loc='upper left')
    plt.show()

# %%
if TEST_MODEL is True:
    ##########################
    # # view model summary # #
    ##########################
    model.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 256)            488448
#
#  dense (Dense)               (None, 1, 256)            65792
#
#  dropout (Dropout)           (None, 1, 256)            0
#
#  batch_normalization (BatchN  (None, 1, 256)           1024
#  ormalization)
#
#  lstm_1 (LSTM)               (None, 1, 128)            197120
#
#  dense_1 (Dense)             (None, 1, 128)            16512
#
#  dropout_1 (Dropout)         (None, 1, 128)            0
#
#  batch_normalization_1 (Batc  (None, 1, 128)           512
#  hNormalization)
#
#  lstm_2 (LSTM)               (None, 1, 64)             49408
#
#  dense_2 (Dense)             (None, 1, 64)             4160
#
#  dropout_2 (Dropout)         (None, 1, 64)             0
#
#  batch_normalization_2 (Batc  (None, 1, 64)            256
#  hNormalization)
#
#  lstm_3 (LSTM)               (None, 1, 32)             12416
#
#  dense_3 (Dense)             (None, 1, 32)             1056
#
#  dropout_3 (Dropout)         (None, 1, 32)             0
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense_4 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 837,100
# Trainable params: 836,204
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# #### MODEL TESTING
# - Get Model Accuracy on the Test Dataset
# - Generate Confusion Matrix
# - Generate ROC Curves
# - Save the Model if Appropriate

# %%
if TEST_MODEL is True:
    y_pred = model.predict_proba(X_test)

    # evaluate predictions
    acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    print("Testing accuracy: %.3f%%" % (acc*100))
# Out:
# Testing accuracy: 83.750%

# %% [markdown]
# ##### Confusion Matrix

# %%
if TEST_MODEL is True and CON_MATRIX is True:
    # confusion matrix
    print(str(len(y_pred)) + " is the number of test value in kfold_val / train_test_split")
    cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
    df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                         columns = [i for i in np.unique(lb.inverse_transform(y_test))])

    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=True, cmap="BuPu")
# Out:
# 240 is the number of test value in kfold_val / train_test_split

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
if TEST_MODEL is True and ROC_GRAPH is True: # compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    for i in range(n_classes):
        plt.figure()
        lw = 2
        plt.plot(
            fpr[i],
            tpr[i],
            color="darkorange",
            lw=lw,
            label="ROC curve (area = %0.2f)" % roc_auc[i],
        )
        plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
        plt.xlim([-0.005, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ##### ROC Curve (Multiclass)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    # compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # first aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    # plt.figure()
    # plt.plot(
    #     fpr["micro"],
    #     tpr["micro"],
    #     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    #     color="deeppink",
    #     linestyle=":",
    #     linewidth=4,
    # )

    # plt.plot(
    #     fpr["macro"],
    #     tpr["macro"],
    #     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    #     color="navy",
    #     linestyle=":",
    #     linewidth=4,
    # )

    colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
        )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Multiclass)")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Average)

# %%
if TEST_MODEL is True and ROC_GRAPH is True:
    fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

    # calculate equal-error-rate
    eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('Average ROC Curve')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #### FIT AND SAVE MODEL
# - Fitting of model
# - Get Accuracy and Loss of Mdoel
# - Saving Model

# %%
############################
# # reshaping of dataset # #
############################
# loading of dataset
df = pd.read_csv(SAMPLE_DATASET_PATH)

df.head()
dataset = df.values

# divide data into features X and target (classes) Y
# convert target Y to labelbinarizer Y for model
X, Y, lb, class_list = prepare_dataset(df)

# reshaping the dataset to include LSTM Timesteps
X = reshape_dataset(X, TIMESTEPS)
n_classes = Y.shape[1]

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# LabelBinarizer is able to decipher:
# ['andy' 'azfar' 'bryce' 'chris' 'cy' 'gerald' 'ken' 'qk' 'sz' 'vale' 'ye'
#  'ys']
#
#
# X | Features | Dataset Shape: (1200, 220)
# Y | Classes  | Dataset Shape: (1200, 12)
# There are a total of 12 classes.
# Epoch 1/200
# 12/12 [==============================] - 5s 12ms/step - loss: 2.6975 - accuracy: 0.0825
# Epoch 2/200
# 12/12 [==============================] - 0s 11ms/step - loss: 2.6423 - accuracy: 0.0775
# Epoch 3/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.5779 - accuracy: 0.0775
# Epoch 4/200
# 12/12 [==============================] - 0s 13ms/step - loss: 2.5489 - accuracy: 0.0858
# Epoch 5/200
# 12/12 [==============================] - 0s 13ms/step - loss: 2.5126 - accuracy: 0.0883
# Epoch 6/200
# 12/12 [==============================] - 0s 13ms/step - loss: 2.4738 - accuracy: 0.1067
# Epoch 7/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.4335 - accuracy: 0.1342
# Epoch 8/200
# 12/12 [==============================] - 0s 13ms/step - loss: 2.3637 - accuracy: 0.1458
# Epoch 9/200
# 12/12 [==============================] - 0s 13ms/step - loss: 2.3027 - accuracy: 0.1600
# Epoch 10/200
# 12/12 [==============================] - 0s 14ms/step - loss: 2.2338 - accuracy: 0.1708
# Epoch 11/200
# 12/12 [==============================] - 0s 13ms/step - loss: 2.1917 - accuracy: 0.1783
# Epoch 12/200
# 12/12 [==============================] - 0s 13ms/step - loss: 2.1571 - accuracy: 0.1742
# Epoch 13/200
# 12/12 [==============================] - 0s 13ms/step - loss: 2.0835 - accuracy: 0.2033
# Epoch 14/200
# 12/12 [==============================] - 0s 13ms/step - loss: 2.0610 - accuracy: 0.2042
# Epoch 15/200
# 12/12 [==============================] - 0s 13ms/step - loss: 2.0099 - accuracy: 0.2142
# Epoch 16/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.9976 - accuracy: 0.2225
# Epoch 17/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.9496 - accuracy: 0.2308
# Epoch 18/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.8951 - accuracy: 0.2392
# Epoch 19/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.8744 - accuracy: 0.2458
# Epoch 20/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.8408 - accuracy: 0.2258
# Epoch 21/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.8152 - accuracy: 0.2325
# Epoch 22/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.7961 - accuracy: 0.2200
# Epoch 23/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.7993 - accuracy: 0.2367
# Epoch 24/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.7742 - accuracy: 0.2375
# Epoch 25/200
# 12/12 [==============================] - 0s 18ms/step - loss: 1.7707 - accuracy: 0.2358
# Epoch 26/200
# 12/12 [==============================] - 0s 17ms/step - loss: 1.7717 - accuracy: 0.2417
# Epoch 27/200
# 12/12 [==============================] - 0s 18ms/step - loss: 1.7267 - accuracy: 0.2383
# Epoch 28/200
# 12/12 [==============================] - 0s 17ms/step - loss: 1.7501 - accuracy: 0.2392
# Epoch 29/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.7206 - accuracy: 0.2567
# Epoch 30/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.7198 - accuracy: 0.2400
# Epoch 31/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.7362 - accuracy: 0.2183
# Epoch 32/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.7071 - accuracy: 0.2333
# Epoch 33/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.7132 - accuracy: 0.2300
# Epoch 34/200
# 12/12 [==============================] - 0s 16ms/step - loss: 1.6913 - accuracy: 0.2208
# Epoch 35/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.6675 - accuracy: 0.2417
# Epoch 36/200
# 12/12 [==============================] - 0s 18ms/step - loss: 1.6647 - accuracy: 0.2350
# Epoch 37/200
# 12/12 [==============================] - 0s 19ms/step - loss: 1.6558 - accuracy: 0.2283
# Epoch 38/200
# 12/12 [==============================] - 0s 20ms/step - loss: 1.6451 - accuracy: 0.2400
# Epoch 39/200
# 12/12 [==============================] - 0s 17ms/step - loss: 1.6607 - accuracy: 0.2317
# Epoch 40/200
# 12/12 [==============================] - 0s 17ms/step - loss: 1.6803 - accuracy: 0.2275
# Epoch 41/200
# 12/12 [==============================] - 0s 20ms/step - loss: 1.6745 - accuracy: 0.2392
# Epoch 42/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.6442 - accuracy: 0.2425
# Epoch 43/200
# 12/12 [==============================] - 0s 20ms/step - loss: 1.6770 - accuracy: 0.2283
# Epoch 44/200
# 12/12 [==============================] - 0s 20ms/step - loss: 1.6266 - accuracy: 0.2533
# Epoch 45/200
# 12/12 [==============================] - 0s 17ms/step - loss: 1.6205 - accuracy: 0.2600
# Epoch 46/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.6301 - accuracy: 0.2600
# Epoch 47/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.6559 - accuracy: 0.2433
# Epoch 48/200
# 12/12 [==============================] - 0s 19ms/step - loss: 1.6354 - accuracy: 0.2367
# Epoch 49/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.6303 - accuracy: 0.2375
# Epoch 50/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.6500 - accuracy: 0.2408
# Epoch 51/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.6206 - accuracy: 0.2408
# Epoch 52/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.6228 - accuracy: 0.2442
# Epoch 53/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.7066 - accuracy: 0.2475
# Epoch 54/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.6348 - accuracy: 0.2550
# Epoch 55/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.6130 - accuracy: 0.2575
# Epoch 56/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.5981 - accuracy: 0.2633
# Epoch 57/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.6128 - accuracy: 0.2592
# Epoch 58/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.5769 - accuracy: 0.2925
# Epoch 59/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.5653 - accuracy: 0.2875
# Epoch 60/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.5492 - accuracy: 0.3050
# Epoch 61/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.5567 - accuracy: 0.3117
# Epoch 62/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.5237 - accuracy: 0.3192
# Epoch 63/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.5240 - accuracy: 0.3183
# Epoch 64/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.5062 - accuracy: 0.3267
# Epoch 65/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.4748 - accuracy: 0.3392
# Epoch 66/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.4821 - accuracy: 0.3383
# Epoch 67/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.4771 - accuracy: 0.3133
# Epoch 68/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4619 - accuracy: 0.3325
# Epoch 69/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.4727 - accuracy: 0.3267
# Epoch 70/200
# 12/12 [==============================] - 0s 17ms/step - loss: 1.4465 - accuracy: 0.3425
# Epoch 71/200
# 12/12 [==============================] - 0s 18ms/step - loss: 1.4645 - accuracy: 0.3192
# Epoch 72/200
# 12/12 [==============================] - 0s 17ms/step - loss: 1.4439 - accuracy: 0.3267
# Epoch 73/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.4624 - accuracy: 0.3133
# Epoch 74/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.4388 - accuracy: 0.3125
# Epoch 75/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.4401 - accuracy: 0.3350
# Epoch 76/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.4404 - accuracy: 0.3108
# Epoch 77/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.4276 - accuracy: 0.3517
# Epoch 78/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.4436 - accuracy: 0.3425
# Epoch 79/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4368 - accuracy: 0.3317
# Epoch 80/200
# 12/12 [==============================] - 0s 19ms/step - loss: 1.4268 - accuracy: 0.3200
# Epoch 81/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.4057 - accuracy: 0.3375
# Epoch 82/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.4171 - accuracy: 0.3400
# Epoch 83/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.4245 - accuracy: 0.3517
# Epoch 84/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.4336 - accuracy: 0.3258
# Epoch 85/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.3926 - accuracy: 0.3492
# Epoch 86/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4091 - accuracy: 0.3717
# Epoch 87/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4337 - accuracy: 0.3567
# Epoch 88/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.4118 - accuracy: 0.3642
# Epoch 89/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.3580 - accuracy: 0.3617
# Epoch 90/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.3470 - accuracy: 0.3800
# Epoch 91/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.3535 - accuracy: 0.3642
# Epoch 92/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.3515 - accuracy: 0.3775
# Epoch 93/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.3611 - accuracy: 0.3667
# Epoch 94/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.3344 - accuracy: 0.3850
# Epoch 95/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.3383 - accuracy: 0.3750
# Epoch 96/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.2965 - accuracy: 0.3817
# Epoch 97/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.2974 - accuracy: 0.3792
# Epoch 98/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.2899 - accuracy: 0.3858
# Epoch 99/200
# 12/12 [==============================] - 0s 23ms/step - loss: 1.3043 - accuracy: 0.3658
# Epoch 100/200
# 12/12 [==============================] - 0s 17ms/step - loss: 1.2749 - accuracy: 0.3825
# Epoch 101/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.3030 - accuracy: 0.3683
# Epoch 102/200
# 12/12 [==============================] - 0s 19ms/step - loss: 1.2821 - accuracy: 0.4058
# Epoch 103/200
# 12/12 [==============================] - 0s 20ms/step - loss: 1.2755 - accuracy: 0.4100
# Epoch 104/200
# 12/12 [==============================] - 0s 20ms/step - loss: 1.2711 - accuracy: 0.3933
# Epoch 105/200
# 12/12 [==============================] - 0s 25ms/step - loss: 1.2771 - accuracy: 0.3908
# Epoch 106/200
# 12/12 [==============================] - 0s 22ms/step - loss: 1.2645 - accuracy: 0.4033
# Epoch 107/200
# 12/12 [==============================] - 0s 21ms/step - loss: 1.2430 - accuracy: 0.4067
# Epoch 108/200
# 12/12 [==============================] - 0s 19ms/step - loss: 1.2815 - accuracy: 0.4017
# Epoch 109/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.2501 - accuracy: 0.4083
# Epoch 110/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.2576 - accuracy: 0.3942
# Epoch 111/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.2600 - accuracy: 0.4100
# Epoch 112/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.2469 - accuracy: 0.4042
# Epoch 113/200
# 12/12 [==============================] - 0s 17ms/step - loss: 1.2484 - accuracy: 0.4067
# Epoch 114/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.2316 - accuracy: 0.4158
# Epoch 115/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.2332 - accuracy: 0.4042
# Epoch 116/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.2312 - accuracy: 0.4233
# Epoch 117/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.2249 - accuracy: 0.4242
# Epoch 118/200
# 12/12 [==============================] - 0s 21ms/step - loss: 1.2325 - accuracy: 0.4417
# Epoch 119/200
# 12/12 [==============================] - 0s 17ms/step - loss: 1.2188 - accuracy: 0.4283
# Epoch 120/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.2107 - accuracy: 0.4383
# Epoch 121/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.2419 - accuracy: 0.4283
# Epoch 122/200
# 12/12 [==============================] - 0s 18ms/step - loss: 1.2412 - accuracy: 0.4267
# Epoch 123/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.2221 - accuracy: 0.4542
# Epoch 124/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.1861 - accuracy: 0.4433
# Epoch 125/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.1956 - accuracy: 0.4475
# Epoch 126/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.1713 - accuracy: 0.4542
# Epoch 127/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.2082 - accuracy: 0.4333
# Epoch 128/200
# 12/12 [==============================] - 0s 19ms/step - loss: 1.1683 - accuracy: 0.4608
# Epoch 129/200
# 12/12 [==============================] - 0s 18ms/step - loss: 1.1659 - accuracy: 0.4675
# Epoch 130/200
# 12/12 [==============================] - 0s 24ms/step - loss: 1.1631 - accuracy: 0.4750
# Epoch 131/200
# 12/12 [==============================] - 0s 17ms/step - loss: 1.1482 - accuracy: 0.4833
# Epoch 132/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.1297 - accuracy: 0.4808
# Epoch 133/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.1477 - accuracy: 0.4692
# Epoch 134/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.1440 - accuracy: 0.4883
# Epoch 135/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.1356 - accuracy: 0.4883
# Epoch 136/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0883 - accuracy: 0.5042
# Epoch 137/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.1004 - accuracy: 0.5142
# Epoch 138/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.0798 - accuracy: 0.5292
# Epoch 139/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0716 - accuracy: 0.5383
# Epoch 140/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0752 - accuracy: 0.5017
# Epoch 141/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.0504 - accuracy: 0.5458
# Epoch 142/200
# 12/12 [==============================] - 0s 15ms/step - loss: 1.0228 - accuracy: 0.5508
# Epoch 143/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.0179 - accuracy: 0.5525
# Epoch 144/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.9831 - accuracy: 0.5642
# Epoch 145/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.9989 - accuracy: 0.5283
# Epoch 146/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.9963 - accuracy: 0.5608
# Epoch 147/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9699 - accuracy: 0.5542
# Epoch 148/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9701 - accuracy: 0.5467
# Epoch 149/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9521 - accuracy: 0.5525
# Epoch 150/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9321 - accuracy: 0.5517
# Epoch 151/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9636 - accuracy: 0.5458
# Epoch 152/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9424 - accuracy: 0.5508
# Epoch 153/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9567 - accuracy: 0.5425
# Epoch 154/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9499 - accuracy: 0.5583
# Epoch 155/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9304 - accuracy: 0.5508
# Epoch 156/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.8967 - accuracy: 0.5567
# Epoch 157/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.9135 - accuracy: 0.5583
# Epoch 158/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.9400 - accuracy: 0.5608
# Epoch 159/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.9142 - accuracy: 0.5458
# Epoch 160/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.8853 - accuracy: 0.5733
# Epoch 161/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8880 - accuracy: 0.5567
# Epoch 162/200
# 12/12 [==============================] - 0s 14ms/step - loss: 0.8669 - accuracy: 0.5733
# Epoch 163/200
# 12/12 [==============================] - 0s 16ms/step - loss: 0.8969 - accuracy: 0.5533
# Epoch 164/200
# 12/12 [==============================] - 0s 20ms/step - loss: 0.8871 - accuracy: 0.5533
# Epoch 165/200
# 12/12 [==============================] - 0s 17ms/step - loss: 0.8986 - accuracy: 0.5592
# Epoch 166/200
# 12/12 [==============================] - 0s 14ms/step - loss: 0.9103 - accuracy: 0.5633
# Epoch 167/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.9000 - accuracy: 0.5500
# Epoch 168/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.8502 - accuracy: 0.5800
# Epoch 169/200
# 12/12 [==============================] - 0s 17ms/step - loss: 0.8594 - accuracy: 0.5692
# Epoch 170/200
# 12/12 [==============================] - 0s 14ms/step - loss: 0.8470 - accuracy: 0.5575
# Epoch 171/200
# 12/12 [==============================] - 0s 14ms/step - loss: 0.8784 - accuracy: 0.5650
# Epoch 172/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.8552 - accuracy: 0.5808
# Epoch 173/200
# 12/12 [==============================] - 0s 30ms/step - loss: 0.8603 - accuracy: 0.5550
# Epoch 174/200
# 12/12 [==============================] - 0s 31ms/step - loss: 0.8345 - accuracy: 0.5983
# Epoch 175/200
# 12/12 [==============================] - 0s 27ms/step - loss: 0.8703 - accuracy: 0.5700
# Epoch 176/200
# 12/12 [==============================] - 0s 26ms/step - loss: 0.8537 - accuracy: 0.5675
# Epoch 177/200
# 12/12 [==============================] - 0s 25ms/step - loss: 0.8494 - accuracy: 0.6058
# Epoch 178/200
# 12/12 [==============================] - 0s 23ms/step - loss: 0.8494 - accuracy: 0.5808
# Epoch 179/200
# 12/12 [==============================] - 0s 25ms/step - loss: 0.8418 - accuracy: 0.6025
# Epoch 180/200
# 12/12 [==============================] - 0s 25ms/step - loss: 0.8115 - accuracy: 0.6150
# Epoch 181/200
# 12/12 [==============================] - 0s 18ms/step - loss: 0.8171 - accuracy: 0.6017
# Epoch 182/200
# 12/12 [==============================] - 0s 15ms/step - loss: 0.8000 - accuracy: 0.6267
# Epoch 183/200
# 12/12 [==============================] - 0s 18ms/step - loss: 0.7931 - accuracy: 0.6350
# Epoch 184/200
# 12/12 [==============================] - 0s 35ms/step - loss: 0.7905 - accuracy: 0.6500
# Epoch 185/200
# 12/12 [==============================] - 0s 24ms/step - loss: 0.7997 - accuracy: 0.6350
# Epoch 186/200
# 12/12 [==============================] - 0s 20ms/step - loss: 0.7928 - accuracy: 0.6250
# Epoch 187/200
# 12/12 [==============================] - 0s 25ms/step - loss: 0.8164 - accuracy: 0.6417
# Epoch 188/200
# 12/12 [==============================] - 0s 25ms/step - loss: 0.7904 - accuracy: 0.6500
# Epoch 189/200
# 12/12 [==============================] - 0s 21ms/step - loss: 0.8157 - accuracy: 0.6300
# Epoch 190/200
# 12/12 [==============================] - 0s 31ms/step - loss: 0.7807 - accuracy: 0.6617
# Epoch 191/200
# 12/12 [==============================] - 0s 24ms/step - loss: 0.7700 - accuracy: 0.6667
# Epoch 192/200
# 12/12 [==============================] - 0s 17ms/step - loss: 0.7611 - accuracy: 0.6650
# Epoch 193/200
# 12/12 [==============================] - 0s 17ms/step - loss: 0.7471 - accuracy: 0.6867
# Epoch 194/200
# 12/12 [==============================] - 0s 15ms/step - loss: 0.7335 - accuracy: 0.7008
# Epoch 195/200
# 12/12 [==============================] - 0s 14ms/step - loss: 0.7253 - accuracy: 0.7117
# Epoch 196/200
# 12/12 [==============================] - 0s 19ms/step - loss: 0.7093 - accuracy: 0.7333
# Epoch 197/200
# 12/12 [==============================] - 0s 16ms/step - loss: 0.7136 - accuracy: 0.7342
# Epoch 198/200
# 12/12 [==============================] - 0s 15ms/step - loss: 0.7088 - accuracy: 0.7417
# Epoch 199/200
# 12/12 [==============================] - 0s 18ms/step - loss: 0.6935 - accuracy: 0.7367
# Epoch 200/200
# 12/12 [==============================] - 0s 20ms/step - loss: 0.6782 - accuracy: 0.7458

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# #### SAVE MODEL

# %%
##################
# # save model # #
##################
model.model.save(MODEL_PATH)

# %% [markdown]
# # LIVE TESTING
# > Live test with new dataset to check if model function as it should

# %% [markdown]
# #### LOAD MODEL

# %%
##################
# # load model # #
##################

# model = create_model()
model = load_model(MODEL_PATH)

# %% [markdown]
# #### LOAD DATA
# - Import new dataset to verify the model is able to predict accurately

# %%
# import unseen data
pred_df = pd.read_csv(ACTUAL_DATASET_PATH)
pred_df.head()
# Out:
#   Subject Actual  Password    T2-D|0  T2-I|0+1  T2-PF|0+1  T2-RF|0+1  \
# 0   azfar   andy  play4pay  0.103503 -0.047849   0.055654   0.136592
# 1   azfar   andy  play4pay  0.127932 -0.056047   0.071885   0.103925
# 2   azfar   andy  play4pay  0.120614 -0.024571   0.096043   0.119338
# 3   azfar   andy  play4pay  0.159906 -0.048063   0.111843   0.088209
# 4   azfar   andy  play4pay  0.159645 -0.024543   0.135103   0.104402
#
#    T2-NG|0+1    T2-D|1  T2-I|1+2  ...  T7-RF|VAR  T7-NG|VAR   T7-I|SD  \
# 0   0.240095  0.184441 -0.080906  ...   0.000801   0.007317  0.022186
# 1   0.231857  0.159972 -0.048710  ...   0.000125   0.000131  0.016900
# 2   0.239952  0.143909 -0.096417  ...   0.001102   0.000280  0.021553
# 3   0.248115  0.136272 -0.064991  ...   0.000771   0.000122  0.033484
# 4   0.264047  0.128944 -0.088349  ...   0.000289   0.000022  0.017208
#
#    T7-PF|SD  T7-RF|SD  T7-NG|SD  T8-I|0+7  T8-PF|0+7  T8-RF|0+7  T8-NG|0+7
# 0  0.079417  0.028307  0.085538  0.832086   0.935589   0.984156   1.087659
# 1  0.005756  0.011193  0.011463  0.744166   0.872098   0.911203   1.039135
# 2  0.005081  0.033199  0.016728  0.728093   0.848707   0.880007   1.000621
# 3  0.016773  0.027768  0.011057  0.647457   0.807363   0.807494   0.967400
# 4  0.038917  0.016993  0.004716  0.679519   0.839164   0.864348   1.023993
#
# [5 rows x 223 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values
actual_np = pred_dataset[:,CLASSES_COL_NUM]

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

FEATURES_COL_NUM = 3

########################
# # predict all rows # #
########################
pred_row=pred_df.iloc[:,FEATURES_COL_NUM:]

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[46:54,FEATURES_COL_NUM:]
# print(pred_row)

############################
# # predict a single row # #
############################

# pred_row=pred_df.iloc[11:12,FEATURES_COL_NUM:]

##################
# # shape data # #
##################
pred_row = pred_row.values.tolist()
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

print(class_list)
Y = np.asarray(class_list)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)
# Out:
# ['andy', 'azfar', 'bryce', 'chris', 'cy', 'gerald', 'ken', 'qk', 'sz', 'vale', 'ye', 'ys']

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)

# pred_proba = np.sum(pred_proba, axis=0)
# pred_proba = np.reshape(pred_proba, (1, 9))

pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

match_list = []

for _ in range(actual_np.size):
    if pred[_] == actual_np[_]:
        match_list.append("match")
    else:
        match_list.append("nope")

match_count = match_list.count("match")
total_count = len(match_list)

match_header = str(match_count) + "/" + str(total_count) + " (" + str(match_count/total_count*100)+ "%)"
match_np = np.array(match_list)

exported_output = np.column_stack((actual_np, pred))
exported_output = np.column_stack((exported_output, acc))
exported_output = np.column_stack((exported_output, match_np))

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(data=exported_output, index=None, columns=['Actual', 'Prediction', 'Accuracy', match_header])
# print(df)
df.to_csv(RESULT_PATH)

print("Accuracy of the Model is: " + str(match_header))
# Out:
# Accuracy of the Model is: 146/660 (22.12121212121212%)
